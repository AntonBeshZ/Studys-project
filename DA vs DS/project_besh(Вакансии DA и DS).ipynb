# %% [markdown]
# ## Исследование вакансий Аналитиков данных и Data Scientist

# %% [markdown]
# **Цель исследования:**<br>
# Выявить различия в предлагаемых вакансиях Аналитиков данных и Data Scientist.<br>
#
# Входные данные - данные собранные из API сайта hh.ru<br>
#
# **Описание:**<br>
# 1. Обработка сырых данных, полученных с сайта hh.ru и их подготовка для проведения исследования: обработка пропусков, дубликатов и аномалий.
# 2. Проведение непосредственного исследования. Необходимо выяснить: кто размещает вакансии, какие необходимы hard и soft навыки, в каких городах требуются специалисты, определить доли желаемого уровня подготовки и какие требования к каждому уровню.
# 3. Выводы и рекомендации по исследованию.
#
# Исследование поможет выявить текущий тренд на то, какими необходимыми навыками должны обладать специалисты на должности Аналитик данных и Data Scientist в зависимости от уровня подготовки, а также локации организации.

# %% [markdown]
# ## Чтение и проверка исходных данных

# %% [markdown]
# Импортируем необходимые библиотеки.

# %%
import pandas as pd

# %%
import datetime

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Сохраним исходные файлы в переменные для дальнейшего удобства их обработки.

# %%
df_da = pd.read_excel(r'C:\Users\Besheniy\Обучение\project_Мастерская\Датасет\vacancies_da.xlsx') # аналитики данных (далее DA)

# %%
df_ds = pd.read_excel(r'C:\Users\Besheniy\Обучение\project_Мастерская\Датасет\vacancies_ds.xlsx') # data scientist (далее DS)

# %% [markdown]
# Напишем функцию для вывода общей информации о датафрейме.

# %%
def print_df_info(df):
    display(df.head()) # первые строки
    print('Общая информация:')
    print(df.info()) # общая информация
    print('Количество уникальных значений колонок:')
    for col in df.columns: # количество уникальных значений
        print(f'  {col}: {df[col].nunique()}')
    print('Количество дубликатов:', df.duplicated().sum()) # количество дубликатов

# %% [markdown]
# Используем функцию *print_df_info* для вывода информации об DA.

# %%
print_df_info(df_da)
# Out:
#           id                                    name        published_at  \
# 0  100039284  Junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         Аналитик данных 2024-05-24 09:39:00
# 2  100042705         Аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 Ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         Аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills     schedule  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  Полный день
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  Полный день
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  Полный день
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  Полный день
# 4                                   ['Документация']  Полный день
#
#          employment                                        description  \
# 0  Полная занятость  наше направление занимается повышением эффекти...
# 1  Полная занятость  сегодня комус один из крупнейших поставщиков о...
# 2  Полная занятость  наше направление занимается повышением эффекти...
# 3  Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 4  Полная занятость  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  наш направление заниматься повышение эффективн...      60000.0        NaN
# 1  сегодня комус крупный поставщик офисный товар ...          NaN        NaN
# 2  наш направление заниматься повышение эффективн...      90000.0        NaN
# 3  задача разработка бизнес модель групповой прог...          NaN        NaN
# 4  обязанность участие проектирование разработка ...          NaN        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
#
#   hard_skills_from_description soft_skills_from_description
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3       Pandas, Юнит-экономика                 Коммуникация
# 4                          NaN                 Документация
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1801 entries, 0 to 1800
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1801 non-null   int64
#  1   name                              1801 non-null   object
#  2   published_at                      1801 non-null   datetime64[ns]
#  3   alternate_url                     1801 non-null   object
#  4   type                              1801 non-null   object
#  5   employer                          1801 non-null   object
#  6   department                        521 non-null    object
#  7   area                              1801 non-null   object
#  8   experience                        1801 non-null   object
#  9   key_skills                        1801 non-null   object
#  10  schedule                          1801 non-null   object
#  11  employment                        1801 non-null   object
#  12  description                       1801 non-null   object
#  13  description_lemmatized            1801 non-null   object
#  14  salary_from                       348 non-null    float64
#  15  salary_to                         228 non-null    float64
#  16  salary_bin                        1801 non-null   object
#  17  key_skills_from_key_skills_field  1093 non-null   object
#  18  hard_skills_from_description      418 non-null    object
#  19  soft_skills_from_description      588 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 281.5+ KB
# None
# Количество уникальных значений колонок:
#   id: 1801
#   name: 763
#   published_at: 1746
#   alternate_url: 1801
#   type: 1
#   employer: 690
#   department: 86
#   area: 70
#   experience: 4
#   key_skills: 833
#   schedule: 4
#   employment: 4
#   description: 1460
#   description_lemmatized: 1429
#   salary_from: 71
#   salary_to: 65
#   salary_bin: 5
#   key_skills_from_key_skills_field: 774
#   hard_skills_from_description: 8
#   soft_skills_from_description: 35
# Количество дубликатов: 0

# %% [markdown]
# Прочитали и посмотрели на датафрейм DA. В датафрейме 1801 строка. Есть значительные пропуски в столбцах 'department', 'salary_from', 'salary_to', 'key_skills_from_key_skills_field'. Также имеются проблемы с типами данных в столбцах 'salary_from', 'salary_to' - необходимо изменить на float. Дубликаты не обнаружены.<br>
#
# По количеству уникальных значений можно сказать следующее:<br>
# - type - статус вакансии на момент получения данных от api - одно значение "открытая", неинформативный столбец;
# - employer - работодатель - в выборке 690 организаций, которым требуются Аналитики данных;
# - area - регион места работы - вакансии из 70 городов;
# - experience - требуемый опыт работы - подразделяется на 4 группы;
# - schedule - график работы - 4 группы;
# - employment - тип занятости - 4 группы;
# - salary_bin - категория зарплаты - 5 групп.<br>
#
# Удалим ненужные столбцы 'hard_skills_from_description', 'soft_skills_from_description', 'type'.

# %%
df_da.drop(['hard_skills_from_description', 'soft_skills_from_description', 'type'], axis=1, inplace=True)

# %% [markdown]
# Используем функцию *print_df_info* для вывода информации об DS.

# %%
print_df_info(df_ds)
# Out:
#           id                               name        published_at  \
# 0  100049339  Стажер Data Science (Новосибирск) 2024-05-24 10:44:01
# 1  100051447                     Data Scientist 2024-05-24 10:58:18
# 2  100070495       ML Engineer / Data Scientist 2024-05-24 13:15:26
# 3  100076648             Team Lead Data Science 2024-05-24 14:07:00
# 4  100077910      Data Analyst / Data Scientist 2024-06-08 14:17:47
#
#                      alternate_url      type  \
# 0  https://hh.ru/vacancy/100049339  Открытая
# 1  https://hh.ru/vacancy/100051447  Открытая
# 2  https://hh.ru/vacancy/100070495  Открытая
# 3  https://hh.ru/vacancy/100076648  Открытая
# 4  https://hh.ru/vacancy/100077910  Открытая
#
#                               employer          department         area  \
# 0                                 СБЕР  Сбер для экспертов  Новосибирск
# 1  Бюро кредитных историй Скоринг Бюро                 NaN       Москва
# 2                               ГК ФСК                 NaN       Москва
# 3                                 СБЕР  Сбер для экспертов       Москва
# 4                                Итсен                 NaN       Москва
#
#               experience                                         key_skills  \
# 0  Junior (no experince)                                                 []
# 1    Junior+ (1-3 years)  ['Python', 'Hadoop', 'Machine Learning', 'Рабо...
# 2    Junior+ (1-3 years)  ['Python', 'PyTorch', 'Machine Learning', 'Doc...
# 3     Middle (3-6 years)                                                 []
# 4     Middle (3-6 years)  ['DataLens', 'MS SQL', 'SQL', 'Spark', 'Аналит...
#
#            schedule        employment  \
# 0       Полный день        Стажировка
# 1  Удаленная работа  Полная занятость
# 2       Полный день  Полная занятость
# 3       Полный день  Полная занятость
# 4       Полный день  Полная занятость
#
#                                          description  \
# 0  sberseasons - оплачиваемая программа стажирово...
# 1  бюро кредитных историй «скоринг бюро» является...
# 2  о компании и команде: группа компаний фск – мн...
# 3  наша команда разрабатывает модели машинного об...
# 4  мы ищем талантливого middle data analyst / dat...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  sberseasons оплачивать программа стажировка ра...          NaN        NaN
# 1  бюро кредитный история скоринг бюро являться к...          NaN        NaN
# 2  компания команда группа компания фск многопроф...          NaN        NaN
# 3  наш команда разрабатывать модель машинный обуч...          NaN        NaN
# 4  искать талантливый middle data analyst data sc...     350000.0        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                                                NaN
# 1  ЗП не указана  SQL, MS SQL, Big Data, Python, Spark, Hadoop, ...
# 2  ЗП не указана  Python, PyTorch, ML, Docker, NLP, Pandas, SQL,...
# 3  ЗП не указана                                                NaN
# 4  ЗП не указана  Python, SQL, Обучение и развитие, Data Mining,...
#
#   hard_skills_from_description          soft_skills_from_description
# 0                          NaN                                   NaN
# 1                       Pandas  Документация, Аналитическое мышление
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                Аналитическое мышление
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                974 non-null    int64
#  1   name                              974 non-null    object
#  2   published_at                      974 non-null    datetime64[ns]
#  3   alternate_url                     974 non-null    object
#  4   type                              974 non-null    object
#  5   employer                          974 non-null    object
#  6   department                        413 non-null    object
#  7   area                              974 non-null    object
#  8   experience                        974 non-null    object
#  9   key_skills                        974 non-null    object
#  10  schedule                          974 non-null    object
#  11  employment                        974 non-null    object
#  12  description                       974 non-null    object
#  13  description_lemmatized            974 non-null    object
#  14  salary_from                       88 non-null     float64
#  15  salary_to                         82 non-null     float64
#  16  salary_bin                        974 non-null    object
#  17  key_skills_from_key_skills_field  521 non-null    object
#  18  hard_skills_from_description      449 non-null    object
#  19  soft_skills_from_description      294 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 152.3+ KB
# None
# Количество уникальных значений колонок:
#   id: 974
#   name: 499
#   published_at: 929
#   alternate_url: 974
#   type: 1
#   employer: 305
#   department: 54
#   area: 26
#   experience: 4
#   key_skills: 393
#   schedule: 4
#   employment: 4
#   description: 766
#   description_lemmatized: 752
#   salary_from: 28
#   salary_to: 26
#   salary_bin: 5
#   key_skills_from_key_skills_field: 348
#   hard_skills_from_description: 7
#   soft_skills_from_description: 23
# Количество дубликатов: 0

# %% [markdown]
# Прочитали и посмотрели на датафрейм DS.
# В датафрейме всего 974 строки, что в два раза меньше, необходимо учесть при сравнении показателей. Есть значительные пропуски в столбцах 'department', 'salary_from', 'salary_to', 'key_skills_from_key_skills_field'. С типами данных на первый взгляд всё в порядке. Дубликаты не обнаружены.<br>
#
# По количеству уникальных значений можно сказать следующее:<br>
# - type - статус вакансии на момент получения данных от api - одно значение "открытая", неинформативный столбец;
# - employer - работодатель - в выборке 305 организаций, которым требуются DS;
# - area - регион места работы - вакансии из 26 городов;
# - experience - требуемый опыт работы - подразделяется на 4 группы;
# - schedule - график работы - 4 группы;
# - employment - тип занятости - 4 группы;
# - salary_bin - категория зарплаты - 5 групп.<br>
#
# Сразу удалим ненужные столбцы 'hard_skills_from_description', 'soft_skills_from_description', 'type'.

# %%
df_ds.drop(['hard_skills_from_description', 'soft_skills_from_description', 'type'], axis=1, inplace=True)

# %% [markdown]
# **Выводы:**<br>
# Прочитали исходные файлы и посмотрели на первые строки датафреймов. Удалили ненужные столбцы, о чем необходимо сообщить специалистам Data engine, а также посмотрели общую информацию о датафреймах. Выявлены значительные пропуск в столбцах 'department', 'salary_from', 'salary_to', 'key_skills_from_key_skills_field'. Явные дубликаты также не обнаружены.<br>
# Выборка DA больше выборки DS в два раза.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Столбец name

# %% [markdown]
# Столбец представляет собой название вакансии, который получился из заголовка страницы с вакансией на hh.ru. Всего в DA 763 вариантов названия вакансии, в DS - 499, что говорит об отсутствии какой-либо стандартизации. Также присутствует смешивание вакансии в одного специалиста, т. е. в одном названии может быть отсылка и к DA, и к DS, что подтверждает гипотезу об отсутствии стандартов требований к специалистам, а также отсутствие понимания в компаниях о выполняемых задачах этими специалистами.

# %%
df_da['name'].unique()
# Out:
# array(['Junior аналитик данных (исследователь)', 'Аналитик данных',
#        'Аналитик данных (исследователь)', 'Ведущий аналитик данных',
#        'Senior Data Analyst (Цифровой билайн)', 'Дата аналитик',
#        'Data Analyst', 'Data Analyst / Data Scientist',
#        'Продуктовый аналитик / Data Analyst',
#        'Data analyst / Аналитик данных',
#        'Аналитик данных (Отдел по анализу конкурентов)',
#        'Аналитик данных (в офисе)', 'Data analyst',
#        'Аналитик данных в клиентский сервис',
#        'Аналитик данных (антифрод)', 'Аналитик данных (Data Analyst)',
#        'Старший аналитик данных (клиентский опыт)',
#        'Senior Data Analyst (Ads Platform)', 'Аналитик данных в Банк',
#        'Аналитик данных CV (Северсталь Диджитал)',
#        'Старший Аналитик данных в Яндекс Маркет',
#        'Аналитик данных (Python)',
#        'Data Analyst (Команда Управления Комплаенс)',
#        'Senior Data Analyst', 'Аналитик данных (Data-analyst)',
#        'Data Analyst / Аналитик данных (Middle)', 'Аналитик данных Excel',
#        'Senior PPC Data Analyst',
#        'Senior Data Analyst (Pharma) / Старший аналитик фармацевтических данных',
#        'Аналитик данных (BI)', 'Антифрод Аналитик / Аналитик данных',
#        'Аналитик данных ORM', 'Аналитик данных (Розничные риски)',
#        'Аналитик данных в группу платежной аналитики',
#        'Аналитик данных (тарифы и мотивация)',
#        'Аналитик данных/Бизнес аналитик', 'Аналитик данных (Excel)',
#        'Аналитик данных (менеджер по развитию)',
#        'Аналитик данных в операции',
#        'Middle/Senior Data Analyst (GigaChat)',
#        'Аналитик данных (ФГИС «ЗЕРНО»)',
#        'Data Analyst (Клиентская аналитика)',
#        'Веб-аналитик/Аналитик данных', 'Data Analyst в RuStore',
#        'Lead Data Analyst',
#        'Аналитик данных / Data Analyst в R&D-команду, СМБ VK',
#        'Аналитик данных E-com', 'BI-аналитик/ Аналитик данных',
#        'Аналитик данных (LLM, NLP)', 'Junior data analyst',
#        'Product Data Analyst (удаленно)',
#        'Data analyst (Рекламная платформа)', 'Старший аналитик данных',
#        'Аналитик данных (DA/DS)',
#        'Аналитик данных по кредитным процессам',
#        'Ассистент владельца продукта (начинающий Data Analyst)',
#        'Аналитик данных (Excel,Python)',
#        'Аналитик данных управления архитектуры данных и бизнес-аналитики',
#        'Аналитик данных (направление ORM и SERM)',
#        'Аналитик данных (Middle) в службу управления данными розничных рисков',
#        'Media Data Analyst / Аналитик медиа-данных',
#        'Data analyst (India)', 'Аналитик данных \\ Data analyst',
#        'Младший аналитик данных', 'Аналитик данных (middle)',
#        'Аналитик данных Отдела сопровождения бизнес-процессов',
#        'Middle Data Analyst NLP/SberProfile', 'Стажер - Аналитик данных',
#        'Аналитик данных Senior / (Интернет-эквайринг)',
#        'Аналитик данных (анализ клиентских данных)',
#        'Senior Data Analyst / Ведущий аналитик данных',
#        'Аналитик данных (направление розничных витрин)',
#        'Дата аналитик (Data Strategy Analyst)',
#        'Аналитик данных (Content)', 'Аналитик данных/Data analyst',
#        'Data Analyst в Дивизион "Корпоративное взыскание"',
#        'Аналитик данных (мидл)',
#        'Middle+/Senior Data Analyst в Data Accelerator',
#        'Аналитик данных в отдел онлайн-маркетинга (монетизация)',
#        'Аналитик данных в отдел онлайн-маркетинга', 'Data Analyst (SQL)',
#        'Middle/Senior Data Analyst (продажа Страховых и пенсионных продуктов)',
#        'Data analyst [кибербезопасность]',
#        'Аналитик данных в Управление клиентского опыта блока «Сеть продаж»',
#        'Econometrician / Эконометрист / Аналитик данных',
#        'IT-специалист (аналитик данных)',
#        'Аналитик данных / Data Analyst / Data Engineer',
#        'Middle Data Analyst', 'Аналитик данных телеметрии',
#        'Аналитик данных (Корпоративные резервы)',
#        'Аналитик данных (специалист по power BI)',
#        'Аналитик данных (Модели распознавания изображений и анализа текста)',
#        'Data Analyst (LR)', 'Аналитик данных (Кибербезопасность)',
#        'Junior Data Analyst', 'Data engineer/Аналитик данных',
#        'Геоаналитик / Аналитик данных (Junior+)',
#        'Аналитик данных в управление бизнес развития и стратегии',
#        'Аналитик данных по работе с клиентами', 'Аналитик данных Junior',
#        'Старший аналитик данных (Гео)', 'Data Analyst "Growth"',
#        'Аналитик данных (транспортная логистика)',
#        'Аналитик данных (информационная безопасность)',
#        'Аналитик данных, исследователь (удаленно)',
#        'Аналитик данных (Junior)',
#        'Аналитик данных (направление «Рекомендации», портал «Рамблер»)',
#        'Аналитик данных по проектам',
#        'Аналитик данных по информационной безопасности (дашборды)',
#        'Аналитик данных Python, SQL',
#        'Senior/Middle NLP Data Analyst GigaChat',
#        'Middle Data Analyst / Python developer',
#        'Аналитик данных в группу HR-аналитики Портала и Cloud',
#        'Data Analyst (команда АB lab)', 'Аналитик данных IVR',
#        'Аналитик данных в команду Антифрода', 'Аналитик данных (Банк)',
#        'Младший аналитик данных (Excel)',
#        'Аналитик данных/управляющий продуктом',
#        'Data Analyst / Data scientist middle',
#        'Senior Data Analyst (клиентская аналитика)',
#        'Аналитик данных (Power bi)',
#        'Аналитик данных в отдел персонала \\ HR Data Analyst',
#        'Product Analyst/Data Analyst',
#        'Senior Аналитик данных в Платформу сервисов',
#        'Аналитик данных отдела ПТО',
#        'Аналитик данных для команды малого бизнеса',
#        'Senior Data Analyst / Старший Аналитик Данных',
#        'Аналитик данных (Направление коммерческого планирования)',
#        'BI-Аналитик/Бизнес-Аналитик/Аналитик данных',
#        'Продуктовый аналитик / Senior product analyst / Data analyst',
#        'BI-аналитик, аналитик данных', 'Data Analyst (СберСпасибо)',
#        'Data Analyst (GameDev)', 'Аналитик данных/системный аналитик',
#        'Data Analyst (Проблемные товары)',
#        'Главный специалист-аналитик данных (контакт-центры)',
#        'BI-аналитик / Data Analyst / Аналитик данных',
#        'Аналитик данных (Senior)',
#        'Ведущий консультант по информационным системам (Аналитик данных/BI-аналитик)',
#        'Главный специалист (Аналитик данных/BI-аналитик)',
#        'Аналитик данных в команду What If', 'Data Analyst (Junior)',
#        'Ведущий специалист - аналитик данных связанных с железнодорожными перевозками',
#        'Дата аналитик /Data Analyst', 'Аналитик данных (Tableau)',
#        'Data Analyst (Data Science и клиентская аналитика)',
#        'Data Analyst (middle/senior)', 'Аналитик данных (Data analyst)',
#        'Data Analyst (команда Data Science и клиентская аналитика)',
#        'Junior Аналитик данных / Data Analyst',
#        'Аналитик данных (junior)', 'Аналитик данных (Ozon Global)',
#        'Аналитик данных (г. Нижнекамск)',
#        'Middle/Senior Data Analyst (команда отчетности по cross-sale кампаниям)',
#        'Дата аналитик / Data analyst в online кинотеатр KION 2024',
#        'Аналитик данных (клиентская аналитика)',
#        'Аналитик / Аналитик данных / Маркетолог-аналитик / Data analyst',
#        'Аналитик данных (Геоаналитика)',
#        'Аналитик данных (DA, data analyst) ViewPoint',
#        'Senior Аналитик данных (DS)', 'Data Scientist (Аналитик данных)',
#        'Аналитик данных (Premier)', 'Аналитик данных в Daily Banking',
#        'Аналитик данных в команду операций и клиентского сервиса Senior/Middle Data analyst',
#        'Аналитик данных / bi-аналитик', 'Аналитик данных (List manager)',
#        'Аналитик данных (кредитные операции)',
#        'Ведущий специалист (аналитик данных)',
#        'Junior/Middle Data Analyst',
#        'Аналитик данных в R&D \\ Data Analyst R&D',
#        'Аналитик данных в Клиентский сервис',
#        'Аналитик данных SQL (улучшение метрик)', 'Аналитик Данных',
#        'Аналитик BI / Аналитик данных', 'Стажер Дата Аналитик',
#        'Senior Data Analyst (DS проекты)',
#        'Аналитик данных (Главный специалист Департамента бизнес-планирования и инвестиций)',
#        'Data analyst (автор курсов)',
#        'Аналитик данных в Блок "Транзакционный банкинг B2C"',
#        'Аналитик данных (Middle)', 'Аналитик данных КХД',
#        'Аналитик данных / продуктовый аналитик',
#        'Data analyst/Business analyst', 'Аналитик данных DWH',
#        'Аналитик данных отдела отчетности Финансового департамента',
#        'Бизнес-аналитик данных', 'Middle/Senior Data Analyst',
#        'Junior Data Analyst (работа в офисе)', 'Data analyst (стажер)',
#        'Data Analyst/Аналитик данных (Junior)',
#        'Data Analyst в команду ML360',
#        'Аналитик данных / DS (SolarCloud)',
#        'Аналитик данных (Управление "Цифровой Коллекшн")',
#        'Middle Дата Аналитик в продукт Защитник (Big Data)',
#        'Senior Data Analyst (Finance)',
#        'Аналитик данных / Финансовый аналитик',
#        'Аналитик SQL / Data Analyst', 'Data Analyst (Senior)',
#        'Стажер-аналитик данных',
#        'Аналитик данных в группу управления метаданными [Governance]',
#        'Аналитик данных (SQL)', 'System analyst DWH / Data Analyst',
#        'Аналитик данных BI отдела автоматизации (гибридный график работы)',
#        'Senior Data Analyst "Growth"', 'Аналитик данных (ТОиР)',
#        'Аналитик данных / Дата инженер (ИКТ)',
#        'Аналитик данных (digital маркетинг)', 'Аналитик данных [Retail]',
#        'Data Analyst WMS',
#        'Аналитик данных (Департамент банковского регулирования и аналитики)',
#        'Ведущий дата аналитик',
#        'Аналитик данных / Дата аналитик / data analyst (Анти-фрод)',
#        'Аналитик данных / Data Analyst',
#        'Специалист по учебно-методической работе/Аналитик данных',
#        'Младший аналитик данных (Ozon СНГ)', 'Data Analyst (ТОиР)',
#        'Главный аналитик данных (дата аналитик / data analyst)',
#        'Senior Data analyst', 'Middle Data analyst',
#        'Аналитик данных отдела мотивационной отчетности',
#        'Аналитик данных (Customer Experience)',
#        'Аналитик данных (телеком)',
#        'Аналитик данных (Департамент рисков/внутренний фрод)',
#        'Аналитик данных SQL', 'Аналитик данных/BI analyst',
#        'Data Analyst (Антифрод, Поиск)',
#        'Бизнес-аналитик / Аналитик данных',
#        'Аналитик данных (Департамент развития клиентского опыта)',
#        'Аналитик данных в отдел управления проблемным портфелем (SQL, Python)',
#        'Аналитик данных Excel (транспортные услуги компании)',
#        'Аналитик данных на маркетплейсах/аналитик BI',
#        'Аналитик данных (управленческая и бизнес-отчетность)',
#        'Аналитик данных с отличным знанием Excel',
#        'Дата аналитик (Data Scientist)', 'Data Engineer Аналитик данных',
#        'BI-analyst \\ Data analyst \\ Аналитик данных (Senior)',
#        'Руководитель дата аналитики', 'Аналитик данных / BI-аналитик',
#        'Middle Дата Аналитик в RecSys Platform (Big Data)',
#        'Аналитик данных (data scientist, data engineer)',
#        'Младший аналитик данных (Junior Data Analyst)',
#        'Аналитик данных / Data Analyst (JoomPro)',
#        'Старший аналитик данных/Senior Data Analyst',
#        'Data analyst (SberDevices)',
#        'Аналитик данных BI отдела автоматизации (г. Воронеж)',
#        'Аналитик данных в сфере обращения с отходами',
#        'Аналитик BI (аналитик данных)', 'Инженер данных/ Аналитик данных',
#        'Middle Data Analyst (SQL)', 'Data analyst (Junior)',
#        'Аналитик данных о реализации нефтепродуктов, товаров и услуг',
#        'Аналитик Данных / Data Analyst (Маркетплейс)',
#        'Ведущий аналитик данных ( SQL)', 'Аналитик данных (офис)',
#        'Data Analyst (Growth Partner)', 'Аналитик данных NLP',
#        'Аналитик данных (антифрод направление)',
#        'Аналитик данных в Отдел Логистики',
#        'Аналитик данных (Биотех, Фарма)',
#        'Junior Analyst / Младший аналитик данных',
#        'Аналитик данных по взысканию', 'Дата аналитик (трек отчетность)',
#        'Менеджер по развитию (аналитик данных)',
#        'Разработчик Python / Аналитик данных',
#        'Ассистент отдела продаж / аналитик (Sales\xa0assistant / data analyst), Москва',
#        'Аналитик данных (взыскание)',
#        'Аналитик данных (SQL, OLAP-кубы, BI - инструменты)',
#        'Аналитик данных (Казань-Телематика)',
#        'Data engineer/Data analyst', 'Data analyst/Аналитик данных',
#        'Аналитик данных / Аналитик DWH', 'Аналитик данных/BI аналитик',
#        'Аналитик данных (Управленческая аналитика)',
#        'Аналитик BI/Аналитик данных (Big Data)',
#        'Стажер специалиста (Аналитик данных)',
#        'Консультант (Аналитик данных) отдела анализа и контроля качества данных',
#        'Заместитель начальника отдела анализа и контроля качества данных (Аналитик данных)',
#        'Аналитик данных (Операционный аудит)',
#        'Аналитик данных в команду операций и клиентского сервиса / Middle Data analyst',
#        'Маркетолог-аналитик \\ Аналитик данных',
#        'Аналитик данных (Веб-аналитика)',
#        'Аналитик данных (банковская сфера)',
#        'Аналитик данных (аналитическая отчетность) в службу управления данными розничных рисков',
#        'Главный аналитик данных',
#        'Аналитик данных / Data Analyst (Middle+)',
#        'Аналитик данных (HR направление)',
#        'Аналитик данных (Excel, sql, bi)', 'Аналитик данных (Rambler&Co)',
#        'Аналитик данных отдела расчета и планирования мотивационных показателей',
#        'Data Analyst/System Analyst (AI-помощник)',
#        'Аналитик данных (нефтегазовое строительство)',
#        'Аналитик данных на маркетплейсе Wildberries / Ресёрчер',
#        'Ведущий аналитик данных/ Руководитель (маркетинг, продажи)',
#        'Аналитик данных Мониторинг кредитных рисков',
#        'Аналитик данных BI', 'Аналитик данных/BI-аналитик',
#        'Аналитик данных по клиентской и продуктовой аналитике',
#        'Помощник Директора/Аналитик данных',
#        'Аналитик power bi / Data Analyst', 'Marketing Data Analyst',
#        'Специалист-аналитик данных',
#        'Аналитик данных / специалист Google Data Studio (удалённо)',
#        'Специалист по сопровождению АБС (Аналитик данных - SQL, Oracle, Postgree)',
#        'Data Analyst в блок Стратегия и развитие',
#        'Аналитик данных (collection)',
#        'Аналитик данных / Помощник руководителя',
#        'Ведущий Аналитик Данных (Customer Experience)',
#        'Team lead Data Analyst',
#        'Ведущий аналитик данных (бизнес-аналитик)',
#        'Аналитик данных / Бизнес-аналитик',
#        'Аналитик данных (data analyst)',
#        'Аналитик данных SQL в Департамент финансов',
#        'Аналитик данных (анализ и контроль данных в учетной системе)',
#        'Аналитик данных (IT)', 'Ведущий аналитик данных продаж',
#        'Младший аналитик данных/Junior data analyst (регионы)',
#        'Аналитик данных по проблемному портфелю корпоративных клиентов',
#        'Аналитик данных по проблемному портфелю',
#        'Старший аналитик данных (маркетинг)',
#        'Аналитик данных (офис г. Владимир)',
#        'Аналитик HR / Аналитик C&B / Аналитик данных/ Аналитик в отдел компенсаций и льгот',
#        'Аналитик данных в управление внедрения (Middle)',
#        'Ведущий экономист (аналитик данных)', 'Middle data analyst',
#        'Аналитик данных (Power BI)', 'Дата-аналитик (Data Analyst)',
#        'Аналитик данных в Дивизион "Массовый высокодоходный сегмент"',
#        'Аналитик данных (Data Scientist)', 'Аналитик данных DWH, ETL',
#        'Эксперт по цифровым технологиям аудита (Data Analyst)',
#        'Аналитик данных (Python \\ SQL) в Управление ИТ аудита',
#        'Ведущий аналитик данных CV (Северсталь Диджитал)',
#        'Аналитик данных (Северсталь Диджитал)',
#        'Ассистент менеджера / Аналитик данных', 'Аналитик данных (Риски)',
#        'Аналитик данных (фармдистрибьютор)',
#        'Аналитик данных (расчет премий)', 'Аналитик данных BI / ЩЛЗ',
#        'Аналитик данных в стрим Интернет-Банк СМБ',
#        'Аналитик данных / Data Scientist',
#        'Аналитик данных (Senior/Middle)',
#        'Аналитик данных / Инженер по качеству данных',
#        'Специалист по анализу данных/Data Analyst (направление CRM, маркетинг)',
#        'Data Scientist in Geoscience (Аналитик данных - Геология)',
#        'Аналитик данных B2B/B2G/B2C', 'Data Analyst (C&B отдел)',
#        'Аналитик данных (мобильное приложение)',
#        'Data scientist/Data Analyst', 'Аналитик данных (СМР)',
#        'Аналитик данных в Доставку',
#        'Middle Data Analyst (команда СХ КИБ)',
#        'Senior data analyst (Mobile games marketing)',
#        'Аналитик данных в транзакционный банкинг B2C',
#        'Data Engineer / Data Analyst',
#        'Аналитик данных в Штаб блока "Транзакционный банкинг B2C"',
#        'Аналитик данных в направление инцидент и проблем менеджмент',
#        'Senior data analyst',
#        'Аналитик данных в Центр управления данными',
#        'Начинающий Аналитик данных',
#        'Sr Data analyst / Аналитик разработчик',
#        'Аналитик BI/Аналитик данных',
#        'Аналитик данных (направление "Кошелек клиента", КИБ)',
#        'Аналитик данных (риски) / Data Analyst',
#        'Дата аналитик – инженер (DEA)', 'Стажер Аналитик данных',
#        'Маркетолог-аналитик данных фармотрасли',
#        'Аналитик данных / Data Analyst (middle)', 'Аналитик данных ММБ',
#        'Data Analyst / Data Scientist (Junior/Junior+)',
#        'Data analyst (RTB)', 'Аналитик данных (Excel, Power BI, Python)',
#        'Ведущий аналитик данных / Начальник отдела',
#        'Дата аналитик (дивизион Домклик)',
#        'Junior Аналитик данных в отдел аудита среднего бизнеса',
#        'Product/Data Analyst',
#        'Аналитик данных/ Системный аналитик (Полиматика)',
#        'Аналитик данных / Data analyst',
#        'Аналитик данных в команду платформы АБ-тестирования',
#        'Middle Data Analyst [Python]', 'Data Analyst (e-commerce)',
#        'Junior Marketing Data Analyst', 'Офисный аналитик данных',
#        'Middle Data analyst (Команда Управления Комплаенс)',
#        'Data Analyst в Транзакционный банкинг B2C',
#        'Data analyst ( Мiddle/Middle+ )',
#        'ClickHouse DBA / Аналитик данных',
#        'BI аналитик / аналитик данных (сквозная, web - аналитика, визуализация)',
#        'Data Analyst (remote)',
#        'Системный аналитик/Аналитик данных (DWH)',
#        'Аналитик данных ИТ-инфраструктуры',
#        'Middle Дата Аналитик в продукт Travel (Big Data)',
#        'Аналитик данных (SQL / Excel / Power BI)',
#        'Data analyst (BI-эксперт)',
#        'Аналитик данных внутритрубной диагностики',
#        'Data analyst в направлении маркетинга',
#        'Ведущий экономист - аналитик данных', 'Аналитик данных (НСИ)',
#        'Руководитель аналитики данных / Lead Data Analyst',
#        'Игровой Аналитик Данных (gamedev)',
#        'Аналитик данных (департамент управления цепями поставок)',
#        'Технический аналитик данных (BI)',
#        'Инженер/Аналитик данных Excel',
#        'Аналитик данных (Аналитические сервисы)',
#        'Data Analyst/Аналитик отдела по работе с внешними данными',
#        'Аналитик данных/ исследователь данных',
#        'Аналитик данных (Специалист 1 категории)',
#        'Аналитик данных / аналитик SQL', 'Аналитик данных/Data Analyst',
#        'Аналитик данных (Проектный офис)', 'Financial Data Analyst',
#        'Аналитик данных телепроектов', 'Data Analyst (Качество поиска)',
#        'Middle/Senior Data Analyst (SberNBA)',
#        'Аналитик данных | Data analyst',
#        'Аналитик данных (Data scientist/дата-инженер)',
#        'Аналитик данных / дата аналитик / data analyst (риски автокредитования)',
#        'Главный эксперт (аналитик данных Excel)',
#        'Product/Data Analyst (GigaCode)',
#        'Data Analyst (Customer Communication)',
#        'Data Analyst в Департамент данных и рекомендательных систем В2С',
#        'Data analyst (Middle)',
#        'Преподаватель на курс “Аналитик данных” со знанием английского языка',
#        'Системный аналитик данных',
#        'Ведущий аналитик данных в Блок Люди и Культура',
#        'Аналитик данных систем целевого маркетинга',
#        'Аналитик данных (управленческая отчетность)',
#        'Data Analyst B2B (middle)', 'Senior Data Analyst в Блок Финансы',
#        'Урбан-аналитик данных', 'Аналитик данных (риск отчетность)',
#        'Аналитик данных, Отдел рисков', 'Старший Data Analyst',
#        'Дата аналитик (middle\\senior)',
#        'Junior Data Scientist+Data Analyst (Команда AI Дирекции по экосистеме юр. лиц)',
#        'Аналитик данных (Data Analist)', 'Аналитик данных IDK',
#        'Data Analyst (Подмены)', 'Data Analyst (Big Data)',
#        'Data Analyst (SberCampaigning)', 'Аналитик данных x-code',
#        'Аналитик данных в исследовательскую команду CIB',
#        'Ведущий аналитик/Аналитик-инженер/Аналитик данных',
#        'Аналитик данных (Москва)', 'Data Engineer/Data Analyst',
#        'Аналитик данных (железнодорожный транспорт)',
#        'Аналитик Данных (Базы данных)',
#        'Middle Data Analyst (команда Digital Avatar)',
#        'Аналитик данных в отдел планирования и прогнозирования (data analyst / data scientist)',
#        'Аналитик данных по рискам', 'Аналитик данных начинающий',
#        'Дата аналитик / Data analyst (Кредитный потенциал)',
#        'Аналитик данных (Градостроительство)',
#        'Ведущий аналитик данных отчетности по продуктам благосостояния (инвестиции, страхование)',
#        'Data Analyst (Analytical Support Team) (Ru + En) JEDai',
#        'Аналитик данных (закуп)',
#        'Аналитик данных / специалист Google Data Studio',
#        'Кампейн-инженер (Аналитик данных)',
#        'Аналитик данных/ бизнес-аналитик', 'Аналитик данных в HR',
#        'Data Analyst/Аналитик данных', 'Junior Аналитик данных',
#        'Senior Data Analyst (DMP)', 'Data analyst (middle/senior)',
#        'Junior Data Analyst (iGaming)',
#        'Аналитик данных / Разработчик MS SSAS / MS Power BI',
#        'Data Analyst (Голос клиента)', 'Аналитик данных (SQL, Python)',
#        'Data Scientist / Data Analyst / Data engineer',
#        'Аналитик данных - мониторинг цен', 'Аналитик данных в Риски',
#        'Financial Data Analyst \\ Финансовый дата-аналитик',
#        'Product Data Analyst \\ Продуктовый дата-аналитик',
#        'Junior аналитик данных',
#        'Автор модуля по теме "Аналитик данных" на онлайн-курс',
#        'Инженер отдела медико-статистической информации (Администратор СУБД Аналитик данных)',
#        'Аналитик данных в сервис поддержки стартапов',
#        'Академический руководитель программы "Аналитик данных" в Центре непрерывного образования',
#        'Младший аналитик данных (ETL & BI) / Младший консультант',
#        'Аналитик данных (рынок труда)',
#        'Аналитик данных по направлению потребления капитала',
#        'Бизнес-аналитик / аналитик данных',
#        'Аналитик данных (рынка, клиентов, продуктов, секторов, отчетности МСФО/РСБУ)',
#        'Data Analyst (Finance)',
#        'Главный аналитик данных (Лаборатория розничных технологий)',
#        'Экономист (Аналитик данных)', 'Senior/Middle NLP Data Analyst',
#        'Аналитик данных в стрим "Информационные сервисы" продукт "История операций"',
#        'Специалист по математическому моделированию/аналитик данных/программист C++/R',
#        'Аналитик данных (Голос клиента)',
#        'Аналитик данных (Data Science)',
#        'Аналитик данных (Кампании продаж)',
#        'PL/SQL разработчик/Аналитик данных',
#        'Старший аналитик данных (Data Scientist)',
#        'Аналитик данных (главный эксперт)',
#        'Аналитик (DWH/BI) /Дата Аналитик',
#        'Аналитик данных во внутреннем аудите',
#        'Аналитик данных / Data Scientist (middle+)',
#        'Аналитик данных ORP', 'Аналитик данных в Казначейство',
#        'Аналитик данных в команду Daily Banking',
#        'Аналитик данных в Дивизион развития цифрового профиля клиента',
#        'Бизнес аналитик данных (BI)',
#        'Data Analytics Manager / Аналитик данных',
#        'Аналитик данных/Специалист по работе с базой данных',
#        'Системный аналитик (DWH)/Аналитик данных (офис, Ташкент)',
#        'Аналитик данных в Блок Риски', 'Antifraud / data analyst',
#        'Senior Data Analyst Uzum Avto',
#        'Аналитик данных (розничные кредитные риски)',
#        'Старший аналитик данных эффективности процессов',
#        'Аналитик данных в образовательный трек',
#        'Аналитик данных NLP (Северсталь Диджитал)',
#        'Аналитик/Аналитик данных', 'Аналитик данных (строительство)',
#        'Аналитик данных в Отдел бизнес-аналитики и качества данных',
#        'Data Analyst (Sport)',
#        'Младший аналитик данных в команду Operations банка',
#        'Аналитик данных (отдел продаж)', 'Оператор 1С (аналитик данных)',
#        'Главный специалист (сбор, анализ и контроль качества данных) / Аналитик данных',
#        'Аналитик данных SQL (Middle)', 'Data Analyst / Аналитик данных',
#        'Аналитик данных финансовой отчетности',
#        'Data Analyst / Data scientist',
#        'Middle Data Analyst (Ads Platform)', 'Дата аналитик E-com',
#        'Middle Data Analyst (Юнит «Забота о клиентах» В2С)',
#        'Аналитик данных/Data analyst (Москва)',
#        'Аналитик Данных / Data Analyst', 'Аналитик данных (HR)',
#        'Аналитик данных CRM', 'Аналитик данных в CRM',
#        'Аналитик/ Аналитик данных/Маркетинговый аналитик',
#        'Аналитик данных по аренде',
#        'Middle/Senior Data Analyst в команде Operations банка',
#        'Data Analyst B2B (junior+/middle)',
#        'Главный специалист управления проектом / Аналитик данных (НР Бангладеш)',
#        'Аналитик данных/специалист Excel',
#        'Аналитик данных контактных центров', 'Data Analyst (Game)',
#        'Senior Data Analyst (Game)',
#        'Дата аналитик (управление клиентского опыта В2С)',
#        'Ведущий аналитик данных, Группа операционной аналитики',
#        'Аналитик данных (Облако данных)',
#        'Data Analyst (Блок Daily Banking)', 'Аналитик данных POWER BI',
#        'Data Analyst/Data Scientist', 'Data Analyst (senior)',
#        'Финансовый аналитик / Аналитик данных',
#        'Помощник Директора по продажам/Аналитик данных',
#        'Data Analyst (junior)', 'Аналитик данных (Администрирование)',
#        'Продуктовый аналитик / Аналитик данных',
#        'Аналитик данных (Защита брендов в сети Интернет)',
#        'Стажер/Аналитик данных (Python, Power BI)',
#        'Аналитик данных/data analyst', 'Аналитик данных Data Science',
#        'Аналитик данных в отдел развития на маркетплейсах',
#        'Аналитик данных в команду Рейнджеры (M+/S)',
#        'Middle+ Дата Аналитик в продукт МТС Маркетолог (Big Data)',
#        'Middle Дата Аналитик в продукт МТС Маркетолог (Big Data)',
#        'Data analyst (remote)', 'Аналитик данных (в образовании)',
#        'Аналитик данных (ресторанный холдинг)',
#        'Data Analyst / Аналитик Данных',
#        'Аналитик данных, Маркетплейс, Контент и товары',
#        'Системный/дата аналитик',
#        'Аналитик данных / BI - аналитик (помощник руководителя по работе с данными)',
#        'Финансовый аналитик/ Data Analyst / Data scientist',
#        'Аналитик данных (SQL-запросы) - ОУКД',
#        'Аналитик данных (Департамент информационной безопасности)',
#        'Web-analyst / Data analyst (веб-аналитик / дата аналитик)',
#        'Аналитик данных / разработчик BI',
#        'Аналитик данных, Маркетплейс, Отдел продуктовой аналитики',
#        'Аналитик данных (отдел функционального анализа)',
#        'Аналитик данных по направлению АПК',
#        'Аналитик данных/Бизнес-аналитик',
#        'Аналитик данных в отделе закупа', 'Аналитик данных в банк',
#        'Аналитик данных SQL/PHP (Gamedev)',
#        'Аналитик данных в Управление развития лояльности',
#        'Middle Data Analyst (SberNBA)', 'Аналитик данных (ML-модели)',
#        'Аналитик данных (Астра Консалтинг)',
#        'Аналитик Данных (Бюро кредитных историй)',
#        'Аналитик данных, БЦ "Большевик"',
#        'Аналитик данных (административно-хозяйственный блок)',
#        'Аналитик данных (МСБ)', 'Middle Аналитик данных [#Cloud_MTS]',
#        'Продуктовый аналитик/Аналитик данных',
#        'BI-аналитик/ аналитик данных', 'Аналитик данных (SQL, Excel)',
#        'Team Lead / Lead Data Analyst',
#        'Продуктовый аналитик | Middle Data analyst',
#        'Data Analyst [SmartTaskMining]', 'Process data analyst',
#        'Старший аналитик данных / Старший веб-аналитик',
#        'Аналитик данных (data analyst) контактного центра',
#        'Data Analyst (Команда АB lab)', 'Аналитик данных (1с:ЗУП)',
#        'Аналитик данных (data analyst) в хедж фонд',
#        'Аналитик данных CVM', 'Аналитик данных (инвестиции, трейдинг)',
#        'Аналитик данных (направление CRM)',
#        'Системный аналитик/Аналитик данных ML',
#        'Портфельный риск-аналитик (аналитик данных)',
#        'Data Analyst/Data Engineer',
#        'Аналитик данных / BI аналитик (удаленно)',
#        'Системный/Дата Аналитик', 'Аналитик данных (продуктовый)',
#        'Стажер Аналитик данных (Группа аналитики данных)',
#        'Младший аналитик данных (junior data analyst)',
#        'Product Data analyst (управление товарными потоками)',
#        'Аналитик данных / дата аналитик / data analyst (ипотека)',
#        'Программный эксперт на курс "Аналитик данных со специализацией BI-аналитик"',
#        'Аналитик данных SberJess', 'Аналитик данных в Диадок',
#        'Аналитик данных (стажер)',
#        'Оператор базы данных/Аналитик данных Junior',
#        'Аналитик данных / BI аналитик',
#        'Аналитик Данных (автоматизация процесса кредитования Юридических лиц)',
#        'Аналитик данных (м. Пятницкое шоссе)',
#        'Стажер-аналитик данных, Маркетплей, Отдел продуктовой аналитики',
#        'Аналитик данных в центр управления телемаркетингом',
#        'Автор уроков по визуализации данных на курс "Аналитик данных и специализации BI-аналитик"',
#        'Аналитик данных / Маркетолог-аналитик',
#        'Аналитик данных Process/Task Mining',
#        'Младший аналитик данных ETL (офис)',
#        'Junior Data Scientist / Младший аналитик данных',
#        'Аналитик данных/Специалист по Power BI (data science)',
#        'Data Scientist/ Data Analyst',
#        'Ведущий специалист-аналитик данных (контакт-центры)',
#        'Эксперт-аналитик данных в группу цифрового аудита',
#        'Разработчик VBA / Младший дата аналитик',
#        'Стажер - консультант SAP /Аналитик данных',
#        'Аналитик данных (RWA-калькулятор)',
#        'Аналитик данных стажер/junior', 'Веб-аналитик / Аналитик данных',
#        'Аналитик данных (Депозитарные сервисы)',
#        'Middle Data Analyst / Аналитик BI', 'Data analysts',
#        'Младший аналитик данных (Астра Консалтинг)',
#        'Data Analyst GigaChat', 'Аналитик данных на маркетплейсах',
#        'Аналитик данных в команду вовлеченности клиентов',
#        'Старший аналитик данных в команду Raif Pay',
#        'Аналитик данных (г. Владимир)', 'Lead data analyst',
#        'List manager (Аналитик данных)', 'Аналитик данных с функциями ML',
#        'Data Analyst / Аналитик', 'Data analyst (fintech)',
#        'Аналитик данных центра поддержки планирования, отчётности и методологии',
#        'HR Data Analyst / Аналитик данных в отдел персонала',
#        'Аналитик данных в Блок "Сеть продаж"',
#        'Аналитик данных / Data Scientist (Middle)',
#        'Аналитик данных (CRM)',
#        'Старший аналитик данных / Data Scientist',
#        'Аналитик данных (стажёр)',
#        'Аналитик данных Отдела бизнес-аналитики и финансового планирования',
#        'Team Lead Data Analyst', 'Аналитик данных (SQL, фармацевтика)',
#        'Data Analyst (MTS AI)',
#        'Team lead группы аналитики / Дата аналитик в стрим "Виртуальные ассистенты"',
#        'Аналитик SQL / Data Analyst (Удалённо)',
#        'Аналитик данных (Управление транзакционного розничного бизнеса)',
#        'Middle аналитик данных', 'Дата-аналитик / Data Analyst',
#        'Аналитик данных/Data Scientist в команду "Магистральные автономные грузоперевозки"',
#        'Ведущий аудитор-аналитик данных', 'Data Analyst (Поиск)',
#        'Аналитик данных отдела продаж',
#        'Аналитик данных в команду Advanced HR Analytics',
#        'Главный специалист по статистике (Аналитик данных)',
#        'Аналитик данных/Системный аналитик',
#        'Аналитик данных в R&D / Data Analyst R&D',
#        'Middle Data analyst [Task Mining]', 'Старший Аналитик Данных',
#        'Senior / Middle+ Data Analyst', 'Middle / Junior Data Analyst',
#        'BI-аналитик/Главный аналитик данных',
#        'BI Data Analyst (B2B team)', 'Стажер Data analyst',
#        'Аналитик данных / ML инженер', 'Аналитик данных/Data Scientist',
#        'Продуктовый аналитик / Data Analyst (продукт СберДиск)',
#        'Аналитик данных/Junior DATA SCIENTIST',
#        'Game Data Analyst (Игровой аналитик)',
#        'Junior Python Developer/ Data Analyst (Агентство Starlink)',
#        'Аналитик данных (Data scientist)', 'Аналитик данных (статистика)',
#        'Стажер - консультант SAP MDG/Аналитик данных',
#        'Аналитик данных в группу аудита', 'Дата Аналитик',
#        'Аналитик данных HR',
#        'Data analyst, Ozon Fintech, Группа аналитики клиентского сервиса',
#        'Риск-аналитик / Аналитик данных (middle+)',
#        'Data analyst (регионы, удалённый/гибридный ф/р)',
#        'Аналитик данных в команду Обработки данных (Team Lead)',
#        'Senior Data Analyst c BI',
#        'Главный бизнес-аналитик данных (платформа и витрины данных)',
#        'Аналитик промо (data analyst)',
#        'Аналитик данных в контактный центр', 'Дата инженер/Дата аналитик',
#        'Дата аналитик (BI Аналитик)', 'Аналитик данных (HR-аналитика)',
#        'Product data analyst with mobile app exp (Singapore-based startup)',
#        'Аналитик данных / веб-аналитик', 'Data Analyst (Middle)',
#        'Аналитик данных в управление ИТ-инфраструктуры',
#        'Системный аналитик DWH/Аналитик данных',
#        'Аналитик данных (поиск аномалий в больших объемах данных)',
#        'Middle/Senior Data Analyst (команда Digital Avatar)',
#        'Ведущий аналитик данных (финансовые рынки)',
#        'Аналитик данных Lead', 'Data Analyst Team Lead',
#        'Аналитик данных (поддержка пользователей)',
#        'Data Analyst (витрины данных)',
#        'Аналитик данных в команду Сервисных коммуникаций',
#        'Аналитик данных (Антифрод)', 'Аналитик данных (1С:ЗУП)',
#        'Data Analyst (Руководитель направления анализа данных Центра DPO)',
#        'Маркетолог-аналитик/Аналитик данных',
#        'Программный эксперт на курс “Аналитик данных”',
#        'Дата аналитик в Маркет B2В',
#        'Старший аналитик данных в команду Operations банка',
#        'Product/Data analyst', 'Data Analyst в VK Рекламу',
#        'System data analyst', 'Аналитик данных (Data science)',
#        'Data Analyst в Лабораторию нейронаук и поведения человека Сбера',
#        'Аналитик данных в Дивизион "Корпоративное взыскание"',
#        'Data Analyst (клиентская аналитика CRM)',
#        'Аналитик данных в Департамент залогов',
#        'Аналитик данных/ разработчик SQL', 'Аналитик данных (Щербинка)',
#        'Аналитик данных (в логистику)', 'Аналитик данных Power BI',
#        'Финансовый аналитик данных',
#        'Аналитик данных транспортной логистики',
#        'Аналитик данных (ETL аналитик)', 'Senior Data Analyst ("Kino")',
#        'Финансист/аналитик данных (экономист)',
#        'Аналитик данных / Data Analyst (Senior)',
#        'Data Analyst (Data Scientist)', 'Специалист (аналитик данных)',
#        'Аудитор - аналитик данных',
#        'Аналитик данных в команду технической поддержки сети РОS',
#        'Аналитик данных (портфельный аналитик)',
#        'Аналитик данных (ИТ-аудит)',
#        'Senior Data analyst / Старший Аналитик данных',
#        'Аналитик данных отдела исследований рынка \\ Data analyst (Market intelligence)',
#        'Аналитик данных (здравоохранение)', 'Аналитик данных по продажам',
#        'Аналитик данных (Специалист C&B)', 'Middle/Senior Data analyst',
#        'Аналитик данных в команду малого бизнеса',
#        'Data Analyst Postpaid', 'Аналитик данных, Ozon Fintech',
#        'Портфельный риск-менеджер (аналитик данных) департамента розничных кредитных рисков',
#        'Аналитик данных (внутренний контроль)',
#        'Аналитик данных на производстве \\ Data Analyst in Production'],
#       dtype=object)

# %%
df_ds['name'].unique()
# Out:
# array(['Стажер Data Science (Новосибирск)', 'Data Scientist',
#        'ML Engineer / Data Scientist', 'Team Lead Data Science',
#        'Data Analyst / Data Scientist', 'Senior Data Scientist MLE',
#        'Middle/Senior Data Scientist (LLM)', 'Эксперт Data Science',
#        'Data Scientist/Data miner',
#        'Cпециалист по работе с данными (Data Scientist)',
#        'Эконометрист / Data scientist', 'Data Scientist (удаленно) / CV',
#        'Data Scientist, Маркетплейс, Контент и товары',
#        'Портфельный риск-аналитик / Middle Data Scientist (модели кредитного риска)',
#        'Аналитик / Data scientist',
#        'Data scientist/ML engineer (Рекомендательная система)',
#        'Senior Data Scientist (Промо Прогноз)',
#        'Data scientist / Эксперт по разработке математических моделей (риски)',
#        'Data Scientist middle/senior', 'Data Scientist (Goods Analytics)',
#        'Data Scientist в команду CAP', 'Team Lead Data Scientist',
#        'Junior Data Scientist', 'NLP Data Scientist',
#        'Middle Data Scientist в стрим моделирования КИБ и СМБ (NLP\\классический ML\\графовые сети)',
#        'Data Scientist NLP (портал gosuslugi.ru)',
#        'Middle Data Scientist (Команда Персонализации коммуникаций от потребности клиента)',
#        'Data scientist, Social AI',
#        'Middle Data Scientist (Развитие клиентского опыта В2С)',
#        'Data Scientist в рекомендательные системы',
#        'Руководитель проекта Data Science',
#        'Middle+/Senior Data Scientist (модели кредитного риска)',
#        'Junior NLP Data Scientist', 'Data Scientist (NLP)',
#        'Старший Data Scientist, Группа анализа и валидации экспериментов',
#        'Data Scientist (WMS)',
#        'Data Scientist (Центр модельных рисков сервисных блоков и экосистемы)',
#        'Middle/Senior разработчик систем обработки естественного языка (NLP, ML/Data Scientist)',
#        'Владелец продукта (продукты Data Science)',
#        'Quantitative Data Scientist', 'Senior Data Scientist, FinTech',
#        'Data scientist', 'Team Lead (Data Scientist)',
#        'Middle/Senior NLP Data Scientist (Global Markets)',
#        'Data Scientist (collection)',
#        'Team Lead Data Scientist (NLP, CV)',
#        'Data Scientist в центр AI маркетинга',
#        'Senior Data Scientist (розничное риск-моделирование)',
#        'Middle Data Scientist (Ценообразование)',
#        'Data Scientist в команду Search Quality',
#        'Data Scientist (Sberspace)', 'Data Scientist (антифрод модели)',
#        'Data Scientist (Дата-сайентист, Инженер машинного обучения)',
#        'Data scientist (computer vision)',
#        'Senior NLP Data Scientist / GigaChat',
#        'Data Scientist (Цифровой автолизинг)',
#        'Data Analyst / Data scientist middle',
#        'Data Scientist (NLP/ LLM)',
#        'Middle/Senior Data Scientist (команда СХ)',
#        'Math Modeler/Data Scientist (PREVIOUS EXPERIENCE IN SPORTS BETTING COMPANY A MUST)',
#        'Lead Data Scientist (СберБизнес)',
#        'Data Scientist/python-разработчик',
#        'Middle Data Scientist (команда Клиентского опыта)',
#        'Data Scientist в команду рисков',
#        'Middle Data Scientist в лабораторию Кибербезопасности Сбера',
#        'Data Scientist (предиктивные модели)',
#        'Junior Data Scientist (Гео и Графы)',
#        'Data Analyst (Data Science и клиентская аналитика)',
#        'Стажер Data Science', 'Data Scientist (валидация моделей)',
#        'NLP Инженер / Data Science / LLM / DS / Deep Learning',
#        'Data Analyst (команда Data Science и клиентская аналитика)',
#        'Data Scientist (с релокацией в Сербию)',
#        'Senior Data Scientist (NLP)', 'Junior data scientist',
#        'Ведущий специалист отдела математического моделирования / Data Scientist',
#        'Senior Data Scientist',
#        'Model Development / ML / Data Science professional',
#        'Data Scientist - Специалист по анализу и моделированию данных',
#        'Стажер Data Scientist, Логика ранжирования',
#        'Senior data scientist, Маркетплейс, Доставка',
#        'Senior ML Engineer (Senior Data Scientist), Маркетплейс, Цены и анализ конкурентов',
#        'Data Scientist (Специалист по обработке и анализу данных)',
#        'Data science инженер',
#        'Data scientist (клиентская аналитика и моделирование розничного бизнеса)',
#        'Data Science / ML инженер', 'Middle Data Scientist (R&D команда)',
#        'Стажер Data Scientist, Качество прогнозов',
#        'ML Data Scientist (Senior)', 'Data Scientist (Аналитик данных)',
#        'Бизнес-аналитик (Big Data, Data Science, Master Data Management)',
#        'Middle/Senior Data Scientist в Модерацию контента',
#        'Middle Data Scientist', 'Lead Data Scientist (NLP)',
#        'Senior Data Scientist (NLP направление)',
#        'Lead Data Scientist в SberAI',
#        'Team Lead Data Scientist (Моделирование рисков розничного кредитования) / ИТ',
#        'Senior/ Lead Data Scientist (Поисковой движок)',
#        'Data scientist (Центр модельных рисков розничного бизнеса)',
#        'Data Scientist (модельные риски и валидация)',
#        'Data Scientist Управления модельных рисков и валидации',
#        'Data Scientist NLP (LLM) (MTS AI)', 'Стажер Data scientist/MLE',
#        'Senior/Lead Data Scientist', 'Data Scientist (NLP/LLM)',
#        'Ведущий специалист DATA SCIENCE',
#        'Преподаватель направления "Data Scientist"',
#        'Data Scientist в медицине (Middle/Senior)',
#        'Специалист по исследованию данных/Data Scientist в Центр исследований Сбера',
#        'Lead Data Scientist (ML)',
#        'Data Scientist (Центр модельных рисков розничного бизнеса, NLP задачи)',
#        'Data scientist (Управление рисками корпоративных клиентов)',
#        'Junior/Middle Data Scientist', 'Middle Data Scientist (NLP)',
#        'Data Scientist / ML-инженер',
#        'Senior Исследователь данных/Data Scientist в центр исследований Сбера',
#        'Team Lead Data Scientist (кредитный скоринг)',
#        'Стажер Data Scientist',
#        'Senior data scientist в Softline Digital',
#        'Data scientist (Дирекция рисков)', 'Data Scientist (CLTV)',
#        'Data Scientist (Ranking&Search)',
#        'Senior/Team Lead Data Scientist (NLP)', 'Ведущий Data Scientist',
#        'Middle data scientist',
#        'Ведущий Data Scientist, Ранжирование поиска',
#        'Управляющий директор \\ Data Scientist (Сопровождение процесса разработки и использования моделей)',
#        'Associate Professor - Data Science&AI (english)',
#        'Assistant Professor - Data Science&AI (english)',
#        'Senior Data Scientist в команду «Матчинг»',
#        'Middle \\ Senior Data Scientist в команду моделирования розничного бизнеса',
#        'Data scientist (команда Collection)',
#        'Middle \\ Senior Data scientist (команды CRM и модели оптимизации)',
#        'DevOps инженер (Data Science модели) в Банк',
#        'Lead data scientist (Анализ цены и Trade in)',
#        'Senior Data Scientist (Хаб юридических лиц)',
#        'Senior Data Scientist CV (Generative design)',
#        'Старший Data Scientist, Эффективность рекламы',
#        'Data Scientist / CV Researcher (Middle+/Senior)',
#        'Middle/ senior data scientist (разработка моделей для казначейства и рыночных рисков)',
#        'Data scientist, проекты по разработке симуляционных моделей, моделей оценки стресс-тестирования',
#        'Data Scientist (CoreML + RecSys)', 'Senior Data Scientist [NUUM]',
#        'Senior Data Scientist/Team Lead',
#        'Computer Vision Engineer \\ Data Scientist в команду Layer, SberDevices.',
#        'Data Scientist (NLP, LLM)', 'Data Scientist (middle) (DataProd)',
#        'Data Scientist (middle) (DataLab)',
#        'Data scientist (Персонализация)',
#        'Data Scientist (middle/senior)',
#        'Senior data scientist (NLP), Sber AI',
#        'Data Scientist (сопровождение процесса разработки и использования моделей)',
#        'Team Lead Data Scientist CV (Generative design)',
#        'Специалист по Data Science',
#        'Исследователь алгоритмов машинного обучения Data Scientist / ML Researcher',
#        'Middle/Senior Data Scientist в команду NLP',
#        'Data Scientist (middle)', 'Data Science Specialist',
#        'Эксперт по моделированию и анализу данных / Data Scientist',
#        'Lead Data Scientist', 'Data scientist CV (senior)',
#        'Дата аналитик (Data Scientist)', 'Data Scientist Teamlead NLP',
#        'Data Scientist, Ранжирование поиска',
#        'Data Scientist (Алгоритмы оптимизации)',
#        'Аналитик данных (data scientist, data engineer)',
#        'Senior Data Scientist (главный исследователь данных по КАСКО)',
#        'Data Scientist (математическое моделирование)',
#        'Head of Data Science', 'Data scientist в поиск Маркета',
#        'Senior Data Scientist (Ranking&Search)',
#        'Разработчик Data Science NLP (Middle)',
#        'Руководитель направления (team lead) Data Science',
#        'Middle/Senior Data Scientist в команду ETA/RTA',
#        'Data scientist (Департамент развития отношений с клиентами)',
#        'Data Scientist (Operations)',
#        'Data scientist (Анализ ГИС данных)',
#        'Эксперт Группа аналитики и моделирования (Data scientist)',
#        'Senior Data Scientist в b2c направление',
#        'Data Scientist (внедрение ML-решения)',
#        'Senior Data Scientist (Pricing)',
#        'Senior Data Scientist (ML разработчик)', 'Аналитик Data Science',
#        'Data scientist Middle\\Senior (кредитный скоринг)',
#        'Data Scientist (Scoring)',
#        'Data scientist (Департамент аналитики и развития технологий сбора)',
#        'Программист data science и нейронные сети',
#        'Senior Data scientist',
#        'Data Scientist (Deep Learning), Рекомендации и персонализация',
#        'Программист Python/Data Scientist (middle / senior)',
#        'Ведущий Data Scientist (Python)',
#        'Senior Data Scientist (Rec. system)',
#        'Data Scientist (офис г. Таганрог)',
#        'Data Engineer / Data scientist Middle',
#        'Data Scientist (LLM / NLP направления)',
#        'Менеджер по управлению проектами Data Science/Project Manager DS',
#        'Senior Data Scientist NLP GigaChat',
#        'Data Scientist (Middle+) в промышленности',
#        'Data Scientist / Автоматизация и аналитика корпоративного бизнеса',
#        'Data Scientist (валидация ПВР моделей)',
#        'Junior Data Scientist/ML Engineer',
#        'Data Scientist / Специалист по анализу данных (Эконометрист)',
#        'Ведущий разработчик Python/Data Scientist',
#        'Data Scientist (junior)',
#        'Data Scientist / ML-инженер (Big Data)',
#        'Python разработчик Data Science', 'Data scientist NLP',
#        'Data Scientist AI/ML (Домен ИИ)', 'Data Scientist (риски)',
#        'Senior Data Science', 'Стажер Data scientist',
#        'Data Scientist в Блок Финансы',
#        'Эконометрист (junior data scientist)',
#        'Senior Data Scientist (IT)', 'Middle Data Scientist (IT)',
#        'Data Scientist (в Сербию)', 'Ведущий Data Science инженер',
#        'Data Scientist (СРМ и Оптимизации)',
#        'Medical foundation model research data scientist CV+NLP (Middle+)',
#        'Senior Data Scientist (СберБизнес)',
#        'Data Science Team Lead в команду Virtual Assistants',
#        'NLP Data Scientist в Центр AI Маркетинга',
#        'Аналитик данных (Data Scientist)',
#        'Стажер Data Scientist (MTS AI)', 'Data Scientist (CV+NLP)',
#        'Data Scientist middle+', 'Senior Data Scientist (Fintech)',
#        'Senior Data Scientist (NLP) в автоматизацию коммуникаций',
#        'Ведущий инженер по данным (data science)',
#        'Data Scientist (Junior+/Middle) Классический ML',
#        'Data scientist (риски)',
#        'Senior/ Lead Data Scientist (Индексы магазинов)',
#        'Data Scientist (Центр модельных рисков КИБ, NLP задачи)',
#        'Data scientist (Кредитное Бюро Русский Стандарт)',
#        'Data Scientist / Machine Learning Engineer',
#        'Team-Lead Data Science', 'Data Scientist/Python-разработчик',
#        'Data Scientist в Trust & Safety',
#        'Бизнес-аналитик со знанием SQL (удаленно)/Data scientist',
#        'Data Science специалист', 'Аналитик (Data science)',
#        'Data science Data-инженер Data-программист',
#        'Data Science Manager',
#        'Senior Data Science Specialist (Prediction)',
#        'Data Scientist (Рекомендательная система)',
#        'Senior Data Scientist (RecSys)', 'Data Scientist NLP',
#        'Data scientist (Risk), remote',
#        'Специалист по машинному обучению (Data Science)',
#        'Senior Data Scientist (Кредиты физический лиц)',
#        'Аналитик данных / Data Scientist', 'Middle Data Scientist NLP',
#        'Старший эксперт по анализу данных (data science, ML)',
#        'Data Scientist (CV, OCR)', 'Middle/Senior Data Scientist NLP/LLM',
#        'Data Scientist in Geoscience (Аналитик данных - Геология)',
#        'Data Scientist in Petroleum Engineering',
#        'Senior Data Scientist (LLM)',
#        'Data Science Lead / Руководитель группы специалистов по машинному обучению и аналитике данных',
#        'Head of Data Science/Руководитель Data Science',
#        'Data scientist (CV+NLP)', 'Data scientist/Data Analyst',
#        'Data Scientist (Deep Learning for Demand Forecast)',
#        'Data scientist (middle/senior)', 'Middle Data Science',
#        'Эксперт Data Science в направление Андеррайтинг',
#        'Data scientist senior',
#        'Data Scientist/Analyst "Платформа экспериментов" (Senior)',
#        'Data Scientist middle или senior (переезд в город Тюмень)',
#        'Исследователь / экономист (data science)',
#        'Data Analyst / Data Scientist (Junior/Junior+)',
#        'Senior Data Scientist NLP', 'Senior Data Scientist, Remote',
#        'Middle/Senior Data Scientist (команда PFM GigaChat)',
#        'Data Scientist в команду Out-of-stock',
#        'Middle Data Scientist в команду RecSys',
#        'Middle/Senior Data Scientist', 'Аналитик Data Science (NLP, LLM)',
#        'Data scientist (ML)', 'Team Lead Data Scientist (RecSys)',
#        'Data Scientist LLM (Global markets)',
#        'MLOps инженер/ IT BP (Направление Data science)',
#        'Data Scientist LLM',
#        'Специалист по работе с большими данными (data scientist) Департамента страт развития',
#        'Data Scientist Middle MLE', 'Data Scientist в проект GigaChat',
#        'Middle NLP Data Scientist – GigaChat',
#        'Data Scientist (команда Поиска)', 'Data Scientist (GigaChat)',
#        'Data scientist (скоринг)', 'Data scientist (Middle/Middle+)',
#        'Middle/Senior Data Scientist (блок Управление благосостоянием)',
#        'Data Scientist (Computer Vision)',
#        'Middle / Senior NLP Data Scientist',
#        'Стажер инженер данных (data science)',
#        'Data Scientist (Senior) в Южно-Сахалинск',
#        'Data Scientist (Middle) в Южно-Сахалинск',
#        'Data Scientist (Middle) с переездом в Южно-Сахалинск',
#        'Стажер Data Science, Новосибирск',
#        'ML-разработчик/Data Scientist',
#        'Data Science (подразделение комплаенс)', 'Data Scientist (CVM)',
#        'Data Scientist (Junior/Middle)', 'ML Engineer/Data Scientist',
#        'Senior Data Scientist (CV), Sber AI', 'Data Science',
#        'Data scientist / Аналитик риск-моделей',
#        'Data Scientist (A/B Platform)',
#        'Data Scientist (Моделирование рисков корпоративного кредитования)',
#        'Data Science Project',
#        'Специалист Data Science на роль Академического директора',
#        'Junior Data Scientist (математическое моделирование)',
#        'Руководитель программ повышения операционной эффективности/Data Scientist (г. Ноябрьск)',
#        'Аналитик данных (Data scientist/дата-инженер)',
#        'Руководитель отдела Data Science',
#        'Senior Data Scientist (Управление Комплаенс)',
#        'Team lead Data Scientist, Маркетплейс, Контент и товары, Машинный перевод',
#        'Junior Data Scientist в SberData',
#        'Middle Data Scientist в Департамент "Занять и сберегать"',
#        'Middle/Senior Data Scientist в Блок B2C',
#        'Data Scientist (LLM/ NlP) в Блок B2C',
#        'Team Lead Data Scientist в команду SberCampaigning',
#        'Data Science (Компьютерное зрение)', 'Data Scientist (Pricing)',
#        'Data scientist/ML engineer',
#        'Старший разработчик Data Science (WebCat)',
#        'Junior Data Scientist+Data Analyst (Команда AI Дирекции по экосистеме юр. лиц)',
#        'Data scientist, г. Южно-Сахалинск', 'Team lead Data Scientist',
#        'Machine Learning Data Scientist - Geoscience',
#        'Стажёр - Data scientist, Группа утилизации инфраструктуры, Разработка платформы',
#        'Data Scientist в VK Predict',
#        'Data Scientist (Ранжировани и Персонализации)',
#        'Стажер - Data Scientist', 'Senior Data Scientist (classical ML)',
#        'Middle Data Scientist (SberNBA)', 'Middle Data scientist',
#        'Junior/Middle Data Scientist (команда Персонализация СболПРО)',
#        'Data Scientist в отдел разработки скоринговых моделей',
#        'Аналитик данных в отдел планирования и прогнозирования (data analyst / data scientist)',
#        'Team Lead команды Data Science', 'Team lead Data Science',
#        'Data scientist (Middle)',
#        'Senior NLP Engineer / ML / LLM / Data Science / AI инженер (удаленно)',
#        'Data Scientist (Управление рисками)',
#        'Senior Data Scientist (команда Монетизации)',
#        'Data science/ML Engineer (NLP)',
#        'Data Scientist в команду эффективности монетизации',
#        'Data Scientist / Data Analyst / Data engineer',
#        'Data Scientist (R&D)', 'Data Scientist (Лента онлайн)',
#        'Data Scientist (ДЦО Недвижимость)', 'Data Scientist (Middle)',
#        'Senior Data Scientist (Рекомендательная система)',
#        'Специалист по Machine Learning / Data Science (python)',
#        'Data Scientist Моделирование баланса банка',
#        'Аналитик данных (Data Science)',
#        'Старший аналитик данных (Data Scientist)',
#        'Руководитель группы Data Science, Эффективность рекламы',
#        'Data Scientist, Маркетплейс, Доставка',
#        'Data science (valuation)', 'Data scientist (middle/ senior)',
#        'Аналитик данных / Data Scientist (middle+)',
#        'Data Scientist NLP/LLM, Маркетплейс, Инструменты поддержки и CRM',
#        'Data Scientist (Моделирование рисков розничного кредитования)',
#        'Data scientist (junior)', 'Data Scientist, Маркетплейс, Антибот',
#        'Data Scientist (Python)',
#        'Middle Data Scientist (NLP / LLM CX B2C)',
#        'Senior Data Scientist (NLP, LLM)',
#        'Data Scientist CV (Автомодерация)',
#        'Senior Data Scientist / ML разработчик',
#        'Data Scientist (Middle/Senior)', 'Data Analyst / Data scientist',
#        'Middle Data Scientist в SberData',
#        'Аналитик по машинному обучению / ML-аналитик / Data Scientist',
#        'Team Lead Data Scientist (NLP)', 'Junior Data Science Specialist',
#        'Senior Data Scientist (Прогноз заказов)',
#        'ML-разработчик (Data Science)', 'Data Scientist в Антифрод',
#        'Senior Data scientist (Дирекция цифрового развития)',
#        'Data Scientist (Моделирование RnD)',
#        'Data Analyst/Data Scientist', 'Data Scientist/Analyst',
#        'Middle+/Senior Data Scientist (Промо, Маркетинг)',
#        'Data scientist (модели антифрод)',
#        'Middle Data Scientist (Прогноз спроса)',
#        'Data scientist (Персонализации)',
#        'Data Scientist, Контент и товары',
#        'Middle Data Scientist (Прогноз спроса - маркетплейс МегаМаркет)',
#        'Аналитик данных Data Science', 'Senior data science engineer',
#        'Middle Data Scientist (команда перспективных алгоритмов машинного обучения)',
#        'Data Scientist (LLM)', 'Data Scientist / ML Engineer (NLP)',
#        'RnD/Data Scientist/ML-инженер (NLP)',
#        'Data scientist (CV), Sber AI',
#        'Team Lead Data Scientist в команду внутренних данных',
#        'Data Scientist (Аналитик)',
#        'Финансовый аналитик/ Data Analyst / Data scientist',
#        'Middle Data Scientist CV', 'Data scientist (middle+)',
#        'Junior Data Scientist (Personalization)',
#        'Junior Data Scientist (Ranking&Search)',
#        'Middle Data scientist (CV), Sber AI',
#        'Data Scientist (разработка чат-ботов)',
#        'Middle/Senior ML Engineer/Full-stack Data Scientist (в команду рекомендаций)',
#        'Senior Data Scientist (главный исследователь данных по ДМС)',
#        'Data Scientist (RecSys)',
#        'Руководитель группы Data Science (DL), Рекомендации и персонализация',
#        'Data scientist (Senior)',
#        'Data Scientist (Центр модельных рисков КИБ)',
#        'Senior Data Scientist в команду Collateral Machine',
#        'Junior Data Scientist / Младший аналитик данных',
#        'Middle-Senior ML / Data Science разработчик',
#        'Аналитик данных/Специалист по Power BI (data science)',
#        'Data Scientist / ML Engineer (middle+/senior) FinTech',
#        'Data Scientist/ Data Analyst',
#        'Количественный аналитик/Data Scientist',
#        'Senior AI Researcher / Senior Data scientist in NLP',
#        'Data Scientist (Midlle)', 'Стажер Data science',
#        'Senior Data Scientist в команду антифрода',
#        'Senior Data Scientist NLP в команду клиентского сервиса',
#        'Data Scientist в команду персонализации',
#        'Senior Data Scientist (Deep Learning)',
#        'Team Lead Data science (модели кредитного риска)',
#        'Junior Data Scientist (в команду персонализации коммуникаций от потребности клиента)',
#        'Стажер/Data Science, Новосибирск',
#        'Data Scientist (computer vision)',
#        'Data scientist (middle) в команду моделирования партнерств и ИТ - процессов',
#        'Data Scientist (Ведущий)', 'Senior Data Scientist (GigaChat)',
#        'Менеджер по управлению проектами Data Science',
#        'Data Scientist (Recommendations)',
#        'Middle Data Scientist в команду моделирования копроративно - инвестиционного бизнеса',
#        'Стажёр Data scientist, Группа моделирования и оптимизации складских процессов',
#        'Data Scientist Junior / Junior+ (со знанием английского языка)',
#        'Специалист по работе с большими данными (data scientist)',
#        'Data scientist/ML Engineer', 'Data scientist / ML Engineer',
#        'Аналитик данных / Data Scientist (Middle)',
#        'Data Scientist (Видеоаналитика)',
#        'Старший аналитик данных / Data Scientist',
#        'Data Scientist NLP/Audio',
#        'Junior data scientist (модели кредитного риска)',
#        'Data Scientist R&D', 'Data Scientist в VK Рекламу',
#        'Data scientist в Predict',
#        'Тимлид группы анализа клиентских данных и веб-аналитики/ Senior Data Scientist',
#        'Аналитик в Центре методологии и популяризации Data science',
#        'Data Scientist (Search)',
#        'Аналитик данных/Data Scientist в команду "Магистральные автономные грузоперевозки"',
#        'Аналитик скоринга / Data Scientist', 'Middle ML Data Scientist',
#        'Data Scientist (риски, CRM)',
#        'Data Scientist/Machine Learn developer',
#        'Аналитик данных/Data Scientist',
#        'Аналитик данных/Junior DATA SCIENTIST',
#        'Стажер (Data Scientist/ML)', 'Аналитик данных (Data scientist)',
#        'Data Scientist - NLP/LLM Engineer',
#        'Senior Data Scientist (Промо, Маркетинг)',
#        'Senior (Lead) Data scientist/ ML Engineer',
#        'Data Science /Ведущий эксперт по созданию моделей банковских рисков',
#        'Data scientist (NLP)', 'Data Scientist, Факторы ранжирования',
#        'Data Scientist (ASR, NLP, LLM)',
#        'Machine Learning - Data Scientist - Geoscience',
#        'Data Scientist (Senior)',
#        'Старший Data Scientist (NLP), Понимание запроса',
#        'Data Scientist в команду автоматизации',
#        'Руководитель лаборатории (направление Data Scientist)',
#        'Data scientist (Дирекция цифрового развития)',
#        'Программный эксперт на курс “Data Science”', 'Data Scientist AC',
#        'Senior Data Scientist в Департамент глобальных рынков',
#        'Data Scientist CV (Computer Vision)',
#        'Middle/Senior Data scientist, проект трансформации о. Сахалин',
#        'Data Science Team Lead',
#        'Lead Data Scientist - Релокация на Кипр',
#        'Аналитик данных (Data science)',
#        'Data scientist (Центр модельных рисков розничного бизнеса, ПВР задачи)',
#        'Руководитель R&D группы (Data Scientist, ML)',
#        'Middle/Senior Data scientist (classical ML)',
#        'Исследователь данных (Data Scientist)',
#        'Middle ML-engineer (Data Scientist)',
#        'Data Analyst (Data Scientist)',
#        'Data scientist (научный сотрудник)', 'Data Scientist AutoML',
#        'Data scientist junior (младший научный сотрудник)',
#        'Data Scientist CV (Generative design)',
#        'Senior Data Scientist (NLP, CV)',
#        'Senior Data Scientist (Центр модельных рисков сервисных блоков и экосистемы)',
#        'Junior Data Scientist (NLP)',
#        'Старший Data Scientist, Группа товародвижения собственных продаж',
#        'Ведущий Data Scientist, Группа логистики, Ozon Fresh',
#        'Разработчик в области машинного обучения и больших данных (Data Scientist)'],
#       dtype=object)

# %% [markdown]
# ### Столбец published_at

# %% [markdown]
# Столбец представляет собой дату публикации вакансии, который получился из последней строки страницы с вакансией на hh.ru. Необходимо преобразовать значения и оставить только дату, время исключить.

# %%
df_da['published_at'] = pd.to_datetime(df_da['published_at']).dt.normalize()
df_da['published_at']
# Out:
# 0      2024-05-24
# 1      2024-05-24
# 2      2024-05-24
# 3      2024-05-24
# 4      2024-05-24
#           ...
# 1796   2024-05-23
# 1797   2024-06-10
# 1798   2024-05-23
# 1799   2024-05-23
# 1800   2024-05-23
# Name: published_at, Length: 1801, dtype: datetime64[ns]

# %%
df_ds['published_at'] = pd.to_datetime(df_ds['published_at']).dt.normalize()
df_ds['published_at']
# Out:
# 0     2024-05-24
# 1     2024-05-24
# 2     2024-05-24
# 3     2024-05-24
# 4     2024-06-08
#          ...
# 969   2024-06-11
# 970   2024-06-10
# 971   2024-06-10
# 972   2024-06-10
# 973   2024-05-23
# Name: published_at, Length: 974, dtype: datetime64[ns]

# %% [markdown]
# Проверили результат операции - ок.

# %%
df_da['published_at'].describe()
# Out:
# count                             1801
# mean     2024-05-03 18:16:59.433648128
# min                2024-02-13 00:00:00
# 25%                2024-04-11 00:00:00
# 50%                2024-05-11 00:00:00
# 75%                2024-05-29 00:00:00
# max                2024-06-11 00:00:00
# Name: published_at, dtype: object

# %%
df_ds['published_at'].describe()
# Out:
# count                              974
# mean     2024-04-28 21:43:59.014373632
# min                2024-02-29 00:00:00
# 25%                2024-04-01 00:00:00
# 50%                2024-04-25 12:00:00
# 75%                2024-05-29 00:00:00
# max                2024-06-11 00:00:00
# Name: published_at, dtype: object

# %% [markdown]
# Вакансии DA были опубликованы в период с 13 февраля по 11 июня 2024 года. Вакансии DS - c 29 февраля по 11 июня 2024 года.

# %% [markdown]
# ### Столбец alternate_url

# %% [markdown]
# Столбец представляет собой ссылку на вакансию и в исследовании принимать участие не будет.

# %% [markdown]
# ### Столбец employer

# %% [markdown]
# Столбец представляет собой наименование организации, разместившей вакансию, который получился из заголовка виджета страницы с вакансией на hh.ru. 690 организаций, которые разместили вакансии DA и 305 организаций - DS.

# %%
top_emp_da = df_da['employer'].value_counts().head(10)
top_emp_da
top_emp_da = top_emp_da.reset_index()
top_emp_da.columns = ['employer', 'total']
top_emp_da
# Out:
#                                 employer  total
# 0                                   СБЕР    243
# 1                            WILDBERRIES     43
# 2                                   Ozon     34
# 3                         Банк ВТБ (ПАО)     28
# 4                                     Т1     26
# 5                 МАГНИТ, Розничная сеть     24
# 6                                    МТС     22
# 7                                   Okko     19
# 8  Центральный банк Российской Федерации     16
# 9                                 Яндекс     15

# %% [markdown]
# Топ-10 организаций по количеству вакансий DA. Визуализируем для наглядности.

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,5))
df_da['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DA', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Абсолютный лидер по количеству вакансий DA - СБЕР, который разместил в 5 раз больше вакансий DA ближайшей WILDBERRIES.

# %%
top_emp_ds = df_ds['employer'].value_counts().head(10)
top_emp_ds = top_emp_ds.reset_index()
top_emp_ds.columns = ['employer', 'total']
top_emp_ds
# Out:
#          employer  total
# 0            СБЕР    198
# 1            Ozon     36
# 2     Газпромбанк     24
# 3    Samokat.tech     20
# 4              Т1     19
# 5  Банк ВТБ (ПАО)     18
# 6     WILDBERRIES     16
# 7      Ростелеком     12
# 8     Lamoda Tech     12
# 9         МегаФон     11

# %% [markdown]
# Топ-10 организаций по количеству вакансий DS. Визуализируем для наглядности.

# %%
plt.figure(figsize=(8,5))
df_ds['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DS', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Абсолютный лидер по количеству вакансий DS - СБЕР, который разместил почти в 6 раз больше вакансий DS ближайшего OZON.

# %% [markdown]
# #### Неявные дубликаты по 4 столбцам 'name', 'employer', 'area', 'experience'

# %% [markdown]
# Проверим гипотезу с неявными дубликатами по 4 столбцам *'name', 'employer', 'area', 'experience'*.

# %%
df_da['employer'] = df_da['employer'].str.lower() # приводим к нижнему регистру столбец employer
df_da['name'] = df_da['name'].str.lower() # приводим к нижнему регистру столбец name
df_da.duplicated(['name', 'employer', 'area', 'experience']).sum()
# Out:
# 420

# %%
df_ds['employer'] = df_ds['employer'].str.lower() # приводим к нижнему регистру столбец employer
df_ds['name'] = df_ds['name'].str.lower() # приводим к нижнему регистру столбец name
df_ds.duplicated(['name', 'employer', 'area', 'experience']).sum()
# Out:
# 218

# %% [markdown]
# 420 и 218 дублей это очень много. Посмотрим на них.

# %%
duplicates = df_da[['name', 'employer', 'area', 'experience']]
duplicates[duplicates.duplicated(keep=False)].sort_values(by=['name', 'employer', 'area', 'experience'])
# Out:
#                                                    name  \
# 228        bi-аналитик / data analyst / аналитик данных
# 909        bi-аналитик / data analyst / аналитик данных
# 72                         bi-аналитик/ аналитик данных
# 1408                       bi-аналитик/ аналитик данных
# 215         bi-аналитик/бизнес-аналитик/аналитик данных
# ...                                                 ...
# 1747                              урбан-аналитик данных
# 618   эксперт по цифровым технологиям аудита (data a...
# 1656  эксперт по цифровым технологиям аудита (data a...
# 1302  эксперт-аналитик данных в группу цифрового аудита
# 1777  эксперт-аналитик данных в группу цифрового аудита
#
#                                             employer             area  \
# 228   федеральная сеть книжных магазинов читай-город           Москва
# 909   федеральная сеть книжных магазинов читай-город           Москва
# 72                                            сэлвим           Москва
# 1408                                          сэлвим           Москва
# 215                                          гоудрон           Москва
# ...                                              ...              ...
# 1747                                           mayak           Москва
# 618                                             сбер  Санкт-Петербург
# 1656                                            сбер  Санкт-Петербург
# 1302                    recruitment boutique s.m.art           Москва
# 1777                    recruitment boutique s.m.art           Москва
#
#                experience
# 228   Junior+ (1-3 years)
# 909   Junior+ (1-3 years)
# 72    Junior+ (1-3 years)
# 1408  Junior+ (1-3 years)
# 215   Junior+ (1-3 years)
# ...                   ...
# 1747  Junior+ (1-3 years)
# 618   Junior+ (1-3 years)
# 1656  Junior+ (1-3 years)
# 1302  Junior+ (1-3 years)
# 1777  Junior+ (1-3 years)
#
# [704 rows x 4 columns]

# %%
duplicates = df_ds[['name', 'employer', 'area', 'experience']]
duplicates[duplicates.duplicated(keep=False)].sort_values(by=['name', 'employer', 'area', 'experience'])
# Out:
#                                                   name  \
# 10     cпециалист по работе с данными (data scientist)
# 501    cпециалист по работе с данными (data scientist)
# 85   data analyst (data science и клиентская аналит...
# 575  data analyst (data science и клиентская аналит...
# 832  data analyst (data science и клиентская аналит...
# ..                                                 ...
# 303               эконометрист (junior data scientist)
# 592               эконометрист (junior data scientist)
# 11                       эконометрист / data scientist
# 517                      эконометрист / data scientist
# 805                      эконометрист / data scientist
#
#                                               employer    area  \
# 10                                        открытый код  Самара
# 501                                       открытый код  Самара
# 85                                                сбер  Москва
# 575                                               сбер  Москва
# 832                                               сбер  Москва
# ..                                                 ...     ...
# 303  аналитический центр при правительстве российск...  Москва
# 592  аналитический центр при правительстве российск...  Москва
# 11                                               okkam  Москва
# 517                                              okkam  Москва
# 805                                              okkam  Москва
#
#               experience
# 10   Junior+ (1-3 years)
# 501  Junior+ (1-3 years)
# 85    Middle (3-6 years)
# 575   Middle (3-6 years)
# 832   Middle (3-6 years)
# ..                   ...
# 303  Junior+ (1-3 years)
# 592  Junior+ (1-3 years)
# 11    Middle (3-6 years)
# 517   Middle (3-6 years)
# 805   Middle (3-6 years)
#
# [377 rows x 4 columns]

# %% [markdown]
# Возможная причина таких дубликатов - при обновлении даты размещения вакансий создают новую вакансию с более свежей датой, вместо того чтобы обновить дату уже размещенной вакансии. Удалим строки с дубликатами.

# %%
df_da.sort_values(by='published_at', ascending=False) # отсортируем по дате
df_da.drop_duplicates (subset=['name', 'employer', 'area', 'experience'], keep='first', inplace=True) # удалим все дубликаты кроме первого
df_da.reset_index(drop=True).head()
# Out:
#           id                                    name published_at  \
# 0  100039284  junior аналитик данных (исследователь)   2024-05-24
# 1  100039480                         аналитик данных   2024-05-24
# 2  100042705         аналитик данных (исследователь)   2024-05-24
# 3  100046788                 ведущий аналитик данных   2024-05-24
# 4  100056244                         аналитик данных   2024-05-24
#
#                      alternate_url           employer  \
# 0  https://hh.ru/vacancy/100039284  dns головной офис
# 1  https://hh.ru/vacancy/100039480              комус
# 2  https://hh.ru/vacancy/100042705  dns головной офис
# 3  https://hh.ru/vacancy/100046788           х5 group
# 4  https://hh.ru/vacancy/100056244             лукойл
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills     schedule  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  Полный день
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  Полный день
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  Полный день
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  Полный день
# 4                                   ['Документация']  Полный день
#
#          employment                                        description  \
# 0  Полная занятость  наше направление занимается повышением эффекти...
# 1  Полная занятость  сегодня комус один из крупнейших поставщиков о...
# 2  Полная занятость  наше направление занимается повышением эффекти...
# 3  Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 4  Полная занятость  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  наш направление заниматься повышение эффективн...      60000.0        NaN
# 1  сегодня комус крупный поставщик офисный товар ...          NaN        NaN
# 2  наш направление заниматься повышение эффективн...      90000.0        NaN
# 3  задача разработка бизнес модель групповой прог...          NaN        NaN
# 4  обязанность участие проектирование разработка ...          NaN        NaN
#
#       salary_bin                   key_skills_from_key_skills_field
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN

# %%
round((1 - (1381 / 1801)) * 100, 2)
# Out:
# 23.32

# %% [markdown]
# Можно сделать вывод, что количество вакансий DA на 23 процента завышено.

# %% [markdown]
# Теперь сделаем тоже самое с DS.

# %%
df_ds.sort_values(by='published_at', ascending=False) # отсортируем по дате
df_ds.drop_duplicates (subset=['name', 'employer', 'area', 'experience'], keep='first', inplace=True) # удалим все дубликаты кроме первого
df_ds.reset_index(drop=True).head()
# Out:
#           id                               name published_at  \
# 0  100049339  стажер data science (новосибирск)   2024-05-24
# 1  100051447                     data scientist   2024-05-24
# 2  100070495       ml engineer / data scientist   2024-05-24
# 3  100076648             team lead data science   2024-05-24
# 4  100077910      data analyst / data scientist   2024-06-08
#
#                      alternate_url                             employer  \
# 0  https://hh.ru/vacancy/100049339                                 сбер
# 1  https://hh.ru/vacancy/100051447  бюро кредитных историй скоринг бюро
# 2  https://hh.ru/vacancy/100070495                               гк фск
# 3  https://hh.ru/vacancy/100076648                                 сбер
# 4  https://hh.ru/vacancy/100077910                                итсен
#
#            department         area             experience  \
# 0  Сбер для экспертов  Новосибирск  Junior (no experince)
# 1                 NaN       Москва    Junior+ (1-3 years)
# 2                 NaN       Москва    Junior+ (1-3 years)
# 3  Сбер для экспертов       Москва     Middle (3-6 years)
# 4                 NaN       Москва     Middle (3-6 years)
#
#                                           key_skills          schedule  \
# 0                                                 []       Полный день
# 1  ['Python', 'Hadoop', 'Machine Learning', 'Рабо...  Удаленная работа
# 2  ['Python', 'PyTorch', 'Machine Learning', 'Doc...       Полный день
# 3                                                 []       Полный день
# 4  ['DataLens', 'MS SQL', 'SQL', 'Spark', 'Аналит...       Полный день
#
#          employment                                        description  \
# 0        Стажировка  sberseasons - оплачиваемая программа стажирово...
# 1  Полная занятость  бюро кредитных историй «скоринг бюро» является...
# 2  Полная занятость  о компании и команде: группа компаний фск – мн...
# 3  Полная занятость  наша команда разрабатывает модели машинного об...
# 4  Полная занятость  мы ищем талантливого middle data analyst / dat...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  sberseasons оплачивать программа стажировка ра...          NaN        NaN
# 1  бюро кредитный история скоринг бюро являться к...          NaN        NaN
# 2  компания команда группа компания фск многопроф...          NaN        NaN
# 3  наш команда разрабатывать модель машинный обуч...          NaN        NaN
# 4  искать талантливый middle data analyst data sc...     350000.0        NaN
#
#       salary_bin                   key_skills_from_key_skills_field
# 0  ЗП не указана                                                NaN
# 1  ЗП не указана  SQL, MS SQL, Big Data, Python, Spark, Hadoop, ...
# 2  ЗП не указана  Python, PyTorch, ML, Docker, NLP, Pandas, SQL,...
# 3  ЗП не указана                                                NaN
# 4  ЗП не указана  Python, SQL, Обучение и развитие, Data Mining,...

# %%
round((1 - (756 / 974)) * 100, 2)
# Out:
# 22.38

# %% [markdown]
# Количество вакансий DS тоже завышено почти на 23 процента.

# %% [markdown]
# Проверим топ-10 организаций по вакансиям DA после очистки дублей.

# %%
top_emp_da_new = df_da['employer'].value_counts().head(10)
top_emp_da_new = top_emp_da_new.reset_index()
top_emp_da_new.columns = ['employer_new', 'total_new']
top_emp_da_new
# Out:
#                             employer_new  total_new
# 0                                   сбер        132
# 1                            wildberries         26
# 2                         банк втб (пао)         25
# 3                                   ozon         22
# 4                                    мтс         21
# 5                 магнит, розничная сеть         19
# 6  центральный банк российской федерации         15
# 7                                     т1         14
# 8                                   okko         13
# 9                        райффайзен банк         12

# %%
top_emp_da_new['employer_old'] = top_emp_da['employer']
top_emp_da_new['total_old'] = top_emp_da['total']
top_emp_da_new
# Out:
#                             employer_new  total_new  \
# 0                                   сбер        132
# 1                            wildberries         26
# 2                         банк втб (пао)         25
# 3                                   ozon         22
# 4                                    мтс         21
# 5                 магнит, розничная сеть         19
# 6  центральный банк российской федерации         15
# 7                                     т1         14
# 8                                   okko         13
# 9                        райффайзен банк         12
#
#                             employer_old  total_old
# 0                                   СБЕР        243
# 1                            WILDBERRIES         43
# 2                                   Ozon         34
# 3                         Банк ВТБ (ПАО)         28
# 4                                     Т1         26
# 5                 МАГНИТ, Розничная сеть         24
# 6                                    МТС         22
# 7                                   Okko         19
# 8  Центральный банк Российской Федерации         16
# 9                                 Яндекс         15

# %% [markdown]
# С вакансиями DA картина по топ-10 организаций становится совершенно иной. Лидер по прежнему СБЕР - 132, а далее позиции сильно изменились.

# %%
top_emp_ds_new = df_ds['employer'].value_counts().head(10)
top_emp_ds_new = top_emp_ds_new.reset_index()
top_emp_ds_new.columns = ['employer_new', 'total_new']
top_emp_ds_new
# Out:
#      employer_new  total_new
# 0            сбер        120
# 1            ozon         26
# 2     газпромбанк         24
# 3    samokat.tech         19
# 4  банк втб (пао)         16
# 5              т1         12
# 6          молвер         10
# 7     lamoda tech         10
# 8     wildberries         10
# 9          билайн          9

# %%
top_emp_ds_new['employer_old'] = top_emp_ds['employer']
top_emp_ds_new['total_old'] = top_emp_ds['total']
top_emp_ds_new
# Out:
#      employer_new  total_new    employer_old  total_old
# 0            сбер        120            СБЕР        198
# 1            ozon         26            Ozon         36
# 2     газпромбанк         24     Газпромбанк         24
# 3    samokat.tech         19    Samokat.tech         20
# 4  банк втб (пао)         16              Т1         19
# 5              т1         12  Банк ВТБ (ПАО)         18
# 6          молвер         10     WILDBERRIES         16
# 7     lamoda tech         10      Ростелеком         12
# 8     wildberries         10     Lamoda Tech         12
# 9          билайн          9         МегаФон         11

# %% [markdown]
# С вакансиями DS картина по организациям топ-10 более стабильна. Лидеры не изменились, небольшие изменения с 5 по 10 место, но в целом почти не изменилась.

# %% [markdown]
# ### Столбец department

# %% [markdown]
# Столбец представляет собой наименование отдела организации, разместившей вакансию, который получился из названия виджета страницы с вакансией на hh.ru.

# %%
df_da['department'].isna().sum()
# Out:
# 1049

# %%
df_ds['department'].isna().sum()
# Out:
# 469

# %% [markdown]
# 1049 пропусков в DA и 469 пропусков в DS. Не будем заполнять пропуски, информация является дополнительной для предыдущего столбца *'employer'*, из которой можно понять направление аналитики в которой требуется специалист.

# %% [markdown]
# ### Столбец area

# %% [markdown]
# Столбец представляет собой город размещения выкансии, который берут из строки с адресом на странице с вакансией на hh.ru.

# %%
df_da['area'].nunique() # узнаем количество городов
# Out:
# 70

# %%
df_da['area'].sort_values().unique() # выведем уникальные значения
# Out:
# array(['Адыгейск', 'Алтайское', 'Артем', 'Байбек', 'Балашиха', 'Белгород',
#        'Вейделевка', 'Великие Луки', 'Вельск', 'Верхняя Пышма',
#        'Владивосток', 'Владимир', 'Волгоград', 'Воронеж', 'Горно-Алтайск',
#        'Дзержинский', 'Дмитров', 'Екатеринбург', 'Златоуст',
#        'Иваново (Ивановская область)', 'Ижевск', 'Иркутск', 'Казань',
#        'Калининград', 'Кемерово', 'Киров (Кировская область)', 'Королев',
#        'Краснодар', 'Красноярск', 'Курган', 'Липецк', 'Луховицы',
#        'Магнитогорск', 'Майкоп', 'Москва', 'Мытищи', 'Набережные Челны',
#        'Нефтекамск', 'Нижний Новгород', 'Новосибирск', 'Одинцово', 'Омск',
#        'Оренбург', 'Пермь', 'Подольск (Московская область)', 'Псков',
#        'Пушкино (Московская область)', 'Ростов-на-Дону', 'Рязань',
#        'Самара', 'Санкт-Петербург', 'Саратов',
#        'Северск (Томская область)', 'Симферополь', 'Смоленск', 'Сочи',
#        'Ступино', 'Тверь', 'Тольятти', 'Томск', 'Тула', 'Турочак',
#        'Тюмень', 'Ульяновск', 'Уфа', 'Химки', 'Чебоксары', 'Челябинск',
#        'Щербинка', 'Якутск'], dtype=object)

# %%
df_da['area'].value_counts().head(10) # определим топ-10 городов
# Out:
# area
# Москва             921
# Санкт-Петербург    143
# Екатеринбург        39
# Новосибирск         29
# Нижний Новгород     27
# Казань              25
# Владивосток         23
# Краснодар           19
# Ростов-на-Дону       9
# Пермь                9
# Name: count, dtype: int64

# %% [markdown]
# Визуализируем для наглядности.

# %%
plt.figure(figsize=(8,5))
df_da['area'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 городов по количеству вакансий DA', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Города', fontsize=12);

# %%
df_ds['area'].nunique()
# Out:
# 26

# %%
df_ds['area'].sort_values().unique() # выведем уникальные значения
# Out:
# array(['Верхняя Пышма', 'Владивосток', 'Воронеж', 'Екатеринбург',
#        'Ижевск', 'Казань', 'Калининград', 'Краснодар', 'Липецк', 'Москва',
#        'Нижний Новгород', 'Новосибирск', 'Омск', 'Пермь',
#        'Ростов-на-Дону', 'Самара', 'Санкт-Петербург', 'Сочи', 'Таганрог',
#        'Тамбов', 'Томск', 'Тюмень', 'Уфа', 'Челябинск', 'Южно-Сахалинск',
#        'Ярославль'], dtype=object)

# %%
df_ds['area'].value_counts().head(10) # определим топ-10 городов
# Out:
# area
# Москва             580
# Санкт-Петербург     73
# Новосибирск         22
# Екатеринбург        17
# Нижний Новгород     13
# Казань              12
# Томск                5
# Самара               4
# Краснодар            4
# Сочи                 3
# Name: count, dtype: int64

# %% [markdown]
# Визуализируем для наглядности.

# %%
plt.figure(figsize=(8,5))
df_ds['area'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 городов по количеству вакансий DS', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Города', fontsize=12);

# %% [markdown]
# Как уже написано ранее, вакансии по поиску DA размещены в 70 городах, DS - в 26 городах. Аномалий не обнаружено.
# Абсолютные лидеры по вакансиям Москва и Санкт-Петербург, что не удивительно. Далее в топ-10 входят города миллионники областных центров, что тоже не удивительно.

# %% [markdown]
# ### Столбец experience

# %% [markdown]
# Столбец представляет собой требуемый опыт работы, информацию берут из заголовка вакансии на hh.ru.

# %%
df_da['id'].count()
# Out:
# 1381

# %% [markdown]
# Всего 1381 вакансия DA. Посмотрим как они распределены по категориям опыта.

# %%
df_da_exp = df_da['experience'].value_counts().reset_index() # посчитаем количество каждой группы
df_da_exp['part'] = round((df_da_exp['count'] / df_da_exp['count'].sum()) * 100, 2) # отобразим доли
df_da_exp
# Out:
#               experience  count   part
# 0    Junior+ (1-3 years)    830  60.10
# 1     Middle (3-6 years)    422  30.56
# 2  Junior (no experince)    119   8.62
# 3      Senior (6+ years)     10   0.72

# %%
plt.figure(figsize=(8,5))
df_da['experience'].value_counts().plot.bar(color='#176B87')
plt.title('Распределение вакансий DA по опыту', fontsize=15)
plt.xlabel('Требуемый опыт', fontsize=12);

# %%
df_ds['id'].count()
# Out:
# 756

# %% [markdown]
# Всего 756 вакансий DS. Посмотрим как они распределены по категориям опыта.

# %%
df_ds_exp = df_ds['experience'].value_counts().reset_index() # посчитаем количество каждой группы
df_ds_exp['part'] = round((df_ds_exp['count'] / df_ds_exp['count'].sum()) * 100, 2) # отобразим доли
df_ds_exp
# Out:
#               experience  count   part
# 0     Middle (3-6 years)    359  47.49
# 1    Junior+ (1-3 years)    330  43.65
# 2  Junior (no experince)     39   5.16
# 3      Senior (6+ years)     28   3.70

# %%
plt.figure(figsize=(8,5))
df_ds['experience'].value_counts().plot.bar(color='#176B87')
plt.title('Распределение вакансий DS по опыту', fontsize=15)
plt.xlabel('Требуемый опыт', fontsize=12);

# %% [markdown]
# Всего 4 категории: Junior (no experince), Junior+ (1-3 years), Middle (3-6 years), Senior (6+ years). По количеству требуемых специалистов наблюдается принципиальная разница. У DA из 1381 вакансии больше всех требуется Junior+ (1-3 years) - 60 % всезх вакансий, далее в 2 раза меньше Middle (3-6 years) - 30 %, затем Junior (no experince) - 8 % и Senior (6+ years) - менее 1 %.<br>
# А у DS из 756 вакансий почти на одном уровне требуются Middle (3-6 years) - 47 % и  Junior+ (1-3 years) - 43 %, вакансий Junior (no experince) и Senior (6+ years) значительно меньше - 5 % и 3 %.

# %% [markdown]
# ### Столбец key_skills

# %% [markdown]
# Столбец представляет собой списки ключевых навыков, найденные при анализе
# полного текстастраницы  вакансии на hh.ru.

# %%
df_da['key_skills'].unique()
# Out:
# array(["['Power BI', 'СУБД', 'Python', 'SQL']",
#        "['MS SQL', 'Работа с базами данных', 'MS Excel']",
#        "['SQL', 'Power BI', 'СУБД', 'Python', 'Clickhouse', 'BPMN']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'MS Office', 'Управление командой', 'Python', 'Работа с большим объемом информации', 'Навыки презентации', 'Аналитика', 'Умение принимать решения', 'Hadoop', 'Аналитические исследования', 'Pandas', 'Деловая коммуникация', 'Юнит-экономика', 'Нive']",
#        "['Документация']",
#        "['Python', 'SQL', 'Математическая статистика']", '[]',
#        "['Документация', 'Проактивность', 'Коммуникация']",
#        "['Аналитическое мышление']", "['Pandas']",
#        "['Linux', 'SQL', 'Бизнес-анализ', 'Hadoop', 'Big Data', 'Data Scientist', 'PostgreSQL', 'Аналитическое мышление', 'MS SQL', 'DataLens', 'Аналитика', 'Статистический анализ', 'Spark', 'Английский язык', 'Python', 'Data Analysis', 'Data Mining', 'QlikView', 'Обучение и развитие']",
#        "['Linux', 'SQL', 'поведение пользователей', 'Data Scientist', 'Dask', 'PostgreSQL', 'Google AdWords', 'Facebook', 'LTV', 'Pandas', 'MS Excel', 'AppsFlyer', 'Apple Search Ads', 'pandas', 'Автоматизация ETL', 'b2c', 'Python', 'sklearn', 'Airflow']",
#        "['Анализ данных', 'Проактивность', 'SQL', 'Python', 'Airflow', 'Прогнозирование', 'BigQuery', 'Базы данных']",
#        "['Английский язык', 'MS SQL', 'SQL', 'Power BI', 'Python', 'Data Analysis', 'ETL', 'Pandas', 'Базы данных']",
#        "['Анализ данных', 'MS SQL', 'Python', 'Работа с большим объемом информации', 'Аналитика', 'Tableau', 'Pandas', 'MS Excel', 'Аналитическое мышление']",
#        "['confluence', 'Документация']",
#        "['Python', 'Коммуникация', 'SQL', 'Торговая площадка']",
#        "['Python', 'SQL', 'Маркетплейс']",
#        "['SQL', 'Python', 'Математическая статистика', 'Pandas', 'Торговая площадка']",
#        "['SQL', 'A/B тесты', 'Python', 'Data Analysis', 'BI']", "['SQL']",
#        "['Deep Learning', 'PyTorch', 'Python', 'OpenCV', 'Аналитическое мышление']",
#        "['Анализ данных', 'Администрирование базы данных', 'Аналитика', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'Статистический анализ', 'SQL', 'Математическая статистика']",
#        "['SQL-запросы', 'JIRA', 'Python']", "['Power BI', 'SQL', 'DWH']",
#        "['SQL', 'DAX', 'Работа с базами данных', 'MS Excel', 'VBA']",
#        "['Аналитическое мышление', 'Креативность']",
#        "['Анализ данных', 'Визуализация данных', 'Подготовка презентаций', 'Аналитика', 'Системное мышление', 'Прогнозирование', 'MS Excel', 'Аналитическое мышление', 'Планирование', 'Математический анализ']",
#        "['MS SQL', 'витрины данных', 'Phyton', 'Анализ бизнес показателей']",
#        "['Numpy', 'Python', 'pandas', 'Data Analysis', 'Pandas']",
#        "['репутационный маркетинг', 'WEB аналитика', 'Сбор и анализ информации', 'Маркетинговый анализ', 'Яндекс.Метрика', 'Google Analytics']",
#        "['Python', 'Документация', 'SQL']",
#        "['Анализ данных', 'Коммуникация', 'Сбор и анализ информации', 'Работа с большим объемом информации', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['SQL', 'Бизнес-анализ', 'Постановка задач разработчикам', 'Системное мышление', 'Аналитическое мышление', 'BPMN']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Статистический анализ', 'DAX', 'Математическая статистика']",
#        "['SQL', 'Power BI', 'Python', 'Аналитика', 'Tableau']",
#        "['Анализ данных', 'SQL', 'СУБД', 'Python', 'Сбор и анализ информации', 'Умение принимать решения', 'Математическая статистика', 'Аналитические исследования', 'Прогнозирование', 'Аналитическое мышление', 'PostgreSQL', 'Дашборды']",
#        "['Коммуникация', 'SQL', 'Документация', 'Greenplum', 'Hadoop', 'ETL', 'Airflow', 'DWH']",
#        "['Анализ данных', 'MS PowerPoint', 'Визуализация данных', 'SQL', 'Подготовка презентаций', 'Исследования рынка', 'Работа с большим объемом информации', 'Сбор и анализ информации', 'Power Query', 'Анализ рынка', 'Статистический анализ', 'MS Excel', 'VBA']",
#        "['Machine Learning', 'Python', 'SQL', 'Big Data']",
#        "['confluence']", "['Python', 'SQL']",
#        "['Анализ данных', 'SQL', 'Python', 'Data Analysis', 'Аналитика', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Data Science', 'Python', 'R', 'confluence', 'Pandas']",
#        "['Документация', 'MS SQL', 'Коммуникация', 'SQL']",
#        "['Numpy', 'Анализ данных', 'Коммуникация', 'Метрики оценки моделей', 'Python', 'pandas', 'NLP', 'Pandas', 'Scikit-learn', 'Машинное обучение', 'LLM']",
#        "['SQL', 'СУБД', 'Python', 'Документация', 'Аналитика', 'confluence', 'ETL', 'Pandas']",
#        "['SQL', 'Работа с базами данных', 'Базы данных']",
#        "['Коммуникация']",
#        "['SQL', 'ETL', 'Oracle Pl/SQL', 'Qlik Sense', 'PL/pgSQL', 'Базы данных']",
#        "['Machine Learning', 'Проактивность', 'SQL', 'Python', 'Data Analysis', 'Greenplum', 'ETL', 'Spark', 'Аналитическое мышление', 'PostgreSQL']",
#        "['Анализ данных', 'SQL', 'Power BI', 'MS Excel', 'Аналитическое мышление']",
#        "['SQL', 'Python', 'Data Analysis', 'Аналитика', 'Big Data', 'Работа с базами данных', 'Аналитическое мышление', 'Data Analyst', 'PostgreSQL']",
#        "['Аналитика по клиентам', 'Бизнес-анализ', 'Сводные таблицы', 'Деловая переписка', 'Управление бизнес процессами', 'Бюджетирование', 'Гигиена Клиентской Базы', 'ВПР', 'Управление бюджетом', 'Google Analytics', 'Планирование продаж', 'Стратегическое мышление']",
#        "['Аналитическое мышление', 'Работа с большим объемом информации', 'умение работать с программами Word, Excel, Power Point', 'Формирование отчетности']",
#        "['SQL', 'Python', 'Документация', 'MS Excel', 'MS SQL Server', 'Аналитическое мышление', 'PostgreSQL']",
#        "['Анализ данных', 'SQL', 'Бизнес-анализ', 'Power BI', 'Python', 'Адаптивность']",
#        "['ORM', 'Работа с системами аналитики', 'Подготовка презентаций', 'SMM', 'SERM', 'Excel', 'Internet Marketing', 'Русский язык', 'Аналитическое мышление']",
#        "['SQL', 'Python', 'Документация', 'Hadoop', 'Витрины данных', 'Управленческая отчетность']",
#        "['MS SQL', 'MS PowerPoint', 'Анализ данных', 'Финансовый анализ', 'План-фактный анализ бюджета', 'Финансовая отчетность', 'Анализ текущих финансовых показателей', 'Аналитический склад ума', 'Финансовый менеджмент', 'Точность и внимательность к деталям', 'Аналитические исследования', 'Финансовое планирование', 'Управленческая отчетность']",
#        "['Работа в условиях многозадачности', 'Работа в команде', 'Коммуникабельность, ответственность', 'Умение работать в команде', 'Ответственность и пунктуальность', 'Умение легко находить контакт с людьми', 'Ведение документации', 'Способность эффективно решать проблемы', 'Пользователь ПК', 'внимательность к деталям, умение работать с большими объемами информации', 'оформление документации']",
#        "['Креативность', 'Работа с большим объемом информации', 'Желание зарабатывать', 'Аналитическое мышление', 'Аналитические навыки']",
#        "['Анализ данных', 'Cистемы управления базами данных', 'SQL', 'Бизнес-анализ', 'Internet', 'Аналитика', 'Аналитические исследования', 'Аналитическое мышление', 'Работа со СМИ']",
#        "['SQL', 'API', 'Python', 'Документация', 'confluence', 'ETL', 'DWH', 'PostgreSQL', 'Базы данных']",
#        "['Анализ данных', 'SQL', 'Python', 'Сбор и анализ информации', 'Pandas', 'Работа с базами данных', 'Базы данных']",
#        "['MS SQL', 'SQL', 'Power BI', 'витрины данных', 'OLAP инструменты', 'FSD', 'Работа с большим объемом информации', 'olap-кубы', 'Документация', 'Hadoop', 'Tableau', 'Тестирование', 'Superset', 'UAT', 'FAT', 'Управленческая отчетность', 'GreenPlum']",
#        "['MS SQL', 'Статистический анализ', 'Математическая статистика', 'MS Excel', 'Аналитическое мышление']",
#        "['Коммуникация', 'SQL', 'Python', 'pandas', 'Pandas']",
#        "['Проактивность', 'SQL', 'Python', 'BI', 'confluence', 'Tableau', 'ETL', 'Аналитические исследования']",
#        "['База данных: Oracle', 'MS SQL', 'Анализ данных', 'SQL', 'Oracle Pl/SQL', 'Маркетинговый анализ', 'ORACLE', 'Аналитическое мышление', 'PostgreSQL']",
#        "['Аналитика продаж', 'SQL', 'Коммуникация', 'Python', 'Аналитика данных', 'confluence', 'Tableau']",
#        "['Аналитическое мышление', 'Python', 'SQL']",
#        "['MDM', 'Бизнес-анализ', 'Документация', 'Data Analysis', 'Data management', 'meta данные']",
#        "['SQL', 'Бизнес-анализ', 'Презентация результатов', 'dashboard', 'Статистика', 'Внимание к деталям', 'Анализ рынка', 'Tableau', 'Прогнозирование', 'Решение проблем', 'Data Warehousing', 'Статистический анализ', 'Аналитические исследования', 'Английский язык', 'Коммуникация', 'Power BI', 'Python', 'Data Analysis', 'Analysis', 'EDA', 'Юнит-экономика']",
#        "['Аналитическое мышление', 'Python', 'Анализ данных', 'SQL']",
#        "['SQL', 'Python', 'Data Analysis', 'ALM', 'Казначейство']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Python', 'Data Analysis', 'Аналитика', 'Аналитические исследования', 'Работа с базами данных', 'Базы данных']",
#        "['Python', 'MySQL', 'Документация', 'Data Analysis', 'ETL', 'Pandas']",
#        "['Анализ данных', 'SQL', 'Python', 'confluence', 'Pandas', 'Работа с базами данных', 'Big Data']",
#        "['Аналитика продаж', 'SQL', 'Power BI', 'Python', 'Работа с большим объемом информации', 'Аналитический склад ума', 'ETL']",
#        "['SQL', 'A/B тесты', 'Python', 'Документация', 'confluence', 'Pandas']",
#        "['Проактивность', 'Коммуникация', 'SQL', 'ad-hoc', 'A/B тесты', 'Python', 'LTV', 'ETL', 'PostgreSQL']",
#        "['Анализ данных', 'SQL', 'PostgreSQL']",
#        "['SQL', 'Python', 'confluence', 'Pandas', 'Информационная безопасность']",
#        "['1С: Предприятие 8', 'MS PowerPoint', 'Финансовый анализ', 'Финансовая отчетность', 'Подготовка презентаций', 'Анализ текущих финансовых показателей', 'Финансовый менеджмент', 'Аналитическое мышление', 'Управленческая отчетность', 'Внутренний финансовый аудит']",
#        "['SQL', 'Android', 'Data Mining', 'Прогнозирование', 'Анализ бизнес показателей', 'VBA']",
#        "['Python', 'Статистический анализ', 'Математическая статистика', 'Прогнозирование', 'Обучение и развитие', 'Математический анализ']",
#        "['Аналитическое мышление', 'Информационные технологии', 'Документация', 'Работа с базами данных']",
#        "['Анализ данных', 'MS Power BI', 'Исследования рынка', 'Power BI', 'Работа с большим объемом информации', 'Анализ рынка', 'Аналитические исследования', 'Аналитическое мышление', 'Анализ конкурентной среды', 'Базы данных']",
#        "['Анализ данных', 'SQL', 'Python', 'Аналитические исследования', 'Pandas', 'Аналитическое мышление']",
#        "['Анализ данных', 'Деловая переписка', 'Работа с большим объемом информации', 'Сбор и анализ информации', '1С', 'MS Excel', 'Аналитическое мышление']",
#        "['Python', 'Коммуникация', 'SQL', 'PostgreSQL']",
#        "['Коммуникация', 'Pandas']",
#        "['Анализ данных', 'SQL', 'MS Excel', 'LR', 'Создание дашбордов', 'Выстраивание метрик']",
#        "['Анализ данных', 'Cистемы управления базами данных', 'Google Sheets', 'Работа с базами данных', 'Маркетинговый анализ']",
#        "['Решение проблем', 'Критическое мышление', 'Коммуникация', 'Внимание к деталям']",
#        "['Бизнес-анализ', 'Деловая переписка', 'Навыки межличностного общения', 'Сбор и анализ информации', 'Маркетинговый анализ', 'Организация мероприятий', 'Анализ данных', 'Проведение опросов', 'Электронная почта', 'Ведение переписки', 'Оперативный поиск информации в сети Интернет', 'Анализ продаж', 'Проведение телефонных интервью', 'Деловое общение', 'Деловая коммуникация', 'Корпоративная этика', 'Аналитическое мышление', 'Управленческая отчетность', 'Подготовка отчетов', 'Аналитика', 'Навыки составления отчетности', 'Точность и внимательность к деталям', 'Работа с базами данных', 'Базы данных', 'Исследования рынка']",
#        "['Документация', 'Pandas']", "['A/B тесты', 'Python', 'SQL']",
#        "['MS SQL', 'Анализ данных', 'Python', 'Qlik', 'Oracle BI', 'PostgreSQL']",
#        "['Проактивность', 'aiohttp', 'SQL', 'MongoDB', 'Python', 'Сбор и анализ информации', 'NoSQL', 'Clickhouse', 'Elastic', 'Pandas', 'Работа с базами данных', 'Big Data', 'FastAPI']",
#        "['Английский язык', 'MS SQL', 'SQL', 'Python', 'confluence', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['Анализ данных', 'MS PowerPoint', 'Сбор и анализ информации', 'Работа с большим объемом информации', 'MS Excel', 'Анализ бизнес показателей']",
#        "['Linux', 'Python', 'Анализ данных']",
#        "['Аналитическое мышление', 'Pandas']",
#        "['MS PowerPoint', 'Работа в команде', 'SQL', 'MS Visio', 'сводные таблицы', 'Python', 'MS Access', 'Maplnfo Professional', 'Навыки презентации', 'Google Sheets', 'многозадачность', 'Аналитические исследования', 'MS Excel', 'Аналитическое мышление']",
#        "['Numpy', 'Python', 'pandas', 'ETL', 'Pandas', 'Big Data', 'Prometheus', 'Gitlab', 'Graphana', 'PostgreSQL', 'Git']",
#        "['MS SQL', 'Визуализация данных', 'DataLens', 'Сводные таблицы', 'Power BI', 'Python', 'Теория вероятности', 'R', 'Tableau', 'Математическая статистика', 'MS Excel', 'VBA']",
#        "['Проактивность', 'Python', 'SQL', 'VBA']",
#        "['MS PowerPoint', 'Работа в команде', 'Документация', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'MS Office', 'Организаторские навыки', 'Python', 'Работа с большим объемом информации', 'Pandas', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Бизнес-анализ', 'Python', 'Документация', 'Аналитика', 'confluence', 'Математическая статистика', 'Работа с базами данных', 'Аналитическое мышление', 'Базы данных']",
#        "['Коммуникация', 'SQL', 'A/B тесты', 'confluence', 'Data Analyst']",
#        "['MS PowerPoint', 'Визуализация данных', 'Коммуникация', 'Бизнес-анализ', 'Power BI', 'Аналитика']",
#        "['Анализ данных', 'SQL', 'MS Power BI', 'Документация', 'Data Analysis', 'Power Query', 'DAX', 'Аналитические исследования', 'Big Data', 'DWH']",
#        "['Проактивность', 'Коммуникация']", "['confluence', 'Pandas']",
#        "['Проактивность', 'Python', 'Аналитическое мышление', 'SQL']",
#        "['MS SQL', 'Статистический анализ', 'Аналитические исследования', 'Работа с базами данных']",
#        "['Анализ данных', 'Power BI', 'MS Power BI', 'Работа с большим объемом информации', 'Работа с базами данных', 'MS Excel']",
#        "['Python', 'Документация', 'SQL', 'Pandas']",
#        "['MS PowerPoint', 'SQL', 'Креативность', 'MS Excel', 'Аналитическое мышление', 'Базы данных']",
#        "['MS SQL', 'Коммуникация', 'A/B тесты', 'Python', 'Data Analysis', 'Black box testing', 'Google Data Studio', 'Jupyter Notebook']",
#        "['Документация', 'SQL', 'DWH']",
#        "['Анализ данных', 'Проактивность', 'Коммуникация', 'SQL', 'Бизнес-анализ', 'Python', 'Маркетплейс', 'Pandas', 'Торговая площадка']",
#        "['Анализ данных', 'SQL', 'Работа с большим объемом информации', 'Аналитика', 'Работа с базами данных', 'Базы данных']",
#        "['SQL', 'Power BI', 'A/B тесты', 'Python', 'Анализ продаж', 'ML', 'Аналитические исследования', 'Факторный анализ']",
#        "['Анализ данных', 'Аналитические способности', 'Python', 'Аналитическое мышление', 'Управление проектами']",
#        "['Английский язык', 'Аналитика продаж', 'Анализ ассортиментной линейки', 'Организаторские навыки', 'Сбор и анализ информации', 'Аналитика', 'Аналитическое мышление', 'Руководство коллективом', 'Юнит-экономика', 'Базы данных']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Python', 'Tableau', 'Работа с базами данных']",
#        "['A/B тесты', 'Tableau', 'SQL']",
#        "['Переговоры', 'Документация']",
#        "['MS SQL', 'MS PowerPoint', 'Анализ данных', 'SQL', 'Базы данных', 'Проактивность', 'MS Visio', 'Подготовка презентаций', 'Работа с большим объемом информации', 'Статистический анализ', 'Access', 'Прогнозирование', 'Подготовка отчетов', 'Аналитическое мышление', 'аналитика данных', 'Oracle Siebel CRM', 'Математический анализ', 'VBA']",
#        "['MS SQL', 'Анализ данных', 'SQL', 'MS Excel']",
#        "['Анализ данных', 'Python', 'SQL']",
#        "['MS PowerPoint', 'Power Pivot', 'SQL', 'Аналитика', 'Power Query', 'Макросы', 'Qlik Sense']",
#        "['ETL', 'Документация', 'SQL', 'DWH']",
#        "['Английский язык', 'SQL', 'A/B тесты', 'Data Analysis', 'Pandas', 'PostgreSQL']",
#        "['Коммуникация', 'Power Pivot', 'SQL', 'Power BI', 'Python', 'Power Query', 'Olap (online analytical processing)', 'VBA']",
#        "['Анализ данных', 'SQL', 'оптимизация', 'Сбор и анализ информации', 'Анализ текущих финансовых показателей', 'Power Query', 'А/Бх тесты', 'Математическая статистика', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'Работа в условиях многозадачности', 'Работа в команде', 'SQL', 'Финансовый анализ', 'Продвинутый пользователь ПК', 'Грамотная речь и письмо', 'Google Docs', 'Работа с большим объемом информации', 'Google таблицы', 'Аналитика', 'GExcel', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Сводные таблицы', 'Бизнес-анализ', 'Google Docs', 'Системное мышление', 'Работа с базами данных', 'Анализ бизнес показателей', 'Аналитическое мышление']",
#        "['Торговая площадка', 'SQL', 'Python', 'Маркетплейс']",
#        "['Python', 'SQL', 'JavaScript', 'Docker']",
#        "['Knime', 'Анализ данных', 'SQL', 'Python', 'MS Excel']",
#        "['Способность к саморазвитию', 'Инициативность и лидерство', 'Критическое мышление', 'Коммуникативная гибкость', 'Системность мышления']",
#        "['R', 'Python', 'Data Analysis']",
#        "['Apache Spark', 'Atlassian Confluence', 'SQL', 'Python', 'Atlassian Jira', 'Greenplum', 'confluence', 'Pandas']",
#        "['Анализ данных', 'MS SQL', 'SQL', 'MS Power BI', 'Python', 'Atlassian Jira', 'confluence', 'Tableau', 'GreenplumDB', 'Анализ бизнес показателей']",
#        "['Power BI', 'Аналитическое мышление', 'Анализ данных', 'Юнит-экономика']",
#        "['Анализ данных', 'SQL', 'Python', 'Работа с большим объемом информации', 'Математическая статистика', 'Pandas']",
#        "['Работа с большим объемом информации', 'MS Excel', 'Аналитика']",
#        "['Machine Learning', 'SQL', 'Python', 'Hadoop', 'Spark', 'Big Data']",
#        "['Документация', 'SQL', 'Pandas', 'DataLense']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Python', 'Документация', 'Data Analysis', 'pandas', 'Математическое моделирование', 'Pandas']",
#        "['Юнит-экономика']", "['MS SQL', 'confluence']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Power BI', 'Python', 'Документация', 'AirFlow', 'Математическая статистика', 'MS Excel']",
#        "['Numpy', 'SQL', 'PowerBI', 'Power BI', 'A/B тесты', 'Python', 'Seaborn', 'pandas', 'BI', 'Статистический анализ', 'Математическая статистика', 'Pandas', 'Matplotlib']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Tableau', 'Аналитические исследования', 'Работа с базами данных']",
#        "['Сбор и анализ информации', 'Сводные таблицы', 'Работа в Excel']",
#        "['SQL', 'MS Power BI', 'Работа с большим объемом информации', 'Сбор и анализ информации', 'Аналитика', 'Автоматизация', 'Аналитические исследования', 'MS Excel', 'Анализ бизнес показателей', 'Базы данных']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'PowerBI', 'Power BI', 'MS Power BI', 'Работа с большим объемом информации', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['Проактивность', 'Документация', 'Pandas', 'Креативность']",
#        "['SQL', 'PySpark', 'Python', 'Hadoop', 'confluence', 'Spark']",
#        "['MS Excel (VBA, Power Query), Python', 'Документация']",
#        "['Анализ данных', 'SQL', 'Python', 'MS Excel', 'Подбор контента', 'Контент-анализ', 'Наставничество']",
#        "['Знание MS Office', 'Государственные закупки', '223-ФЗ', 'Закупки', 'подготовка документов для участия в тендерах', 'Документация', 'Ответственность и пунктуальность', 'Математический склад ума', 'MS Excel', '44-ФЗ', 'Аналитическое мышление', 'Тендеры', 'Работа с документами']",
#        "['Python', 'Документация', 'Oracle Pl/SQL', 'DWH', 'Аналитическое мышление', 'BPMN']",
#        "['Анализ данных', 'SQL', 'Python', 'Адаптивность', 'Pandas']",
#        "['Анализ данных', 'SQL', 'A/B тесты', 'Python', 'pandas', 'Clickhouse', 'Pandas', 'Проведение экспериментов', 'Прогнозирование']",
#        "['Business Intelligence Systems', 'Teradata', 'SQL', 'Базы данных', 'Документация', 'Docker', 'Hadoop', 'ORACLE', 'CRM', 'GreenPlam']",
#        "['Анализ данных', 'SQL', 'Бизнес-анализ', 'Power BI', 'Аналитическое мышление']",
#        "['Аналитическое мышление', 'Документация', 'Data Vault', 'DWH']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Arenadata', 'MS Outlook', 'Работа с большим объемом информации', 'Greenplum', 'Data Analysis', 'Аналитика', 'Работа с базами данных', 'MS Excel', 'КХД', 'Аналитическое мышление', 'корпоративное хранилище данных', 'PostgreSQL', 'Базы данных']",
#        "['Анализ данных', 'SQL', 'Бизнес-анализ', 'Python', 'Работа с большим объемом информации', 'Data Analysis', 'Сбор и анализ информации', 'Аналитика']",
#        "['Анализ данных', 'Аналитика', 'Аналитические исследования', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['SQL', 'Python', 'Документация', 'Airflow', 'PostgreSQL', 'Базы данных']",
#        "['SQL', 'Matolib', 'Классическое машинное обучение', 'Python', 'pandas', 'Pandas', 'Scikit-learn']",
#        "['Анализ данных', 'SQL', 'Python', 'Hadoop', 'Spark', 'Big Data']",
#        "['SQL', 'Power BI', 'Python', 'MS Excel', 'Юнит-экономика']",
#        "['Анализ данных', 'SQL', 'data analyst', 'Big Data', 'PostgreSQL']",
#        "['SQL', 'Ad Hoc Analysis', 'A/B тесты', 'Power BI', 'Python', 'Data Analysis', 'Mathematical Statistics']",
#        "['SQL', 'WEB аналитика', 'Clickhouse', 'Яндекс.Метрика', 'Аналитическое мышление']",
#        "['Анализ данных', 'DMBOK DAMA', 'Data Governance', 'Business Glossary', 'Data Catalog']",
#        "['confluence', 'SQL', 'Анализ рисков', 'аналитика данных']",
#        "['Linux', 'SQL', 'Python', 'Поиск аномалий', 'Clickhouse', 'BI', 'HTTP', 'Математическая статистика', 'Pandas', 'Анализ временных рядов', 'Git']",
#        "['SQL', 'СУБД', 'Data Analysis', 'BI', 'Решение проблем']",
#        "['Teradata', 'SQL', 'Документация', 'Greenplum', 'Hadoop', 'Витрины данных', 'Airflow', 'DWH', 'Informatica']",
#        "['Teradata', 'SQL', 'Документация', 'Greenplum', 'Hadoop', 'Витрины данных', 'Airflow', 'DWH']",
#        "['Аналитическое мышление', 'SQL', 'Финансовая отчетность', 'Бизнес-анализ']",
#        "['Грамотная речь', 'MS PowerPoint', 'Аналитика продаж', 'Деловая переписка', 'Документация', 'Проведение презентаций', 'MS Excel', 'Пользователь ПК', 'Olap (online analytical processing)', 'Работа в команде', 'MS Access', 'Работа с большим объемом информации', 'Консультирование', 'MS Project', 'Английский язык', 'Business Intelligence Systems', 'MS Outlook', 'База данных: Olap', 'Управление проектами']",
#        "['Анализ данных', 'Pandas']",
#        "['A/B тесты', 'confluence', 'Python', 'SQL']",
#        "['Анализ данных', 'MS PowerPoint', 'MS SQL', 'Работа с большим объемом информации', 'Аналитика', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'MS PowerPoint', 'Планирование и организация', 'Excel', 'Умение работать в условиях многозадачности', 'Аналитические навыки']",
#        "['MS PowerPoint', 'SQL', 'Бизнес-анализ', 'Power BI', 'Python', 'Аналитические исследования', 'MS Excel']",
#        "['SQL', 'PowerBI', 'Power BI', 'MS Power BI', 'Python', 'PostgreSQL', 'DAX', 'Tableau', 'ORACLE', 'MS SQL Server', 'BigQuery']",
#        "['Power BI', 'Python', 'Коммуникация', 'SQL']",
#        "['Tableau', 'SQL', 'Python']",
#        "['MS SQL', 'MS PowerPoint', 'Анализ данных', 'SQL', 'MS Access', 'Документация', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Python', 'Работа с большим объемом информации', 'Clickhouse', 'Аналитика', 'Tableau', 'Яндекс.Метрика', 'Google Analytics']",
#        "['Анализ данных', 'SQL', 'Документация', 'Умение принимать решения', 'Статистический анализ', 'MS Excel', 'CRM', 'Базы данных']",
#        "['Sas', 'MS SQL', 'Анализ данных', 'Портфельные риски', 'SQL', 'Анти фрод', 'кредитные риски', 'Python', 'Anti-fraud', 'Сбор и анализ информации', 'Риск-менеджмент', 'Анализ рисков', 'BI', 'Аналитика', 'Оценка рисков', 'Математическая статистика', 'Аналитическое мышление', 'Математический анализ']",
#        "['Анализ данных', 'MS PowerPoint', 'Коммуникация', 'Сводные таблицы', 'Подготовка презентаций', 'Работа с большим объемом информации', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'MS PowerPoint', 'SQL', 'Power BI', 'Data Analysis', 'Статистический анализ', 'Аналитические исследования', 'Big Data', 'Работа с базами данных']",
#        "['MS SQL', 'Анализ данных', 'Проактивность', 'Power BI', 'Python', 'Сбор и анализ информации']",
#        "['MS SQL', 'SQL', 'Бизнес-анализ', 'Работа с большим объемом информации', 'Анализ рисков', 'Аналитика', 'Витрины', 'Работа с базами данных', 'MS Excel', 'MS SQL Server', 'Базы данных']",
#        "['Решение проблем', 'Принятие решений', 'Юнит-экономика']",
#        "['SQL', 'Python', 'Data Analysis', 'Spark', 'Big Data']",
#        "['MS SQL', 'Коммуникация', 'Arenadata', 'ETL Framework', 'Python', 'MS Outlook', 'Greenplum', 'AirFlow', 'Jupyter Hab', 'MS Excel', 'КХД', 'Аналитическое мышление', 'корпоративное хранилище данных', 'PostgreSQL']",
#        "['Python', 'SQL', 'Математическая статистика', 'Математический анализ']",
#        "['SQL', 'Power BI', 'Python', 'Data Analysis', 'confluence', 'Работа с базами данных']",
#        "['Анализ данных', 'SQL', 'Работа с базами данных', 'PostgreSQL']",
#        "['1С: Предприятие 8', 'Анализ данных', 'Многозадачность', 'Работа с большим объемом информации', 'Excel', 'MS Excel']",
#        "['дашборд', 'Анализ данных', 'Аналитическое мышление', 'Работа с большим объемом информации', 'Сбор и анализ информации', 'Аналитика', 'MS Excel', 'SQL-запросы', 'Базы данных', 'VBA']",
#        "['MS SQL', 'Teradata Studio', 'SQL', 'Работа с большим объемом информации', 'Informatica']",
#        "['MS SQL', 'SQL', 'Анализ ассортиментной линейки', 'Python', 'Работа с большим объемом информации', 'Аналитика', 'Управление товарными запасами', 'Аналитические исследования', 'Прогнозирование']",
#        "['Анализ данных', 'Проактивность', 'SQL', 'Python', 'Сбор и анализ информации', 'Data Analysis', 'Математическая статистика', 'Аналитические исследования', 'Big Data', 'Pandas', 'Математический анализ', 'Базы данных']",
#        "['Power BI', 'Работа с большим объемом информации', 'SQL', 'Power Query']",
#        "['SQL', 'Антифрод', 'Power BI', 'Python', 'A/B тесты', 'Tableau']",
#        "['Проактивность']",
#        "['Hadoop', 'Python', 'SQL', 'Математическая статистика']",
#        "['SQL', 'Alteryx', 'Power BI', 'Visiology', 'UML', 'MS Visio', 'Документация', 'Loginom', 'NiFi', 'BI', 'Alation', 'ETL', 'confluence', 'OpenMetaData']",
#        "['Поиск информации в интернет', 'Сбор и анализ информации', 'Работа с большим объемом информации', 'Знание Excel', 'Аналитическое мышление', '1C: Предприятие', 'Работа с документами']",
#        "['Анализ данных', 'SQL', 'план счетов', 'MS Office', 'Power BI', 'Python', 'Аналитика', 'BI', 'Arendata', 'Hadoop', 'MS Excel', 'корпоративное хранилище данных', 'Отчетность']",
#        "['1С: Предприятие 8', '1С: Торговля', 'Документация', 'MS Excel', 'Аналитическое мышление', 'CRM', '1С: Документооборот']",
#        "['Анализ данных', 'SQL', 'Работа с базами данных']",
#        "['MS SQL', 'Анализ данных', 'Документация', 'Аналитические исследования', 'MS Excel', 'Анализ бизнес показателей', 'Аналитическое мышление', 'Переговоры']",
#        "['SQL', 'Ad Hoc Analysis', 'Python', 'Data Analysis', 'Аналитические исследования']",
#        "['Numpy', 'SQL', 'Python', 'Статистический анализ', 'Математическая статистика', 'Pandas', 'Прогнозирование', 'MS Excel']",
#        "['Анализ данных', 'Коммуникация', 'Управление командой', 'Python', 'Data Analysis', 'Java']",
#        "['Анализ данных', 'MS SQL', 'WEB аналитика', 'Аналитические исследования', 'Маркетинговый анализ']",
#        "['SQL', 'MS Excel']",
#        "['Деловая коммуникация', 'MS PowerPoint', 'SQL', 'Работа с большим объемом информации']",
#        "['SQL', 'A/B тесты', 'Python', 'Математическая статистика', 'Big Data', 'Spark']",
#        "['Пусконаладочные работы', 'Оформление описаний', 'Python', 'Документация', 'Понимание задач регрессии', 'Математическое моделирование', 'Машинное обучение', 'Системы автоматического контроля', 'Создание моделей']",
#        "['Python', 'SQL', 'Pandas']",
#        "['Анализ данных', 'Python', 'SQL', 'FineBI']",
#        "['SQL', 'Python', 'Pandas', 'Математическая статистика', 'Математический анализ']",
#        "['Debezium', 'Коммуникация', 'SQL', 'Metabase', 'Datalens', 'Python', 'Clickhouse', 'Airflow', 'PostgreSQL']",
#        "['Pandas', 'Google Sheets']",
#        "['Работа в команде', 'SQL', 'Power BI', 'Python', 'DAX', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Работа с большим объемом информации', 'Data Analysis', 'Сбор и анализ информации', 'Tableau', 'Аналитические исследования', 'Прогнозирование', 'Анализ бизнес показателей', 'Аналитическое мышление']",
#        "['Анализ данных', 'MS SQL', 'Работа в условиях многозадачности', 'Power BI', 'Tableau']",
#        "['PowerBI', 'A/B тесты', 'Python', 'Pandas', 'ClickHouse', 'PostgreSQL']",
#        "['Анализ данных', 'SQL', 'Python', 'Документация', 'Статистика', 'Аналитическое мышление', 'airflow', 'Юнит-экономика', 'Git']",
#        "['ArcGIS QGIS Git/Gitlab Python пространственные базы данных Agile']",
#        "['Грамотная речь', 'Первичные документы', 'Работа в команде', 'Поиск информации в интернет', 'Статистика', 'Excel', 'Работа с базами данных', 'Пользователь ПК']",
#        "['Коммуникация', 'SQL', 'Бизнес-анализ', 'API', 'Документация', 'Работа с большим объемом информации', 'Postman', 'Разработка технических заданий', 'Clickhouse', 'SOAPUI', 'Работа с базами данных', 'Базы данных']",
#        "['Коммуникация', 'MS Excel']", "['MS SQL', 'SQL']",
#        "['SQL', 'Power BI', 'Metabase', 'Python', 'Аналитика', 'Финансовая аналитика', 'Airflow', 'Pandas']",
#        "['Анализ данных', 'SQL', 'MS Access', 'Python', 'Документация', 'Аналитическое мышление', 'Базы данных']",
#        "['MS PowerPoint', 'SQL', 'Бизнес-анализ', 'Сбор и анализ информации', 'Анализ бизнес показателей', 'Анализ данных', 'Аналитические способности', 'СУБД', 'Анализ рынка', 'Прогнозирование', 'Аналитическое мышление', 'Управленческая отчетность', 'MS SQL', 'Подготовка презентаций', 'Работа с большим объемом информации', 'Аналитика', 'Точность и внимательность к деталям', 'Аналитические исследования', 'Работа с базами данных', 'Коммуникация']",
#        "['confluence', 'Аналитическое мышление']",
#        "['MS SQL', 'MS Excel']", "['1С:']",
#        "['Tensorflow', 'PyTorch', 'NLP', 'BERT', 'GPT', 'LLM']",
#        "['MS SQL', 'Бизнес-анализ', 'Финансовый анализ', 'Power BI', 'Python', 'Аналитика', 'Power Query', 'Статистический анализ', 'Tableau', 'Аналитические исследования', 'Работа с базами данных', 'Прогнозирование']",
#        "['Анализ данных', 'Составление отчетности', 'Работа с большим объемом информации', 'Аналитика', 'Деловая коммуникация', 'Аналитическое мышление', 'Навыки переговоров', 'Математический анализ', 'Базы данных']",
#        "['SQL', 'Power BI', 'MS Power BI', 'Python', 'Аналитическое мышление']",
#        "['Английский язык', 'Анализ данных', 'Python', 'SQL']",
#        "['SQL', 'Google Sheets', 'MS Excel']",
#        "['Анализ данных', 'Аналитическое мышление', 'SQL', 'Работа с базами данных']",
#        "['Документация', 'confluence', 'Коммуникация', 'Pandas']",
#        "['BI', 'SQL']",
#        "['MS SQL', 'SQL', 'Бизнес-анализ', 'Power BI', 'Работа с базами данных']",
#        "['pyspark', 'Numpy', 'requests', 'Python', 'Clickhouse', 'Docker', 'Pandas', 'Spark', 'PostgreSQL', 'Celery']",
#        "['Английский язык', 'Excel', 'Работа в команде', 'Подготовка презентаций']",
#        "['MS SQL', 'Анализ данных', 'SQL', 'Документация', 'Аналитика', 'Работа с базами данных', 'MS Excel']",
#        "['SQL', 'PySpark', 'Python', 'AirFlow', 'Hadoop', 'confluence', 'Аналитические исследования', 'Работа с базами данных', 'Spark']",
#        "['Анализ данных', 'SQL', 'Power BI', 'MS Excel', 'Аналитическое мышление', 'Базы данных']",
#        "['MS SQL', 'Анализ данных', 'Информационные технологии', 'SQL', 'Power BI', 'MS Power BI', 'Tableau', 'Java', 'Работа с базами данных', 'Умение работать в коллективе', 'Аналитическое мышление']",
#        "['Excel', 'SQL']", "['A/B тесты', 'Python', 'SQL', 'Pandas']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Python', 'MS Excel', 'Git']",
#        "['MS SQL', 'Анализ данных', 'SQL', 'Сводные таблицы', 'Power BI', 'Аналитические способности', 'JSON', 'Работа с большим объемом информации', 'Сбор и анализ информации', 'Аналитика', 'Статистический анализ', 'Навыки составления отчетности', 'Анализ бизнес показателей', 'Работа с базами данных', 'DWH', 'Аналитическое мышление', 'Базы данных']",
#        "['Анализ данных', 'SQL', 'Python', 'Документация', 'confluence']",
#        "['Анализ данных', 'SQL', 'Python', 'confluence', 'Tableau', 'DWH']",
#        "['Power BI', 'DAX', 'SQL', 'PowerBI']",
#        "['MS SQL', 'Анализ данных', 'SQL', 'Python', 'Работа с большим объемом информации', 'Excel', 'Jupiter', 'Аналитическое мышление', 'Макросы', 'Базы данных']",
#        "['MS Excel']",
#        "['Анализ данных', 'MS PowerPoint', 'Atlassian Confluence', 'SQL', 'Деловая переписка', 'Atlassian Jira', 'confluence', 'Аналитические исследования', 'Работа с базами данных', 'Аналитическое мышление', 'Управление проектами']",
#        "['MS PowerPoint', 'SQL', 'Бизнес-анализ', 'confluence', 'Аналитические исследования', 'Аналитическое мышление']",
#        "['Анализ данных', 'Business Intelligence Systems', 'SQL', 'Machine learning', 'Power BI', 'Python', 'Документация', 'Pandas']",
#        "['SQL', 'PowerBI', 'Power BI', 'A/B тесты', 'Python', 'pandas', 'matplotlib', 'BI', 'Статистический анализ', 'Математическая статистика', 'Pandas', 'numpy', 'seaborn']",
#        "['MS SQL', 'Анализ данных', 'SQL', 'Системы отчетности']",
#        "['Коммуникация', 'Python', 'Документация', 'Переговоры', 'ClickHouse', 'PostgreSQL', 'Git']",
#        "['Анализ данных', 'SQL', 'Power BI', 'WEB аналитика', 'Аналитика', 'Аналитические исследования', 'Маркетинговый анализ', 'MS Excel', 'Анализ бизнес показателей']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Python', 'Оптимизация бизнес-процессов', 'Сбор и анализ информации', 'Аналитика', 'Прогнозирование', 'Базы данных']",
#        "['SQL', 'Python', 'Документация', 'Hadoop', 'Оценка рисков', 'Управленческая отчетность']",
#        "['Аналитическое мышление', 'ETL', 'Анализ данных']",
#        "['Numpy', 'SQL', 'Python', 'pandas', 'Статистический анализ', 'Математическая статистика', 'Jupiter', 'Прогнозирование', 'MS Excel', 'Pandas']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Python', 'Документация', 'Excel', 'confluence', 'Tableau']",
#        "['Визуализация данных', 'SQL', 'Сводные таблицы', 'Аналитика данных', 'PowerShell', 'Excel', 'ВПР', 'дашборды']",
#        "['MS PowerPoint', 'Подготовка презентаций', 'Работа с большим объемом информации', 'Аналитический склад ума', 'Статистический анализ', 'Прогнозирование', 'MS Excel']",
#        "['Аналитика продаж', 'E-Commerce', 'Работа с системами аналитики', 'Удаленная работа', 'Продвинутый пользователь ПК', 'Работа с большим объемом информации', 'Аналитический склад ума', 'Знание Excel', 'Умение принимать решения', 'Анализ продаж', 'wildberries', 'Маркетплейсы', 'Конкурентная аналитика']",
#        "['Анализ данных', 'E-Commerce', 'Финансовый анализ', 'ERP', 'Системное мышление', 'MS Excel', 'Аналитическое мышление', 'Планирование продаж']",
#        "['SQL', 'Бизнес-анализ', 'Python', 'Анализ рисков', 'MS Excel']",
#        "['MS SQL', 'Визуализация данных', 'Анализ данных', 'SQL', 'Английский — B1 — Средний', 'PowerBI', 'Power BI', 'Python', 'Документация', 'Data Analysis', 'Аналитика', 'Tableau', 'Pandas', 'Работа с базами данных', 'PostgreSQL', 'Обучение и развитие']",
#        "['Power BI', 'Python', 'SQL']",
#        "['SQL', 'React', 'API', 'BI-инструменты', 'JSON', 'Node-RED', 'ClickHouse']",
#        "['Английский язык', 'SQL', 'Python', 'Tableau', 'Математическая статистика', 'Pandas']",
#        "['Cистемы управления базами данных', 'Организация совещаний', 'Многозадачность', 'Организация деловых поездок', 'Протоколирование', 'Ведение отчетности', 'Работа с большим объемом информации', 'Документация', 'Высокая скорость печати', 'Системное мышление', 'MS Excel', '1С: Предприятие']",
#        "['Коммуникация', 'SQL', 'Python', 'Документация', 'Data Analysis', 'Pandas', 'Аналитическое мышление']",
#        "['Проактивность', 'SQL', 'Бизнес-анализ', 'Анализ бизнес показателей', 'Планирование', 'Лидерство', 'Оптимизация бизнес-процессов', 'Прогнозирование', 'Подготовка отчетов', 'Корпоративная этика', 'Деловая коммуникация', 'Аналитическое мышление', 'Управленческая отчетность', 'Автоматизация процессов', 'Расстановка приоритетов', 'Организаторские навыки', 'Работа с большим объемом информации', 'Аналитика', 'Стратегическое мышление', 'Power BI']",
#        "['Анализ данных', 'SQL', 'Python', 'Data Analysis', 'Pandas']",
#        "['Анализ данных', 'Визуализация данных', 'Сводные таблицы', 'Подготовка презентаций', 'Работа с большим объемом информации', 'Сбор и анализ информации', 'Аналитический склад ума', 'Аналитика', 'ВПР', 'MS Excel', '1С', 'Подготовка отчетов', 'Аналитическое мышление']",
#        "['Анализ данных', 'Бизнес-анализ', 'MS Power BI', 'Анализ бизнес показателей', 'Аналитическое мышление']",
#        "['SQL', 'Appsflyer', 'Яндекс.Метрика', 'AppMetrica', 'A/B тесты', 'модели атрибуции', 'Tableau', 'Pandas', 'Apache Superset', 'plotly', 'Google Analytics', 'Improvado', 'Metabase', 'pandas', 'Amplitude', 'ROAS', 'Firebase', 'Mixpanel', 'ROI', 'scipy', 'Коммуникация', 'Python', 'Jetstat']",
#        "['сводные таблицы', 'BI-отчетность', 'Аналитика', 'Выборка', 'ВПР', 'MS Excel', 'Подготовка отчетов', 'Аналитическое мышление', 'Переговоры']",
#        "['Усидчивость', 'внимательность', 'умение анализировать информацию']",
#        "['SQL', 'Бизнес-анализ', 'Сводные таблицы', 'Сбор и анализ информации', 'Big Data', 'Google Data Studio', 'Анализ бизнес показателей', 'Мой склад', 'Анализ данных', 'Математический анализ', 'Оптимизация бизнес процессов', 'Оптимизация бизнес-процессов', 'Постановка задач разработчикам', 'Прогнозирование', 'Аналитическое мышление', 'Business Analysis', 'UML', 'Atlassian Jira', 'Работа с большим объемом информации', 'Статистический анализ', 'Аналитические исследования', 'Работа с базами данных', 'Базы данных', 'Работа с системами аналитики', 'MS Power BI', 'Power BI', 'Python', 'Data Analysis', 'Data Mining', 'Конкурентная аналитика']",
#        "['Анализ данных', 'Работа с системами аналитики', 'SQL', 'Power BI', 'Python', 'Документация', 'Работа с большим объемом информации', 'Аналитика', 'Статистический анализ', 'Математическая статистика', 'Работа с базами данных', 'Pandas']",
#        "['StreamLit', 'ODS', 'Luxms', 'Greenplum', 'CDM', 'DDS', 'ClickHouse']",
#        "['Анализ данных', 'исполнение поручений руководителя', '1С программирование', 'Сбор и анализ информации', 'Аналитический склад ума', 'Работа с базами данных', 'MS Excel', 'Аналитическое мышление']",
#        "['Документация', 'Анализ данных', 'Аналитические исследования', 'SQL']",
#        "['Анализ данных', 'Аналитика продаж', 'Коммуникация', 'Подготовка презентаций', 'Работа с большим объемом информации', 'Сбор и анализ информации', 'Работа с базами данных', 'Прогнозирование', 'Аналитическое мышление', 'Управленческая отчетность']",
#        "['MS SQL', 'Бизнес-анализ', 'Power BI', 'Dax', 'Работа с базами данных', 'PostgreSQL', 'Базы данных']",
#        "['Tableau', 'Python', 'SQL']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Аналитика', 'Tableau', 'Аналитическое мышление', 'Базы данных']",
#        "['Автоматизация процессов', 'Анализ данных', 'MS PowerPoint', 'MS SQL', 'Аналитика продаж', 'Бизнес-анализ', 'Креативность', 'Сбор и анализ информации', 'Аналитика', 'Подготовка отчетов', 'MS Excel', 'Деловая коммуникация', 'Аналитическое мышление', 'CRM']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Python', 'Документация', 'Tableau', 'Работа с базами данных', 'MS Excel', 'airflow']",
#        "['Внутренний контроль', 'MS Outlook', 'Работа с большим объемом информации', 'Отчеты', 'Работа с базами данных', 'MS Excel']",
#        "['Archimate', 'Анализ данных', 'Проведение тестирований', 'Моделирование баз данных', 'SQL', 'SPARQL', 'MongoDB', 'СУБД', 'UML', 'Работа с большим объемом информации', 'Python', 'JSONATA', 'Постановка задач разработчикам', 'Работа с базами данных', 'Аналитическое мышление', 'BPMN', 'Базы данных']",
#        "['SQL', 'Python', 'Маркетинг, реклама, PR', 'Математическая статистика', 'Pandas', 'аналитика данных']",
#        "['Анализ данных', 'MS SQL', 'SQL', 'Бизнес-анализ', 'Power BI', 'Python', 'UML', 'Документация', 'Аналитика', 'Tableau', 'DAX', 'BPMN', 'Базы данных']",
#        "['Автоматизация процессов', 'Системность', 'Работа с большим объемом информации', 'Оптимизация процессов', 'Работа с базами данных', 'Базы данных']",
#        "['Документация', 'SQL']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Работа с большим объемом информации', 'R', 'Статистический анализ', 'Математическая статистика', 'Базы данных']",
#        "['Анализ данных', 'Хранилище данных', '1С: Торговля', 'Табличная верстка', 'Работа с базами данных', 'MS Excel', 'Аналитическое мышление']",
#        "['Kafka', 'PyTorch', 'Python', 'Docker', 'NLP', 'Kubernetes', 'Transformers', 'LLM']",
#        "['PySpark', 'Python', 'Hadoop', 'Oozie', 'Hive']",
#        "['Анализ данных', 'SQL', 'Power BI', 'MS Power BI', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['Аналитическое мышление', 'Коммуникация', 'Pandas']",
#        "['MS PowerPoint', 'SQL', 'Документация', 'Генерация идей', 'Навыки презентации', 'BI', 'Анализ бизнес показателей', 'Анализ данных', 'Quick Sense', 'Умение принимать решения', 'Tableau', 'MS Excel', 'Apache Superset', 'Деловая коммуникация', 'Аналитическое мышление', 'Дашборды', 'Отчетность', 'Коммуникация', 'Power BI']",
#        "['Сбор и анализ информации', 'Работа с большим объемом информации', '1С', 'MS Excel', 'Подготовка отчетов', 'Аналитическое мышление', 'Сельское хозяйство']",
#        "['Документация', 'Коммуникация']",
#        "['MS SQL', 'XML', 'UML', 'Документация', 'ETL', 'DWH', 'JSON API', 'BPMN']",
#        "['Математическая статистика', 'Python', 'SQL', 'Математическое моделирование']",
#        "['Анализ данных', 'SQL', 'Python', 'Документация', 'Аудит']",
#        "['Анализ данных', 'MS PowerPoint', 'SQL', 'Power BI', 'Python', 'MS Excel', 'Аналитическое мышление', 'ITIL']",
#        "['Deep Learning', 'Computer Vision', 'Tensorflow', 'PyTorch', 'Python', 'OpenCV', 'Руководство коллективом']",
#        "['SQL', 'Python', 'ML', 'Математическая статистика', 'Big Data', 'Pandas']",
#        "['SQL', 'Python', 'Работа с большим объемом информации', 'Аналитика', 'Работа с базами данных', 'Базы данных']",
#        "['Анализ данных', 'Исследования рынка', 'Маркетинговые исследования', 'Работа с большим объемом информации', 'Data Analysis', 'Анализ рынка', 'Аналитические исследования', 'Маркетинговый анализ', 'Работа с базами данных', 'Pandas', 'Деловая коммуникация']",
#        "['SQL', 'Аналитика закупок', 'Power BI', 'Отчетность по закупкам', 'Аналитика', 'MS Excel']",
#        "['Проактивность', 'MS Excel']",
#        "['Расчет заработной платы', 'MS PowerPoint', 'Коммуникация', 'Power BI', 'Адаптивность', 'MS Excel', 'Аналитическое мышление']",
#        "['SQL', 'Python', 'Аналитика', 'Аналитические исследования', 'Математическая статистика', 'Pandas', 'Git']",
#        "['Анализ данных', 'Коммуникабельность', 'SQL', 'Работа в команде', 'Python', 'Статистика', 'Аналитическое мышление']",
#        "['Power BI', 'PostgreSQL', 'MS Excel', 'DWH']",
#        "['Kafka', 'REST', 'Atlassian Confluence', 'SQL', 'API', 'XML', 'Анализ требований', 'UML', 'Atlassian Jira', 'Swagger', 'BPMN']",
#        "['Numpy', 'SQL', 'OpenAI', 'Selenium IDE', 'Python', 'Pandas', 'Big Data', 'PostgreSQL']",
#        "['Анализ данных', 'SQL', 'Python', 'Spark', 'Big Data']",
#        "['Sas', 'SQL', 'Python', 'MS Excel', 'Data Analyst']",
#        "['Коммуникация', 'Сбор и анализ информации', 'Работа с большим объемом информации', 'Аналитические исследования', 'Подготовка отчетов', 'Аналитическое мышление', 'Математический анализ']",
#        "['Английский язык', 'Machine Learning', 'Анализ данных', 'Коммуникация', 'GitLab', 'PyTorch', 'Python', 'Документация', 'Data Analysis', 'Презентация результатов', 'CI/CD', 'TensorFlow', 'Scikit-learn', 'Аналитическое мышление', 'Юнит-экономика', 'Математический анализ']",
#        "['MS SQL', 'Oracle Exadata', 'UML', 'Документация', 'Greenplum', 'confluence', 'PostgreSQL', 'BPMN', 'Oracle DB']",
#        "['Анализ данных', 'MS PowerPoint', 'SQL', 'Бизнес-анализ', 'аналитика', 'MS Excel', 'Анализ бизнес показателей', 'Подготовка отчетов', 'Qlik Sense']",
#        "['Анализ данных', 'Python', 'SQL', 'Data Analysis']",
#        "['Анализ данных', 'Python', 'SQL', 'Работа с базами данных']",
#        "['Machine Learning', 'Numpy', 'SQL', 'SciPy', 'PyTorch', 'Python']",
#        "['Анализ данных', 'SQL', 'Аналитик данных', 'Python', 'Работа с большим объемом информации', 'Pandas', 'Работа с базами данных', 'Airflow', 'Аналитическое мышление', 'ClickHouse']",
#        "['Анализ данных', 'SQL', 'Data Science', 'Python', 'Pandas']",
#        "['Machine Learning', 'Python', 'Документация', 'BI Apache SuperSet', 'confluence', 'Big Data']",
#        "['Английский язык', 'Проактивность', 'SQL', 'Работа с большим объемом информации']",
#        "['MS Project', 'MS PowerPoint', 'Документация', 'Oracle Primavera', 'MS Excel']",
#        "['A/B тесты', 'Python', 'SQL', 'Математическая статистика']",
#        "['Анализ данных', 'ML-прогнозирование', 'Машинное обучение', 'SQL', 'Визуализация данных', 'Google Cloud Platform', 'Matomo', 'Яндекс.Метрика', 'Python', 'Google Tag Manager', 'DBT', 'Google Big Query', 'JavaScript', 'Django Framework', 'Аналитическое мышление', 'Google Analytics', 'DevOps', 'Yandex Data Lens']",
#        "['DWH Lead', 'Анализ данных', 'Data Analysis', 'data engineer', 'data scientist', 'DWH', 'построение хранилищ данных']",
#        "['SQL', 'Power BI', 'Документация', 'Data Analysis', 'Big Data', 'ORACLE', 'Базы данных']",
#        "['SQL', 'BigData', 'Greenplum', 'Hadoop', 'Pandas', 'Spark', 'PostgreSQL']",
#        "['SQL', 'Power BI', 'Python', 'Работа с большим объемом информации', 'Навыки презентации', 'Статистический анализ', 'Tableau', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['Корпоративные финансы', 'Python', 'Аналитик данных', 'SQL']",
#        "['MS SQL', 'SQL', 'MS Excel', 'Аналитическое мышление', 'Управленческая отчетность', 'Базы данных', 'VBA']",
#        "['confluence', 'Аналитическое мышление', 'Pandas']",
#        "['Python', 'Power Query', 'Пользователь ПК', 'MS Excel', '1C']",
#        "['Numpy', 'SQL', 'Python', 'Data Analysis', 'VBA', 'ML', 'Математическая статистика', 'Pandas', 'Git']",
#        "['Анализ данных', 'SQL', 'PowerBI', 'Power BI', 'Python', 'Сбор и анализ информации', 'Аналитика', 'Tableau', 'Superset', 'Работа с базами данных', 'Маркетинговый анализ', 'Big Data']",
#        "['Анализ данных', 'Коммуникация', 'RTB', 'Документация', 'Data Analysis', 'confluence', 'Programmatic']",
#        "['Power BI', 'Python', 'SQL', 'MS Excel']",
#        "['SQL', 'API', 'Python', 'Интеллектуальный анализ данных', 'Математическая статистика', 'Pandas']",
#        "['MS SQL', 'Python', 'SQL', 'Ad Hoc Analysis']",
#        "['Анализ данных', 'hive', 'SQL', 'Data Science', 'Python', 'ML', 'Статистический анализ', 'Математическая статистика', 'Data Mining', 'Big Data', 'Pandas', 'Spark', 'Tableau', 'Pyspark', 'hadoop']",
# ...
#        "['Qlickview', 'Коммуникация', 'SQL', 'SuperSet', 'Python', 'Документация', 'QlickSense']",
#        "['Python', 'ETL', 'Pandas', 'Big Data', 'PostgreSQL', 'Git']",
#        "['Закупки', 'Анализ рынка', 'MS Excel', 'Категорийные закупки', 'ИТ-закупки']",
#        "['confluence', 'SQL', 'BPMN', 'MS Excel']",
#        "['Python', 'SQL', 'Data Analysis', 'Pandas']",
#        "['ERP-системы на базе 1С', 'SQL', 'Power BI', 'Документация', 'MS Excel', '1С: Бухгалтерия и склад']",
#        "['Анализ данных', 'Юнит-экономика', 'ML-моделирование', 'Бизнес-анализ', 'SQL', 'Python', 'динамическое ценообразование', 'Pandas', 'прогнозирование спроса', 'Планирование продаж']",
#        "['стажер', 'Аналитика продаж', 'E-Commerce', 'Сводные таблицы', 'Анализ ассортиментной линейки', 'Контроль отгрузки и доставки товара', 'Работа с большим объемом информации', 'Анализ продаж', 'Аналитика', 'начинающий специалист', 'Маркетплейсы', 'ВПР', 'Логистика поставок', 'MS Excel', 'Аналитическое мышление', 'Планирование ассортимента', 'Ассортиментная матрица']",
#        "['Анализ данных', 'SQL', 'Аналитические способности', 'Документация', 'Оптимизация бизнес-процессов', 'Работа с большим объемом информации', 'Работа с базами данных', 'Анализ бизнес показателей', 'PostgreSQL', 'BPMN']",
#        "['Анализ данных', 'Документация', 'SQL', 'Data Analysis']",
#        "['Анализ данных', 'Аналитические способности', 'Сбор и анализ информации', 'Работа с большим объемом информации', 'Аналитика', 'Аналитические исследования', 'Работа с базами данных', 'Анализ бизнес показателей', 'Деловая коммуникация', 'Аналитическое мышление', 'Базы данных']",
#        "['Амплитуда', 'Продуктовые гипотезы', 'Веб-аналитика']",
#        "['Анализ данных', 'MS PowerPoint', 'MS SQL', 'SQL', 'Power BI', 'MS Power BI', 'Подготовка презентаций', 'Python', 'Проведение инвентаризаций', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['Коммуникация', 'SQL', 'IPC', 'Apache Airflow', 'Power BI', 'Документация', 'MS Olap', 'ORACLE', 'Postgres']",
#        "['MS SQL', 'SQL', 'A/B тесты', 'Python', 'Аналитика']",
#        "['Numpy', 'Анализ данных', 'SQL', 'Python', 'Pandas']",
#        "['Автоматизация процессов', 'Анализ данных', 'SQL', 'Python', 'Сбор и анализ информации', 'Статистика', 'Навыки презентации', 'Статистический анализ', 'MS Excel', 'Планирование', 'Математический анализ']",
#        "['SQL', 'Python', 'Документация', 'Математическая статистика', 'Google Analytics']",
#        "['Python', 'SQL', 'Pandas', 'Анализ ценообразования']",
#        "['runtime CRM', 'SQL', 'Документация', 'ORACLE', 'SAS RTDM', 'realtime marketing', 'RTM', 'DRTM', 'Evam', 'RTDM', 'CRM']",
#        "['Atlassian Jira', 'Python', 'Atlassian Confluence', 'SQL']",
#        "['Ad Hoc Analysis', 'Python', 'BI', 'NLP', 'ML', 'ETL', 'Pandas']",
#        "['Анализ данных', 'SQL', 'Бизнес-анализ', 'Looker Studio', 'MySQL', 'Yandex DataLens', 'Data Analysis', 'Математическая статистика']",
#        "['Английский язык', 'SQL', 'Power BI', 'Python', 'Tableau', 'Аналитическое мышление']",
#        "['Грамотность', 'Аналитическое мышление', 'Статистический анализ']",
#        "['Machine Learning', 'SQL', 'Hadoop', 'ML', 'Big Data', 'DWH', 'PostgreSQL', 'Анализ данных', 'Прогнозирование', 'Машинное обучение', 'Аналитическое мышление', 'NoSQL', 'Математическое моделирование', 'Spark', 'Hive', 'Базы данных', 'Git', 'Коммуникация', 'Python', 'Data Analysis', 'ETL', 'Airflow']",
#        "['Проактивность', 'Python', 'SQL', 'Pandas']",
#        "['Анализ данных', 'E-Commerce', 'Сводные таблицы', 'Анализ ассортиментной линейки', 'Power BI', 'MS Power BI', 'Google Docs', 'Работа с большим объемом информации', 'Аналитика', 'Статистический анализ', 'Маркетплейсы', 'ВПР', 'ABC-анализ', 'Аналитическое мышление']",
#        "['SQL', 'Python', 'Документация', 'Hadoop', 'ETL', 'Big Data', 'Spark', 'DWH']",
#        "['MongoDB', 'SQL', 'PowerBI', 'UML', 'Clickhouse', 'BI', 'ETL', 'Tableau', 'PostgreSQL']",
#        "['Анализ данных', 'SQL', 'Документация', 'математика', 'Статистика', 'Excel', 'Аналитическое мышление']",
#        "['Power BI', 'Анализ данных', 'SQL', 'DWH']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Python', 'Tableau']",
#        "['Деловая коммуникация', 'Анализ данных', 'Работа с большим объемом информации']",
#        "['Power BI', 'Аналитическое мышление', 'Аналитический склад ума', 'MS Excel']",
#        "['SQL', 'Документация', 'Data Analysis', 'Работа с базами данных', 'tableau']",
#        "['Разработка', 'RecSys', 'SQL', 'Ad Hoc Analysis', 'pyTorch', 'Python', 'ML', 'Big Data', 'Машинное обучение', 'Git']",
#        "['Computer Vision', 'Machine Learning', 'Numpy', 'Анализ данных', 'SQL', 'Keras', 'PyTorch', 'Python', 'Работа с большим объемом информации', 'R', 'ML', 'NLP', 'Go', 'Pandas', 'TensorFlow', 'Scikit-learn', 'Машинное обучение', 'Работа с базами данных']",
#        "['Machine Learning', 'Data Science', 'SQL', 'Scikit-Learn', 'PyTorch', 'Python', 'NumPy', 'NLP', 'Pandas']",
#        "['SQL', 'A/B тесты', 'Документация', 'Оптимизация бизнес-процессов', 'Аналитическое мышление']",
#        "['Анализ данных', 'Machine Learning', 'Коммуникация', 'SQL', 'Python', 'Сбор и анализ информации', 'Hadoop', 'Математическое моделирование', 'ETL', 'Аналитические исследования', 'Работа с базами данных', 'Прогнозирование', 'Big Data', 'Spark', 'Hive', 'Git']",
#        "['Анализ данных', 'SQL']",
#        "['SQL', 'Python', 'Сбор и анализ информации', 'Аналитика', 'Работа с базами данных', 'Базы данных']",
#        "['Power BI', 'MS SQL', 'Юнит-экономика', 'DWH']",
#        "['confluence', 'Документация', 'Аналитическое мышление']",
#        "['WoE', 'Shap/Lime', 'XGBoost', 'Python', 'Документация', 'pandas', 'Docker', 'ML', 'sklearn', 'Pandas', 'numpy', 'scipy', 'SQL.']",
#        "['Анализ данных', 'Бизнес-анализ', 'Документация', 'Аналитическое мышление', 'Базы данных']",
#        "['Аналитическое мышление', 'Python', 'Коммуникация', 'SQL']",
#        "['Анализ данных', 'MS PowerPoint', 'SQL', 'Python', 'Работа с большим объемом информации', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'MS PowerPoint', 'SQL', 'Python', 'Работа с большим объемом информации', 'Работа с базами данных', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Автоматизация процессов управления персоналом', 'Рекрутмент', 'Управление персоналом', 'Power BI', 'Аналитические исследования', 'Работа с базами данных', 'HR']",
#        "['Apache SuperSet', 'Python', 'SQL']",
#        "['SQL', 'Python', 'Сбор и анализ информации', 'Аналитика', 'Jupiter', 'Pandas', 'MS Excel']",
#        "['MS PowerPoint', 'Аналитика продаж', 'SQL', 'Ведение переговоров', 'Big Data', 'Анализ бизнес показателей', 'Планирование продаж', 'Анализ данных', 'Qlik', 'Анализ продаж', 'Tableau', 'MS Excel', 'Подготовка отчетов', 'Деловая коммуникация', 'Аналитическое мышление', 'MS SQL', 'Управление продажами', 'Работа в команде', 'Power Pivot', 'PowerBI', 'Организаторские навыки', 'Работа с большим объемом информации', 'Прогнозирование продаж', 'Аналитика', 'Работа с базами данных', 'Базы данных', 'Работа с системами аналитики', 'XML', 'Python', 'Управление проектами']",
#        "['MS SQL', 'А/В-тестирования', 'Power Pivot', 'Английский – А2', 'Power BI', 'Python', 'DAX', 'MS Excel', 'Аналитическое мышление']",
#        "['Аналитическое мышление', 'Power Pivot', 'Power BI', 'Документация', 'DAX', 'OLAP', 'Pandas', 'PowerQuery']",
#        "['MS PowerPoint', 'SQL', 'MS Access', 'Аналитические исследования', 'Аналитическое мышление']",
#        "['MS SQL', 'Анализ данных', 'Управление командой', 'Python', 'Документация', 'Разработка технических заданий', 'Pandas', 'Аналитическое мышление', 'Написание документации для пользователей']",
#        "['MS SQL', 'GitLab', 'SuperSet', 'Python', 'AirFlow', '1С-Битрикс', 'Pandas', 'MS Excel']",
#        "['confluence', 'Документация', 'Оптимизация бизнес-процессов', 'BPMN']",
#        "['Английский язык', 'Анализ данных', 'Project management', 'SQL', 'Документация', 'Оптимизация бизнес-процессов', 'Data Analysis', 'Markdown', 'Юнит-экономика', 'Базы данных']",
#        "['PowerBL', 'SQL', 'Power BI', 'visiology', 'Аналитика', 'ETL', 'хранилища данных']",
#        "['SQL', 'Документация', 'Сбор и анализ информации', 'MS SQL Server', 'СУБД', 'Tableau', 'Аналитическое мышление', 'MS SQL', 'Аналитика', 'Power Query', 'Статистический анализ', 'Работа с базами данных', 'ClickHouse', 'Базы данных', 'Коммуникация', 'Power BI', 'MS Power BI', 'Python', 'Superset', 'Математическая статистика']",
#        "['FineBI', 'SQL', 'Python', 'Tableau', 'PostgreSQL']",
#        "['Анализ данных', 'Визуализация данных', 'Коммуникация', 'SQL', 'Сводные таблицы', 'PowerBI', 'Power BI', 'Сбор и анализ информации', 'Аналитика', 'Автоматизация', 'Системный подход', 'Аналитическое мышление', 'Базы данных']",
#        "['Юнит-экономика', 'Python', 'SQL', 'Data Analysis']",
#        "['Коммуникация', 'Сводные таблицы', 'Сбор и анализ информации', 'Работа с большим объемом информации', 'Аналитика', 'MS Excel', 'Подготовка отчетов', 'Аналитическое мышление']",
#        "['Грамотная речь', 'Визуализация данных', 'Работа в команде', 'SQL', 'Анализ данных', 'PowerBI', 'Организационные навыки', 'MS Access', 'Python', 'Tableau', 'Pandas', 'Анализ бизнес показателей', 'Аналитическое мышление', 'clickhouse', 'AB тестирование']",
#        "['Анализ данных', 'Machine Learning', 'SQL', 'A/B тесты', 'Python', 'Data Analysis', 'confluence', 'Tableau', 'Математическая статистика', 'Аналитические исследования', 'Анализ бизнес показателей', 'Математический анализ']",
#        "['SQL', 'Power BI', 'Python', 'Работа с большим объемом информации', 'ETL', 'Аналитические исследования', 'Работа с базами данных', 'Аналитическое мышление', 'PostgreSQL']",
#        "['Коммуникация', 'Data Vault', 'Документация', 'DWH', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Python', 'Математическая статистика', 'Анализ временных рядов']",
#        "['SQL', 'Power BI', 'Python', 'Работа с большим объемом информации', 'Аналитика', 'Big Data', 'Анализ бизнес показателей', 'PostgreSQL']",
#        "['SQL', 'Python', 'Документация', 'Аналитика', 'confluence', 'Математическая статистика', 'Pandas', 'Аналитическое мышление', 'Базы данных']",
#        "['MS Outlook', 'Работа с большим объемом информации', 'Работа с базами данных', 'Аналитическое мышление', '1C: Предприятие', '1С: Документооборот']",
#        "['Power BI', 'Статистический анализ', 'Работа с базами данных', 'MS Excel', 'Анализ бизнес показателей']",
#        "['nltk', 'Информационные технологии', 'DataLens', 'SQL', 'Анализ данных', 'Vertica', 'Python', 'Posgresql', 'NoSQL', 'Data Analysis', 'panda', 'Tableau', 'sklearn', 'Airflow', 'numpy', 'scipy', 'Git']",
#        "['Английский язык', 'Анализ данных', 'Коммуникация', 'SQL', 'Организация учебного процесса', 'Работа с большим объемом информации', 'MS Excel', 'Аналитическое мышление']",
#        "['MS SQL', 'Teradata', 'Data Science', 'написание скриптов', 'аналитика больших массивов данных', 'ORACLE', 'витрины данных']",
#        "['SQL', 'API', 'Power BI', 'Python', 'Математическая статистика', 'Pandas', 'MS Excel']",
#        "['Математическая статистика']",
#        "['Анализ данных', 'Сводные таблицы', 'Подготовка презентаций', 'Ценообразование', 'Сквозная аналитика', 'Маркетинговые исследования', 'Работа с большим объемом информации', 'Ценовая политика', 'Аналитика', 'Анализ рынка', 'Аналитические исследования', 'Маркетинговый анализ', 'Прогнозирование', 'Подготовка отчетов', 'Аналитическое мышление', 'Анализ конкурентной среды', 'Конкурентная аналитика', 'Анализ ценообразования']",
#        "['Анализ данных', 'Проактивность', 'SQL', 'Tableau', 'Superset', 'Аналитическое мышление']",
#        "['Power BI', 'SQL']",
#        "['SQL', 'Power BI', 'Подготовка презентаций', 'Python', 'A/B тесты', 'Работа с большим объемом информации', 'Анализ рынка', 'Аналитические исследования', 'Pandas', 'Аналитическое мышление']",
#        "['Python', 'Коммуникация', 'SQL']",
#        "['Документация', 'SQL', 'Работа с базами данных', 'Базы данных']",
#        "['Анализ данных', 'Tableau', 'SQL']",
#        "['Аналитическое мышление', 'Работа с большим объемом информации', 'SQL', 'Стратегическое мышление']",
#        "['Анализ данных', 'SQL', 'Маркетинговый анализ']",
#        "['MS SQL', 'SQL', 'Python', 'Data Analysis', 'Работа с базами данных']",
#        "['Проактивность', 'Документация', 'Pandas', 'Юнит-экономика']",
#        "['Power BI', 'Excel', 'Работа с большим объемом информации', 'Работа с базами данных']",
#        "['XML', 'Power BI', 'Документация', 'confluence', 'JSON API', 'PostgreSQL']",
#        "['Коммуникация', 'SQL']",
#        "['SQL', 'Python', 'Анализ рисков', 'QlickSense', 'Spark', 'Hive']",
#        "['ClickHouse', 'SQL']", "['SQL', 'Работа с базами данных']",
#        "['MS SQL', 'Визуализация данных', 'Анализ данных', 'SQL', 'Power BI', 'MS Power BI', 'MS Visio', 'Работа с большим объемом информации', 'Аналитическое мышление']",
#        "['Анализ данных', 'Экономический анализ', 'Документация', 'Аналитика', 'Работа с базами данных', 'Google Analytics', 'Базы данных']",
#        "['Логистика', 'Финансовый анализ', 'Экономический анализ', 'Работа с большим объемом информации', 'Аналитика данных', 'Транспортная логистика', 'Аналитическое мышление']",
#        "['Анализ данных', 'Работа в команде', 'SQL', 'Амбициозность', 'Ответственность', 'СУБД', 'Документация', 'Доброжелательность', 'MS Excel']",
#        "['MS SQL', 'Python', 'VBA']",
#        "['Финансовый контроль', 'Финансовый анализ', 'Финансовая отчетность', 'Финансовое моделирование', 'Финансовый менеджмент', 'Финансовое планирование', 'Аналитическое мышление', 'Управленческая отчетность']",
#        "['Работа в команде', 'Коммуникабельность', 'Ответственность', 'Python', 'Работа с большим объемом информации', 'Системное мышление', 'Аналитическое мышление', 'Целеустремленность', 'VBA']",
#        "['Анализ данных', 'Аналитическое мышление', 'SQL', 'Python', 'Ведение отчетности', 'Аналитика', 'Pandas', 'MS Excel', 'Аудит', 'риски']",
#        "['Numpy', 'SQL', 'Power BI', 'Python', 'ETL', 'Pandas', 'VBA']",
#        "['Power BI', 'SQL', 'Аналитика']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Python', 'Аналитика', 'Exasol', 'ClickHouse']",
#        "['Проактивность', 'SQL', 'Power BI', 'Python', 'Математическая статистика', 'Аналитическое мышление']",
#        "['SQL', 'Power BI', 'Python', 'Работа с большим объемом информации', 'Аналитический склад ума', 'Аналитика']",
#        "['Анализ данных', 'SQL', 'Python', 'Работа с большим объемом информации', 'Data Analysis', 'Аналитика', 'Аналитические исследования', 'Работа с базами данных', 'Анализ бизнес показателей', 'Аналитическое мышление']",
#        "['Анализ данных', 'Коммуникация', 'SQL', 'Power BI', 'Python', 'Документация', 'MS Excel', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'Power BI', 'Python', 'Статистический анализ', 'Математическая статистика', 'Анализ бизнес показателей', 'Базы данных']",
#        "['Excel', '1С: Зарплата и кадры', 'Офисные программы', 'Компенсации и льготы']",
#        "['MS PowerPoint', 'SQL', 'Power BI', 'Проведение презентаций', 'Tableau']",
#        "['Коммуникация', 'Power Pivot', 'Сводные таблицы', 'Документация', 'Работа с большим объемом информации', 'Сбор и анализ информации', 'Power Query', 'Аналитика', 'Анализ бизнес показателей', 'Работа с базами данных', 'MS Excel', 'Прогнозирование', 'Аналитическое мышление', 'VBA']",
#        "['Python', 'Data Science', 'SQL']",
#        "['Математическая статистика', 'Python', 'Data Science', 'SQL']",
#        "['Анализ данных', 'MS SQL', 'SQL', 'Портфельный анализ', 'Анализ рисков', 'Управление рисками']",
#        "['Внутренний контроль', 'Внутренний аудит информационных систем', 'Контрольно-аналитические проверки', 'Работа с базами данных', 'Аналитическое мышление']",
#        "['Анализ данных', 'SQL', 'MS Power BI', 'Python', 'Data Analysis', 'Аналитика', 'Tableau']"],
#       dtype=object)

# %%
df_ds['key_skills'].unique()
# Out:
# array(['[]',
#        "['Python', 'Hadoop', 'Machine Learning', 'Работа с базами данных', 'Математический анализ', 'Статистический анализ', 'MS SQL', 'SQL', 'Spark', 'Big Data', 'Аналитические исследования', 'Аналитическое мышление', 'Pandas', 'Документация', 'Математическая статистика']",
#        "['Python', 'PyTorch', 'Machine Learning', 'Docker', 'Deep Learning', 'SQL', 'Data Science', 'NLP', 'Pandas', 'ML']",
#        "['DataLens', 'MS SQL', 'SQL', 'Spark', 'Аналитическое мышление', 'Data Scientist', 'Python', 'PostgreSQL', 'Аналитика', 'Data Mining', 'Английский язык', 'Обучение и развитие', 'QlikView', 'Hadoop', 'Статистический анализ', 'Data Analysis', 'Big Data', 'Linux', 'Бизнес-анализ']",
#        "['Python', 'sklearn', 'PostgreSQL', 'numpy', 'ml', 'scipy', 'Pandas', 'Документация', 'pandas', 'Clickhouse']",
#        "['Python', 'Machine Learning', 'SQL', 'Big Data', 'Pandas', 'Git']",
#        "['Python', 'Документация', 'SQL']",
#        "['Python', 'Работа с базами данных', 'Статистика', 'Статистический анализ', 'Математическое моделирование', 'Big Data', 'Документация']",
#        "['Pandas']", "['Pandas', 'Коммуникация']",
#        "['Python', 'sklearn', 'PyTorch', 'Machine Learning', 'Numpy', 'SQL', 'Data Analysis', 'Data Science', 'Big Data', 'Pandas', 'Linux', 'Mathematical Statistics', 'Машинное обучение']",
#        "['Python', 'PyTorch', 'confluence', 'ИТ', 'IT']",
#        "['Документация']", "['Pandas', 'confluence']",
#        "['Python', 'Hadoop', 'Airflow', 'SQL', 'Spark', 'Linux', 'Юнит-экономика']",
#        "['Python', 'кредитные риски', 'SQL', 'Скоринговые модели', 'Документация', 'Sas']",
#        "['Python', 'Big Data', 'Hadoop', 'Machine Learning']",
#        "['Python', 'Управление командой', 'Machine Learning', 'Алгоритмы', 'Мотивация персонала', 'Организаторские навыки', 'Управленческие навыки', 'Data Science', 'Лидерство', 'Big Data', 'Scikit-learn', 'ML', 'Pandas', 'pandas', 'Коммуникабельность', 'CI/CD', 'Высокие коммуникативные навыки', 'Машинное обучение']",
#        "['Python']", "['Python', 'Pandas', 'Юнит-экономика', 'SQL']",
#        "['NLP', 'Big Data', 'Hadoop', 'PySpark']", "['Коммуникация']",
#        "['Pandas', 'Юнит-экономика', 'confluence']",
#        "['Python', 'Управление проектами', 'SQL', 'Математическое моделирование', 'Сельское хозяйство', 'Аналитическое мышление', 'Коммуникация']",
#        "['GPT', 'Python', 'PyTorch', 'GPU', 'Seq2Seq', 'Docker', 'NLP', 'LLM', 'Коммуникация']",
#        "['it', 'торговая площадка']",
#        "['Python', 'Docker', 'SQL', 'Spark', 'Pandas', 'ML', 'AirFlow']",
#        "['Юнит-экономика']",
#        "['Python', 'PyTorch', 'Docker', 'Документация', 'Tensorflow']",
#        "['Data science', 'Agile']",
#        "['Python', 'R', 'SQL', 'Финансовая математика', 'Pandas', 'Стохастический анализ', 'Коммуникация']",
#        "['Python', 'PyTorch', 'Stock market', 'NN', 'trading', 'ML', 'Hedge Fund', 'Quants']",
#        "['Matplotlib', 'Seaborn', 'Pandas', 'Caffe', 'Nvidia TLT', 'Clickhouse', 'Git', 'Python', 'PostgreSQL', 'Numpy', 'computer vision', 'Теория графов', 'Keras', 'CNTK', 'TensorFlow', 'PyTorch', 'Документация', 'Machine learning', 'Data science']",
#        "['Python', 'DL', 'openCV', 'AI', 'NumPy', 'DevOps', 'NLP', 'Pandas', 'Документация', 'LLM', 'ИИ', 'MLOps']",
#        "['Data Scientist', 'Python', 'SQL', 'Spark', 'Pandas']",
#        "['Python', 'Статистический анализ', 'SQL', 'Multi-Armed Bandits', 'Reinforcement Learning', 'Pandas', 'Математическая статистика']",
#        "['Python', 'Работа с большим объемом информации', 'Data Analysis', 'SQL', 'Математическая статистика', 'Коммуникация']",
#        "['Python', 'Postgres', 'Airflow', 'SQL', 'Ценообразование', 'Machine learning', 'ClickHouse', 'Data science', 'Kubernetes']",
#        "['Python', 'Machine Learning', 'Data Science', 'Математическое моделирование', 'Pandas', 'Прогнозирование', 'Математическая статистика', 'Машинное обучение']",
#        "['Python', 'boosting', 'scikit-learn', 'Machine Learning', 'numpy', 'Работа с базами данных', 'Datalens', 'regression', 'Airflow', 'clustering', 'SQL', 'Pandas', 'catboost', 'Git', 'Коммуникация']",
#        "['Python', 'Machine Learning', 'confluence', 'Computer vision', 'Data scientist', 'Машинное обучение']",
#        "['Python', 'Transact-SQL', 'sklearn', 'PostgreSQL', 'Machine Learning', 'sns', 'plotly', 'SQL', 'Data Science', 'Pandas', 'ML']",
#        "['Python', 'Pandas', 'Документация', 'SQL']",
#        "['Pandas', 'Документация']",
#        "['Python', 'Принятие решений', 'Решение проблем', 'Machine Learning', 'Креативность', 'Data Analysis', 'Английский язык', 'Юнит-экономика', 'Leadership Skills', 'Коммуникация']",
#        "['Python', 'Умение работать в команде', 'SQL', 'Data Science', 'ООП', 'ML', 'Аналитическое мышление', 'Аналитический склад ума', 'Разработка ПО']",
#        "['Python', 'Docker', 'SQL', 'Pandas', 'MLOps']",
#        "['Python', 'SQL', 'Математическое моделирование', 'Pandas', 'Коммуникация']",
#        "['Python', 'Machine Learning', 'Numpy', 'Matplotlib', 'TensorFlow', 'Data Analysis', 'Big Data', 'Scikit-learn', 'pandas', 'SciPy']",
#        "['Python', 'Статистический анализ', 'SQL', 'Pandas', 'Аналитическое мышление', 'Математическая статистика']",
#        "['Python', 'Machine Learning', 'SQL', 'Математическое моделирование', 'Аналитические исследования']",
#        "['Python', 'Machine Learning', 'MongoDB', 'Natural Language Processing', 'Deep Learning', 'SQL', 'NLP', 'Big Data', 'Анализ данных', 'Pandas', 'AWS', 'Математическая статистика', 'LLM']",
#        "['Python', 'PyTorch', 'Numpy', 'matplotlib/plotly', 'langchain', 'BERT', 'Pandas', 'transformers', 'Документация', 'pandas']",
#        "['Docker', 'Streamlit', 'Apache Airflow']",
#        "['Теория вероятностей', 'Python', 'Machine Learning', 'Статистический анализ', 'SQL', 'Математическое моделирование', 'Эконометрика', 'Математическая статистика']",
#        "['Python', 'Data Analysis', 'Data Science', 'SQL', 'Анализ данных']",
#        "['Python', 'Документация']",
#        "['Python', 'Разработка поисковых технологий', 'DS', 'ML', 'IT']",
#        "['Python', 'PySpark', 'SQL', 'Pandas', 'ML', 'pandas']",
#        "['PyTorch', 'Python', 'PySpark', 'Проактивность', 'ML']",
#        "['Python', 'PyTorch', 'data science', 'TensorFlow', 'Документация', 'Английский язык', 'Математическая статистика']",
#        "['Python', 'Machine Learning', 'SQL', 'Data Science', 'NLP', 'Big Data', 'Pandas', 'ML', 'pandas']",
#        "['Python', 'Математическая статистика', 'Аналитическое мышление']",
#        "['Data Scientist', 'Python', 'Machine Learning', 'SQL', 'Математическое моделирование', 'Аналитика продаж', 'Машинное обучение']",
#        "['Python', 'Numpy', 'Matplotlib', 'Bash', 'SQL', 'XGBoost', 'Scikit-learn', 'Pandas', 'CatBoost', 'pandas', 'Linux', 'LightGBM', 'Git']",
#        "['Python', 'SQL', 'Разработка поисковых технологий', 'ML', 'IT']",
#        "['Linux', 'PostgreSQL', 'ORACLE', 'Clickhouse']",
#        "['Python', 'Machine Learning', 'SQL', 'Bokeh', 'Pandas', 'Документация', 'Plotly']",
#        "['Python', 'Data Analysis', 'SQL', 'Математическое моделирование', 'Анализ данных', 'Pandas', 'Документация', 'pandas', 'Коммуникация']",
#        "['Python', 'BERT', 'SQL', 'Transformers', 'Нейронные сети', 'CNN', 'LSTM']",
#        "['Data Scientist', 'Работа с базами данных', 'ml', 'nlp', 'Big Data', 'Аналитические исследования', 'Документация']",
#        "['Документация', 'Коммуникация']",
#        "['Python', 'PD', 'LGD', 'Machine Learning', 'Data Science', 'ПВР']",
#        "['Python', 'Валидация моделей', 'Статистический анализ', 'SQL', 'Математическое моделирование', 'Анализ данных', 'Модельный риск']",
#        "['Валидация моделей', 'Статистический анализ', 'SQL', 'Математическое моделирование', 'Анализ данных', 'Модельный риск']",
#        "['Python', 'Pandas']",
#        "['Pandas', 'Проактивность', 'Креативность']",
#        "['Python', 'Machine Learning', 'Docker', 'SQL', 'Pandas', 'Kubernetes']",
#        "['Python', 'PyTorch', 'Machine Learning', 'SQL', 'confluence', 'NLP', 'Pandas', 'Llama2', 'Математическая статистика', 'LLM']",
#        "['Python', 'Базы данных', 'SQL', 'machine learning', 'Коммуникация']",
#        "['Python', 'Математический анализ', 'Работа с большим объемом информации', 'Data Science', 'NLP']",
#        "['System Integration', 'SQL', 'API', 'Data Engineer', 'Python', 'PostgreSQL', 'Machine Learning', 'Data Science', 'Reinforcement Learning', 'Машинное обучение', 'Математический анализ', 'Базы данных', 'Deep Learning', 'Математическое моделирование', 'Аналитические исследования', 'Feature engineering', 'Работа с базами данных', 'теория вероятности', 'Data Analysis', 'NLP', 'Big Data', 'Анализ данных', 'ML', 'Прогнозирование']",
#        "['Python', 'sklearn', 'Hadoop', 'Numpy', 'CV', 'Deep Learning', 'NLP', 'Spark', 'Pandas', 'ML', 'CatBoost', 'pandas', 'Машинное обучение']",
#        "['Python', 'Machine learning', 'Риск менеджмент', 'Банки', 'Прикладная статистика', 'SQL', 'A/B тесты', 'Pandas', 'ML', 'Fintech', 'Риск аналитика', 'Скоринг', 'Прогнозирование', 'Математическая статистика', 'Теория вероятности', 'Excel', 'Машинное обучение']",
#        "['Python', 'SQL']",
#        "['Python', 'Hadoop', 'Machine Learning', 'Apache Hive', 'Airflow', 'SQL', 'Spark', 'Big Data']",
#        "['Python', 'FastAPI', 'PostgreSQL', 'ORACLE', 'SQL']",
#        "['Python', 'IT', 'data science', 'Разработка поисковых технологий']",
#        "['Портфельные риски', 'кредитные риски', 'Статистический анализ', 'SQL', 'Математическое моделирование', 'PD, LGD, EAD', 'Управление рисками', 'Оценка рисков', 'MS PowerPoint']",
#        "['Data Mining', 'Machine Learning', 'Writing Articles', 'Юнит-экономика', 'Public Speaking', 'Information Technology', 'Fluent English', 'Research']",
#        "['Data Mining', 'Machine Learning', 'Презентация результатов', 'Writing Articles', 'Юнит-экономика', 'Public Speaking', 'Information Technology', 'Fluent English', 'Research']",
#        "['TypeScript', 'Python', 'PHP', 'MySQL', 'Базы данных', 'SQL', 'Spark', 'Elastic Search', 'ClickHouse', 'SCALA']",
#        "['Python', 'R', 'Математический анализ', 'Креативность', 'SQL', 'Математическое моделирование', 'Документация', 'Коммуникация']",
#        "['Python', 'SQL', 'Математическое моделирование', 'Big Data', 'ML', 'Документация']",
#        "['Python', 'Hadoop', 'Креативность', 'confluence', 'Spark', 'ML', 'Документация', 'DL']",
#        "['Python', 'sklearn', 'numpy', 'pytorch', 'Базы данных', 'tensorflow', 'SQL', 'Pandas', 'keras', 'pandas']",
#        "['PyTorch', 'Kaldi', 'librosa', 'ffmpeg', 'soxi', 'TensorFlow']",
#        "['Python', 'нейронная сеть', 'обучение модели', 'CV', 'SQL', 'NLP', 'Computer Vision', 'Pandas', 'ML', 'машинное обучение', 'machine learning']",
#        "['Python', 'Hadoop', 'SQL', 'Spark', 'Pandas', 'Коммуникация']",
#        "['Python', 'CI\\\\CD', 'Pandas', 'ML', 'Документация', 'СУБД', 'Linux']",
#        "['Machine Learning', 'MLE', 'GD', 'CV', 'Deep Learning', 'Data Science', 'DS', 'Computer Vision', 'ML', 'Generative Design', 'Генеративный Дизайн', 'DL', 'Машинное обучение']",
#        "['Python', 'Hadoop', 'Hive', 'Yarn', 'MLFlow', 'Разработка поисковых технологий', 'Spark', 'Проактивность', 'ML', 'HDFS', 'поиск', 'IT']",
#        "['Python', 'Hadoop', 'SQL', 'Математическое моделирование', 'Spark', 'Pandas', 'ML', 'Математическая статистика', 'Коммуникация']",
#        "['Python', 'PyTorch', 'Data Science', 'NLP', 'Computer Vision', 'ML', 'Tensorflow']",
#        "['Python', 'Анализ рисков', 'SQL', 'Английский язык', 'Математическая статистика']",
#        "['Python', 'PyTorch', 'Keras', 'SQL', 'Юнит-экономика', 'Математическая статистика', 'Коммуникация']",
#        "['Python', 'Анализ данных', 'Machine Learning', 'SQL']",
#        "['Python', 'PostgreSQL', 'ORACLE', 'SQL', 'Анализ данных', 'Pandas', 'Документация', 'Git']",
#        "['Python', 'PyTorch', 'Machine Learning', 'Linux', 'Машинное обучение']",
#        "['Python', 'Docker', 'NLP', 'Pandas', 'ML', 'Linux']",
#        "['Python', 'Yandex Cloud Platform', 'Airflow', 'Docker', 'SQL', 'Коммуникация', 'Документация', 'Power BI', 'Kubernetes']",
#        "['Yandex Cloud Platform', 'ETL', 'SQL', 'Документация', 'Power BI', 'Коммуникация']",
#        "['Python', 'Oracle Pl/SQL', 'SQL', 'confluence', 'Big Data', 'ML', 'Машинное обучение']",
#        "['Python', 'Hadoop', 'Machine Learning', 'Hive', 'PySpark', 'SQL', 'Data Science', 'Spark', 'Big Data', 'Pandas', 'Анализ данных', 'Data Analysis', 'ML', 'Машинное обучение']",
#        "['Портфельные риски', 'кредитные риски', 'Статистический анализ', 'SQL', 'Математическое моделирование', 'Pandas', 'PD, LGD, EAD', 'Управление рисками', 'Оценка рисков']",
#        "['Generative design', 'Python', 'Machine Learning', 'AI', 'CV', 'Deep Learning', 'confluence', 'ML', 'LLM']",
#        "['Python', 'Docker', 'NLP', 'Анализ данных', 'LLM', 'Git']",
#        "['Креативность']", "['Python', 'FMCG Продажи', 'SQL']",
#        "['Python', 'PyTorch', 'SQL', 'Pandas', 'Аналитическое мышление']",
#        "['Python', 'PyTorch', 'Sklearn', 'Numpy', 'Data Science', 'NLP']",
#        "['confluence']", "['Python', 'Pandas', 'API', 'SQL']",
#        "['Python', 'NumPy', 'Docker', 'Статистический анализ', 'SQL', 'Flask', 'Scikit-learn', 'Pandas', 'Git', 'Mlflow']",
#        "['Python', 'Моделирование', 'SQL', 'Анализ данных', 'Git']",
#        "['ClickHouse', 'SCALA', 'Java']",
#        "['Data Science', 'OCR', 'OpenCV']",
#        "['Python', 'Математическая статистика', 'Методы оптимизации', 'C++']",
#        "['Python', 'Пусконаладочные работы', 'Создание моделей', 'Математическое моделирование', 'Понимание задач регрессии', 'Документация', 'Оформление описаний', 'Системы автоматического контроля', 'Машинное обучение']",
#        "['Python', 'СУБДД: MS SQL PostgreSQL Oracle', 'Библиотеки: Statsmodels CatBoost GLM', 'Статистический анализ', 'MS SQL', 'SQL', 'Data Science', 'Data Analysis', 'Математическое моделирование', 'Pandas', 'Аналитическое мышление', 'MLflow', 'Apache Airflow', 'Математическая статистика', 'Машинное обучение']",
#        "['Hadoop', 'Kafka', 'Spark', 'Pandas', 'Документация', 'ClickHouse']",
#        "['Математическое моделирование', 'Python', 'PD', 'LGD']",
#        "['Python', 'Hadoop', 'Machine Learning', 'Hive', 'Spark', 'Big Data', 'ML']",
#        "['PyTorch', 'Docker', 'API', 'Linux', 'Git']",
#        "['Python', 'Machine Learning', 'Data Analysis', 'ETL', 'Pandas']",
#        "['Аналитика продаж', 'Oracle Pl/SQL', 'Аналитическое мышление']",
#        "['Python', 'PySpark', 'Machine Learning', 'Big Data']",
#        "['ArcGIS QGIS Git/Gitlab Python пространственные базы данных Agile']",
#        "['Python', 'Data Mining', 'Machine Learning', 'SQL', 'Математическое моделирование', 'Документация', 'Математическая статистика', 'Машинное обучение']",
#        "['PyTorch', 'Python', 'SQL', 'Pandas', 'Tensorflow', 'Atlassian Jira']",
#        "['Recommender systems', 'Java', 'SQL', 'Pandas', 'Python', 'Machine Learning', 'Numpy', 'Mathematics', 'Scikit-learn', 'Scipy', 'Neural nets', 'presto', 'Nlp', 'hadoop', 'PyTorch', 'hive', 'a/b-experiments', 'Анализ данных', 'Search ranking']",
#        "['Проведение презентаций', 'Деловая коммуникация', 'Работа с большим объемом информации', 'Pandas', 'ML', 'машинное обучение', 'Аналитическое мышление', 'Документация', 'ИТ-системы']",
#        "['Python', 'SQL', 'Математическое моделирование', 'Анализ данных', 'Английский язык', 'Коммуникация']",
#        "['Python', 'Machine Learning', 'Spark', 'Big Data', 'ML']",
#        "['Python', 'Data Mining', 'Machine Learning', 'Data Analysis', 'SQL', 'confluence', 'Pandas']",
#        "['Python', 'sklearn', 'boosting', 'seaborn', 'plotly', 'Airflow', 'pyspark', 'Pandas']",
#        "['Python', 'Математический анализ', 'confluence', 'SQL', 'Big Data', 'Документация']",
#        "['Работа с базами данных', 'Базы данных', 'ORACLE', 'SQL']",
#        "['Python', 'data science', 'Deep Learning', 'Разработка поисковых технологий', 'Алгоритмы и структуры данных', 'IT']",
#        "['XML', 'Python', 'Django Framework', 'MS SQL', 'SQL', 'Pandas']",
#        "['Go', 'Python', 'Golang', 'Docker', 'Kafka', 'Java', 'confluence', 'Английский язык', 'Linux', 'Git']",
#        "['rust', 'PyTorch', 'PostgreSQL', 'Cassandra']",
#        "['Python', 'PyTorch', 'Keras', 'Документация', 'TensorFlow']",
#        "['Python', 'confluence', 'SQL', 'ML', 'deep learning']",
#        "['Data Scientist', 'PyTorch', 'Python', 'Аналитик', 'Keras', 'SciPy', 'NumPy', 'Seaborn', 'Scikit-learn', 'Pandas', 'Аналитическое мышление', 'TensorFlow', 'Plotly']",
#        "['Python', 'Анализ данных', 'Git', 'Machine Learning']",
#        "['ClickHouse', 'LLM']",
#        "['Data Science', 'Python', 'Статистика', 'Machine Learning']",
#        "['Machine Learning', 'Data Analysis', 'Data Science', 'Анализ данных', 'ML', 'Аналитика']",
#        "['Python', 'Проактивность', 'MS SQL']",
#        "['Python', 'Hadoop', 'Креативность', 'confluence', 'Spark', 'ML', 'Документация', 'Коммуникация']",
#        "['Python', 'numpy', 'SQL', 'Pandas', 'Документация']",
#        "['Elasticsearch', 'REST API', 'SQL', 'Python', 'RabbitMQ', 'PostgreSQL', 'Spring', 'Data Science', 'REST', 'Юнит-экономика', 'Математическая статистика', 'Redis', 'Data Mining', 'Docker', 'Базы данных', 'Dashboards', 'Работа с базами данных', 'MS SQL Server', 'MySQL', 'JSON API', 'Kafka', 'Асинхронное программирование', 'ETL', 'Linux']",
#        "['Python', 'Hadoop', 'Hive', 'Airflow', 'Docker', 'Confluence', 'MLFlow', 'confluence', 'Spark', 'k8s', 'ClickHouse', 'Atlassian Jira', 'Git']",
#        "['Python', 'Machine Learning', 'Data Science', 'Математическая статистика', 'Git', 'Коммуникация']",
#        "['Python', 'Статистический анализ', 'Data Analysis', 'Анализ данных', 'Pandas', 'Математическая статистика']",
#        "['Python', 'Машинное обучение', 'SQL', 'RecSys', 'Big Data', 'Разработка', 'ML', 'Git', 'pyTorch']",
#        "['Python', 'Моделирование', 'Разработка финансовых моделей', 'Pandas', 'Документация']",
#        "['Python', 'PyTorch', 'Machine Learning', 'Docker', 'NLP', 'Computer Vision', 'Linux', 'Git']",
#        "['Python', 'Коммуникация', 'Machine Learning', 'SQL']",
#        "['Python', 'C/C++', 'C++', 'Qt', 'SQL', 'Linux', 'искусственный интеллект', 'Git', 'Машинное обучение']",
#        "['Python', 'программирование 1С', 'Machine Learning', 'MS SQL', 'SQL', 'Анализ данных', 'Big Data', 'ML', 'машинное обучение', 'Коммуникация']",
#        "['Python', 'программирование 1С', 'Machine Learning', 'MS SQL', 'SQL', 'Анализ данных', 'Big Data', 'ML', 'машинное обучение', 'Pandas']",
#        "['Python', 'MLFlow', 'SQL', 'NLP', 'Pandas', 'ML', 'Linux', 'DVC', 'Git']",
#        "['Python', 'Математический анализ', 'Статистика', 'Статистический анализ', 'Data Science', 'Математическое моделирование', 'Аналитические исследования', 'Анализ данных', 'Pandas', 'Математическая статистика']",
#        "['Коммуникация', 'Документация', 'Креативность', 'confluence']",
#        "['Проактивность']",
#        "['Python', 'classic ML', 'Airflow', 'Deep Learning', 'SQL', 'Data Science', 'Pandas', 'MLflow']",
#        "['Python', 'Pandas', 'SQL']",
#        "['Python', 'sklearn', 'PyTorch', 'Machine Learning', 'Numpy', 'SQL', 'Data Analysis', 'Data Science', 'Big Data', 'Pandas', 'NLP', 'Linux', 'Mathematical Statistics', 'Машинное обучение']",
#        "['Python', 'MS Excel', 'Machine Learning', 'Data Analysis', 'SQL', 'Spark', 'Анализ данных', 'Big Data', 'Аналитическое мышление', 'Английский язык']",
#        "['Аналитическое мышление']",
#        "['Python', 'a/b', 'SQL', 'dwh', 'ml-моделирование']",
#        "['Python', 'PyTorch', 'Hadoop', 'NLP', 'Computer Vision']",
#        "['Data Scientist', 'FinTech', 'Коммуникация']",
#        "['Python', 'Коммуникация', 'Юнит-экономика']",
#        "['ClearML', 'Pyton', 'Data Science', 'Pandas', 'MLflow', 'MLOps']",
#        "['A/B тестирование', 'Python', 'PySpark', 'NLP', 'ML']",
#        "['Python', 'PostgreSQL', 'Работа с базами данных', 'Анализ данных', 'Big Data', 'Pandas', 'Коммуникация']",
#        "['Data Science', 'NLP', 'Python']",
#        "['Планирование карьеры', 'Умение планировать', 'Работа в команде', 'SQL', 'Умение работать в коллективе']",
#        "['Python', 'RBP', 'NCL', 'SQL', 'NPV', 'Pandas']",
#        "['Data Science', 'ML', 'Коммуникация']",
#        "['Python', 'Pandas', 'Git', 'SQL']",
#        "['Machine Learning', 'Data Analysis', 'Data Science', 'Big Data', 'Юнит-экономика', 'Презентация результатов', 'Коммуникация']",
#        "['Python', 'Machine Learning', 'ROS', 'Математический анализ', 'C++', 'Deep Learning', 'NLP', 'Computer Vision', 'Linux']",
#        "['Python', 'Numpy', 'confluence', 'Scikit-learn', 'Pandas', 'Математическая статистика']",
#        "['Python', 'Публичные выступления', 'C++', 'Английский язык', 'Linux']",
#        "['Pandas', 'Документация', 'confluence']",
#        "['Python', 'Коммуникация', 'SQL']",
#        "['Python', 'Аналитическое мышление', 'Power BI', 'Машинное обучение', 'Коммуникация']",
#        "['Python', 'Machine Learning', 'Numpy', 'Математический анализ', 'Deep Learning', 'Data Science', 'Математическое моделирование', 'Big Data', 'Pandas', 'Natural language processing', 'Математическая статистика', 'Машинное обучение']",
#        "['Python', 'PostgreSQL', 'Numpy', 'OpenAI', 'SQL', 'Big Data', 'Pandas', 'Selenium IDE']",
#        "['Принятие решений', 'Pandas']",
#        "['Python', 'OCR', 'NLP', 'Computer Vision', 'Pandas', 'Документация']",
#        "['Python', 'PyTorch', 'CI/CD', 'Machine Learning', 'GitLab', 'Математический анализ', 'Data Analysis', 'Анализ данных', 'Scikit-learn', 'Аналитическое мышление', 'Документация', 'Английский язык', 'Юнит-экономика', 'TensorFlow', 'Презентация результатов', 'Коммуникация']",
#        "['Python', 'PyTorch', 'Принятие решений', 'Data Analysis', 'Анализ данных', 'Scikit-learn', 'Документация', 'Английский язык', 'Юнит-экономика', 'TensorFlow', 'Презентация результатов', 'Коммуникация']",
#        "['Python', 'SQL', 'ML', 'DL', 'Машинное обучение']",
#        "['Коммуникация', 'Документация', 'confluence']",
#        "['Работа с большим объемом информации', 'Работа в команде', 'SQL', 'Data Science', 'ML', 'Английский язык']",
#        "['Pandas', 'Юнит-экономика']",
#        "['Python', 'PyTorch', 'Machine Learning', 'Numpy', 'SQL', 'SciPy']",
#        "['Прогнозирование', 'Deep Learning', 'Time Series']",
#        "['Python', 'pd', 'lgd']",
#        "['Python', 'Docker', 'MLFlow', 'SQL', 'Pandas', 'AirFlow', 'DVC', 'Git']",
#        "['Python', 'data science', 'SQL']",
#        "['A/B тесты', 'Python', 'confluence', 'SQL']",
#        "['Python', 'Numpy', 'VBA', 'Data Analysis', 'SQL', 'Pandas', 'ML', 'Математическая статистика', 'Git']",
#        "['NLP', 'Юнит-экономика']",
#        "['LTV prediction', 'SQL', 'RecSys', 'A/B тесты', 'Анализ данных', 'Churn prediction', 'Ulift modeling']",
#        "['Python', 'Numpy', 'Data Analysis', 'SQL', 'Pandas']",
#        "['Python', 'Machine Learning', 'Docker', 'SQL', 'A/B тесты', 'Pandas', 'Документация', 'Git']",
#        "['confluence', 'RecSys', 'Machine learning', 'Data science', 'Коммуникация']",
#        "['Pandas', 'Документация', 'Юнит-экономика']",
#        "['PyTorch', 'Python', 'Pandas', 'Проактивность', 'Linux', 'Kubernetes']",
#        "['Python', 'SQL', 'Spark', 'Big Data', 'Английский язык', 'Linux']",
#        "['Python', 'Numpy', 'MySQL', 'SQL', 'Pandas', 'ML', 'Документация']",
#        "['scikit-learn', 'lightgbm', 'SQL', 'scipy', 'Python', 'Machine Learning', 'data science', 'search ranking', 'Mathematics', 'neural nets', 'numpy', 'recommender systems', 'pandas', 'presto', 'hadoop', 'PyTorch', 'hive', 'pytorch', 'a/b-experiments', 'nlp', 'Анализ данных']",
#        "['Python', 'Hadoop', 'PySpark', 'MLFlow', 'SQL', 'confluence', 'Spark']",
#        "['Python', 'FastAPI', 'PostgreSQL', 'Hive', 'Greenplum', 'Airflow', 'Docker', 'PySpark', 'SQL', 'Data Science', 'ML', 'MLflow', 'Документация']",
#        "['Pandas', 'Документация', 'Аналитическое мышление']",
#        "['Python', 'PyTorch', 'Xgboost', 'HuggingFace', 'Arima', 'Numpy', 'Catboost', 'Pandas', 'Tensorflow']",
#        "['Python', 'PyTorch', 'NumPy', 'Docker', 'Deep Learning', 'ONNX', 'Scikit Learn', 'OpenCV', 'Коммуникация']",
#        "['Python', 'Machine Learning', 'Математический анализ', 'Data Analysis', 'Big Data', 'Аналитические исследования', 'Документация', 'data Scientist', 'Прогнозирование', 'Математическая статистика']",
#        "['Python', 'sklearn', 'Hadoop', 'Numpy', 'CV', 'Deep Learning', 'NLP', 'Spark', 'Pandas', 'ML', 'catboost', 'Машинное обучение']",
#        "['Python', 'Machine Learning', 'NLP', 'Pandas', 'AI/ML']",
#        "['Python', 'Статистический анализ', 'SQL', 'Анализ данных', 'Pandas', 'Математическая статистика']",
#        "['Python', 'statsmodels', 'numpy', 'PowerPoint', 'scipy', 'Pandas', 'pandas', 'Excel']",
#        "['Python', 'PyTorch', 'Scikit learn', 'Data Mining', 'Статистический анализ', 'Data Analysis', 'Анализ данных', 'Pandas', 'ML', 'LLM']",
#        "['Python', 'Data Mining', 'Data Analysis', 'Анализ данных', 'Аналитическое мышление', 'Английский язык', 'Git']",
#        "['Коммуникация', 'Юнит-экономика']",
#        "['Python', 'Machine Learning', 'Базы данных', 'дашборд', 'Анализ данных', 'Pandas', 'Аналитическое мышление', 'Linux', 'Аналитика', 'Математическая статистика', 'Сбор и анализ информации']",
#        "['sklearn', 'Python', 'lightgbm', 'numpy', 'Machine Learning', 'matploblib&seaborn', 'xgboost', 'tensorflow', 'docker', 'Data Science', 'Big Data', 'Pandas', 'Документация', 'pandas', 'torch']",
#        "['Python', 'SQL', 'Анализ данных', 'Математическая статистика', 'Аналитическое мышление', 'Sas']",
#        "['A/B тесты', 'Python', 'Big Data', 'Machine Learning']",
#        "['Python', 'Pandas', 'Английский язык', 'Data Analysis']",
#        "['Python', 'Data Mining', 'Математический анализ', 'Регрессионный анализ', 'Статистический анализ', 'Deep Learning', 'Креативность', 'Математическое моделирование', 'Big Data', 'MATLAB', 'Математическая статистика']",
#        "['Python', 'Data Science', 'Экономика', 'Операционная эффективность', 'IT']",
#        "['Python', 'Hadoop', 'Hive', 'SQL', 'Spark', 'ML']",
#        "['sklearn', 'Pandas', 'CatBoost', 'Time Series']",
#        "['Python', 'Machine Learning', 'MS SQL', 'SQL', 'Математическая статистика']",
#        "['CV', 'ИТ', 'NLP', 'ML', 'IT']",
#        "['Pricing', 'Python', 'Big Data', 'Machine Learning']",
#        "['Портфельные риски', 'Python', 'SQL', 'Анализ данных', 'Machine learning']",
#        "['Прогнозирование', 'Mathematical Statistics', 'Machine Learning', 'Data Science']",
#        "['Python', 'MLFlow', 'SQL', 'NLP', 'Pandas', 'LLM', 'DVC']",
#        "['Python', 'Machine Learning', 'SQL', 'Data Science', 'Математическое моделирование', 'Коммуникация']",
#        "['Python', 'English', 'Geology', 'Data Science', 'Письменная коммуникация', 'Документация', 'Geoscience', 'Linux', 'CI/CD', 'Юнит-экономика', 'Git', 'Презентация результатов', 'Коммуникация']",
#        "['Python', 'PyTorch', 'Keras', 'Machine Learning', 'numpy', 'matplotlib', 'CV', 'Data Science', 'Computer Vision', 'Pandas', 'ML', 'Tensorflow', 'pandas', 'opencv']",
#        "['Python', 'Machine Learning', 'Data Science', 'Математическое моделирование', 'Spark', 'Pandas', 'Математическая статистика']",
#        "['Python', 'Hadoop', 'Hive', 'SQL', 'Spark', 'Анализ данных', 'ML']",
#        "['ML', 'Python', 'Управление командой', 'SQL']",
#        "['Python', 'Machine Learning', 'SQL', 'Pandas', 'ML']",
#        "['HuggingFace', 'Pytorch', 'OpenCV', 'Torchvision']",
#        "['Математический анализ', 'Python', 'Machine Learning', 'SQL']",
#        "['ETL', 'Data Analysis', 'Работа с базами данных', 'SQL']",
#        "['Математическое моделирование', 'Python', 'Документация', 'SQL']",
#        "['Python', 'SQL', 'Pandas', 'ML', 'deep learning']",
#        "['Time Series Analysis', 'Python', 'Machine Learning', 'Data Analysis', 'Data Science', 'Анализ данных', 'Pandas', 'Анализ временных рядов', 'Математическая статистика']",
#        "['Адаптивность', 'confluence']",
#        "['Python', 'SQL', 'Pandas', 'Машинное обучение', 'Коммуникация']",
#        "['ChatGPT', 'Vicuna', 'Python', 'Machine Learning', 'Работа с базами данных', 'Базы данных', 'Data Science', 'NLP', 'Аналитические исследования', 'Анализ данных', 'ML', 'Аналитическое мышление', 'AWS', 'Mistral', 'Llama', 'LLM', 'Машинное обучение']",
#        "['Python', 'PyTorch', 'Machine Learning', 'data science', 'a/b-experiments', 'Docker', 'Pandas', 'recommender systems', 'Коммуникация']",
#        "['Python', 'PostgreSQL', 'Linux', 'Elasticsearch', 'Grafana', 'SQL', 'Pandas', 'Документация', 'Аналитическое мышление', 'Clickhouse', 'Коммуникация']",
#        "['Python', 'Работа с базами данных', 'Математический анализ', 'SQL', 'Pandas', 'Аналитическое мышление', 'Прогнозирование', 'Математическая статистика', 'Машинное обучение']",
#        "['Python', 'C/C++', 'NLU', 'MySQL', 'NLP', 'Pandas', 'ML', 'Английский язык', 'ClickHouse']",
#        "['Python', 'PostgreSQL', 'SQL', 'A/B тесты', 'ML', 'Коммуникация']",
#        "['Python', 'numpy', 'SQL', 'Data Science', 'confluence', 'Pandas', 'ML', 'pandas', 'Машинное обучение']",
#        "['Python', 'Data Mining', 'Pandas', 'Tensorflow', 'Pytorch', 'Linux', 'Git']",
#        "['Управление командой', 'Разработка поисковых технологий', 'Data Science', 'ML', 'IT', 'Коммуникация']",
#        "['Python', 'PySpark', 'SQL', 'Pandas', 'ML']",
#        "['System design', 'Python', 'Machine Learning', 'SQL']",
#        "['Python', 'Математическая статистика', 'Pandas', 'SQL']",
#        "['Python', 'Jupyter notebook, PySpark', 'ClickHouse, PostgreSQL', 'Pandas', 'Коммуникация']",
#        "['Python', 'it', 'Торговая площадка', 'SQL', 'API', 'Коммуникация']",
#        "['AI', 'Python', 'Документация']",
#        "['Python', 'NumPy', 'SQL', 'Pandas', 'Machine learning', 'Коммуникация']",
#        "['IT', 'Документация', 'Торговая площадка']",
#        "['Python', 'scikit-learn', 'PostgreSQL', 'Numpy', 'Работа с базами данных', 'Математический анализ', 'Docker', 'Работа с большим объемом информации', 'REST API', 'Data Analysis', 'Pandas', 'Git']",
#        "['Теория вероятностей', 'Python', 'sklearn', 'Sklearn', 'Алгоритмы', 'Numpy', 'MongoDB', 'Базы данных', 'MS SQL', 'SQL', 'Data Science', 'Математическое моделирование', 'Pandas', 'ML', 'Коммуникация', 'Математическая статистика', 'Машинное обучение']",
#        "['Python', 'PostgreSQL', 'MS SQL', 'SQL', 'ETL', 'Data Analysis', 'Анализ данных', 'Apache Airflow', 'Clickhouse', 'Git']",
#        "['PyTorch', 'Python', 'Image Classification', 'CV', 'Image Segmentation', 'OpenCV', 'GradCam']",
#        "['Redis', 'Python', 'Machine Learning', 'MongoDB', 'SQL', 'ML', 'NoSQL', 'ElasticSearch', 'Kubernetes']",
#        "['Документация', 'Юнит-экономика']",
#        "['NLP', 'Pandas', 'Коммуникация', 'confluence']",
#        "['Python', 'Работа в команде', 'Статистический анализ', 'Pandas', 'Английский язык', 'Sas', 'R-Studio']",
#        "['Python', 'Deep learning', 'Data Science', 'ML', 'Pytorch', 'Machine learning', 'Математическая статистика', 'DNN']",
#        "['Data Scientist', 'Python', 'Data Analysis', 'SQL', 'NLP', 'Аналитические исследования', 'ML', 'Аналитическое мышление', 'LLM']",
#        "['Python', 'Machine Learning', 'SQL', 'Data Science', 'confluence', 'Big Data', 'Pandas', 'ML', 'NLP модели', 'Математическая статистика']",
#        "['Внимание к деталям', 'Python', 'Принятие решений', 'Адаптивность', 'Работа в команде', 'SQL', 'Data Analysis', 'Лидерство', 'Google Analytics', 'Pandas', 'Юнит-экономика']",
#        "['Python', 'Математическая статистика', 'Анализ данных', 'SQL']",
#        "['Python', 'PyTorch']", "['PyTorch', 'TensorFlow', 'OpenCV']",
#        "['Работа с базами данных', 'Базы данных', 'Статистический анализ', 'SQL', 'Pandas', 'Tableau']",
#        "['Python', 'Keras', 'Deep Learning', 'Scikit-learn', 'Pandas', 'ML', 'Алгоритмы и структуры данных']",
#        "['Python', 'Hadoop', 'Hive', 'SQL', 'Spark', 'Computer Vision', 'NLP', 'ML', 'Pytorch', 'Pandas', 'Нейросети', 'Математическая статистика']",
#        "['Python', 'Machine Learning', 'Математический анализ', 'SQL', 'Pandas', 'Английский язык', 'Коммуникация']",
#        "['LangChain', 'PyTorch', 'Python', 'RAG', 'ReAct', 'NLP', 'VectorDB', 'Llama', 'LLM', 'LlamaIndex']",
#        "['Управление командой', 'Управление рисками']",
#        "['Python', 'Анализ данных', 'Аналитическое мышление', 'SQL']",
#        "['Python', 'Machine Learning', 'SQL', 'Big Data', 'Pandas']",
#        "['Python', 'Machine Learning', 'CV', 'confluence', 'SQL']",
#        "['Python', 'Математическая статистика', 'Machine Learning']",
#        "['Python', 'Machine Learning', 'Spark', 'Big Data', 'ML', 'Математическая статистика']",
#        "['Коммуникация', 'Документация', 'Юнит-экономика']",
#        "['GPT', 'RAG', 'BERT', 'Документация', 'Retrieval-Augmented Generation']",
#        "['Redis', 'Python', 'Golang', 'Machine Learning', 'SQL', 'A/B тесты', 'ClickHouse']",
#        "['Python', 'Управление командой', 'Разработка поисковых технологий', 'Data Science', 'IT']",
#        "['NLP', 'Pandas', 'ML', 'confluence']",
#        "['АВ-тестирование', 'Python', 'Математическая статистика', 'SQL']",
#        "['Python', 'Data Mining', 'SQL', 'NLP', 'Аналитические исследования', 'ML']",
#        "['Python', 'ML/DL', 'NLP', 'Pandas', 'Аналитическое мышление']",
#        "['Python', 'Pandas', 'Аналитическое мышление', 'NLP']",
#        "['scikit-learn', 'matplotlib', 'GRU', 'lightGBM', 'XGBoost', 'Pandas', 'Principal Component Analysis', 'Decision Tree', 'Data Scientist', 'Python', 'Attention Mechanism', 'LSTM', 'ИИ', 'Linear Regression', 'numpy', 'plotly', 'MLP', 'CatBoost', 'искусственный интеллект', 'statsmodels', 'Random Forest', 'ML', 'Документация', 'ARIMA']",
#        "['Python', 'Обучение и развитие', 'Математический анализ', 'Статистический анализ', 'Pandas', 'Прогнозирование', 'Математическая статистика']",
#        "['OCR', 'confluence', 'NLP', 'Документация', 'Atlassian Confluence', 'Jira', 'Git', 'Машинное обучение']",
#        "['Power BI', 'Python', 'data science', 'Коммуникация']",
#        "['Python', 'Работа с большим объемом информации', 'Анализ бизнес показателей', 'Моделирование бизнес процессов', 'Data Analysis', 'Анализ данных', 'Аналитическое мышление']",
#        "['Python', 'Data Science', 'NLP', 'Машинное обучение', 'Коммуникация']",
#        "['Python', 'SciPy', 'SQL', 'Mathematical Statistics', 'Грамотность']",
#        "['Анализ данных', 'Документация', 'Аналитическое мышление']",
#        "['Python', 'NLP', 'Deep Learning', 'Machine Learning']",
#        "['Коммуникация', 'confluence']",
#        "['Python', 'PyTorch', 'SQL', 'NLP', 'Spark', 'Pandas', 'ML']",
#        "['Мотивация персонала', 'Алгоритмы', 'Airflow', 'Лидерство', 'Spark', 'Pandas', 'Коммуникабельность', 'Организаторские навыки', 'Python', 'Machine Learning', 'Data Science', 'Высокие коммуникативные навыки', 'Kubernetes', 'Машинное обучение', 'Docker', 'Hadoop', 'Управление командой', 'MySQL', 'Kafka', 'Big Data', 'ML', 'Управленческие навыки']",
#        "['Деловая коммуникация', 'SQL', 'Data Science', 'Cистемы управления базами данных', 'Принципы работы БД', 'Проектный менеджмент', 'Организационное проектирование']",
#        "['Python', 'Big Data', 'Machine Learning', 'Linux']",
#        "['Python', 'Machine Learning', 'Статистика', 'Статистический анализ', 'SQL', 'Data Science', 'Анализ данных', 'Аналитические исследования', 'Pandas', 'Английский язык', 'Linux', 'Прогнозирование', 'Математическая статистика', 'Машинное обучение']",
#        "['Python', 'ICAAP', 'SQL', 'Spark', 'Документация', 'Basel']",
#        "['Python', 'Работа с большим объемом информации', 'Pandas', 'SQL']",
#        "['Python', 'SQL', 'Pandas', 'ML', 'ML-алгоритмы', 'SOTA-методы']",
#        "['Python', 'PostgreSQL', 'Machine Learning', 'SQL', 'Pandas', 'Аналитическое мышление']",
#        "['Python', 'SQL', 'Google Analytics', 'Документация', 'Математическая статистика']",
#        "['Python', 'SQL', 'Pandas', 'Power BI', 'Linux', 'Коммуникация']",
#        "['Python', 'Machine Learning', 'Data Science', 'NLP', 'Pandas', 'ML', 'Проактивность']",
#        "['Python', 'Базовые знания SQL']",
#        "['Python', 'Data Analysis', 'Spark', 'Анализ данных', 'Pandas', 'Математическая статистика']",
#        "['Python', 'Machine Learning', 'Руководство коллективом', 'NLP', 'Pandas', 'Linux']",
#        "['Python', 'R', 'CRM', 'Риски', 'Моделирование', 'SQL', 'Data Sceince', 'Скоринг']",
#        "['Python', 'Machine Learning', 'Статистический анализ', 'SQL', 'Аналитическое мышление', 'Математическая статистика', 'Машинное обучение']",
#        "['Python', 'PyTorch', 'Keras', 'Machine Learning', 'NumPy', 'SQL', 'Data Science', 'Pandas', 'Scikit-Learn', 'TensorFlow']",
#        "['Python', 'PyTorch', 'Machine Learning', 'NumPy', 'SQL', 'Data Science', 'NLP', 'Pandas', 'Scikit-Learn']",
#        "['Python', 'sklearn', 'numpy', 'Docker', 'XGBoost', 'SQL.', 'ML', 'scipy', 'pandas', 'Shap/Lime', 'Pandas', 'Документация', 'WoE']",
#        "['PostgreSQL', 'Machine Learning', 'JavaScript', 'Data Analysis', 'Data Science', 'NLP', 'Анализ данных', 'Английский язык', 'Юнит-экономика', 'LLM', 'prompt engineering']",
#        "['Python', 'MS SQL', 'SQL', 'Математическое моделирование', 'Аналитические исследования', 'Pandas']",
#        "['Python', 'Работа с базами данных', 'SQL', 'Математическое моделирование', 'Аналитические исследования', 'ML']",
#        "['Python', 'PD', 'LGD', 'Переговоры', 'Математическое моделирование']",
#        "['Python', 'Machine Learning', 'Analytical skills', 'Dynamic Pricing', 'Data Analysis', 'Data Science', 'Revenue Management', 'Information Technology', 'Digital Marketing']",
#        "['Python', 'doker', 'SQL', 'Pandas', 'Git']",
#        "['Python', 'Управление командой', 'GitLab', 'Docker', 'SQL', 'confluence', 'Agile Project Management', 'Pandas', 'Atlassian Jira', 'Разработка ПО', 'Машинное обучение']",
#        "['IT', 'Разработка поисковых технологий']",
#        "['Python', 'Hadoop', 'Spark', 'Pandas', 'ML']",
#        "['Python', 'data science', 'Разработка поисковых технологий', 'NLP', 'IT']",
#        "['Python', 'SQL', 'Spark', 'NLP', 'Pandas', 'ML']",
#        "['AL', 'ML', 'ИИ', 'Креативность']",
#        "['Python', 'TensorPT', 'SQL', 'NamPy', 'Computer Vision', 'Pandas', 'ML', 'Документация', 'OpenCV']",
#        "['Spark', 'Битрикс24', 'amoCRM', 'Английский язык']",
#        "['Python', 'SQL', 'Data Analysis']",
#        "['Python', 'Работа с базами данных', 'MS SQL', 'Data Analysis', 'SQL']",
#        "['Data Scientist', 'PostgreSQL', 'MS SQL', 'confluence', 'NLP', 'Анализ данных', 'Аналитические исследования', 'СУБД']",
#        "['Python', 'sklearn', 'Data Mining', 'pytorch', 'plotly', 'xgboost', 'NLP', 'Анализ данных', 'Pandas', 'scipy', 'Machine learning', 'Машинное обучение']",
#        "['Python', 'MS Excel', 'Numpy', 'Статистический анализ', 'SQL', 'Jupiter', 'Pandas', 'pandas', 'Прогнозирование', 'Математическая статистика']",
#        "['Python', 'Научная деятельность', 'владение методами XAI', 'понимание принципов обучения, тюнинга, оценки deeplearning моделей', 'уверенное владение Python и основными ML-библиотеками, опыт их применения на практике', 'Написание научных статей', 'опыт работы с NLP, знание стека от TF-IDFдо LLM', '- умение читать и разбирать статьи о новых архитектурах и подходах', 'Pandas', 'Английский язык', 'владение Pandas, NumPy, Scikit-learn, PyTorch', 'опыт отладки нейронных сетей и модификации архитектур или создания собственных']",
#        "['Python', '\\uf02d понимание принципов обучения, тюнинга, оценки deeplearning моделей', '\\uf02d умение читать и разбирать статьи о новых архитектурах и подходах', '\\uf02d владение Pandas, NumPy, Scikit-learn, PyTorch', 'Pandas', 'Английский язык', '\\uf02d владение Python и основными ML-библиотеками, опыт их применения на практике']",
#        "['Python', 'Docker', 'Git', 'SQL']",
#        "['Python', 'Machine Learning', 'Big Data', 'Pandas', 'Математическая статистика']",
#        "['Python', 'Data Mining', 'Математическая статистика', 'Git', 'Машинное обучение']",
#        "['Python', 'PyTorch', 'Keras', 'Решение нестандартных задач', 'Удаленная работа', 'Гибкость мышления', 'Анализ данных', 'Аналитическое мышление', 'Tensorflow', 'Gamedev', 'ML', 'Нейросеть', 'Математический склад ума', 'Машинное обучение', 'Разработка компьютерных Игр']"],
#       dtype=object)

# %% [markdown]
# Значения столбца представляют собой *списки обернутые в строку*, также присутствуют пустые списки - "[]". Найдём количество таких вакансий.

# %%
df_da.query('key_skills == "[]"')['key_skills'].count()
# Out:
# 273

# %%
df_ds.query('key_skills == "[]"')['key_skills'].count()
# Out:
# 128

# %% [markdown]
# 273 и 128 - это много, удалить не получится. Необходимо заменить на частотные значения. Найдём их.

# %%
# превращаем список обернутый в строку в список
list_key_skills = []
for i in df_da['key_skills']:
    i = eval(i)
    list_key_skills.append(i)

# %%
# объединяем список списков в единый список
big_list_key_skills = []
for i in list_key_skills:
    for z in i:
        big_list_key_skills.append(z)
all_key = pd.DataFrame(big_list_key_skills)

all_key.columns = ['skills']

all_key.head()
# Out:
#      skills
# 0  Power BI
# 1      СУБД
# 2    Python
# 3       SQL
# 4    MS SQL

# %% [markdown]
# Теперь можем посмотреть на самые требуемые навыки.

# %%
all_key.value_counts().head(10)
# Out:
# skills
# SQL                                    602
# Python                                 452
# Анализ данных                          332
# Аналитическое мышление                 300
# Pandas                                 230
# Документация                           211
# Power BI                               183
# MS Excel                               168
# Работа с базами данных                 155
# Работа с большим объемом информации    149
# Name: count, dtype: int64

# %% [markdown]
# Нашли топ-10 самых востребованных навыков для аналитиков данных.<br>
# Теперь создадим функцию для определения навыков, для того чтобы выделить навыки в зависимости от категории требуемого опыта, а затем заполнить наиболее частотными значениями пропуски в столбце.

# %%
def top_skills(series):
    # убираем "обёртку" от строки и сохраняем в отдельный список - получится список списков
    list_top_skills = []
    for i in series:
        i = eval(i)
        list_top_skills.append(i)

    # перебираем списки, а затем элементы списка и сохраняем в общий список
    big_list_top_skills = []
    for i in list_top_skills:
        for z in i:
            big_list_top_skills.append(z)

    # конвертируем список в датафрейм
    df_skills = pd.DataFrame(big_list_top_skills)

    df_skills.columns = ['skills']

    return df_skills

# %%
# нарезаем датафреймы по требуемому опыту
df_da_jun1 = df_da.query('experience == "Junior (no experince)"')
df_da_jun2 = df_da.query('experience == "Junior+ (1-3 years)"')
df_da_mid = df_da.query('experience == "Middle (3-6 years)"')
df_da_sen = df_da.query('experience == "Senior (6+ years)"')

# %% [markdown]
# #### Заполнение пропусков стлбца 'key_skills' DA

# %% [markdown]
# Теперь воспользуемся нашей функцией для каждого датафрейма и выведем топ-10 навыков. А затем заменим пропуски на 5 самых чатотных навыков.

# %%
top_skills(df_da_jun1['key_skills']).value_counts().head(10)
# Out:
# skills
# Аналитическое мышление                 33
# SQL                                    30
# Анализ данных                          27
# Python                                 26
# MS Excel                               25
# Работа с большим объемом информации    17
# Pandas                                 15
# Коммуникация                           15
# Документация                           15
# Базы данных                            12
# Name: count, dtype: int64

# %% [markdown]
# Получили топ-10 навыков для DA уровня Junior (no experince). Среди основных требований: Аналитическое мышление, SQL, Анализ данных.

# %% [markdown]
# Заменим пропуски на 5 самых популярных навыков.

# %%
df_da.loc[(df_da['experience'] == 'Junior (no experince)') & (df_da['key_skills'] == '[]'), 'key_skills'] = \
    "['Аналитическое мышление', 'SQL', 'Анализ данных', 'Python', 'MS Excel']"

# %%
df_da.loc[(df_da['experience'] == 'Junior (no experince)') & (df_da['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Проделаем то же самое для остальных категорий DA. На очереди Junior+ (1-3 years).

# %%
top_skills(df_da_jun2['key_skills']).value_counts().head(10)
# Out:
# skills
# SQL                                    371
# Python                                 249
# Анализ данных                          213
# Аналитическое мышление                 198
# Pandas                                 131
# MS Excel                               114
# Power BI                               114
# Документация                           111
# Работа с базами данных                 105
# Работа с большим объемом информации     99
# Name: count, dtype: int64

# %% [markdown]
# В целом набор требований изменился не сильно, изменились места. Для Junior+ (1-3 years) обязательным является SQL, Python и Анализ данных.

# %%
df_da.loc[(df_da['experience'] == 'Junior+ (1-3 years)') & (df_da['key_skills'] == '[]'), 'key_skills'] = \
    "['SQL', 'Python', 'Анализ данных', 'Аналитическое мышление', 'Pandas']"

# %%
df_da.loc[(df_da['experience'] == 'Junior+ (1-3 years)') & (df_da['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Переходим к Middle (3-6 years).

# %%
top_skills(df_da_mid['key_skills']).value_counts().head(10)
# Out:
# skills
# SQL                       195
# Python                    171
# Анализ данных              91
# Документация               83
# Pandas                     82
# Аналитическое мышление     67
# Power BI                   59
# Data Analysis              48
# Коммуникация               45
# Работа с базами данных     40
# Name: count, dtype: int64

# %% [markdown]
# В целом набор требований также не сильно изменился. Для Middle (3-6 years) также обязательным является SQL, Python. Чуть меньше требуется Анализ данных, Документация и Pandas

# %%
df_da.loc[(df_da['experience'] == 'Middle (3-6 years)') & (df_da['key_skills'] == '[]'), 'key_skills'] = \
    "['SQL', 'Python', 'Анализ данных', 'Документация', 'Pandas']"

# %%
df_da.loc[(df_da['experience'] == 'Middle (3-6 years)') & (df_da['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Идём к Senior (6+ years).

# %%
top_skills(df_da_sen['key_skills']).value_counts().head(10)
# Out:
# skills
# SQL                           6
# Python                        6
# Power BI                      3
# Проактивность                 3
# Pandas                        2
# Аналитическое мышление        2
# Аналитические исследования    2
# Документация                  2
# confluence                    2
# Tableau                       2
# Name: count, dtype: int64

# %% [markdown]
# Для Senior (6+ years) помимо SQL и Python становится обязательным требованием владение Power BI и Проактивность. Также появляется требование владеть confluence и Tableau.

# %%
df_da.loc[(df_da['experience'] == 'Senior (6+ years)') & (df_da['key_skills'] == '[]'), 'key_skills'] = \
    "['SQL', 'Python', 'Power BI', 'Проактивность', 'Pandas']"

# %%
df_da.loc[(df_da['experience'] == 'Senior (6+ years)') & (df_da['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# #### Заполнение пропусков стлбца 'key_skills' DS

# %% [markdown]
# Разобрались с пропусками в вакансиях DA. Переходим к DS. Выполним те же операции: нарежем датафреймы по группам опыта. Воспользовавшись функцией, найдём топ-10 навыков каждой группы и заменим пропуски на 5 самых востребованных.

# %%
# нарезаем датафреймы по требуемому опыту
df_ds_jun1 = df_ds.query('experience == "Junior (no experince)"')
df_ds_jun2 = df_ds.query('experience == "Junior+ (1-3 years)"')
df_ds_mid = df_ds.query('experience == "Middle (3-6 years)"')
df_ds_sen = df_ds.query('experience == "Senior (6+ years)"')

# %% [markdown]
# Первая группа Junior (no experince).

# %%
top_skills(df_ds_jun1['key_skills']).value_counts().head(10)
# Out:
# skills
# Python                       17
# Математическая статистика     9
# Data Mining                   7
# Pandas                        6
# Git                           6
# Machine Learning              5
# Машинное обучение             5
# Документация                  4
# ML                            4
# Анализ данных                 3
# Name: count, dtype: int64

# %% [markdown]
# В топ-10 требований для DS Junior (no experince) попадают: Python, Машинное обучение, Математическая статистика, Data Mining. Сразу видны первые отличия от требований для DA - появились Математическая статистика, Git, Машинное обучение.

# %%
df_ds.loc[(df_ds['experience'] == 'Junior (no experince)') & (df_ds['key_skills'] == '[]'), 'key_skills'] = \
    "['Python', 'Математическая статистика', 'Data Mining', 'Pandas', 'Git']"

# %%
df_ds.loc[(df_ds['experience'] == 'Junior (no experince)') & (df_ds['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Переходим к категории Junior+ (1-3 years).

# %%
top_skills(df_ds_jun2['key_skills']).value_counts().head(10)
# Out:
# skills
# Python                       152
# Pandas                       145
# SQL                          107
# Machine Learning              51
# Документация                  44
# Коммуникация                  37
# Математическая статистика     32
# ML                            28
# Big Data                      28
# Data Science                  26
# Name: count, dtype: int64

# %% [markdown]
# Для Junior+ (1-3 years) обязательными являютя - Python, Pandas, SQL. Чуть менее желаемы  Machine Learning и Документация.

# %%
df_ds.loc[(df_ds['experience'] == 'Junior+ (1-3 years)') & (df_ds['key_skills'] == '[]'), 'key_skills'] = \
    "['Python', 'Pandas', 'SQL', 'Machine Learning', 'Документация']"

# %%
df_ds.loc[(df_ds['experience'] == 'Junior+ (1-3 years)') & (df_ds['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Далее Middle (3-6 years).

# %%
top_skills(df_ds_mid['key_skills']).value_counts().head(10)
# Out:
# skills
# Python              167
# Pandas              121
# SQL                  89
# Документация         70
# ML                   51
# Machine Learning     47
# Коммуникация         47
# Data Science         32
# confluence           29
# NLP                  29
# Name: count, dtype: int64

# %% [markdown]
# Для Middle (3-6 years) специалистов требования не изменились. Обязательны Python, Pandas, Machine Learning, SQL и Документация.

# %%
df_ds.loc[(df_ds['experience'] == 'Middle (3-6 years)') & (df_ds['key_skills'] == '[]'), 'key_skills'] = \
    "['Python', 'Pandas', 'SQL', 'Machine Learning', 'Документация']"

# %%
df_ds.loc[(df_ds['experience'] == 'Middle (3-6 years)') & (df_ds['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Остались Senior (6+ years).

# %%
top_skills(df_ds_sen['key_skills']).value_counts().head(10)
# Out:
# skills
# Python                 12
# Документация            7
# Pandas                  7
# ML                      5
# Data Science            4
# PyTorch                 4
# Machine Learning        4
# SQL                     4
# Управление командой     3
# Коммуникация            3
# Name: count, dtype: int64

# %% [markdown]
# Основные требования - Python, Machine Learning, Документация и Pandas. Добавились также Управление командой и Коммуникация - потому что специалисты такого уровня, как правило, являются лидами команды.

# %%
df_ds.loc[(df_ds['experience'] == 'Senior (6+ years)') & (df_ds['key_skills'] == '[]'), 'key_skills'] = \
    "['Python', 'Pandas', 'Data Science', 'Machine Learning', 'Документация']"

# %%
df_ds.loc[(df_ds['experience'] == 'Senior (6+ years)') & (df_ds['key_skills'] == '[]')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# ### Столбец schedule

# %% [markdown]
# Столбец представляет собой тип графика работы, который указывается в заголовке вакансии на hh.ru.

# %%
df_da['schedule'].value_counts()
# Out:
# schedule
# Полный день         1097
# Удаленная работа     247
# Гибкий график         31
# Сменный график         6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_da['schedule'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Распределение занятости по количеству вакансий DA', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Тип занятости', fontsize=12);

# %% [markdown]
# Абсолютное большинство работодателей хотели бы задействовать специалистов DA на полный рабочий день - 1097 вакансий, в 4 раза меньше на удалённой работе - 247 вакансий, ещё в 8 раз меньше на гибком графике - 31 и 8 вакансий на сменном графике.

# %%
df_ds['schedule'].value_counts()
# Out:
# schedule
# Полный день         548
# Удаленная работа    167
# Гибкий график        38
# Сменный график        3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_ds['schedule'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Распределение занятости по количеству вакансий DA', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Тип занятости', fontsize=12);

# %% [markdown]
# Почти такая же картина наблюдается у DS. Такой же порядок, но немного другие пропорции.

# %% [markdown]
# В целом анамалий не выявленно.

# %% [markdown]
# ### Столбец employment

# %% [markdown]
# Столбец представляет собой тип занятости, также полученный из заголовка вакансии на hh.ru.

# %%
df_da['employment'].value_counts()
# Out:
# employment
# Полная занятость       1350
# Стажировка               14
# Частичная занятость      13
# Проектная работа          4
# Name: count, dtype: int64

# %%
df_ds['employment'].value_counts()
# Out:
# employment
# Полная занятость       726
# Стажировка              17
# Частичная занятость      8
# Проектная работа         5
# Name: count, dtype: int64

# %% [markdown]
# Аномалий не выявленно. Абсолютное большинство работодателей предлагают полную занятость - около 97 % и на 3 % приходится - стажировка, частичная занятость, проектная работа.

# %% [markdown]
# ### Столбец description

# %% [markdown]
# Столбец представляет собой описание вакансии, полученный из описания в тексте вакансии на hh.ru.

# %%
df_da['description'].unique()
# Out:
# array(['наше направление занимается повышением эффективности каналов продаж и улучшением взаимодействия с клиентами. для достижения этой цели мы собираем очень много данных о работе наших магазинов, создаем и развиваем систему отчетности, а также проводим различные исследования для бизнеса и принимаем участие в бизнес-проектах направления.  мы в поиске аналитика данных, который хочет:- много работать с данными - проводить исследования - помогать бизнесу находить ответы на интересующие вопросы твои основные задачи:  участие в процессе исследований: сбор необходимых данных и их последующая обработка; проверка гипотез; оформление выводов, интерпретация результатов написание ad-hoc запросов постановка задач на автоматизацию сбора данных разработка дашбордов  что мы ждем от тебя:    уверенное владение sql    базовые знания статистики  развитые коммуникативные навыки критическое мышление  будет плюсом:     опыт работы с python  знания основных концепций в работе с данными (типы данных, методы простой обработки, агрегации, фильтрации)   опыт работы с bi-системами     условия: у нас действует система грейдов. заработная плата зависит от навыков и знаний. для роста необходимо обучаться, для этого мы:   закрепляем наставника,   собрали базу знаний,   компенсируем обучение на сторонних курсах 70%,   ездим на конференции за счет компании,   у нас официальное трудоустройство с первого рабочего дня. полностью &quot;белая&quot; заработная плата, выплаты 2 раза в месяц на карту от банка-партнера с дополнительными бонусами. есть корп скидки от партнеров (фитнес-клуб, мобильная связь), скидки на обучение английскому языку; график: 5/2 10:00-19:00 или 09:00-18:00. опен-офис. в нашей внутренней корпоративной социальной сети можно найти коллег по интересам для участия в командных спортивных соревнованиях, настольных играх, для путешествий по краю и многое другое.   если заинтересовала вакансия - ждем резюме откликом или по электронной почте!',
#        'сегодня комус один из крупнейших поставщиков офисных товаров и услуг для бизнеса. сейчас мы в поиске аналитика обязанности:  работа с большими массивами данных; сбор данных в единый дашборд; формирование аналитических отчетов  требования:  умение работать с цифровыми массивами данных, обрабатывать статистику (мат. методы), консолидировать информацию в удобные для аналитики разрезы, анализировать данные; желателен опыт в сфере аналитики данных в разрезе клиентов (клиентских баз) и ассортимента; хорошее знание excel и надстройки, bi-систем (желательно).  условия:  оформление по тк рф; вся необходимая техника для работы; современный офис в бц &quot;интеграл&quot; рядом с метро авиамоторная; гибридный формат работы; стабильные выплаты заработной платы; льготное добровольное медицинское страхование; возможности карьерного развития, программа &quot;таланты&quot;; корпоративное обучение и курсы для повышения квалификации и освоения новых инструментов; отдельная программа лояльности на приобретение товаров для сотрудников компании; корпоративная скидка на изучение иностранных языков; льготное корпоративное кредитование сотрудников; скидки на досуговые мероприятия, организация отдыха и досуга, мероприятия для детей, конкурсы с ценными призами; корпоративный спорт: настольный теннис, футбол, волейбол, танцы; посещение фитнес-клуба и туристические поездки на выгодных условиях; корпоративная мобильная связь.',
#        'наше направление занимается повышением эффективности каналов продаж и улучшением взаимодействия с клиентами. для достижения этой цели мы собираем очень много данных о работе наших магазинов, создаем и развиваем систему отчетности, а также проводим различные исследования для бизнеса и принимаем участие в бизнес-проектах направления.  мы в поиске аналитика данных, который хочет:- много работать с данными - проводить исследования - помогать бизнесу находить ответы на интересующие вопросы твои основные задачи:  проведение исследований: изучение предметной области, сбор необходимых данных и их последующая обработка, формирование и проверка гипотез, оформление выводов, интерпретация результатов разработка инструментов контроля по результатам проведенных исследований: формирование источника, постановка задач на автоматизацию сбора данных, разработка инструментов контроля (дашборд, мониторинг), описание инструмента написание ad-hoc запросов участие в проектной команде в роли аналитика данных  что мы ждем от тебя:  уверенное владение sql уверенное владение python базовые знания статистики знания основных концепций в работе с данными опыт работы с bi-системами развитые коммуникативные навыки самостоятельность  будет плюсом:   опыт работы с clickhouse знание нотаций описания бизнес-процессов  условия: у нас действует система грейдов. заработная плата зависит от навыков и знаний. для роста необходимо обучаться, для этого мы:   закрепляем наставника,   собрали базу знаний,   компенсируем обучение на сторонних курсах 70%,   ездим на конференции за счет компании,   у нас официальное трудоустройство с первого рабочего дня. полностью &quot;белая&quot; заработная плата, выплаты 2 раза в месяц на карту от банка-партнера с дополнительными бонусами. есть корп скидки от партнеров (фитнес-клуб, мобильная связь), скидки на обучение английскому языку; график: 5/2 10:00-19:00 или 09:00-18:00. опен-офис. в нашей внутренней корпоративной социальной сети можно найти коллег по интересам для участия в командных спортивных соревнованиях, настольных играх, для путешествий по краю и многое другое.   если заинтересовала вакансия - ждем резюме откликом или по электронной почте!',
#        ...,
#        'обязанности:  регулярный анализ качества входящего потока, аквизиции и портфеля потребительских кредитов через оценку риск-показателей в разрезе продуктов, программ, технологий, каналов продаж, свойств заемщика и пр.; владение основными метриками по кредитному портфелю (ar, tr, pd, lgd, cor, eroa, rorac), навыками факторного анализа изменений; вынесение предложений по доработке кредитных стратегии/процедур и формирование рекомендаций по минимизации рисков; подготовка аналитических материалов для высшего руководства блока риски; взаимодействие с бизнес-подразделением в части оценки рисков при запуске новых продуктов и прочих инициатив; анализ клиентской базы банка и его поведения; работа с большими данными.  требования:  высшее образование (физико-математическое, техническое, финансово-экономическое); опыт работы в управление кредитными рисками (портфельный менеджмент, моделирование/построение скоринговых карт/отчетность); владение основными метриками по кредитному портфелю (ar, tr, pd, lgd, cor, eroa), навыками факторного анализа изменений; хорошее знание процесса кредитования (в том числе процесса формирования предодобренных предложений); хорошие аналитические навыки: умение определить суть проблемы, выбрать правильный метод решения, оценить полноту и сравнимость данных; навыки составления sql - запросов; умение самостоятельно разбираться в сложно структурированных данных.',
#        'обязанности:  разрабатывать и внедрять методики проведения контрольно-аналитических проверок, методов анализа информационных баз данных, а также разрабатывать шаблоны и форматы отчетности. осуществлять анализ информационных систем общества с целью выявления признаков нарушений, злоупотреблений и неэффективного использования ресурсов. осуществлять проведение контрольных мероприятий, аналитических процедур и проверок бизнес-процессов и структурных подразделений с целью выявления нарушений требований законодательства рф, организационно-распорядительных документов и локальных нормативных актов. принимать участие в разработке мер по предупреждению повторного появления нарушений и замечаний, выявленных в результате контрольных-аналитических мероприятий. принимать участие в разработке и внедрении контрольных процедур (аналитических инструментов), позволяющих в автоматическом режиме выявлять признаки нарушений и злоупотреблений, нестандартные или аномальные показатели и тренды в рамках компетенции. осуществлять подготовку отчетов и презентационных материалов по итогам проведенных контрольно-аналитических проверок и анализа данных.  требования:  высшее образование. опыт работы во внешнем контроле от 1 года. знание ms excel (сводные таблицы, формулы, visual basic for applications, power query и power pivot). навыки программирования (python, r и др.), работы с инструментами анализа большого объема данных (sql, qlik sense, tableau и др.). опыт подготовки аналитических и презентационных материалов.  условия:  работа в стабильной компании федерального уровня. годовое премирование. соблюдение требований тк рф. социальный пакет: расширенный пакет дмс и страхование при выезде за рубеж (по истечении 3-х месяцев с даты приема на работу); страхование от несчастных случаев и болезней 24/7 (с даты приема на работу); корпоративные скидки на членство в фитнес-клубах, страхование и путевки от туроператоров; специальные программы на банковские продукты. график работы 5/2 (возможен гибридный график работы после испытательного срока). расположение офиса: бизнес-центр «вэб арена», 3-я песчаная ул., 2а.',
#        'аналитик будет заниматься сбором, обработкой, изучением, анализом и интерпритацией данных производства, при этом аналитик фокусируется на создании ценности для бизнеса основанной на данных, с помощью современных инструментов и технологий глубокого анализа данных. является владельцем репортинга уровня завода.   вы будете:   работать с различными командами по внедрению данных в процесс принятия решений и планирования. разрабатывать и создавать отчеты, информационные панели и прогностические модели;   отвечать за поиск и анализ данных, необходимых для создания продуктов на основе данных;   подготавливать технические требования для данных/витрин данных и быть готовым разработать витрины с нуля на основе сырых данных;   осуществлять поддержку, модификацию существующих отчетов в power bi. поддерживать стабильную работу потоков данных (power bi dataflows);   осуществлять мониторинг метрик использования отчетов, коммуницировать с пользователями и работать с обратной связью по разработанным отчетам;   разрабатывать фреймворки/шаблоны для создания новых bi-отчетов и систем оповещения;   разрабатывать сложные специальные отчеты в соответствии с внутренними запросами бизнес-пользователей;   подготавливать подробные отчеты, выявляющие основные тенденции и закономерности, и преобразовывать данные в практические и полезные рекомендации для поддержки стратегических целей;   документировать процесс разработки отчетов, создавать бизнес-глоссарии для предметных областей и kpi внутри отдела и поддерживать их актуальность;   обучать конечных пользователей работе с новыми отчетами и информационными панелями, обучать сотрудников работе с приложением, его функциональности, качеству данных и отчетности, а также помогать в решении проблем с приложением;   проводить ревью кода и разрабатываемых решений аналитиками-стажерами, а также делегировать им задачи по поддержке/модификации существующих аналитических отчетов.   мы ожидаем:  1-3 года опыта работы в области анализа или визуализации данных (например, на позициях «аналитик данных», «bi-аналитик», «бизнес-аналитик»); владение инструментами визуализации данных (н-р.: tableau, graphana, qlik, power bi, datalens и др.) для полномасштабного анализа данных, обобщения и представления информации. опыт работы с ms power bi как преимущество; уверенное знание sql, dax; базовые знания принципов построения системной архитектуры, архитектуры данных, работы с базами данных и очистки данных; знание принципов разработки ит-продуктов; способность коммуницировать с бизнес стейкхолдерами. опыт управления требованиями сбор и детализация функциональных требований, управление ими); понимание и демонстрация опыта применения принципов ux, ui; английский язык - средний и выше; знания в области производства и сегмента товаров повседневного спроса (будет преимуществом).  мы предлагаем:   конкурентная зарплата, система бонусов, дмс и страхование жизни с первого рабочего дня;   корпоративная пенсионная программа;   компенсация питания;   оплата мобильной связи;   гибкий рабочий график;   дополнительный оплачиваемый отпуск при стаже работы от 5 лет;   насыщенная образовательная программа, которую формируете вы.'],
#       dtype=object)

# %% [markdown]
# ### Столбец description_lemmatized

# %% [markdown]
# Столбец представляет собой лемматизированное описание вакансии, т. е. все слова из описания находятся в своей начальной форме.

# %%
df_da['description_lemmatized'].unique()
# Out:
# array(['наш направление заниматься повышение эффективность канал продажа улучшение взаимодействие клиент достижение цель собирать данные работа наш магазин создавать развивать система отчетность также проводить различный исследование бизнес принимать участие бизнес проект направление поиск аналитик данные хотеть работать данный проводить исследование помогать бизнес находить ответ интересовать вопрос твой основной задача участие процесс исследование сбор необходимый данные последующий обработка проверка гипотеза оформление вывод интерпретация результат написание ad hoc запрос постановка задача автоматизация сбор данный разработка дашборд ждать уверенный владение sql базовый знание статистика развитый коммуникативный навык критический мышление плюс опыт работа python знание основной концепция работа данные тип данные метод простой обработка агрегация фильтрация опыт работа bi система условие действовать система грейд заработный плата зависеть навык знание рост необходимо обучаться закреплять наставник собирать база знание компенсировать обучение сторонний курсы 7 ездить конференция счет компания официальный трудоустройство первый рабочий день полностью quot белый quot заработный плата выплата 2 месяц карта банк партнер дополнительный бонус корп скидка партнер фитнес клуб мобильный связь скидка обучение английский язык график 5 2 1 19 9 18 опен офис наш внутренний корпоративный социальный сеть находить коллега интерес участие командный спортивный соревнование настольный игра путешествие край многий заинтересовывать вакансия ждать резюме отклик электронный почта',
#        'сегодня комус крупный поставщик офисный товар услуга бизнес поиск аналитика обязанность работа большой массив данные сбор данные единый дашборд формирование аналитический отчет требование умение работать цифровой массив данные обрабатывать статистика мат метод консолидировать информация удобный аналитика разрез анализировать данные желательный опыт сфера аналитика данные разрез клиент клиентский база ассортимент хороший знание excel надстройка bi система желательно условие оформление тк рф весь необходимый техника работа современный офис бц quot интеграл quot рядом метро авиамоторный гибридный формат работа стабильный выплата заработный плата льготный добровольный медицинский страхование возможность карьерный развитие программа quot талант quot корпоративный обучение курсы повышение квалификация освоение новый инструмент отдельный программа лояльность приобретение товар сотрудник компания корпоративный скидка изучение иностранный язык льготный корпоративный кредитование сотрудник скидка досуговой мероприятие организация отдых досуг мероприятие ребенок конкурс ценный приз корпоративный спорт настольный теннис футбол волейбол танец посещение фитнес клуб туристический поездка выгодный условие корпоративный мобильный связь',
#        'наш направление заниматься повышение эффективность канал продажа улучшение взаимодействие клиент достижение цель собирать данные работа наш магазин создавать развивать система отчетность также проводить различный исследование бизнес принимать участие бизнес проект направление поиск аналитик данные хотеть работать данный проводить исследование помогать бизнес находить ответ интересовать вопрос твой основной задача проведение исследование изучение предметный область сбор необходимый данные последующий обработка формирование проверка гипотеза оформление вывод интерпретация результат разработка инструмент контроль результат проводить исследование формирование источник постановка задача автоматизация сбор данный разработка инструмент контроль дашборд мониторинг описание инструмент написание ad hoc запрос участие проектный команда роль аналитика данные ждать уверенный владение sql уверять владение python базовый знание статистика знание основной концепция работа данные опыт работа bi система развитый коммуникативный навык самостоятельность плюс опыт работа clickhouse знание нотация описание бизнес процесс условие действовать система грейд заработный плата зависеть навык знание рост необходимо обучаться закреплять наставник собирать база знание компенсировать обучение сторонний курсы 7 ездить конференция счет компания официальный трудоустройство первый рабочий день полностью quot белый quot заработный плата выплата 2 месяц карта банк партнер дополнительный бонус корп скидка партнер фитнес клуб мобильный связь скидка обучение английский язык график 5 2 1 19 9 18 опен офис наш внутренний корпоративный социальный сеть находить коллега интерес участие командный спортивный соревнование настольный игра путешествие край многий заинтересовывать вакансия ждать резюме отклик электронный почта',
#        ...,
#        'обязанность регулярный анализ качество входить поток аквизиция портфель потребительский кредит оценка риск показатель разрез продукт программа технология канал продажа свойство заемщик пр владение основной метрика кредитный портфель ar tr pd lgd cor eroa rorac навык факторный анализ изменение вынесение предложение доработка кредитный стратегия процедура формирование рекомендация минимизация риск подготовка аналитический материал высокий руководство блок риск взаимодействие бизнес подразделение часть оценка риск запуск новый продукт прочий инициатива анализ клиентский база банк поведение работа большой данные требование высокий образование физико математический технический финансовый экономический опыт работа управление кредитный риск портфельный менеджмент моделирование построение скоринговый карта отчетность владение основной метрика кредитный портфель ar tr pd lgd cor eroa навык факторный анализ изменение хороший знание процесс кредитование число процесс формирование предодобрять предложение хороший аналитический навык умение определять суть проблема выбирать правильный метод решение оценивать полнота сравнимость данный навык составление sql запрос умение самостоятельно разбираться сложно структурировать данные',
#        'обязанность разрабатывать внедрять методика проведение контрольный аналитический проверка метод анализ информационный база данные также разрабатывать шаблон формат отчетность осуществлять анализ информационный система общество цель выявление признак нарушение злоупотребление неэффективный использование ресурс осуществлять проведение контрольный мероприятие аналитический процедура проверка бизнес процесс структурный подразделение цель выявление нарушение требование законодательство рф организационно распорядительный документ локальный нормативный акт принимать участие разработка мера предупреждение повторный появление нарушение замечание выявлять результат контрольный аналитический мероприятие принимать участие разработка внедрение контрольный процедура аналитический инструмент позволять автоматический режим выявлять признак нарушение злоупотребление нестандартный аномальный показатель тренд рамка компетенция осуществлять подготовка отчет презентационный материал итог проводить контрольный аналитический проверка анализ данные требование высокий образование опыт работа внешний контроль 1 год знание ms excel сводный таблица формула visual basic for applications power query power pivot навык программирование python r др работа инструмент анализ большой объем данные sql qlik sense tableau др опыт подготовка аналитический презентационный материал условие работа стабильный компания федеральный уровень годовой премирование соблюдение требование тк рф социальный пакет расширять пакет дмс страхование выезд рубеж истечение 3 х месяц дата прием работа страхование несчастный случай болезнь 24 7 дата прием работа корпоративный скидка членство фитнес клуб страхование путевка туроператор специальный программа банковский продукт график работа 5 2 возможный гибридный график работа испытательный срок расположение офис бизнес центр вэб арена 3 песчаный ул 2а',
#        'аналитик заниматься сбор обработка изучение анализ интерпритация данные производство аналитик фокусироваться создание ценность бизнес основывать данные помощь современный инструмент технология глубокий анализ данные являться владелец репортинг уровень завод работать различный команда внедрение данный процесс принятие решение планирование разрабатывать создавать отчет информационный панель прогностический модель отвечать поиск анализ данные необходимый создание продукт основа данные подготавливать технический требование данный витрина данные готовый разрабатывать витрина ноль основа сырой данные осуществлять поддержка модификация существующий отчет power bi поддерживать стабильный работа поток данные power bi dataflows осуществлять мониторинг метрика использование отчет коммуницировать пользователь работать обратный связь разрабатывать отчет разрабатывать фреймворка шаблон создание новый bi отчет система оповещение разрабатывать сложный специальный отчет соответствие внутренний запрос бизнес пользователь подготавливать подробный отчет выявлять основной тенденция закономерность преобразовывать данный практический полезный рекомендация поддержка стратегический цель документировать процесс разработка отчет создавать бизнес глоссарий предметный область kpi внутри отдел поддерживать актуальность обучать конечный пользователь работа новый отчет информационный панель обучать сотрудник работа приложение функциональность качество данные отчетность также помогать решение проблема приложение проводить ревивать код разрабатывать решение аналитик стажер также делегировать задача поддержка модификация существующий аналитический отчет ожидать 1 3 год опыт работа область анализ визуализация данные например позиция аналитик данные bi аналитик бизнес аналитик владение инструмент визуализация данные н р tableau graphana qlik power bi datalens др полномасштабный анализ данные обобщение представление информация опыт работа ms power bi преимущество уверенный знание sql dax базовый знание принцип построение системный архитектура архитектура данные работа баз данные очистка данные знание принцип разработка ита продукт способность коммуницировать бизнес стейкхолдер опыт управление требование сбор детализация функциональный требование управление понимание демонстрация опыт применение принцип ux ui английский язык средний высокий знание область производство сегмент товар повседневный спрос преимущество предлагать конкурентный зарплата система бонус дмс страхование жизнь первый рабочий день корпоративный пенсионный программа компенсация питание оплата мобильный связь гибкий рабочий график дополнительный оплачивать отпуск стаж работа 5 год насыщенный образовательный программа формировать'],
#       dtype=object)

# %% [markdown]
# Столбцы description и description_lemmatized могут быть использованы только для поиска узкоспециализированных навыков. Поэтому в исследовании участие принимать не будут.

# %% [markdown]
# ### Столбец salary_from

# %% [markdown]
# Столбец представляет собой нижнюю границу предлагаемой заработной платы, полученная из заголовка вакансии на hh.ru.

# %%
df_da['salary_from'].isna().sum()
# Out:
# 1086

# %%
df_ds['salary_from'].isna().sum()
# Out:
# 678

# %% [markdown]
# 1086 и 678 пропусков - это очень много. Найдём медианные значения для каждой группы в соответствии с опытом и заполним ими пропуски.

# %%
# нарезаем датафреймы по требуемому опыту
df_da_jun1 = df_da.query('experience == "Junior (no experince)"')
df_da_jun2 = df_da.query('experience == "Junior+ (1-3 years)"')
df_da_mid = df_da.query('experience == "Middle (3-6 years)"')
df_da_sen = df_da.query('experience == "Senior (6+ years)"')

# %%
df_da_jun1['salary_from'].median()
# Out:
# 60000.0

# %%
df_da_jun2['salary_from'].median()
# Out:
# 90000.0

# %%
df_da_mid['salary_from'].median()
# Out:
# 150000.0

# %%
df_da_sen['salary_from'].median()
# Out:
# 200000.0

# %% [markdown]
# Чёткие границы по зарплатам в зависимости от уроня опыта:<br>
# - Junior (no experince) - 60 тыс.
# - Junior+ (1-3 years) - 90 тыс.
# - Middle (3-6 years) - 150 тыс.
# - Senior (6+ years) - 200 тыс.
#
# Проведем замену пропусков DA на медианные значения.

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Junior (no experince)'), 'salary_from'] = 60000

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Junior (no experince)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Junior+ (1-3 years)'), 'salary_from'] = 90000

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Junior+ (1-3 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Middle (3-6 years)'), 'salary_from'] = 150000

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Middle (3-6 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Senior (6+ years)'), 'salary_from'] = 200000

# %%
df_da.loc[(df_da['salary_from'].isna()) & (df_da['experience'] == 'Senior (6+ years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Теперь то же для DS.

# %%
# нарезаем датафреймы по требуемому опыту
df_ds_jun1 = df_ds.query('experience == "Junior (no experince)"')
df_ds_jun2 = df_ds.query('experience == "Junior+ (1-3 years)"')
df_ds_mid = df_ds.query('experience == "Middle (3-6 years)"')
df_ds_sen = df_ds.query('experience == "Senior (6+ years)"')

# %%
df_ds_jun1['salary_from'].median()
# Out:
# 60000.0

# %%
df_ds_jun2['salary_from'].median()
# Out:
# 105000.0

# %%
df_ds_mid['salary_from'].median()
# Out:
# 200000.0

# %%
df_ds_sen['salary_from'].median()
# Out:
# 160000.0

# %% [markdown]
# По сравнению с DA картина следующая:
# - Junior (no experince) - 60 тыс., что одинаково
# - Junior+ (1-3 years) - 105 тыс., что на 15 больше, чем у DA
# - Middle (3-6 years) - 200 тыс., что на 50 больше, чем у DA и соответствует уровню сеньор у DA
# - Senior (6+ years) - 160 тыс., связано с тем, что имеется одно единственное значение, которое не соответствует рыночным значениям.

# %% [markdown]
# Заменим пропуски на медианные значения, исключением станет группа Senior (6+ years), в которой пропуски заменим на 250 тыс.

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Junior (no experince)'), 'salary_from'] = 60000

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Junior (no experince)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Junior+ (1-3 years)'), 'salary_from'] = 105000

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Junior+ (1-3 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Middle (3-6 years)'), 'salary_from'] = 200000

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Middle (3-6 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Senior (6+ years)'), 'salary_from'] = 250000

# %%
df_ds.loc[(df_ds['salary_from'].isna()) & (df_ds['experience'] == 'Senior (6+ years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da['salary_from'].isna().sum()
# Out:
# 0

# %%
df_ds['salary_from'].isna().sum()
# Out:
# 0

# %%
df_da['salary_from'] = df_da['salary_from'].astype(int)
df_ds['salary_from'] = df_ds['salary_from'].astype(int)

# %% [markdown]
# Провели замену пропусков столбца salary_from на медианные значения, за исключением группы Senior (6+ years) у DS. Также изменили тип данных на int.

# %% [markdown]
# ### Столбец salary_to

# %% [markdown]
# Столбец представляет собой верхнюю границу предлагаемой заработной платы, полученная из заголовка вакансии на hh.ru. Проведём те же манипуляции как со столбцом salary_from.

# %%
df_da['salary_to'].isna().sum()
# Out:
# 1186

# %%
df_ds['salary_to'].isna().sum()
# Out:
# 688

# %% [markdown]
# 1186 и 688 пропусков - это ещё больше чем в предыдущем столбце. Найдём медианные значения для каждой группы в соответствии с опытом и заполним ими пропуски.

# %%
df_da_jun1['salary_to'].median()
# Out:
# 80000.0

# %%
df_da_jun2['salary_to'].median()
# Out:
# 120000.0

# %%
df_da_mid['salary_to'].median()
# Out:
# 200000.0

# %%
df_da_sen['salary_to'].median()
# Out:
# 240000.0

# %% [markdown]
# Такие же чёткие границы по зарплатам в зависимости от уроня опыта:<br>
# - Junior (no experince) - 80 тыс.
# - Junior+ (1-3 years) - 120 тыс.
# - Middle (3-6 years) - 200 тыс.
# - Senior (6+ years) - 240 тыс.
#
# Проведем замену пропусков DA на медианные значения.

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Junior (no experince)'), 'salary_to'] = 80000

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Junior (no experince)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Junior+ (1-3 years)'), 'salary_to'] = 120000

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Junior+ (1-3 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Middle (3-6 years)'), 'salary_to'] = 200000

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Middle (3-6 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Senior (6+ years)'), 'salary_to'] = 240000

# %%
df_da.loc[(df_da['salary_to'].isna()) & (df_da['experience'] == 'Senior (6+ years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %% [markdown]
# Теперь проведем замены у DS. Найдём медианные значения для каждой группы.

# %%
df_ds_jun1['salary_to'].median()
# Out:
# 80000.0

# %%
df_ds_jun2['salary_to'].median()
# Out:
# 200000.0

# %%
df_ds_mid['salary_to'].median()
# Out:
# 300000.0

# %%
df_ds_sen['salary_to'].median()
# Out:
# 300000.0

# %% [markdown]
# По сравнению с DA картина следующая:
# - Junior (no experince) - 80 тыс., что одинаково
# - Junior+ (1-3 years) - 200 тыс., что на 80 больше, чем у DA
# - Middle (3-6 years) - 300 тыс., что на 100 больше
# - Senior (6+ years) - 300 тыс., связано с тем, что имеется всего 3 значения

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Junior (no experince)'), 'salary_to'] = 80000

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Junior (no experince)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Junior+ (1-3 years)'), 'salary_to'] = 200000

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Junior+ (1-3 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Middle (3-6 years)'), 'salary_to'] = 300000

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Middle (3-6 years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Senior (6+ years)'), 'salary_to'] = 350000

# %%
df_ds.loc[(df_ds['salary_to'].isna()) & (df_ds['experience'] == 'Senior (6+ years)')]
# Out:
# Empty DataFrame
# Columns: [id, name, published_at, alternate_url, employer, department, area, experience, key_skills, schedule, employment, description, description_lemmatized, salary_from, salary_to, salary_bin, key_skills_from_key_skills_field]
# Index: []

# %%
df_da['salary_to'].isna().sum()
# Out:
# 0

# %%
df_ds['salary_to'].isna().sum()
# Out:
# 0

# %%
df_da['salary_to'] = df_da['salary_to'].astype(int)
df_ds['salary_to'] = df_ds['salary_to'].astype(int)

# %% [markdown]
# Провели замену пропусков столбца salary_to на медианные значения, за исключением группы Senior (6+ years) у DS. Также изменили тип данных на int.

# %% [markdown]
# ### Столбец salary_bin

# %% [markdown]
# Столбец представляет собой категорию предлагаемой заработной платы.

# %%
df_da['salary_bin'].value_counts()
# Out:
# salary_bin
# ЗП не указана                1186
# От 100 тысяч до 200 тысяч      85
# Меньше 100 тысяч               57
# От 200 тысяч до 300 тысяч      32
# Больше 300 тысяч               21
# Name: count, dtype: int64

# %% [markdown]
# Всего 5 категорий в зависимости от уровня зароботной платы. Из которых 1186 вакансий в которых заработная плата не указана. Но после того, как мы заменили пропуски в предыдущих столбцах, в данном столбце информация стала не достоверной.

# %% [markdown]
# ### Столбец key_skills_from_key_skills_field

# %% [markdown]
# Столбец представляет собой ключевые навыки из поля key_skills.lls

# %%
df_da['key_skills_from_key_skills_field'].isna().sum()
# Out:
# 514

# %%
df_ds['key_skills_from_key_skills_field'].isna().sum()
# Out:
# 341

# %%
df_da['key_skills_from_key_skills_field'].unique()
# Out:
# array(['SQL, Power BI, Python, СУБД',
#        'Работа с базами данных, MS SQL, MS Excel',
#        'SQL, Power BI, Python, СУБД, BPMN, Clickhouse',
#        'MS Office, SQL, Python, Hadoop, Нive, Аналитические исследования, Навыки презентации, Работа с большим объемом информации, Аналитика, Умение принимать решения, Управление командой, Деловая коммуникация, Анализ данных',
#        nan, 'Python, SQL, Математическая статистика',
#        'Python, SQL, Обучение и развитие, Data Mining, Английский язык, Бизнес-анализ, Аналитика, MS SQL, Data Analysis, Linux, Data Scientist, QlikView, Статистический анализ, Big Data, DataLens, Hadoop, Spark, PostgreSQL',
#        'SQL, PostgreSQL, Python, MS Excel, LTV, AppsFlyer, Facebook, Apple Search Ads, Google AdWords, Автоматизация ETL, Data Scientist, поведение пользователей, b2c, pandas, Dask, sklearn, Airflow, Linux',
#        'SQL, Python, Airflow, Анализ данных, Базы данных, BigQuery, Прогнозирование',
#        'Data Analysis, Python, SQL, Power BI, Английский язык, MS SQL, Базы данных, ETL',
#        'MS Excel, Аналитика, Анализ данных, Аналитическое мышление, MS SQL, Работа с большим объемом информации, Tableau, Python',
#        'SQL, Python, Торговая площадка', 'SQL, Python, Маркетплейс',
#        'SQL, Python, Математическая статистика, Торговая площадка',
#        'Python, SQL, Data Analysis, BI, A/B тесты', 'SQL',
#        'OpenCV, Python, Deep Learning, Аналитическое мышление, PyTorch',
#        'MS Excel, Анализ данных, Аналитика, Администрирование базы данных',
#        'SQL, Анализ данных, Статистический анализ, Математическая статистика',
#        'JIRA, Python, SQL-запросы', 'SQL, DWH, Power BI',
#        'SQL, DAX, Работа с базами данных, VBA, MS Excel',
#        'MS Excel, Прогнозирование, Аналитика, Системное мышление, Планирование, Анализ данных, Подготовка презентаций, Аналитическое мышление, Визуализация данных, Математический анализ',
#        'MS SQL, Phyton, Анализ бизнес показателей, витрины данных',
#        'Data Analysis, Python, Numpy, pandas',
#        'репутационный маркетинг, WEB аналитика, Google Analytics, Яндекс.Метрика, Маркетинговый анализ, Сбор и анализ информации',
#        'SQL, Python',
#        'Аналитическое мышление, Сбор и анализ информации, Анализ данных, Работа с большим объемом информации, Работа с базами данных',
#        'Бизнес-анализ, BPMN, SQL, Постановка задач разработчикам, Аналитическое мышление, Системное мышление',
#        'SQL, Анализ данных, Математическая статистика, Статистический анализ, Power BI, DAX',
#        'SQL, Python, Power BI, Tableau, Аналитика',
#        'SQL, Математическая статистика, СУБД, Сбор и анализ информации, Прогнозирование, Анализ данных, Аналитические исследования, Умение принимать решения, Аналитическое мышление, Python, PostgreSQL, Дашборды',
#        'SQL, ETL, DWH, Greenplum, Airflow, Hadoop',
#        'MS PowerPoint, Анализ данных, Работа с большим объемом информации, Анализ рынка, Исследования рынка, Сбор и анализ информации, MS Excel, Подготовка презентаций, VBA, SQL, Статистический анализ, Визуализация данных, Power Query',
#        'Python, SQL, Big Data, Machine Learning',
#        'SQL, Python, Data Analysis, Аналитическое мышление, Аналитика, Анализ данных',
#        'SQL, Python, Анализ данных, R, Data Science', 'SQL, MS SQL',
#        'LLM, Scikit-learn, NLP, Python, pandas, Numpy, Анализ данных, Машинное обучение, Метрики оценки моделей',
#        'SQL, Аналитика, СУБД, ETL, Python',
#        'SQL, Работа с базами данных, Базы данных',
#        'ETL, SQL, Oracle Pl/SQL, PL/pgSQL, Qlik Sense, Базы данных',
#        'Python, SQL, Data Analysis, PostgreSQL, ETL, Spark, Machine Learning, Greenplum',
#        'Аналитическое мышление, Анализ данных, SQL, MS Excel, Power BI',
#        'Python, Data Analyst, SQL, PostgreSQL, Data Analysis, Big Data, Аналитическое мышление, Работа с базами данных, Аналитика',
#        'Планирование продаж, Стратегическое мышление, Бизнес-анализ, Управление бизнес процессами, Деловая переписка, ВПР, Сводные таблицы, Google Analytics, Бюджетирование, Управление бюджетом, Гигиена Клиентской Базы, Аналитика по клиентам',
#        'умение работать с программами Word, Excel, Power Point, Аналитическое мышление, Формирование отчетности, Работа с большим объемом информации',
#        'Python, SQL, MS SQL Server, PostgreSQL, MS Excel',
#        'Python, SQL, Power BI, Бизнес-анализ, Анализ данных',
#        'SMM, ORM, SERM, Работа с системами аналитики, Internet Marketing, Подготовка презентаций, Аналитическое мышление, Excel, Русский язык',
#        'SQL, Управленческая отчетность, Python, Hadoop, Витрины данных',
#        'Финансовый анализ, Анализ текущих финансовых показателей, План-фактный анализ бюджета, Финансовое планирование, Управленческая отчетность, MS SQL, MS PowerPoint, Финансовый менеджмент, Аналитические исследования, Анализ данных, Финансовая отчетность, Аналитический склад ума, Точность и внимательность к деталям',
#        'Пользователь ПК, Работа в команде, Умение работать в команде, Ведение документации, оформление документации, Умение легко находить контакт с людьми, внимательность к деталям, умение работать с большими объемами информации, Работа в условиях многозадачности, Ответственность и пунктуальность, Коммуникабельность, ответственность, Способность эффективно решать проблемы',
#        'Аналитические навыки, Желание зарабатывать, Работа с большим объемом информации',
#        'SQL, Internet, Аналитика, Cистемы управления базами данных, Бизнес-анализ, Аналитическое мышление, Аналитические исследования, Работа со СМИ, Анализ данных',
#        'SQL, Python, PostgreSQL, API, ETL, DWH, Базы данных',
#        'Python, SQL, Работа с базами данных, Анализ данных, Базы данных, Сбор и анализ информации',
#        'SQL, Power BI, Tableau, MS SQL, GreenPlum, Управленческая отчетность, Работа с большим объемом информации, OLAP инструменты, FAT, UAT, Тестирование, витрины данных, FSD, Hadoop, Superset, olap-кубы',
#        'Аналитическое мышление, MS Excel, Математическая статистика, MS SQL, Статистический анализ',
#        'SQL, Python, pandas',
#        'SQL, Python, ETL, Tableau, Аналитические исследования, BI',
#        'SQL, ORACLE, Oracle Pl/SQL, База данных: Oracle, MS SQL, Маркетинговый анализ, PostgreSQL, Анализ данных, Аналитическое мышление',
#        'SQL, Python, Tableau, Аналитика данных, Аналитика продаж',
#        'SQL, Аналитическое мышление, Python',
#        'MDM, meta данные, Data Analysis, Бизнес-анализ, Data management',
#        'SQL, Python, Английский язык, Data Analysis, Tableau, Аналитические исследования, Бизнес-анализ, Статистический анализ, Power BI, Data Warehousing, EDA, Анализ рынка, Прогнозирование, Статистика, Analysis, dashboard',
#        'Python, SQL',
#        'SQL, Аналитическое мышление, Python, Анализ данных',
#        'SQL, Data Analysis, Python, Казначейство, ALM',
#        'SQL, Python, Работа с базами данных, Анализ данных, Аналитика, Аналитические исследования, Базы данных, Data Analysis',
#        'Data Analysis, MySQL, ETL, Python',
#        'Python, SQL, Анализ данных, Работа с базами данных, Big Data',
#        'Python, SQL, Аналитический склад ума, Аналитика продаж, Работа с большим объемом информации, Power BI, ETL',
#        'Python, SQL, A/B тесты',
#        'SQL, ad-hoc, A/B тесты, ETL, LTV, Python, PostgreSQL',
#        'SQL, Анализ данных, PostgreSQL',
#        'SQL, Python, Информационная безопасность',
#        'Финансовый анализ, Финансовый менеджмент, MS PowerPoint, Управленческая отчетность, Анализ текущих финансовых показателей, 1С: Предприятие 8, Внутренний финансовый аудит, Аналитическое мышление, Финансовая отчетность, Подготовка презентаций',
#        'SQL, VBA, Data Mining, Android, Прогнозирование, Анализ бизнес показателей',
#        'Python, Математическая статистика, Обучение и развитие, Статистический анализ, Прогнозирование, Математический анализ',
#        'Информационные технологии, Работа с базами данных, Аналитическое мышление',
#        'Аналитическое мышление, Аналитические исследования, Работа с большим объемом информации, Базы данных, MS Power BI, Исследования рынка, Анализ рынка, Анализ данных, Power BI, Анализ конкурентной среды',
#        'SQL, Python, Pandas, Аналитическое мышление, Аналитические исследования, Анализ данных',
#        'MS Excel, 1С, Анализ данных, Работа с большим объемом информации, Аналитическое мышление, Сбор и анализ информации, Деловая переписка',
#        'SQL, PostgreSQL, Python',
#        'SQL, MS Excel, Анализ данных, LR, Выстраивание метрик, Создание дашбордов',
#        'Cистемы управления базами данных, Анализ данных, Маркетинговый анализ, Работа с базами данных',
#        'Работа с базами данных, Проведение телефонных интервью, Деловое общение, Аналитика, Деловая переписка, Сбор и анализ информации, Управленческая отчетность, Аналитическое мышление, Анализ данных, Бизнес-анализ, Деловая коммуникация, Базы данных, Маркетинговый анализ, Корпоративная этика, Ведение переписки, Организация мероприятий, Навыки составления отчетности, Точность и внимательность к деталям, Анализ продаж, Подготовка отчетов, Навыки межличностного общения, Проведение опросов, Исследования рынка, Электронная почта, Оперативный поиск информации в сети Интернет',
#        'MS SQL, Python, Анализ данных, Oracle BI, Qlik, PostgreSQL',
#        'SQL, Python, Работа с базами данных, Сбор и анализ информации, FastAPI, NoSQL, MongoDB, Big Data, Elastic, Clickhouse, aiohttp',
#        'SQL, Python, Английский язык, MS SQL, Работа с базами данных',
#        'Анализ данных, Сбор и анализ информации, Анализ бизнес показателей, MS Excel, MS PowerPoint, Работа с большим объемом информации',
#        'SQL, Python, A/B тесты', 'Python, Linux, Анализ данных',
#        'Python, Аналитическое мышление, Аналитические исследования, Работа в команде, многозадачность, Навыки презентации, сводные таблицы, SQL, MS Visio, MS Access, MS Excel, MS PowerPoint, Google Sheets, Maplnfo Professional',
#        'Python, PostgreSQL, ETL, Big Data, Git, pandas, Numpy, Gitlab, Prometheus, Graphana',
#        'VBA, MS Excel, MS SQL, Python, R, Power BI, Tableau, DataLens, Математическая статистика, Теория вероятности, Визуализация данных, Сводные таблицы',
#        'SQL, Python, VBA',
#        'Аналитическое мышление, Работа в команде, MS Excel, MS PowerPoint',
#        'Анализ данных, Аналитическое мышление, Python, Работа с большим объемом информации, Организаторские навыки, MS Office',
#        'SQL, Работа с базами данных, Аналитика, Анализ данных, Бизнес-анализ, Математическая статистика, Python, Базы данных',
#        'SQL, Data Analyst, A/B тесты',
#        'Аналитика, Power BI, MS PowerPoint, Бизнес-анализ, Визуализация данных',
#        'MS Power BI, DAX, Power Query, SQL, DWH, Big Data, Анализ данных, Аналитические исследования, Data Analysis',
#        'MS SQL, Аналитические исследования, Статистический анализ, Работа с базами данных',
#        'Анализ данных, MS Excel, Power BI, Работа с большим объемом информации, Работа с базами данных, MS Power BI',
#        'Аналитическое мышление, SQL, MS Excel, MS PowerPoint, Базы данных',
#        'Data Analysis, Python, MS SQL, Black box testing, Jupyter Notebook, Google Data Studio, A/B тесты',
#        'SQL, DWH',
#        'SQL, Python, Анализ данных, Бизнес-анализ, Маркетплейс, Торговая площадка',
#        'SQL, Аналитика, Анализ данных, Базы данных, Работа с большим объемом информации, Работа с базами данных',
#        'ML, Power BI, A/B тесты, SQL, Python, Аналитические исследования, Факторный анализ, Анализ продаж',
#        'Управление проектами, Аналитическое мышление, Аналитические способности, Анализ данных, Python',
#        'Анализ ассортиментной линейки, Аналитика продаж, Руководство коллективом, Английский язык, Аналитическое мышление, Базы данных, Аналитика, Организаторские навыки, Сбор и анализ информации',
#        'Python, SQL, Tableau, Power BI, Работа с базами данных, Анализ данных',
#        'SQL, A/B тесты, Tableau',
#        'MS PowerPoint, Работа с большим объемом информации, Oracle Siebel CRM, MS Visio, VBA, MS SQL, Access, аналитика данных, Математический анализ, Статистический анализ, Анализ данных, SQL, Подготовка отчетов, Подготовка презентаций, Прогнозирование, Аналитическое мышление, Базы данных',
#        'MS SQL, SQL, Анализ данных, MS Excel',
#        'Python, SQL, Анализ данных',
#        'MS PowerPoint, Qlik Sense, Power Pivot, Power Query, Аналитика, Макросы, SQL',
#        'SQL, ETL, DWH',
#        'SQL, Английский язык, PostgreSQL, A/B тесты, Data Analysis',
#        'Power BI, Power Query, Power Pivot, Olap (online analytical processing), VBA, SQL, Python',
#        'SQL, Анализ данных, Аналитическое мышление, Математическая статистика, Сбор и анализ информации, А/Бх тесты, оптимизация, MS Excel, Анализ текущих финансовых показателей, Power Query',
#        'MS Excel, Финансовый анализ, SQL, Работа в команде, Анализ данных, Google Docs, Аналитика, Google таблицы, Работа в условиях многозадачности, Работа с большим объемом информации, Грамотная речь и письмо, GExcel, Продвинутый пользователь ПК, Аналитическое мышление',
#        'SQL, Google Docs, Сводные таблицы, Системное мышление, Анализ бизнес показателей, Работа с базами данных, Бизнес-анализ, Анализ данных',
#        'Маркетплейс, Торговая площадка, SQL, Python',
#        'SQL, Python, JavaScript, Docker',
#        'SQL, MS Excel, Python, Knime, Анализ данных',
#        'Коммуникативная гибкость, Системность мышления, Критическое мышление, Способность к саморазвитию, Инициативность и лидерство',
#        'Python, R, Data Analysis',
#        'SQL, Python, Apache Spark, Greenplum, Atlassian Jira, Atlassian Confluence',
#        'Анализ данных, SQL, Python, GreenplumDB, Анализ бизнес показателей, Tableau, Atlassian Jira, MS Power BI, MS SQL',
#        'Аналитическое мышление, Анализ данных, Power BI',
#        'Анализ данных, Python, SQL, Работа с большим объемом информации, Математическая статистика',
#        'Работа с большим объемом информации, Аналитика, MS Excel',
#        'SQL, Python, Spark, Hadoop, Big Data, Machine Learning',
#        'SQL, DataLense',
#        'Python, SQL, Анализ данных, Математическое моделирование, Data Analysis, pandas',
#        'MS SQL',
#        'SQL, Python, Power BI, Математическая статистика, AirFlow, MS Excel, Анализ данных',
#        'SQL, Python, Power BI, Математическая статистика, Статистический анализ, PowerBI, BI, A/B тесты, Numpy, pandas, Matplotlib, Seaborn',
#        'Power BI, Аналитические исследования, Работа с базами данных, Анализ данных, Tableau, SQL',
#        'Работа в Excel, Сбор и анализ информации, Сводные таблицы',
#        'MS Excel, SQL, Автоматизация, Анализ бизнес показателей, Базы данных, Аналитические исследования, Работа с большим объемом информации, MS Power BI, Сбор и анализ информации, Аналитика',
#        'SQL, Power BI, Анализ данных, Аналитическое мышление, MS Power BI, Работа с большим объемом информации, Работа с базами данных, PowerBI',
#        'SQL, Spark, Hadoop, Python, PySpark',
#        'MS Excel (VBA, Power Query), Python',
#        'SQL, Python, MS Excel, Анализ данных, Наставничество, Контент-анализ, Подбор контента',
#        'Тендеры, Закупки, Аналитическое мышление, подготовка документов для участия в тендерах, Математический склад ума, Знание MS Office, Государственные закупки, Работа с документами, Ответственность и пунктуальность, 223-ФЗ, 44-ФЗ, MS Excel',
#        'Oracle Pl/SQL, DWH, Python, BPMN, Аналитическое мышление',
#        'Python, Анализ данных, SQL',
#        'SQL, Python, A/B тесты, Проведение экспериментов, Анализ данных, pandas, Clickhouse, Прогнозирование',
#        'SQL, Hadoop, Business Intelligence Systems, CRM, GreenPlam, ORACLE, Базы данных, Teradata, Docker',
#        'SQL, Power BI, Анализ данных, Бизнес-анализ',
#        'Data Vault, Аналитическое мышление, DWH',
#        'PostgreSQL, Arenadata, Greenplum, MS Excel, MS Outlook, корпоративное хранилище данных, КХД, Анализ данных, Работа с базами данных, SQL, Data Analysis, Работа с большим объемом информации, Базы данных, Аналитика',
#        'Python, SQL, Анализ данных, Data Analysis, Аналитика, Работа с большим объемом информации, Сбор и анализ информации, Бизнес-анализ',
#        'Анализ данных, Аналитика, Работа с базами данных, Аналитическое мышление, Аналитические исследования',
#        'SQL, Python, Базы данных, Airflow, PostgreSQL',
#        'Python, SQL, pandas, Scikit-learn, Matolib, Классическое машинное обучение',
#        'SQL, Python, Big Data, Spark, Hadoop, Анализ данных',
#        'Python, SQL, MS Excel, Power BI',
#        'SQL, Анализ данных, data analyst, Big Data, PostgreSQL',
#        'Python, Data Analysis, SQL, A/B тесты, Ad Hoc Analysis, Power BI, Mathematical Statistics',
#        'SQL, WEB аналитика, Аналитическое мышление, Яндекс.Метрика, Clickhouse',
#        'Data Catalog, DMBOK DAMA, Business Glossary, Data Governance, Анализ данных',
#        'SQL, аналитика данных, Анализ рисков',
#        'SQL, Математическая статистика, Linux, Clickhouse, BI, HTTP, Git, Python, Поиск аномалий, Анализ временных рядов',
#        'BI, SQL, СУБД, Data Analysis',
#        'SQL, DWH, Teradata, Hadoop, Airflow, Greenplum, Витрины данных, Informatica',
#        'SQL, DWH, Teradata, Hadoop, Airflow, Greenplum, Витрины данных',
#        'SQL, Финансовая отчетность, Бизнес-анализ, Аналитическое мышление',
#        'Business Intelligence Systems, MS Excel, MS Access, Пользователь ПК, MS Outlook, Консультирование, Управление проектами, Грамотная речь, Работа в команде, Работа с большим объемом информации, Аналитика продаж, MS PowerPoint, MS Project, Проведение презентаций, Деловая переписка, Английский язык, Olap (online analytical processing), База данных: Olap',
#        'Анализ данных',
#        'MS Excel, Аналитика, MS PowerPoint, Анализ данных, Аналитическое мышление, MS SQL, Работа с большим объемом информации',
#        'Анализ данных, Аналитические навыки, Планирование и организация, Умение работать в условиях многозадачности, Excel, MS PowerPoint',
#        'SQL, Python, Power BI, Аналитические исследования, Бизнес-анализ, MS PowerPoint, MS Excel',
#        'SQL, Python, Power BI, PowerBI, DAX, MS Power BI, BigQuery, Tableau, PostgreSQL, ORACLE, MS SQL Server',
#        'Python, SQL, Power BI', 'SQL, Tableau, Python',
#        'SQL, MS PowerPoint, MS SQL, MS Access, Аналитическое мышление, Анализ данных',
#        'SQL, Аналитика, Python, Анализ данных, Работа с большим объемом информации, Tableau, Яндекс.Метрика, Power BI, Clickhouse, Google Analytics',
#        'SQL, Анализ данных, Умение принимать решения, Статистический анализ, Базы данных, MS Excel, CRM',
#        'SQL, MS SQL, Анализ рисков, Риск-менеджмент, Оценка рисков, Математическая статистика, Sas, BI, Портфельные риски, кредитные риски, Сбор и анализ информации, Аналитика, Математический анализ, Анализ данных, Python, Анти фрод, Anti-fraud',
#        'Анализ данных, MS PowerPoint, Аналитическое мышление, Работа с большим объемом информации, Сводные таблицы, Подготовка презентаций, MS Excel',
#        'Торговая площадка, Маркетплейс, SQL, Python',
#        'SQL, Data Analysis, Аналитические исследования, Статистический анализ, Big Data, MS PowerPoint, Анализ данных, Работа с базами данных, Power BI',
#        'MS SQL, Python, Анализ данных, Сбор и анализ информации, Power BI',
#        'SQL, Аналитика, Базы данных, MS SQL Server, Анализ рисков, Бизнес-анализ, MS SQL, Работа с базами данных, Работа с большим объемом информации, Витрины, MS Excel',
#        'SQL, Data Analysis, Python, Big Data, Spark',
#        'Data Analysis, SQL, Big Data, Python, Spark',
#        'PostgreSQL, MS SQL, Python, Arenadata, Greenplum, Jupyter Hab, MS Excel, MS Outlook, AirFlow, ETL Framework, корпоративное хранилище данных, КХД',
#        'Python, SQL, Математическая статистика, Математический анализ',
#        'SQL, Data Analysis, Python, Работа с базами данных, Power BI',
#        'SQL, Анализ данных, Работа с базами данных, PostgreSQL',
#        'MS Excel, 1С: Предприятие 8, Анализ данных, Многозадачность, Excel, Работа с большим объемом информации',
#        'SQL-запросы, VBA, Анализ данных, MS Excel, Работа с большим объемом информации, Аналитическое мышление, Базы данных, Сбор и анализ информации, Аналитика, дашборд',
#        'SQL, MS SQL, Работа с большим объемом информации, Teradata Studio, Informatica',
#        'SQL, Управление товарными запасами, Анализ ассортиментной линейки, Аналитика, MS SQL, Работа с большим объемом информации, Аналитические исследования, Прогнозирование, Python',
#        'Python, SQL, Data Analysis, Аналитические исследования, Математическая статистика, Сбор и анализ информации, Анализ данных, Математический анализ, Базы данных, Big Data',
#        'Работа с большим объемом информации, Power BI, Power Query, SQL',
#        'Python, SQL, Антифрод, A/B тесты, Power BI, Tableau',
#        'SQL, Python, Математическая статистика, Hadoop',
#        'BI, Power BI, Visiology, ETL, Loginom, NiFi, UML, MS Visio, SQL, Alation, Alteryx, OpenMetaData',
#        'Работа с большим объемом информации, Работа с документами, Поиск информации в интернет, Аналитическое мышление, Сбор и анализ информации, Знание Excel, 1C: Предприятие',
#        'SQL, Python, Анализ данных, Power BI, Аналитика, корпоративное хранилище данных, Отчетность, Arendata, MS Office, Hadoop, план счетов, MS Excel, BI',
#        '1С: Предприятие 8, 1С: Торговля, 1С: Документооборот, CRM, MS Excel',
#        'SQL, Работа с базами данных, Анализ данных',
#        'Анализ бизнес показателей, MS SQL, MS Excel, Аналитические исследования, Аналитическое мышление, Анализ данных',
#        'SQL, Python, Data Analysis, Аналитические исследования, Ad Hoc Analysis',
#        'Python, Статистический анализ, Прогнозирование, Математическая статистика, SQL, MS Excel, Pandas, Numpy',
#        'Python, Java, Анализ данных, Data Analysis, Управление командой',
#        'WEB аналитика, Анализ данных, MS SQL, Аналитические исследования, Маркетинговый анализ',
#        'SQL, MS Excel',
#        'SQL, MS PowerPoint, Работа с большим объемом информации, Деловая коммуникация',
#        'SQL, Python, Математическая статистика, A/B тесты, Big Data, Spark',
#        'Python, Системы автоматического контроля, Создание моделей, Машинное обучение, Математическое моделирование, Понимание задач регрессии, Оформление описаний, Пусконаладочные работы',
#        'SQL, Анализ данных, Python, FineBI',
#        'Математический анализ, Математическая статистика, SQL, Python',
#        'PostgreSQL, Airflow, Metabase, Clickhouse, Debezium, Datalens, SQL, Python',
#        'SQL, Аналитическое мышление, MS Excel, Power BI, Python, DAX, Работа в команде',
#        'SQL, Прогнозирование, Tableau, Анализ данных, Аналитическое мышление, Аналитические исследования, Работа с большим объемом информации, Power BI, Data Analysis, Анализ бизнес показателей, Сбор и анализ информации',
#        'Анализ данных, MS SQL, Power BI, Tableau, Работа в условиях многозадачности',
#        'PostgreSQL, ClickHouse, PowerBI, Python, A/B тесты',
#        'Python, SQL, Git, Аналитическое мышление, Анализ данных, airflow, Статистика',
#        'ArcGIS QGIS Git/Gitlab Python пространственные базы данных Agile',
#        'Пользователь ПК, Работа в команде, Грамотная речь, Поиск информации в интернет, Статистика, Работа с базами данных, Excel, Первичные документы',
#        'Базы данных, Работа с базами данных, Бизнес-анализ, SQL, API, Postman, SOAPUI, Работа с большим объемом информации, Разработка технических заданий, Clickhouse',
#        'MS Excel',
#        'Python, SQL, Power BI, Airflow, Metabase, Финансовая аналитика, Аналитика',
#        'SQL, Python, MS Access, Аналитическое мышление, Анализ данных, Базы данных',
#        'SQL, MS SQL, Анализ данных, MS PowerPoint, Работа с базами данных, Аналитические способности, Точность и внимательность к деталям, Анализ бизнес показателей, Сбор и анализ информации, Аналитика, СУБД, Управленческая отчетность, Прогнозирование, Аналитическое мышление, Аналитические исследования, Работа с большим объемом информации, Бизнес-анализ, Подготовка презентаций, Анализ рынка',
#        'MS Excel, MS SQL', '1С:',
#        'NLP, LLM, GPT, BERT, PyTorch, Tensorflow',
#        'MS SQL, Python, Аналитические исследования, Бизнес-анализ, Финансовый анализ, Прогнозирование, Статистический анализ, Power BI, Аналитика, Работа с базами данных, Tableau, Power Query',
#        'Анализ данных, Работа с большим объемом информации, Аналитическое мышление, Составление отчетности, Математический анализ, Аналитика, Базы данных, Деловая коммуникация, Навыки переговоров',
#        'Power BI, MS Power BI, SQL, Python, Аналитическое мышление',
#        'Python, SQL, Анализ данных, Английский язык', 'MS Excel, SQL',
#        'SQL, Анализ данных, Работа с базами данных, Аналитическое мышление',
#        'SQL, BI',
#        'SQL, MS SQL, Power BI, Работа с базами данных, Бизнес-анализ',
#        'Python, Celery, Clickhouse, PostgreSQL, Spark, Docker, Pandas, Numpy, requests, pyspark',
#        'Работа в команде, Английский язык, Подготовка презентаций, Excel',
#        'MS SQL, MS Excel, Анализ данных, Аналитика, SQL, Работа с базами данных',
#        'SQL, Python, Аналитические исследования, Работа с базами данных, Hadoop, Spark, PySpark, AirFlow',
#        'SQL, Power BI, Анализ данных, Аналитическое мышление, Базы данных, MS Excel',
#        'MS SQL, Java, Анализ данных, Аналитическое мышление, Работа с базами данных, Информационные технологии, Умение работать в коллективе, Power BI, SQL, MS Power BI, Tableau',
#        'Excel, SQL', 'SQL, MS Excel, Анализ данных, Python, Git',
#        'SQL, MS SQL, Базы данных, DWH, Power BI, Анализ данных, Анализ бизнес показателей, Аналитические способности, Работа с большим объемом информации, Статистический анализ, Работа с базами данных, Сводные таблицы, JSON, Аналитика, Сбор и анализ информации, Навыки составления отчетности, Аналитическое мышление',
#        'SQL, Python, Анализ данных',
#        'SQL, Tableau, Python, Анализ данных, DWH',
#        'SQL, Power BI, DAX, PowerBI',
#        'Python, SQL, MS SQL, Анализ данных, Базы данных, Jupiter, Excel, Макросы, Работа с большим объемом информации',
#        'Деловая переписка, Аналитические исследования, Аналитическое мышление, MS PowerPoint, Управление проектами, SQL, Работа с базами данных, Atlassian Jira, Atlassian Confluence, Анализ данных',
#        'SQL, Бизнес-анализ, MS PowerPoint, Аналитическое мышление, Аналитические исследования',
#        'Python, Machine learning, Business Intelligence Systems, Анализ данных, SQL, Power BI',
#        'SQL, Python, Power BI, Математическая статистика, Статистический анализ, PowerBI, BI, A/B тесты, numpy, pandas, matplotlib, seaborn',
#        'MS SQL, SQL, Анализ данных, Системы отчетности',
#        'Python, ClickHouse, PostgreSQL, Git',
#        'MS Excel, Маркетинговый анализ, SQL, Анализ данных, WEB аналитика, Анализ бизнес показателей, Аналитика, Аналитические исследования, Power BI',
#        'SQL, Python, Прогнозирование, Аналитика, Анализ данных, Базы данных, Оптимизация бизнес-процессов, Сбор и анализ информации',
#        'SQL, Управленческая отчетность, Оценка рисков, Python, Hadoop',
#        'ETL, Аналитическое мышление, Анализ данных',
#        'Python, Статистический анализ, Прогнозирование, Математическая статистика, SQL, MS Excel, pandas, Numpy, Jupiter',
#        'SQL, Анализ данных, Power BI, Excel, Tableau, Python',
#        'SQL, PowerShell, дашборды, ВПР, Сводные таблицы, Excel, Аналитика данных, Визуализация данных',
#        'Статистический анализ, MS Excel, Прогнозирование, Работа с большим объемом информации, MS PowerPoint, Подготовка презентаций, Аналитический склад ума',
#        'Маркетплейсы, Знание Excel, Удаленная работа, Работа с большим объемом информации, Аналитический склад ума, Умение принимать решения, Продвинутый пользователь ПК, Аналитика продаж, Анализ продаж, E-Commerce, wildberries, Конкурентная аналитика, Работа с системами аналитики',
#        'Системное мышление, Анализ данных, Финансовый анализ, Планирование продаж, MS Excel, Аналитическое мышление, E-Commerce, ERP',
#        'MS Excel, SQL, Python, Бизнес-анализ, Анализ рисков',
#        'Python, SQL, Tableau, MS SQL, Аналитика, PostgreSQL, Визуализация данных, Анализ данных, Работа с базами данных, Power BI, Data Analysis, PowerBI, Обучение и развитие, Английский — B1 — Средний',
#        'Python, Power BI, SQL',
#        'SQL, JSON, ClickHouse, Node-RED, BI-инструменты, React, API',
#        'SQL, Python, Английский язык, Математическая статистика, Tableau',
#        'Протоколирование, Организация деловых поездок, Работа с большим объемом информации, Организация совещаний, Высокая скорость печати, Cистемы управления базами данных, Ведение отчетности, Системное мышление, Многозадачность, 1С: Предприятие, MS Excel',
#        'SQL, Python, Pandas, Аналитическое мышление, Data Analysis',
#        'Аналитическое мышление, Бизнес-анализ, Аналитика, Power BI, SQL, Лидерство, Автоматизация процессов, Управленческая отчетность, Деловая коммуникация, Анализ бизнес показателей, Стратегическое мышление, Работа с большим объемом информации, Прогнозирование, Планирование, Организаторские навыки, Оптимизация бизнес-процессов, Подготовка отчетов, Расстановка приоритетов, Корпоративная этика',
#        'Python, SQL, Data Analysis, Анализ данных',
#        'Анализ данных, Аналитика, MS Excel, Работа с большим объемом информации, Подготовка презентаций, Сбор и анализ информации, Сводные таблицы, ВПР, 1С, Визуализация данных, Аналитический склад ума, Подготовка отчетов',
#        'Анализ данных, Аналитическое мышление, Бизнес-анализ, Анализ бизнес показателей, MS Power BI',
#        'ROAS, ROI, A/B тесты, SQL, Python, pandas, scipy, plotly, Metabase, Tableau, Apache Superset, Appsflyer, Firebase, Amplitude, Mixpanel, Google Analytics, Яндекс.Метрика, AppMetrica, модели атрибуции, Jetstat, Improvado',
#        'MS Excel, BI-отчетность, ВПР, сводные таблицы, Аналитическое мышление, Подготовка отчетов, Аналитика, Выборка',
#        'умение анализировать информацию, внимательность, Усидчивость',
#        'Google Data Studio, Анализ данных, Работа с базами данных, Анализ бизнес показателей, Постановка задач разработчикам, Data Mining, MS Power BI, Оптимизация бизнес-процессов, Сбор и анализ информации, Работа с системами аналитики, Data Analysis, Прогнозирование, Математический анализ, Power BI, Конкурентная аналитика, Базы данных, Аналитическое мышление, Бизнес-анализ, UML, Atlassian Jira, Big Data, Python, SQL, Аналитические исследования, Статистический анализ, Работа с большим объемом информации, Оптимизация бизнес процессов, Business Analysis, Сводные таблицы, Мой склад',
#        'Работа с системами аналитики, SQL, Аналитика, Математическая статистика, Анализ данных, Power BI, Python, Работа с большим объемом информации, Работа с базами данных, Статистический анализ',
#        'ODS, DDS, CDM, Greenplum, ClickHouse, Luxms, StreamLit',
#        '1С программирование, MS Excel, Аналитический склад ума, Сбор и анализ информации, исполнение поручений руководителя, Аналитическое мышление, Анализ данных, Работа с базами данных',
#        'SQL, Аналитические исследования, Анализ данных',
#        'Аналитика продаж, Прогнозирование, Анализ данных, Работа с базами данных, Работа с большим объемом информации, Подготовка презентаций, Сбор и анализ информации, Управленческая отчетность',
#        'MS SQL, Бизнес-анализ, PostgreSQL, Базы данных, Работа с базами данных, Power BI, Dax',
#        'SQL, Python, Tableau',
#        'SQL, Базы данных, Аналитика, Аналитическое мышление, Power BI, Анализ данных, Tableau',
#        'Бизнес-анализ, Анализ данных, Аналитическое мышление, Деловая коммуникация, Сбор и анализ информации, Аналитика, MS Excel, MS PowerPoint, MS SQL, Подготовка отчетов, CRM, Аналитика продаж, Автоматизация процессов',
#        'SQL, Анализ данных, Работа с базами данных, Tableau, Power BI, MS Excel, airflow, Python',
#        'MS Outlook, Внутренний контроль, MS Excel, Отчеты, Работа с базами данных, Работа с большим объемом информации',
#        'SQL, SPARQL, Базы данных, СУБД, Моделирование баз данных, BPMN, UML, Работа с большим объемом информации, Работа с базами данных, Аналитическое мышление, Python, MongoDB, Анализ данных, Постановка задач разработчикам, JSONATA, Archimate, Проведение тестирований',
#        'Маркетинг, реклама, PR, аналитика данных, Python, SQL, Математическая статистика',
#        'Python, SQL, Power BI, DAX, Tableau, Бизнес-анализ, Анализ данных, BPMN, UML, MS SQL, Аналитика, Базы данных',
#        'Работа с базами данных, Базы данных, Работа с большим объемом информации, Автоматизация процессов, Оптимизация процессов, Системность',
#        'SQL, R, Power BI, Анализ данных, Математическая статистика, Базы данных, Работа с большим объемом информации, Статистический анализ',
#        'Хранилище данных, MS Excel, Табличная верстка, Работа с базами данных, 1С: Торговля, Аналитическое мышление, Анализ данных',
#        'Python, PyTorch, Transformers, NLP, Kubernetes, Kafka, Docker, LLM',
#        'Hadoop, Hive, Python, PySpark, Oozie',
#        'SQL, Анализ данных, Power BI, Аналитическое мышление, MS Power BI, Работа с базами данных',
#        'Отчетность, MS PowerPoint, BI, MS Excel, Tableau, Анализ бизнес показателей, Анализ данных, Навыки презентации, Аналитическое мышление, Умение принимать решения, Деловая коммуникация, Генерация идей, Power BI, Quick Sense, SQL, Apache Superset, Дашборды',
#        'MS Excel, Аналитическое мышление, 1С, Подготовка отчетов, Сбор и анализ информации, Работа с большим объемом информации, Сельское хозяйство',
#        'DWH, MS SQL, UML, BPMN, JSON API, XML, ETL',
#        'SQL, Python, Математическое моделирование, Математическая статистика',
#        'Анализ данных, Аудит, Python, SQL',
#        'SQL, Power BI, MS Excel, Анализ данных, MS PowerPoint, ITIL, Python',
#        'Python, OpenCV, Deep Learning, PyTorch, Tensorflow, Руководство коллективом, Computer Vision',
#        'Python, SQL, Математическая статистика, Big Data, ML',
#        'Python, SQL, Аналитика, Работа с большим объемом информации, Базы данных, Работа с базами данных',
#        'Маркетинговый анализ, Data Analysis, Аналитические исследования, Маркетинговые исследования, Работа с большим объемом информации, Анализ рынка, Анализ данных, Деловая коммуникация, Исследования рынка, Работа с базами данных',
#        'Аналитика, Аналитика закупок, Отчетность по закупкам, SQL, Power BI, MS Excel',
#        'MS Excel, MS PowerPoint, Power BI, Аналитическое мышление, Расчет заработной платы',
#        'SQL, Python, Аналитические исследования, Git, Математическая статистика, Аналитика',
#        'SQL, Python, Аналитическое мышление, Анализ данных, Коммуникабельность, Статистика, Работа в команде',
#        'PostgreSQL, DWH, MS Excel, Power BI',
#        'XML, Atlassian Jira, SQL, REST, Swagger, Kafka, Анализ требований, BPMN, UML, API, Atlassian Confluence',
#        'SQL, Python, PostgreSQL, Pandas, Numpy, OpenAI, Big Data, Selenium IDE',
#        'Python, SQL, Spark, Big Data, Анализ данных',
#        'SQL, Python, Big Data, Spark, Data Analysis',
#        'Data Analyst, SQL, MS Excel, Sas, Python',
#        'Математический анализ, Аналитические исследования, Подготовка отчетов, Сбор и анализ информации, Аналитическое мышление, Работа с большим объемом информации',
#        'Python, Machine Learning, Английский язык, Data Analysis, Математический анализ, Аналитическое мышление, Анализ данных, TensorFlow, PyTorch, Scikit-learn, GitLab, CI/CD',
#        'UML, BPMN, Oracle DB, Oracle Exadata, PostgreSQL, Greenplum, MS SQL',
#        'SQL, MS PowerPoint, Анализ данных, аналитика, Бизнес-анализ, MS Excel, Qlik Sense, Анализ бизнес показателей, Подготовка отчетов',
#        'SQL, Python, Анализ данных, Data Analysis',
#        'SQL, Python, Анализ данных, Работа с базами данных',
#        'Python, Machine Learning, SciPy, PyTorch, Numpy, SQL',
#        'Аналитик данных, Работа с большим объемом информации, Python, ClickHouse, Работа с базами данных, Анализ данных, Airflow, SQL',
#        'SQL, Python, Анализ данных, Data Science',
#        'Big Data, BI Apache SuperSet, Python, Machine Learning',
#        'SQL, Работа с большим объемом информации, Английский язык',
#        'MS Excel, MS PowerPoint, Oracle Primavera, MS Project',
#        'SQL, Python, A/B тесты, Математическая статистика',
#        'Анализ данных, Аналитическое мышление, SQL, Python, Django Framework, Google Cloud Platform, Google Big Query, Яндекс.Метрика, Yandex Data Lens, JavaScript, DevOps, Google Analytics, DBT, ML-прогнозирование, Машинное обучение, Google Tag Manager, Визуализация данных, Matomo',
#        'построение хранилищ данных, Анализ данных, Data Analysis, data scientist, data engineer, DWH Lead, DWH',
#        'Power BI, Big Data, SQL, Data Analysis, Базы данных, ORACLE',
#        'SQL, PostgreSQL, Hadoop, Greenplum, Spark, BigData',
#        'Power BI, Статистический анализ, Tableau, Работа с базами данных, Работа с большим объемом информации, Аналитическое мышление, Python, SQL, Навыки презентации',
#        'SQL, Python, Аналитик данных, Корпоративные финансы',
#        'SQL, VBA, MS SQL, Управленческая отчетность, MS Excel, Базы данных, Аналитическое мышление',
#        'Python, Power Query, 1C, MS Excel, Пользователь ПК',
#        'Python, SQL, Математическая статистика, Git, Data Analysis, VBA, ML, Pandas, Numpy',
#        'SQL, Python, Анализ данных, Маркетинговый анализ, Работа с базами данных, Аналитика, Tableau, Сбор и анализ информации, PowerBI, Big Data, Power BI, Superset',
#        'Анализ данных, RTB, Programmatic, Data Analysis',
#        'SQL, Python, Power BI, MS Excel',
#        'Интеллектуальный анализ данных, SQL, API, Python, Математическая статистика',
#        'Ad Hoc Analysis, Python, MS SQL, SQL',
#        'Data Mining, Python, SQL, Pyspark, ML, Big Data, Математическая статистика, Pandas, Анализ данных, Статистический анализ, Data Science, Spark, Tableau, hadoop, hive',
#        'Аналитическое мышление, Аналитика, Анализ данных, Прогнозирование, Работа с большим объемом информации, Сбор и анализ информации',
#        'SQL, Python, Анализ данных, Аудит, Excel, Hadoop',
#        'Системный анализ, ETL, База данных: Olap',
#        'Аналитическое мышление, Аналитика, Анализ данных, Работа с большим объемом информации, Аналитические исследования, MS Excel, Анализ рынка, Сбор и анализ информации, Работа с базами данных, ВПР, Прогнозирование, Сводные таблицы, Анализ конкурентной среды, Анализ ассортиментной линейки, Анализ ценообразования, Анализ продаж, Аналитика продаж, Контроль и анализ ценообразования, Конкурентная аналитика, Ассортиментная матрица, Мониторинг цен, Подготовка отчетов',
#        'SQL, Power BI, Анализ данных, Python, Базы данных',
#        'SQL, Базы данных, Анализ данных',
#        'pandas, numpy, Python, Data Analysis',
#        'SQL, Power BI, Python, Tableau, MS Excel',
#        'SQL, Metabase, ORACLE, Data Analysis, Google Analytics, Английский язык',
#        'Складской Учет, Складская логистика, Складской документооборот, 1С: Предприятие 8, Учет ТМЦ, Учет остатков, Работа с ТМЦ, 1С: Торговля и склад, MS Excel, Аналитический склад ума',
#        'SQL, Анализ данных, Python, Системный анализ, MS SQL, Работа с базами данных, Power BI, MS Excel, Vertica',
#        'Data Science, SQL, Hive, PostgreSQL, Greenplum, Python, Pandas, Polars, Scipy, Numpy, Matplotlib, Seaborn, Plotly, Bokeh',
#        'data Scientist, Big Data, Machine Learning, Прогнозирование, Data Analysis, Python, Математическая статистика, Математический анализ, Аналитические исследования',
#        'PL/SQL, Системный анализ, PostgreSQL, GreenPlum, BI, Python, Анализ данных, DataVault, hadoop, ORACLE',
#        'SQL, Python, Apache Airflow, Аналитическое мышление, Аналитические исследования, Аналитика, Работа с базами данных, Анализ данных, Анализ бизнес показателей, Data Analysis, Работа с большим объемом информации',
#        'SQL, Python, Power BI, Аналитические исследования, Работа с большим объемом информации, Подготовка презентаций, Анализ рынка, Аналитическое мышление',
#        'SQL, Python, Математическая статистика, Big Data, Spark, Hadoop, Яндекс.Метрика',
#        'SQL, MS SQL, ETL, Power BI, Google Analytics, Яндекс.Метрика, DWH, Работа с базами данных, Анализ данных, Tableau, MS Excel, Google Docs',
#        'SQL, Python, Работа с базами данных, Анализ данных, Аналитика, Навыки презентации, Аналитические исследования, Проведение презентаций, Базы данных, Визуализация данных, Data Analysis, superset',
#        'Пользователь ПК, Работа в команде, Грамотная речь, Английский язык, Работа с большим объемом информации',
#        'Маркетинговый анализ, Аналитические исследования, Аналитическое мышление, SQL',
#        'Работа с большим объемом информации, Работа с базами данных, Аналитическое мышление, Макросы, НСИ, Сводные таблицы Excel',
#        'Tableau, Data Analysis, SQL, Python, Power BI',
#        'Анализ данных, SQL, Математическая статистика',
#        'Аналитическое мышление, Работа с большим объемом информации, Сбор и анализ информации, MS Excel, Английский язык, Деловая коммуникация, Сводные таблицы, Power Query',
#        'SAP, ERP Systems, Оптимизация бизнес-процессов, SAP SM, PostgreSQL, MS SQL, ORACLE',
#        'MS Excel, Работа с базами данных',
#        'SQL, MS Excel, Анализ данных, Аналитика, Базы данных, Сбор и анализ информации, Подготовка презентаций',
#        'SQL, Python, Работа с базами данных, Анализ данных, Сбор и анализ информации',
#        'SQL, Анализ данных, Работа с базами данных, Аналитика, Сбор и анализ информации, Обучение и развитие, Работа с большим объемом информации',
#        'Python, SQL, Критическое мышление, Системное мышление, Анализ данных, Визуализация данных',
#        'MS SQL, SQL, Python, Git, Tableau, Data Analysis, PowerBI, MySQL, Аналитик BI, Математический анализ, Сбор и анализ информации, формирование отчетов, построение дашбордов, BI',
#        'Анализ данных, Аналитическое мышление, Power BI, Маркетинговый анализ, Сбор и анализ информации, Анализ рынка',
#        'Data, analyst, Аналитик, Данных, SQL, Pandas',
#        'SQL, Ad Hoc Analysis, Анализ рисков, Оценка рисков, Портфельные риски, кредитные риски',
#        'Big Data, Data Analysis, Python, Математическое моделирование, Структуры данных, Анализ данных, Data Science, SQL',
#        'Финансовый анализ, Экономический анализ, Финансовый контроль, Управленческая отчетность',
#        'MS Excel, SQL, Python, MS SQL, PostgreSQL, Аналитика, MS SQL Server, Работа с базами данных, Аналитическое мышление',
#        'Английский язык',
#        'SQL, Power BI, Работа с базами данных, Анализ данных, Аналитическое мышление, Работа в команде',
#        'Аналитический склад ума, Развитые коммуникативные навыки',
#        'Python, SQL, Статистический анализ, Tableau, MS Power BI, BI, PowerBI, Работа с базами данных, Data Analysis, Anaconda, Pandas, Yandex Cloud, Data Lens, Google Data Studio',
#        'Анализ данных, SQL, Python, OLAP, airflow, BI',
#        'Python, SQL, Power BI, Tableau, Git',
#        'Python, Работа с системами аналитики, Английский язык, Преподаватель, SQL, API',
#        'Python, SQL, Teradata, ETL, IBM Unica, WSO2 Stream Processor, Kibana, Siddhi, Knime',
#        'Веб-аналитика, SQL, Базы данных, Статистический анализ, Анализ данных, Аналитика, Python',
#        'Python, ETL, SQL, Работа с большим объемом информации, Работа с базами данных, MS SQL, Oracle BI',
#        'SQL, Python, Ответственность, Аналитическое мышление, Tableau, MS SQL, Работа с базами данных, Анализ данных, Аналитические исследования, Визуализация данных',
#        'Маркетинговый анализ, Английский язык, GIS, Тайм-менеджмент, Многозадачность, Высшее образование, Работа с большим объемом информации, Анализ данных, Строительство, Моделирование, Девелопмент, ArcGIS, QGIS, Python',
#        'SQL, Анализ рисков, Python, Анализ финансовых показателей',
#        'Tableau, SQL, Python, Data Analysis, A/B тестирование',
#        'SQL, ETL', 'SQL, Python, Data Analysis, Power BI',
#        'Аналитическое мышление, Статистический анализ, Работа с большим объемом информации',
#        'ClickHouse, Python, Data Analysis',
#        'SQL, Аналитика, CJM, Python, Бизнес-анализ',
#        'Big Data, Работа с базами данных, Spark, Tableau, Python, Power BI',
#        'SQL, BigData, Hadoop',
#        'Аналитическое мышление, SQL, Python, Data Analysis, Работа с базами данных, PostgreSQL',
#        'SQL, Аналитика, tableau, FineBI, SuperSet',
#        'Аналитическое мышление, Работа с большим объемом информации, Сбор и анализ информации, Математическая статистика, Анализ ассортиментной линейки, Аналитические исследования, MS PowerPoint, Английский язык',
#        'Python, SQL, Power BI, Аналитика',
#        'ETL, SQL, Teradata, Oracle Pl/SQL, Python',
#        'MS Excel, Аналитические исследования, Экономический анализ, Продвинутый пользователь ПК, Готовность обучаться, Креативность, Анализ данных, Работа с большим объемом информации, Гибкость мышления, Аналитическое мышление',
#        'Airflow, DBT', 'MS PowerPoint, SQL, MS Excel, Python',
#        'Git, ООП, Python, Pytorch, gitlab',
#        'Аналитическое мышление, MS SQL, Базы данных, Анализ бизнес показателей, Аналитика, Сбор и анализ информации, Python, Аналитические исследования, Деловая переписка, Оптимизация бизнес процессов, MS Excel, Power Query, Data Analysis, Работа с базами данных, Экономический анализ',
#        'Анализ данных, Python, Математическая статистика, MS Power BI, Математическое моделирование, SQL, Анализ бизнес показателей',
#        'Power Query, Power BI, 1С: Торговля, DAX, MS Excel',
#        'Python, SQL, Базы данных',
#        'Базы данных, Анализ бизнес показателей, Аналитическое мышление, Анализ данных, Работа с базами данных, Power BI, SQL, Подготовка отчетов',
#        'SQL, ORACLE, Power BI, Python, MS Excel',
#        'MS Excel, MS PowerPoint, MS SQL, Power BI, Статистический анализ, Аналитика продаж, Аналитическое мышление, Анализ данных, Работа с большим объемом информации, Маркетинговый анализ, Подготовка презентаций, Google Docs, SPSS',
#        'Английский язык, SQL, Power BI',
#        'Аналитика, Креативность, Ответственность, внимательность',
#        'Supply Chain Management, Analytical skills, Warehouse Management, MS PowerPoint, MS Excel',
#        'SQL, Python, Numpy, Scikit-learn, Scipy, MS SQL, Анализ данных, Математическая статистика, Работа с базами данных, Прогнозирование, Git, Streamlit',
#        'VBA, MS SQL, MS Power BI, SQL, MS Excel, Анализ данных, Ведение отчетности',
#        'SQL, Python, AB-test', 'SQL, ORACLE, SAS Guide, Miner',
#        'SQL, Power BI, Grafana',
#        'аналитик данных, bi аналитик, SQL, Python, Power Query, Анализ данных, DWH, конфигурирование 1с, СlickHouse, PostgreSQL',
#        'Python, PostgreSQL, Grafana, Elasticsearch, Clickhouse, Linux, SQL',
#        'SQL, Google Analytics, Python, Анализ данных, Power BI, Data Analysis, Appmetrika, GA4, Appsflyer, Системный подход, Аналитическое мышление, DAX, Маркетинговая аналитика, Продуктовая аналитика',
#        'Анализ данных, MS Excel, Аналитическое мышление, Работа в команде, Мониторинг цен, Мониторинг рынка, Алгоритмы, Управление проектами, Аналитические исследования, Сбор и анализ информации, Аналитика',
#        'MS SQL, Дашборд, Ad Hoc Analysis',
#        'Анализ текущих финансовых показателей, Прогнозирование, Финансовое моделирование, Анализ данных, Data Analysis, Аналитическое мышление, Python, SQL, Аналитические исследования, Финансовый анализ, Бизнес-анализ, Аналитика, PowerBI, PostgreSQL, BigQuery, Crypto',
#        'Data Analysis, Работа с базами данных, SQL, PostgreSQL, BigQuery, Power BI, Анализ данных, Аналитическое мышление, Базы данных',
#        'Анализ данных, Базы данных, SQL, Data Analysis, Аналитические исследования',
#        'Python, SQL, BPMN, Superset, Power BI, DataLens, 1C',
#        'Python, SQL, Математическая статистика, BPMN, Superset, Power BI, DataLens, Apache Airflow, 1С',
#        'SQL, Маркетинговая аналитика, Бизнес-модели, Продуктовая аналитика',
#        'Информационные технологии, Техническая поддержка, Медицинская документация, медицинская статистика, Статистика, Статистический анализ, Анализ данных, бюджет',
#        'SQL, DataLens, Power BI, Аналитика, Анализ данных',
#        'MS Excel, MS SQL, Power BI, Tableau, Grafana, Разработка технических заданий, Анализ данных, Работа с большим объемом информации',
# ...
#        'SQL, Python, BPMN, СУБД, Разработка технических заданий, Техническая документация, Mashine learning, Анализ данных',
#        'SQL, MS Excel, Аналитическое мышление, Аналитика',
#        'SQL, Разработка технических заданий, Сбор и анализ информации, Аналитика, Анализ данных, Работа с базами данных',
#        'MS Power BI, Python, SQL, MS Excel, Google Docs, Работа с большим объемом информации, Сбор и анализ информации, Big Data, Data Analysis, Визуализация данных',
#        'SQL, Аналитика, Аналитическое мышление, Python, Анализ данных, Работа с базами данных, Superset, Big Data, продуктовые метрики',
#        'SQL, Data Analysis, Анализ данных, Аналитическое мышление, Аналитика, Сбор и анализ информации, MS SQL',
#        'MS SQL, Аналитическое мышление, Работа с базами данных, Power BI',
#        'Ехсеl, Microsoft Power BI, сводные таблицы, формулы',
#        'Работа с базами данных, SQL, PostgreSQL, Python, ETL',
#        'SQL, Python, Английский язык, Анализ данных, Tableau, Аналитическое мышление, Работа с большим объемом информации, Базы данных, BI',
#        'SQL, Python, СУБД, Анализ данных, MS SQL, Работа с базами данных',
#        'Python, A/B тесты, Big Data, Data Analysis, Tableau, SQL, airflow, Английский язык',
#        'Знание офисных программ, Опытный пользователь ПК, Знание MS Office, Cистемы управления базами данных, Работа с базами данных, Битрикс 24, Excel, Знание 1С',
#        'Торговая площадка, SQL, Python, Анализ данных',
#        'Работа в команде, Ответственность, Доброжелательность, Амбициозность, Power Query, Excel, JIRA (желательно), Confluence (желательно)',
#        'Аналитика, Телемаркетинг, SQL, Python, Работа с базами данных, VBA, MS Excel',
#        'Маркетинговые исследования, Анализ рынка, Прогнозирование, SWOT анализ, MS PowerPoint, Power BI',
#        'SQL, Power BI, СУБД, ETL, Hadoop',
#        'SQL, Python, Базы данных, Анализ данных, Работа с большим объемом информации',
#        'PowerBI, Отчетность, Python, SQL, Работа с большим объемом информации, Аналитика',
#        'data science, Power BI, Python',
#        'Аналитическое мышление, Базы данных, Анализ бизнес показателей, Аналитические исследования, Анализ данных, Английский язык, Работа с большим объемом информации, Power BI',
#        'Data Analysis, Python, Работа с большим объемом информации, Аналитическое мышление, Анализ данных, Анализ бизнес показателей, Моделирование бизнес процессов',
#        'Аудит, MS SQL, Python', 'SQL, Python, ML, A/B/n',
#        'SQL, Power BI, MS Excel',
#        'Аналитическое мышление, Анализ данных, Бизнес-анализ',
#        'RWA, ALM, SQL, Бухгалтерский учет, Системный анализ, разработка хранилищ, банковские продукты',
#        'SQL, MS Excel, Grafana, аналитика данных',
#        'Работа с большим объемом информации, VBA, MS Excel, MS SQL, Power Query, Python, Power Point',
#        'Power BI, API, Аналитическое мышление, Базы данных',
#        'аналитик данных, Python, Hypersonic Sql, СУБД',
#        'Аналитическое мышление, Анализ данных, 1С, MS Excel, Сводные таблицы, Системное мышление, Анализ ассортиментной линейки, Power BI, Навыки презентации, Аналитика продаж',
#        'SQL, Базы данных, Работа с базами данных, СУБД, Аналитическое мышление, Анализ данных, Офисные программы, ПК, Уверенный пользователь ПК (MS Office), Python, Flask, Pandas, PostgreSQL, ClickHouse',
#        'Аналитика, Аналитика закупок, SQL, Power BI, Tableau, BI-инструменты, MS Excel',
#        'SQL, Python, Qlickview, QlickSense, SuperSet',
#        'Python, PostgreSQL, ETL, Big Data, Git',
#        'Закупки, Анализ рынка, MS Excel, Категорийные закупки, ИТ-закупки',
#        'SQL, BPMN, MS Excel',
#        'ERP-системы на базе 1С, SQL, Power BI, MS Excel, 1С: Бухгалтерия и склад',
#        'прогнозирование спроса, Планирование продаж, динамическое ценообразование, ML-моделирование, Анализ данных, Бизнес-анализ, SQL, Python',
#        'E-Commerce, Работа с большим объемом информации, Маркетплейсы, Аналитическое мышление, Сводные таблицы, ВПР, Анализ продаж, Анализ ассортиментной линейки, Планирование ассортимента, Ассортиментная матрица, Аналитика, Аналитика продаж, Логистика поставок, Контроль отгрузки и доставки товара, начинающий специалист, стажер, MS Excel',
#        'SQL, PostgreSQL, Анализ данных, BPMN, Работа с базами данных, Анализ бизнес показателей, Оптимизация бизнес-процессов, Аналитические способности, Работа с большим объемом информации',
#        'SQL, Анализ данных, Data Analysis',
#        'Работа с базами данных, Деловая коммуникация, Анализ бизнес показателей, Сбор и анализ информации, Аналитика, Анализ данных, Базы данных, Работа с большим объемом информации, Аналитические исследования, Аналитические способности',
#        'Амплитуда, Продуктовые гипотезы, Веб-аналитика',
#        'SQL, Power BI, Работа с базами данных, Аналитическое мышление, Анализ данных, MS PowerPoint, MS SQL, MS Power BI, Проведение инвентаризаций, Подготовка презентаций, Python',
#        'ORACLE, Postgres, SQL, Power BI, MS Olap, IPC, Apache Airflow',
#        'SQL, Python, A/B тесты, MS SQL, Аналитика',
#        'Python, SQL, Pandas, Numpy, Анализ данных',
#        'Анализ данных, Статистический анализ, Математический анализ, Python, Сбор и анализ информации, Автоматизация процессов, SQL, Статистика, Планирование, Навыки презентации, MS Excel',
#        'Python, Google Analytics, SQL, Математическая статистика',
#        'Анализ ценообразования, Python, SQL',
#        'SQL, ORACLE, CRM, RTM, RTDM, SAS RTDM, DRTM, runtime CRM, realtime marketing, Evam',
#        'SQL, Python, Atlassian Confluence, Atlassian Jira',
#        'Python, ETL, NLP, ML, Ad Hoc Analysis, BI',
#        'SQL, Математическая статистика, Data Analysis, Анализ данных, Бизнес-анализ, MySQL, Looker Studio, Yandex DataLens',
#        'Python, SQL, Tableau, Power BI, Английский язык',
#        'Статистический анализ, Аналитическое мышление, Грамотность',
#        'Python, SQL, Git, PostgreSQL, Spark, Hadoop, Hive, Big Data, DWH, ML, Машинное обучение, Математическое моделирование, Прогнозирование, ETL, Data Analysis, Machine Learning, Аналитическое мышление, Базы данных, Airflow, Анализ данных, NoSQL',
#        'Анализ данных, Аналитика, E-Commerce, Сводные таблицы, Маркетплейсы, Анализ ассортиментной линейки, Power BI, Работа с большим объемом информации, Статистический анализ, MS Power BI, ABC-анализ, Google Docs, ВПР',
#        'SQL, Python, Big Data, ETL, DWH, Hadoop, Spark',
#        'Clickhouse, PostgreSQL, MongoDB, ETL, PowerBI, Tableau, UML, SQL, BI',
#        'Статистика, Анализ данных, SQL, Excel, математика',
#        'SQL, Power BI, DWH, Анализ данных',
#        'SQL, Python, Tableau, Power BI, Анализ данных',
#        'Деловая коммуникация, Анализ данных, Работа с большим объемом информации',
#        'Power BI, MS Excel, Аналитический склад ума',
#        'SQL, Data Analysis, tableau, Работа с базами данных',
#        'ML, Big Data, Python, pyTorch, Git, RecSys, SQL, Машинное обучение, Разработка, Ad Hoc Analysis',
#        'ML, Machine Learning, Python, R, Go, Pandas, Scikit-learn, TensorFlow, PyTorch, Keras, NLP, Computer Vision, SQL, Машинное обучение, Numpy, Работа с большим объемом информации, Работа с базами данных, Анализ данных',
#        'Machine Learning, Data Science, SQL, Python, PyTorch, NumPy, Scikit-Learn, NLP',
#        'SQL, A/B тесты, Аналитическое мышление, Оптимизация бизнес-процессов',
#        'Python, SQL, Git, Математическое моделирование, Прогнозирование, ETL, Анализ данных, Аналитические исследования, Работа с базами данных, Machine Learning, Сбор и анализ информации, Big Data, Spark, Hadoop, Hive',
#        'SQL, Анализ данных',
#        'SQL, Аналитика, Python, Сбор и анализ информации, Работа с базами данных, Базы данных',
#        'MS SQL, DWH, Power BI',
#        'ML, Python, WoE, SQL., sklearn, numpy, pandas, scipy, Shap/Lime, XGBoost, Docker',
#        'Аналитическое мышление, Анализ данных, Бизнес-анализ, Базы данных',
#        'SQL, MS PowerPoint, Аналитическое мышление, Python, Анализ данных, Работа с большим объемом информации, MS Excel',
#        'SQL, MS PowerPoint, Аналитическое мышление, Python, Анализ данных, Работа с базами данных, Работа с большим объемом информации, MS Excel',
#        'SQL, Работа с базами данных, Аналитические исследования, Анализ данных, Power BI, HR, Автоматизация процессов управления персоналом, Управление персоналом, Рекрутмент',
#        'Python, SQL, Apache SuperSet',
#        'SQL, Python, MS Excel, Аналитика, Jupiter, Сбор и анализ информации',
#        'Организаторские навыки, Ведение переговоров, Управление проектами, Управление продажами, Аналитика продаж, Деловая коммуникация, Работа в команде, Power Pivot, MS Excel, Подготовка отчетов, MS SQL, Работа с большим объемом информации, MS PowerPoint, XML, Работа с базами данных, Планирование продаж, Анализ продаж, Анализ бизнес показателей, Прогнозирование продаж, Анализ данных, Аналитическое мышление, Аналитика, Tableau, SQL, Базы данных, Python, Big Data, PowerBI, Работа с системами аналитики, Qlik',
#        'MS Excel, MS SQL, Python, Power Pivot, DAX, Power BI, Английский – А2, А/В-тестирования',
#        'Power BI, Power Pivot, OLAP, DAX, PowerQuery',
#        'MS PowerPoint, SQL, Аналитическое мышление, Аналитические исследования, MS Access',
#        'Написание документации для пользователей, Разработка технических заданий, MS SQL, Python, Анализ данных, Аналитическое мышление, Управление командой',
#        'Python, MS SQL, SuperSet, GitLab, AirFlow, 1С-Битрикс, MS Excel',
#        'Оптимизация бизнес-процессов, BPMN',
#        'Python, SQL, Power BI, Data Analysis',
#        'Английский язык, Project management, Анализ данных, Data Analysis, SQL, Базы данных, Markdown, Оптимизация бизнес-процессов',
#        'ETL, visiology, PowerBL, SQL, Power BI, Аналитика, хранилища данных',
#        'SQL, Статистический анализ, MS SQL, СУБД, Python, Power BI, Superset, MS Power BI, Аналитика, Сбор и анализ информации, Power Query, Математическая статистика, Tableau, Работа с базами данных, Базы данных, Аналитическое мышление, MS SQL Server, ClickHouse',
#        'Tableau, SQL, FineBI, PostgreSQL, Python',
#        'Системный подход, Автоматизация, Визуализация данных, Сводные таблицы, Сбор и анализ информации, Анализ данных, PowerBI, Power BI, Аналитика, SQL, Аналитическое мышление, Базы данных',
#        'Data Analysis, SQL, Python',
#        'MS Excel, Аналитическое мышление, Аналитика, Работа с большим объемом информации, Сбор и анализ информации, Сводные таблицы, Подготовка отчетов',
#        'Работа в команде, Грамотная речь, Аналитическое мышление, MS Access, Организационные навыки, SQL, AB тестирование, clickhouse, Tableau, PowerBI, Визуализация данных, Анализ бизнес показателей, Анализ данных, Python',
#        'Python, SQL, Анализ данных, Математическая статистика, Анализ бизнес показателей, Data Analysis, Аналитические исследования, A/B тесты, Математический анализ, Tableau, Machine Learning',
#        'SQL, Python, ETL, PostgreSQL, Power BI, Аналитическое мышление, Аналитические исследования, Работа с базами данных, Работа с большим объемом информации',
#        'Python, SQL, Математическая статистика, Анализ временных рядов, Анализ данных',
#        'SQL, Python, Apache SuperSet',
#        'SQL, Python, Power BI, Big Data, Анализ бизнес показателей, Аналитика, PostgreSQL, Работа с большим объемом информации',
#        'Аналитическое мышление, SQL, Python, Математическая статистика, Базы данных, Аналитика',
#        'MS Outlook, Работа с базами данных, Работа с большим объемом информации, 1С: Документооборот, 1C: Предприятие',
#        'Анализ бизнес показателей, Статистический анализ, Работа с базами данных, Power BI, MS Excel',
#        'Python, SQL, NoSQL, sklearn, scipy, nltk, numpy, panda, Git, Posgresql, Vertica, Tableau, DataLens, Airflow, Информационные технологии, Анализ данных, Data Analysis',
#        'Работа с большим объемом информации, Аналитическое мышление, Организация учебного процесса, Анализ данных, SQL, Английский язык, MS Excel',
#        'написание скриптов, аналитика больших массивов данных, MS SQL, ORACLE, Teradata, витрины данных, Data Science',
#        'SQL, Python, Математическая статистика, Power BI, MS Excel, API',
#        'Аналитические исследования, Маркетинговый анализ, Аналитика, Анализ конкурентной среды, Маркетинговые исследования, Анализ рынка, Подготовка презентаций, Работа с большим объемом информации, Прогнозирование, Ценообразование, Аналитическое мышление, Конкурентная аналитика, Подготовка отчетов, Ценовая политика, Сводные таблицы, Сквозная аналитика, Анализ данных, Анализ ценообразования',
#        'SQL, Анализ данных, Tableau, Superset', 'SQL, Power BI',
#        'SQL, Python, Power BI, Аналитические исследования, Работа с большим объемом информации, Подготовка презентаций, Анализ рынка, Аналитическое мышление, A/B тесты',
#        'SQL, Tableau, Анализ данных',
#        'Аналитическое мышление, Стратегическое мышление, Работа с большим объемом информации, SQL',
#        'SQL, Маркетинговый анализ, Анализ данных',
#        'SQL, Data Analysis, MS SQL, Python, Работа с базами данных',
#        'Работа с большим объемом информации, Работа с базами данных, Power BI, Excel',
#        'PostgreSQL, XML, JSON API, Power BI',
#        'SQL, Python, Анализ рисков, Hive, Spark, QlickSense',
#        'SQL, ClickHouse', 'SQL, Работа с базами данных',
#        'Power BI, SQL, MS SQL, MS Visio, MS Power BI, Визуализация данных, Аналитическое мышление, Анализ данных, Работа с большим объемом информации',
#        'Анализ данных, Google Analytics, Работа с базами данных, Базы данных, Экономический анализ, Аналитика',
#        'Аналитика данных, Экономический анализ, Финансовый анализ, Аналитическое мышление, Работа с большим объемом информации, Логистика, Транспортная логистика',
#        'Работа в команде, Ответственность, Доброжелательность, Амбициозность, MS Excel, SQL, СУБД, Анализ данных',
#        'MS SQL, Python, VBA',
#        'Финансовый анализ, Финансовое планирование, Финансовый менеджмент, Финансовое моделирование, Финансовая отчетность, Финансовый контроль, Аналитическое мышление, Управленческая отчетность',
#        'Аналитическое мышление, Python, VBA, Работа с большим объемом информации, Ответственность, Системное мышление, Целеустремленность, Работа в команде, Коммуникабельность',
#        'Аудит, риски, Анализ данных, Ведение отчетности, Аналитика, MS Excel, SQL, Python',
#        'Python, Power BI, Pandas, Numpy, VBA, SQL, ETL',
#        'SQL, Аналитика, Power BI',
#        'SQL, Python, Power BI, Математическая статистика, Аналитическое мышление',
#        'Python, SQL, Аналитический склад ума, Аналитика, Работа с большим объемом информации, Power BI',
#        'SQL, Python, Аналитическое мышление, Аналитические исследования, Аналитика, Работа с базами данных, Анализ данных, Анализ бизнес показателей, Data Analysis, Работа с большим объемом информации',
#        'SQL, Python, Анализ данных, Power BI, MS Excel',
#        'SQL, Python, Анализ данных, Power BI, Базы данных, Статистический анализ, Математическая статистика, Анализ бизнес показателей',
#        'Компенсации и льготы, Excel, Офисные программы, 1С: Зарплата и кадры',
#        'SQL, Tableau, MS PowerPoint, Power BI, Проведение презентаций',
#        'Аналитическое мышление, MS Excel, Работа с большим объемом информации, Сводные таблицы, VBA, Power Query, Power Pivot, Работа с базами данных, Прогнозирование, Анализ бизнес показателей, Сбор и анализ информации, Аналитика',
#        'Data Science, Python, SQL',
#        'Data Science, Python, SQL, Математическая статистика',
#        'Управление рисками, Анализ данных, Анализ рисков, MS SQL, Портфельный анализ, SQL',
#        'Работа с базами данных, Аналитическое мышление, Внутренний контроль, Контрольно-аналитические проверки, Внутренний аудит информационных систем',
#        'MS Power BI, Аналитика, Python, SQL, Tableau, Data Analysis, Анализ данных'],
#       dtype=object)

# %%
df_ds['key_skills_from_key_skills_field'].unique()
# Out:
# array([nan,
#        'SQL, MS SQL, Big Data, Python, Spark, Hadoop, Machine Learning, Математическая статистика, Аналитические исследования, Работа с базами данных, Статистический анализ, Аналитическое мышление, Математический анализ',
#        'Python, PyTorch, ML, Docker, NLP, Pandas, SQL, Data Science, Machine Learning, Deep Learning',
#        'Python, SQL, Обучение и развитие, Data Mining, Английский язык, Бизнес-анализ, Аналитика, MS SQL, Data Analysis, Linux, Data Scientist, QlikView, Статистический анализ, Big Data, DataLens, Hadoop, Spark, PostgreSQL',
#        'ml, Python, numpy, scipy, pandas, sklearn, Clickhouse, PostgreSQL',
#        'Python, Big Data, SQL, Machine Learning, Git', 'Python, SQL',
#        'Python, Big Data, Работа с базами данных, Статистический анализ, Статистика, Математическое моделирование',
#        'Python, SQL, Linux, Numpy, Pandas, Machine Learning, Машинное обучение, Data Analysis, Mathematical Statistics, Big Data, Data Science, sklearn, PyTorch',
#        'Python, PyTorch, ИТ, IT',
#        'SQL, Hadoop, Spark, Python, Airflow, Linux',
#        'Python, SQL, Sas, Скоринговые модели, кредитные риски',
#        'Python, Hadoop, Big Data, Machine Learning',
#        'Big Data, Data Science, Machine Learning, Python, ML, Машинное обучение, Высокие коммуникативные навыки, Управление командой, Scikit-learn, pandas, CI/CD, Алгоритмы, Лидерство, Коммуникабельность, Управленческие навыки, Мотивация персонала, Организаторские навыки',
#        'Python', 'Hadoop, Big Data, PySpark, NLP',
#        'Python, SQL, Математическое моделирование, Управление проектами, Сельское хозяйство',
#        'NLP, LLM, Seq2Seq, GPT, Python, Docker, PyTorch, GPU',
#        'it, торговая площадка', 'SQL, Python, ML, Spark, AirFlow, Docker',
#        'Python, Tensorflow, PyTorch, Docker', 'Data science, Agile',
#        'Python, Финансовая математика, SQL, R, Стохастический анализ',
#        'Python, PyTorch, ML, NN, Quants, trading, Stock market, Hedge Fund',
#        'Data science, Machine learning, Python, Numpy, Pandas, Matplotlib, Seaborn, Clickhouse, PostgreSQL, Git, Теория графов, TensorFlow, CNTK, Keras, PyTorch, Caffe, Nvidia TLT, computer vision',
#        'Python, ИИ, AI, openCV, NumPy, Pandas, DL, NLP, LLM, MLOps, DevOps',
#        'Data Scientist, Python, SQL, Spark',
#        'Python, Математическая статистика, SQL, Статистический анализ, Pandas, Reinforcement Learning, Multi-Armed Bandits',
#        'SQL, Python, Data Analysis, Математическая статистика, Работа с большим объемом информации',
#        'Python, SQL, Postgres, ClickHouse, Airflow, Kubernetes, Data science, Machine learning, Ценообразование',
#        'Data Science, Machine Learning, Математическое моделирование, Прогнозирование, Математическая статистика, Python, Машинное обучение',
#        'Python, SQL, Machine Learning, Git, Работа с базами данных, Pandas, numpy, scikit-learn, regression, boosting, catboost, clustering, Airflow, Datalens',
#        'Data scientist, Computer vision, Машинное обучение, Machine Learning, Python',
#        'Pandas, Python, PostgreSQL, ML, SQL, Transact-SQL, sklearn, Machine Learning, sns, plotly, Data Science',
#        'Python, Leadership Skills, Английский язык, Machine Learning, Data Analysis',
#        'Python, SQL, ML, Data Science, ООП, Умение работать в команде, Аналитический склад ума, Аналитическое мышление, Разработка ПО',
#        'SQL, Python, Docker, MLOps',
#        'Python, SQL, Математическое моделирование',
#        'Python, Machine Learning, pandas, Data Analysis, SciPy, Big Data, Numpy, Scikit-learn, TensorFlow, Matplotlib',
#        'Python, SQL, Математическая статистика, Статистический анализ',
#        'Python, SQL, Machine Learning, Аналитические исследования, Математическое моделирование',
#        'Python, Natural Language Processing, NLP, LLM, Big Data, Анализ данных, Математическая статистика, SQL, MongoDB, Machine Learning, AWS, Deep Learning',
#        'BERT, Python, Numpy, pandas, matplotlib/plotly, PyTorch, transformers, langchain',
#        'Streamlit, Apache Airflow, Docker',
#        'Python, Статистический анализ, SQL, Математическое моделирование, Эконометрика, Математическая статистика, Теория вероятностей, Machine Learning',
#        'Python, SQL, Анализ данных, Data Science, Data Analysis',
#        'Python, IT, Разработка поисковых технологий, DS, ML',
#        'ML, Python, PySpark, SQL, pandas', 'PyTorch, PySpark, Python, ML',
#        'Python, data science, Математическая статистика, Английский язык, TensorFlow, PyTorch',
#        'SQL, Python',
#        'Python, Big Data, Machine Learning, NLP, Data Science, ML, SQL, pandas',
#        'Python, Аналитическое мышление, Математическая статистика',
#        'Машинное обучение, Data Scientist, Python, SQL, Математическое моделирование, Machine Learning, Аналитика продаж',
#        'Linux, Bash, Git, XGBoost, LightGBM, CatBoost, SQL, Scikit-learn, Numpy, pandas, Matplotlib, Python',
#        'IT, Разработка поисковых технологий, Python, ML, SQL',
#        'PostgreSQL, ORACLE, Clickhouse, Linux',
#        'Python, Machine Learning, Bokeh, Plotly, SQL',
#        'Python, SQL, Анализ данных, Математическое моделирование, Data Analysis, pandas',
#        'Python, SQL, CNN, LSTM, BERT, Transformers, Нейронные сети',
#        'nlp, Data Scientist, Big Data, Аналитические исследования, Работа с базами данных, ml',
#        'Python, PD, LGD, ПВР, Data Science, Machine Learning',
#        'Математическое моделирование, Анализ данных, Статистический анализ, Валидация моделей, Модельный риск, SQL, Python',
#        'Математическое моделирование, Анализ данных, Статистический анализ, Валидация моделей, Модельный риск, SQL',
#        'Machine Learning, Python, SQL, Docker, Kubernetes',
#        'Математическая статистика, Machine Learning, Python, SQL, NLP, Llama2, LLM, PyTorch',
#        'Python, machine learning, SQL, Базы данных',
#        'Data Science, Python, Математический анализ, Работа с большим объемом информации, NLP',
#        'Python, Data Analysis, Machine Learning, PostgreSQL, Data Science, Прогнозирование, ML, SQL, Big Data, NLP, Машинное обучение, Базы данных, Математическое моделирование, Reinforcement Learning, Deep Learning, Анализ данных, Feature engineering, Data Engineer, API, System Integration, Математический анализ, Аналитические исследования, Работа с базами данных, теория вероятности',
#        'Python, ML, NLP, Deep Learning, Машинное обучение, pandas, Numpy, Hadoop, Spark, sklearn, CatBoost, CV',
#        'Python, SQL, Математическая статистика, Теория вероятности, Прикладная статистика, Машинное обучение, Скоринг, Прогнозирование, ML, Machine learning, Риск менеджмент, Риск аналитика, Fintech, Банки, A/B тесты, Excel',
#        'Python, SQL, Hadoop, Apache Hive, Spark, Airflow, Machine Learning, Big Data',
#        'Python, SQL, ORACLE, PostgreSQL, FastAPI',
#        'Python, data science, Разработка поисковых технологий, IT',
#        'Оценка рисков, MS PowerPoint, Статистический анализ, Управление рисками, Математическое моделирование, PD, LGD, EAD, SQL, Портфельные риски, кредитные риски',
#        'Information Technology, Fluent English, Research, Public Speaking, Machine Learning, Data Mining, Writing Articles',
#        'Python, SQL, Spark, Базы данных, PHP, ClickHouse, Elastic Search, MySQL, SCALA, TypeScript',
#        'Python, SQL, Математическое моделирование, Математический анализ, R',
#        'SQL, Python, Математическое моделирование, Big Data, ML',
#        'Python, Hadoop, Spark, ML, DL',
#        'Python, Базы данных, SQL, keras, tensorflow, sklearn, numpy, pandas, pytorch',
#        'Kaldi, PyTorch, TensorFlow, librosa, ffmpeg, soxi',
#        'SQL, Python, Pandas, ML, machine learning, обучение модели, машинное обучение, NLP, CV, Computer Vision, нейронная сеть',
#        'Python, SQL, Hadoop, Pandas, Spark',
#        'Python, ML, CI\\CD, СУБД, Linux',
#        'Machine Learning, ML, Data Science, DS, Машинное обучение, CV, Computer Vision, MLE, Deep Learning, DL, Generative Design, GD, Генеративный Дизайн',
#        'IT, поиск, Python, ML, Hadoop, Spark, Yarn, Hive, HDFS, MLFlow, Разработка поисковых технологий',
#        'Python, SQL, Математическая статистика, Hadoop, Математическое моделирование, Spark, ML',
#        'Python, PyTorch, Tensorflow, ML, NLP, Computer Vision, Data Science',
#        'Python, Математическая статистика, SQL, Анализ рисков, Английский язык',
#        'Python, SQL, PyTorch, Математическая статистика, Keras',
#        'Python, SQL, Machine Learning, Анализ данных',
#        'Python, SQL, PostgreSQL, Анализ данных, ORACLE, Git',
#        'Python, Machine Learning, PyTorch, Машинное обучение, Linux',
#        'NLP, ML, Linux, Python, Docker',
#        'SQL, Python, Yandex Cloud Platform, Airflow, Docker, Kubernetes, Power BI',
#        'SQL, ETL, Power BI, Yandex Cloud Platform',
#        'Python, SQL, Oracle Pl/SQL, Big Data, ML, Машинное обучение',
#        'Python, Spark, SQL, Machine Learning, Pandas, Машинное обучение, Data Science, Big Data, PySpark, Hive, Анализ данных, Data Analysis, ML, Hadoop',
#        'Оценка рисков, Статистический анализ, Управление рисками, Математическое моделирование, PD, LGD, EAD, SQL, Портфельные риски, кредитные риски',
#        'Machine Learning, Deep Learning, Generative design, AI, ML, CV, Python, LLM',
#        'Python, Анализ данных, Git, Docker, LLM, NLP',
#        'FMCG Продажи, Python, SQL', 'Python, PyTorch, SQL',
#        'NLP, Python, PyTorch, Data Science, Numpy, Sklearn',
#        'Python, SQL, API',
#        'Python, Статистический анализ, NumPy, Pandas, Mlflow, Flask, Scikit-learn, SQL, Docker, Git',
#        'SQL, Git, Python, Анализ данных, Моделирование',
#        'ClickHouse, Java, SCALA', 'OpenCV, Data Science, OCR',
#        'Python, C++, Математическая статистика, Методы оптимизации',
#        'Python, Системы автоматического контроля, Создание моделей, Машинное обучение, Математическое моделирование, Понимание задач регрессии, Оформление описаний, Пусконаладочные работы',
#        'Python, Математическая статистика, SQL, Pandas, Статистический анализ, Машинное обучение, Data Science, MS SQL, Аналитическое мышление, Data Analysis, Математическое моделирование, Библиотеки: Statsmodels CatBoost GLM, СУБДД: MS SQL PostgreSQL Oracle, Apache Airflow, MLflow',
#        'Hadoop, Spark, Kafka, ClickHouse',
#        'PD, LGD, Математическое моделирование, Python',
#        'Python, Big Data, Machine Learning, Hadoop, Hive, Spark, ML',
#        'Docker, API, Linux, Git, PyTorch',
#        'Python, ETL, Machine Learning, Data Analysis',
#        'Аналитика продаж, Oracle Pl/SQL',
#        'Python, PySpark, Big Data, Machine Learning',
#        'ArcGIS QGIS Git/Gitlab Python пространственные базы данных Agile',
#        'Python, Математическое моделирование, Математическая статистика, SQL, Machine Learning, Машинное обучение, Data Mining',
#        'Python, SQL, Atlassian Jira, Tensorflow, PyTorch',
#        'Python, Machine Learning, SQL, PyTorch, Java, Numpy, Scipy, Pandas, Scikit-learn, Neural nets, Nlp, Recommender systems, Search ranking, a/b-experiments, Анализ данных, hadoop, hive, presto, Mathematics',
#        'ML, машинное обучение, ИТ-системы, Работа с большим объемом информации, Проведение презентаций, Аналитическое мышление, Деловая коммуникация',
#        'Python, SQL, Английский язык, Математическое моделирование, Анализ данных',
#        'Python, Machine Learning, Big Data, ML, Spark',
#        'Python, Data Mining, Machine Learning, SQL, Data Analysis',
#        'Python, Pandas, pyspark, Airflow, sklearn, boosting, seaborn, plotly',
#        'Python, SQL, Big Data, Математический анализ',
#        'SQL, Работа с базами данных, Базы данных, ORACLE',
#        'IT, Разработка поисковых технологий, data science, Python, Deep Learning, Алгоритмы и структуры данных',
#        'Python, Django Framework, SQL, XML, MS SQL',
#        'Python, Linux, Git, Golang, Go, Kafka, Java, Docker, Английский язык',
#        'rust, PyTorch, Cassandra, PostgreSQL',
#        'Python, TensorFlow, PyTorch, Keras',
#        'Python, SQL, deep learning, ML',
#        'Data Scientist, Аналитик, Pandas, NumPy, Scikit-learn, TensorFlow, Keras, SciPy, Plotly, Seaborn, PyTorch, Python',
#        'Python, Machine Learning, Анализ данных, Git', 'ClickHouse, LLM',
#        'Data Science, Python, Machine Learning, Статистика',
#        'Data Analysis, Анализ данных, Аналитика, Data Science, ML, Machine Learning',
#        'MS SQL, Python', 'ML, Python, Spark, Hadoop',
#        'Python, SQL, Pandas, numpy',
#        'SQL, Python, MySQL, Kafka, ETL, RabbitMQ, PostgreSQL, Docker, MS SQL Server, Redis, Работа с базами данных, REST API, REST, Data Science, Data Mining, Асинхронное программирование, Spring, JSON API, Математическая статистика, Elasticsearch, Базы данных, Dashboards, Linux',
#        'Python, Spark, Hadoop, Hive, Airflow, Docker, k8s, MLFlow, ClickHouse, Git, Atlassian Jira, Confluence',
#        'Python, Machine Learning, Data Science, Математическая статистика, Git',
#        'Статистический анализ, Математическая статистика, Data Analysis, Python, Анализ данных',
#        'ML, Big Data, Python, pyTorch, Git, RecSys, SQL, Машинное обучение, Разработка',
#        'Python, Разработка финансовых моделей, Моделирование',
#        'Python, NLP, PyTorch, Linux, Computer Vision, Machine Learning, Git, Docker',
#        'Python, Machine Learning, SQL',
#        'C++, Git, SQL, C/C++, Linux, Python, Qt, Машинное обучение, искусственный интеллект',
#        'машинное обучение, Анализ данных, программирование 1С, Python, Machine Learning, ML, MS SQL, SQL, Big Data',
#        'NLP, ML, Python, Git, DVC, MLFlow, SQL, Linux',
#        'Python, Анализ данных, Статистический анализ, Аналитические исследования, Математическая статистика, Математический анализ, Математическое моделирование, Data Science, Статистика',
#        'Python, classic ML, Data Science, SQL, Airflow, MLflow, Deep Learning',
#        'Python, SQL, Linux, Numpy, Pandas, Machine Learning, Машинное обучение, Data Analysis, Mathematical Statistics, Big Data, Data Science, sklearn, PyTorch, NLP',
#        'Python, Английский язык, Аналитическое мышление, Анализ данных, Big Data, Data Analysis, Spark, SQL, MS Excel, Machine Learning',
#        'ml-моделирование, a/b, dwh, Python, SQL',
#        'Python, PyTorch, Hadoop, Computer Vision, NLP',
#        'FinTech, Data Scientist',
#        'Pyton, MLflow, ClearML, MLOps, Data Science',
#        'Python, PySpark, ML, NLP, A/B тестирование',
#        'Python, Анализ данных, Big Data, Работа с базами данных, PostgreSQL',
#        'NLP, Python, Data Science',
#        'Работа в команде, SQL, Умение работать в коллективе, Умение планировать, Планирование карьеры',
#        'NCL, NPV, RBP, Python, SQL', 'ML, Data Science',
#        'SQL, Git, Python',
#        'Big Data, Machine Learning, Data Science, Data Analysis',
#        'C++, Математический анализ, Computer Vision, Deep Learning, Python, ROS, Machine Learning, Linux, NLP',
#        'Python, Numpy, Pandas, Математическая статистика, Scikit-learn',
#        'Python, Английский язык, Linux, Публичные выступления, C++',
#        'Python, Power BI, Машинное обучение',
#        'Machine Learning, Natural language processing, Математическая статистика, Python, Data Science, Математический анализ, Математическое моделирование, Deep Learning, Numpy, Pandas, Big Data, Машинное обучение',
#        'SQL, Python, PostgreSQL, Pandas, Numpy, OpenAI, Big Data, Selenium IDE',
#        'Python, Computer Vision, OCR, NLP',
#        'Python, Machine Learning, Английский язык, Data Analysis, Математический анализ, Аналитическое мышление, Анализ данных, TensorFlow, PyTorch, Scikit-learn, GitLab, CI/CD',
#        'Python, Data Analysis, Английский язык, Анализ данных, TensorFlow, PyTorch, Scikit-learn',
#        'SQL, Python, Машинное обучение, ML, DL',
#        'Работа в команде, Data Science, ML, Работа с большим объемом информации, SQL, Английский язык',
#        'Python, Machine Learning, SciPy, PyTorch, Numpy, SQL',
#        'Deep Learning, Прогнозирование, Time Series', 'Python, pd, lgd',
#        'Python, SQL, DVC, MLFlow, AirFlow, Git, Docker',
#        'data science, Python, SQL', 'Python, SQL, A/B тесты',
#        'Python, SQL, Математическая статистика, Git, Data Analysis, VBA, ML, Pandas, Numpy',
#        'NLP',
#        'SQL, Анализ данных, A/B тесты, LTV prediction, RecSys, Ulift modeling, Churn prediction',
#        'Python, SQL, Pandas, Data Analysis, Numpy',
#        'Python, Machine Learning, SQL, A/B тесты, Docker, Git',
#        'Machine learning, Data science, RecSys',
#        'Python, Linux, Kubernetes, Pandas, PyTorch',
#        'Python, Linux, Spark, Английский язык, SQL, Big Data',
#        'Python, MySQL, SQL, ML, Pandas, Numpy',
#        'Python, PyTorch, SQL, Machine Learning, Анализ данных, data science, numpy, scipy, pandas, lightgbm, pytorch, scikit-learn, neural nets, nlp, search ranking, recommender systems, a/b-experiments, hadoop, hive, presto, Mathematics',
#        'SQL, Python, Hadoop, Spark, PySpark, MLFlow',
#        'ML, Data Science, Python, SQL, Hive, PostgreSQL, Greenplum, Airflow, MLflow, Docker, FastAPI, PySpark',
#        'Python, PyTorch, Tensorflow, Pandas, Numpy, Xgboost, Catboost, HuggingFace, Arima',
#        'Python, NumPy, Scikit Learn, PyTorch, Deep Learning, OpenCV, Docker, ONNX',
#        'data Scientist, Big Data, Machine Learning, Прогнозирование, Data Analysis, Python, Математическая статистика, Математический анализ, Аналитические исследования',
#        'Python, ML, NLP, Deep Learning, Машинное обучение, Pandas, Numpy, Hadoop, Spark, sklearn, catboost, CV',
#        'Python, AI/ML, NLP, Machine Learning',
#        'SQL, Python, Анализ данных, Математическая статистика, Статистический анализ',
#        'Python, numpy, pandas, scipy, statsmodels, Excel, PowerPoint',
#        'ML, Python, Data Mining, Анализ данных, Data Analysis, LLM, Scikit learn, PyTorch, Статистический анализ',
#        'Python, Data Mining, Git, Английский язык, Data Analysis, Анализ данных, Аналитическое мышление',
#        'Анализ данных, Аналитическое мышление, Базы данных, Сбор и анализ информации, Аналитика, дашборд, Математическая статистика, Machine Learning, Python, Linux',
#        'Data Science, Machine Learning, numpy, pandas, sklearn, lightgbm, xgboost, tensorflow, torch, matploblib&seaborn, Big Data, Python, docker',
#        'Python, SQL, Sas, Анализ данных, Математическая статистика',
#        'Python, Big Data, Machine Learning, A/B тесты',
#        'Python, Data Analysis, Английский язык, Pandas',
#        'Python, Data Mining, MATLAB, Математическая статистика, Статистический анализ, Big Data, Математический анализ, Deep Learning, Регрессионный анализ, Математическое моделирование',
#        'Data Science, Python, IT, Экономика, Операционная эффективность',
#        'SQL, Python, ML, Hadoop, Spark, Hive',
#        'CatBoost, Pandas, sklearn, Time Series',
#        'Математическая статистика, Machine Learning, Python, SQL, MS SQL',
#        'IT, ИТ, CV, NLP, ML',
#        'Python, Big Data, Machine Learning, Pricing',
#        'Python, SQL, Machine learning, Портфельные риски, Анализ данных',
#        'Прогнозирование, Machine Learning, Mathematical Statistics, Data Science',
#        'DVC, MLFlow, SQL, Python, NLP, LLM',
#        'Python, Data Science, SQL, Machine Learning, Математическое моделирование',
#        'Linux, Git, CI/CD, English, Python, Geology, Geoscience, Data Science',
#        'Data Science, Python, ML, Machine Learning, PyTorch, Tensorflow, Keras, CV, Computer Vision, numpy, pandas, matplotlib, opencv',
#        'Python, Machine Learning, Математическое моделирование, Spark, Data Science, Математическая статистика',
#        'Python, SQL, Анализ данных, Hadoop, Spark, Hive, ML',
#        'Управление командой, Python, SQL, ML',
#        'Python, ML, Machine Learning, SQL',
#        'Pytorch, OpenCV, HuggingFace, Torchvision',
#        'Python, SQL, Математический анализ, Machine Learning',
#        'SQL, Data Analysis, ETL, Работа с базами данных',
#        'Python, Data Analysis, Анализ данных, Data Science, Machine Learning, Математическая статистика, Анализ временных рядов, Time Series Analysis',
#        'Python, SQL, Pandas, Машинное обучение',
#        'LLM, ChatGPT, Mistral, Vicuna, Llama, ML, NLP, Python, Machine Learning, Машинное обучение, Работа с базами данных, Data Science, Базы данных, Аналитические исследования, Анализ данных, Аналитическое мышление, AWS',
#        'Python, Pandas, Docker, Machine Learning, PyTorch, recommender systems, a/b-experiments, data science',
#        'Python, PostgreSQL, Grafana, Elasticsearch, Clickhouse, Linux, SQL',
#        'Python, SQL, Работа с базами данных, Математическая статистика, Аналитическое мышление, Математический анализ, Прогнозирование, Машинное обучение',
#        'Python, NLP, Английский язык, MySQL, C/C++, ML, NLU, ClickHouse',
#        'A/B тесты, Python, SQL, ML, PostgreSQL',
#        'Data Science, Python, ML, Машинное обучение, SQL, numpy, pandas',
#        'Python, Git, Pytorch, Tensorflow, Linux, Pandas, Data Mining',
#        'Разработка поисковых технологий, IT, Data Science, ML, Управление командой',
#        'ML, Python, PySpark, SQL, Pandas',
#        'Python, SQL, Machine Learning, System design',
#        'Python, SQL, Математическая статистика',
#        'ClickHouse, PostgreSQL, Python, Jupyter notebook, PySpark',
#        'Торговая площадка, it, SQL, Python, API', 'AI, Python',
#        'Python, SQL, Pandas, NumPy, Machine learning',
#        'Торговая площадка, IT',
#        'Git, Python, Pandas, REST API, Numpy, scikit-learn, PostgreSQL, Работа с базами данных, Docker, Работа с большим объемом информации, Data Analysis, Математический анализ',
#        'Python, Математическая статистика, SQL, Pandas, Sklearn, Numpy, MS SQL, Математическое моделирование, Базы данных, Теория вероятностей, Машинное обучение, Data Science, Алгоритмы, MongoDB, ML, sklearn',
#        'SQL, Python, Анализ данных, Apache Airflow, Git, PostgreSQL, Clickhouse, ETL, Data Analysis, MS SQL',
#        'PyTorch, OpenCV, Python, CV, GradCam, Image Classification, Image Segmentation',
#        'Python, SQL, ML, Machine Learning, Kubernetes, NoSQL, MongoDB, ElasticSearch, Redis',
#        'Python, Английский язык, Статистический анализ, Работа в команде, R-Studio, Sas',
#        'Python, Machine learning, ML, Математическая статистика, DNN, Deep learning, Pytorch, Data Science',
#        'SQL, Аналитическое мышление, Data Analysis, Аналитические исследования, ML, Data Scientist, Python, LLM, NLP',
#        'SQL, Python, ML, Data Science, NLP модели, Математическая статистика, Machine Learning, Big Data',
#        'Google Analytics, Data Analysis, Python, SQL',
#        'SQL, Python, Математическая статистика, Анализ данных',
#        'Python, PyTorch', 'OpenCV, TensorFlow, PyTorch',
#        'SQL, Tableau, Работа с базами данных, Статистический анализ, Базы данных',
#        'Python, Deep Learning, Алгоритмы и структуры данных, Pandas, Scikit-learn, Keras, ML',
#        'Python, Spark, Hadoop, Hive, ML, SQL, Pytorch, Computer Vision, NLP, Нейросети, Математическая статистика',
#        'Python, Математический анализ, SQL, Pandas, Machine Learning, Английский язык',
#        'LLM, NLP, RAG, Llama, LangChain, LlamaIndex, PyTorch, Python, ReAct, VectorDB',
#        'Управление рисками, Управление командой',
#        'SQL, Python, Аналитическое мышление, Анализ данных',
#        'Python, Big Data, SQL, Machine Learning',
#        'CV, Python, Machine Learning, SQL',
#        'Python, Математическая статистика, Machine Learning',
#        'Python, Математическая статистика, Big Data, Machine Learning, Spark, ML',
#        'Retrieval-Augmented Generation, RAG, GPT, BERT',
#        'Python, A/B тесты, SQL, Machine Learning, Redis, Golang, ClickHouse',
#        'Разработка поисковых технологий, IT, Управление командой, Python, Data Science',
#        'ML, NLP',
#        'Python, SQL, АВ-тестирование, Математическая статистика',
#        'Python, SQL, Data Mining, Аналитические исследования, NLP, ML',
#        'Аналитическое мышление, NLP, Python, ML/DL',
#        'Python, Аналитическое мышление, NLP',
#        'ML, MLP, LSTM, Attention Mechanism, ИИ, Python, искусственный интеллект, Data Scientist, CatBoost, XGBoost, lightGBM, scikit-learn, ARIMA, Random Forest, Decision Tree, Linear Regression, Principal Component Analysis, Pandas, plotly, numpy, statsmodels, matplotlib, GRU',
#        'Python, Математическая статистика, Обучение и развитие, Статистический анализ, Прогнозирование, Математический анализ',
#        'Git, NLP, OCR, Машинное обучение, Atlassian Confluence, Jira',
#        'data science, Power BI, Python',
#        'Data Analysis, Python, Работа с большим объемом информации, Аналитическое мышление, Анализ данных, Анализ бизнес показателей, Моделирование бизнес процессов',
#        'Python, Data Science, NLP, Машинное обучение',
#        'Python, SQL, SciPy, Mathematical Statistics, Грамотность',
#        'Анализ данных', 'Python, Machine Learning, Deep Learning, NLP',
#        'SQL, Python, PyTorch, ML, NLP, Spark',
#        'Big Data, Data Science, Machine Learning, Python, ML, Машинное обучение, Высокие коммуникативные навыки, Управление командой, Kafka, Pandas, Алгоритмы, Лидерство, Kubernetes, Airflow, Коммуникабельность, Управленческие навыки, Мотивация персонала, Организаторские навыки, Hadoop, Spark, Docker, MySQL',
#        'Деловая коммуникация, Проектный менеджмент, Cистемы управления базами данных, Организационное проектирование, SQL, Принципы работы БД, Data Science',
#        'Python, Big Data, Linux, Machine Learning',
#        'Python, Machine Learning, SQL, Английский язык, Анализ данных, Linux, Математическая статистика, Статистический анализ, Статистика, Прогнозирование, Машинное обучение, Data Science, Аналитические исследования',
#        'Spark, Python, SQL, ICAAP, Basel',
#        'SQL, Python, Работа с большим объемом информации',
#        'ML, Python, SQL, ML-алгоритмы, SOTA-методы',
#        'Python, SQL, Аналитическое мышление, Machine Learning, PostgreSQL',
#        'Python, Google Analytics, SQL, Математическая статистика',
#        'Python, SQL, Linux, Power BI',
#        'Python, NLP, Pandas, Machine Learning, ML, Data Science',
#        'Python, Базовые знания SQL',
#        'Python, Анализ данных, Математическая статистика, Data Analysis, Spark',
#        'Python, Linux, Machine Learning, NLP, Руководство коллективом',
#        'Риски, CRM, Моделирование, Data Sceince, SQL, Python, R, Скоринг',
#        'Статистический анализ, Машинное обучение, Математическая статистика, Python, SQL, Machine Learning',
#        'Machine Learning, Data Science, SQL, Python, PyTorch, NumPy, Scikit-Learn, Keras, TensorFlow',
#        'Machine Learning, Data Science, SQL, Python, PyTorch, NumPy, Scikit-Learn, NLP',
#        'ML, Python, WoE, SQL., sklearn, numpy, pandas, scipy, Shap/Lime, XGBoost, Docker',
#        'Data Analysis, Английский язык, Анализ данных, LLM, NLP, Data Science, Machine Learning, prompt engineering, JavaScript, PostgreSQL',
#        'Python, SQL, MS SQL, Аналитические исследования, Математическое моделирование',
#        'ML, SQL, Python, Математическое моделирование, Аналитические исследования, Работа с базами данных',
#        'Python, Математическое моделирование, LGD, PD',
#        'Revenue Management, Information Technology, Data Analysis, Data Science, Analytical skills, Machine Learning, Python, Digital Marketing, Dynamic Pricing',
#        'Python, SQL, Git, doker',
#        'SQL, Python, Docker, Atlassian Jira, Pandas, GitLab, Машинное обучение, Разработка ПО, Agile Project Management, Управление командой',
#        'IT, Разработка поисковых технологий',
#        'Python, data science, Разработка поисковых технологий, IT, NLP',
#        'Python, Spark, SQL, NLP, ML', 'ML, ИИ, AL',
#        'Computer Vision, Python, OpenCV, NamPy, Pandas, ML, SQL, TensorPT',
#        'Битрикс24, amoCRM, Spark, Английский язык',
#        'Data Analysis, Python, SQL',
#        'SQL, Data Analysis, MS SQL, Python, Работа с базами данных',
#        'MS SQL, PostgreSQL, Аналитические исследования, СУБД, Анализ данных, Data Scientist, NLP',
#        'Machine learning, NLP, Python, Pandas, scipy, plotly, pytorch, sklearn, xgboost, Data Mining, Анализ данных, Машинное обучение',
#        'Python, Статистический анализ, Прогнозирование, Математическая статистика, SQL, MS Excel, pandas, Numpy, Jupiter',
#        'Python, уверенное владение Python и основными ML-библиотеками, опыт их применения на практике, опыт работы с NLP, знание стека от TF-IDFдо LLM, - умение читать и разбирать статьи о новых архитектурах и подходах, понимание принципов обучения, тюнинга, оценки deeplearning моделей, опыт отладки нейронных сетей и модификации архитектур или создания собственных, владение Pandas, NumPy, Scikit-learn, PyTorch, владение методами XAI, Английский язык, Научная деятельность, Написание научных статей',
#        '\uf02d владение Python и основными ML-библиотеками, опыт их применения на практике, \uf02d умение читать и разбирать статьи о новых архитектурах и подходах, \uf02d понимание принципов обучения, тюнинга, оценки deeplearning моделей, \uf02d владение Pandas, NumPy, Scikit-learn, PyTorch, Английский язык, Python',
#        'Python, SQL, Git, Docker',
#        'Python, Математическая статистика, Big Data, Machine Learning, Pandas',
#        'Python, Математическая статистика, Git, Data Mining, Машинное обучение',
#        'Tensorflow, Аналитическое мышление, Анализ данных, Разработка компьютерных Игр, Gamedev, Python, Удаленная работа, ML, Машинное обучение, Математический склад ума, Гибкость мышления, Решение нестандартных задач, Нейросеть, Keras, PyTorch'],
#       dtype=object)

# %% [markdown]
# 514 и 341 пропусков, что значительно. Значения дублируют столбец key_skills, поэтому в исследовании принимать участие не будут.

# %%
print_df_info(df_da)
# Out:
#           id                                    name published_at  \
# 0  100039284  junior аналитик данных (исследователь)   2024-05-24
# 1  100039480                         аналитик данных   2024-05-24
# 2  100042705         аналитик данных (исследователь)   2024-05-24
# 3  100046788                 ведущий аналитик данных   2024-05-24
# 4  100056244                         аналитик данных   2024-05-24
#
#                      alternate_url           employer  \
# 0  https://hh.ru/vacancy/100039284  dns головной офис
# 1  https://hh.ru/vacancy/100039480              комус
# 2  https://hh.ru/vacancy/100042705  dns головной офис
# 3  https://hh.ru/vacancy/100046788           х5 group
# 4  https://hh.ru/vacancy/100056244             лукойл
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills     schedule  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  Полный день
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  Полный день
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  Полный день
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  Полный день
# 4                                   ['Документация']  Полный день
#
#          employment                                        description  \
# 0  Полная занятость  наше направление занимается повышением эффекти...
# 1  Полная занятость  сегодня комус один из крупнейших поставщиков о...
# 2  Полная занятость  наше направление занимается повышением эффекти...
# 3  Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 4  Полная занятость  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  наш направление заниматься повышение эффективн...        60000      80000
# 1  сегодня комус крупный поставщик офисный товар ...        60000      80000
# 2  наш направление заниматься повышение эффективн...        90000     120000
# 3  задача разработка бизнес модель групповой прог...        90000     120000
# 4  обязанность участие проектирование разработка ...       150000     200000
#
#       salary_bin                   key_skills_from_key_skills_field
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1381 entries, 0 to 1800
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1381 non-null   int64
#  1   name                              1381 non-null   object
#  2   published_at                      1381 non-null   datetime64[ns]
#  3   alternate_url                     1381 non-null   object
#  4   employer                          1381 non-null   object
#  5   department                        332 non-null    object
#  6   area                              1381 non-null   object
#  7   experience                        1381 non-null   object
#  8   key_skills                        1381 non-null   object
#  9   schedule                          1381 non-null   object
#  10  employment                        1381 non-null   object
#  11  description                       1381 non-null   object
#  12  description_lemmatized            1381 non-null   object
#  13  salary_from                       1381 non-null   int32
#  14  salary_to                         1381 non-null   int32
#  15  salary_bin                        1381 non-null   object
#  16  key_skills_from_key_skills_field  867 non-null    object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(13)
# memory usage: 183.4+ KB
# None
# Количество уникальных значений колонок:
#   id: 1381
#   name: 714
#   published_at: 93
#   alternate_url: 1381
#   employer: 690
#   department: 82
#   area: 70
#   experience: 4
#   key_skills: 772
#   schedule: 4
#   employment: 4
#   description: 1276
#   description_lemmatized: 1265
#   salary_from: 68
#   salary_to: 62
#   salary_bin: 5
#   key_skills_from_key_skills_field: 717
# Количество дубликатов: 0

# %%
print_df_info(df_ds)
# Out:
#           id                               name published_at  \
# 0  100049339  стажер data science (новосибирск)   2024-05-24
# 1  100051447                     data scientist   2024-05-24
# 2  100070495       ml engineer / data scientist   2024-05-24
# 3  100076648             team lead data science   2024-05-24
# 4  100077910      data analyst / data scientist   2024-06-08
#
#                      alternate_url                             employer  \
# 0  https://hh.ru/vacancy/100049339                                 сбер
# 1  https://hh.ru/vacancy/100051447  бюро кредитных историй скоринг бюро
# 2  https://hh.ru/vacancy/100070495                               гк фск
# 3  https://hh.ru/vacancy/100076648                                 сбер
# 4  https://hh.ru/vacancy/100077910                                итсен
#
#            department         area             experience  \
# 0  Сбер для экспертов  Новосибирск  Junior (no experince)
# 1                 NaN       Москва    Junior+ (1-3 years)
# 2                 NaN       Москва    Junior+ (1-3 years)
# 3  Сбер для экспертов       Москва     Middle (3-6 years)
# 4                 NaN       Москва     Middle (3-6 years)
#
#                                           key_skills          schedule  \
# 0  ['Python', 'Математическая статистика', 'Data ...       Полный день
# 1  ['Python', 'Hadoop', 'Machine Learning', 'Рабо...  Удаленная работа
# 2  ['Python', 'PyTorch', 'Machine Learning', 'Doc...       Полный день
# 3  ['Python', 'Pandas', 'SQL', 'Machine Learning'...       Полный день
# 4  ['DataLens', 'MS SQL', 'SQL', 'Spark', 'Аналит...       Полный день
#
#          employment                                        description  \
# 0        Стажировка  sberseasons - оплачиваемая программа стажирово...
# 1  Полная занятость  бюро кредитных историй «скоринг бюро» является...
# 2  Полная занятость  о компании и команде: группа компаний фск – мн...
# 3  Полная занятость  наша команда разрабатывает модели машинного об...
# 4  Полная занятость  мы ищем талантливого middle data analyst / dat...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  sberseasons оплачивать программа стажировка ра...        60000      80000
# 1  бюро кредитный история скоринг бюро являться к...       105000     200000
# 2  компания команда группа компания фск многопроф...       105000     200000
# 3  наш команда разрабатывать модель машинный обуч...       200000     300000
# 4  искать талантливый middle data analyst data sc...       350000     300000
#
#       salary_bin                   key_skills_from_key_skills_field
# 0  ЗП не указана                                                NaN
# 1  ЗП не указана  SQL, MS SQL, Big Data, Python, Spark, Hadoop, ...
# 2  ЗП не указана  Python, PyTorch, ML, Docker, NLP, Pandas, SQL,...
# 3  ЗП не указана                                                NaN
# 4  ЗП не указана  Python, SQL, Обучение и развитие, Data Mining,...
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# Index: 756 entries, 0 to 972
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                756 non-null    int64
#  1   name                              756 non-null    object
#  2   published_at                      756 non-null    datetime64[ns]
#  3   alternate_url                     756 non-null    object
#  4   employer                          756 non-null    object
#  5   department                        287 non-null    object
#  6   area                              756 non-null    object
#  7   experience                        756 non-null    object
#  8   key_skills                        756 non-null    object
#  9   schedule                          756 non-null    object
#  10  employment                        756 non-null    object
#  11  description                       756 non-null    object
#  12  description_lemmatized            756 non-null    object
#  13  salary_from                       756 non-null    int32
#  14  salary_to                         756 non-null    int32
#  15  salary_bin                        756 non-null    object
#  16  key_skills_from_key_skills_field  415 non-null    object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(13)
# memory usage: 100.4+ KB
# None
# Количество уникальных значений колонок:
#   id: 756
#   name: 473
#   published_at: 85
#   alternate_url: 756
#   employer: 305
#   department: 53
#   area: 26
#   experience: 4
#   key_skills: 380
#   schedule: 4
#   employment: 4
#   description: 687
#   description_lemmatized: 684
#   salary_from: 29
#   salary_to: 26
#   salary_bin: 5
#   key_skills_from_key_skills_field: 338
# Количество дубликатов: 0

# %% [markdown]
# **Выводы:**<br>
# Провели предобработку данных, в ходе которой улучшили качество предоставленных данных, а также частично исследовали их.<br>
#
# В столбце *name* обнаружено огромное количество вариаций названия вакансии, а также смешивание вакансии в одного специалиста, т. е. в одном названии может быть отсылка и к DA, и к DS. Это своего рода проблема отрасли, которая носит системный характер и говорит об необходимости введении стандартов требований к специальностям и об отсутствии понимания в компаниях о выполняемых задачах этими специалистами. Решить эту проблему можно на экспертном уровне, разработав стандарты и требования к специальностям. Далее введя эти стандарты в учебные заведения мы получим хорошую систему подготовки кадров для отрасли.<br>
#
# Преобразовали столбец published_at и выяснили, что вакансии DA были опубликованы в период с 13 февраля по 11 июня 2024 года. Вакансии DS - c 29 февраля по 11 июня 2024 года.<br>
#
# Проверили гипотезу с неявными дубликатами по 4 столбцам 'name', 'employer', 'area', 'experience'. Выявили 420 и 218 дублей DA и DS. Отсюда вывод, что количество вакансий DA и DS завышено на 23 %. Возможная причина таких дубликатов - при обновлении даты размещения вакансий создают новую вакансию с более свежей датой, вместо того чтобы обновить дату уже размещенной вакансии.<br>
#
# Вакансии по поиску DA размещены в 70 городах, DS - в 26 городах.Абсолютные лидеры по вакансиям Москва и Санкт-Петербург, что не удивительно. Далее в топ-10 входят города миллионники областных центров, что тоже не удивительно.<br>
#
# В столбце *experience* всего 4 категории: Junior (no experince), Junior+ (1-3 years), Middle (3-6 years), Senior (6+ years). По количеству требуемых специалистов наблюдается принципиальная разница. У DA больше всех требуется Junior+ (1-3 years) - 60 % всезх вакансий, далее в 2 раза меньше Middle (3-6 years) - 30 %, затем Junior (no experince) - 8 % и Senior (6+ years) - менее 1 %.
# А у DS почти на одном уровне требуются Middle (3-6 years) - 47 % и Junior+ (1-3 years) - 43 %, вакансий Junior (no experince) и Senior (6+ years) значительно меньше - 5 % и 3 %<br>
#
# Большое количество пропусков было обнаружено в столбце *key_skills* - 273 и 128. И проблема со значениями столбца, которые представляют собой списки "обернутые в строку".<br>
# С помощью функции *top_skills*  выделили навыки каждой категории вакансии в зависимости от опыта и заменили пропуски пятью самыми востребованными.<br>
#
# В столбце schedule 4 типа графика работы. Абсолютное большинство работодателей хотели бы задействовать специалистов на полный рабочий день в несколько раз меньше на удалённой работе и незначительное количество на гибком графике и сменном графике.<br>
#
# В столбце *employment* абсолютное большинство работодателей предлагают полную занятость - около 97 % и на 3 % приходится - стажировка, частичная занятость, проектная работа.<br>
#
# В столбце *salary_from* было выявленно 1086 и 678 пропусков, что очень много. В ходе обработки пропусков нашли медианные значения для каждой группы в соответствии с опытом. Наблюдаются чёткие границы по уровню заработной платы в зависимости от опыта.<br>
#
# Нижняя граница DA:<br>
# - Junior (no experince) - 60 тыс.
# - Junior+ (1-3 years) - 90 тыс.
# - Middle (3-6 years) - 150 тыс.
# - Senior (6+ years) - 200 тыс.<br>
#
# Нижняя граница DS:<br>
#
# - Junior+ (1-3 years) - 105 тыс., что на 15 больше, чем у DA
# - Middle (3-6 years) - 200 тыс., что на 50 больше, чем у DA и соответствует уровню сеньор у DA
# - Junior (no experince) - 60 тыс.
# - Senior (6+ years) - 160 тыс., связано с тем, что имеется одно единственное значение, которое не соответствует рыночным значениям. Заполнили пропуски - 250 тыс.<br>
#
# В столбце *salary_to* наблюдалась такая же картина - большое количество пропусков, которые заменили на медианные значения.<br>
# Такие же чёткие границы по зарплатам в зависимости от уроня опыта.<br>
# Верхняя граница DA:<br>
# - Junior (no experince) - 80 тыс.
# - Junior+ (1-3 years) - 120 тыс.
# - Middle (3-6 years) - 200 тыс.
# - Senior (6+ years) - 240 тыс.<br>
#
# Верхняя граница DS:<br>
# - Junior (no experince) - 80 тыс.
# - Junior+ (1-3 years) - 200 тыс., что на 80 больше, чем у DA
# - Middle (3-6 years) - 300 тыс., что на 100 больше
# - Senior (6+ years) - 300 тыс., связано с тем, что имеется всего 3 значения. Заменим на 350 тыс.<br>
#
# Изменили тип данных в столбцах *salary_from* и *salary_to* на int.
#
# Удалили столбцы 'hard_skills_from_description', 'soft_skills_from_description', 'type'. Теперь можем приступать к основному исследованию.

# %% [markdown]
# ## Проведение исследования

# %% [markdown]
# Перед исследованием перезапишем подгруппы по категориям опыта.

# %%
# нарезаем датафреймы по требуемому опыту
df_da_jun1 = df_da.query('experience == "Junior (no experince)"')
df_da_jun2 = df_da.query('experience == "Junior+ (1-3 years)"')
df_da_mid = df_da.query('experience == "Middle (3-6 years)"')
df_da_sen = df_da.query('experience == "Senior (6+ years)"')

# %%
# нарезаем датафреймы по требуемому опыту
df_ds_jun1 = df_ds.query('experience == "Junior (no experince)"')
df_ds_jun2 = df_ds.query('experience == "Junior+ (1-3 years)"')
df_ds_mid = df_ds.query('experience == "Middle (3-6 years)"')
df_ds_sen = df_ds.query('experience == "Senior (6+ years)"')

# %% [markdown]
# ### Топ требуемых навыков

# %% [markdown]
# С помощью функции *top_skills* найдём топ требуемых навыков для DA и DS.

# %%
df_skills_da = top_skills(df_da['key_skills'])
df_skills_da.value_counts().head(15)
# Out:
# skills
# SQL                                    875
# Python                                 725
# Анализ данных                          604
# Аналитическое мышление                 487
# Pandas                                 474
# Документация                           296
# MS Excel                               197
# Power BI                               184
# Работа с базами данных                 155
# Работа с большим объемом информации    149
# Коммуникация                           141
# Аналитика                              140
# Data Analysis                          109
# Базы данных                            108
# MS SQL                                 104
# Name: count, dtype: int64

# %%
df_skills_da.nunique()
# Out:
# skills    814
# dtype: int64

# %% [markdown]
# 814 навыков для вакансии DA. Найдём процентное соотношение.

# %%
# найдё общее количество навыков
df_skills_da.count()
# Out:
# skills    7904
# dtype: int64

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_da_top = df_skills_da.value_counts().head(15).reset_index()
df_skills_da_top['part'] = round((df_skills_da_top['count'] / 7904) * 100, 2)
df_skills_da_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_da_top
# Out:
#                                   skill  cnt_skill  part_skill
# 0                                   SQL        875       11.07
# 1                                Python        725        9.17
# 2                         Анализ данных        604        7.64
# 3                Аналитическое мышление        487        6.16
# 4                                Pandas        474        6.00
# 5                          Документация        296        3.74
# 6                              MS Excel        197        2.49
# 7                              Power BI        184        2.33
# 8                Работа с базами данных        155        1.96
# 9   Работа с большим объемом информации        149        1.89
# 10                         Коммуникация        141        1.78
# 11                            Аналитика        140        1.77
# 12                        Data Analysis        109        1.38
# 13                          Базы данных        108        1.37
# 14                               MS SQL        104        1.32

# %% [markdown]
# Визуализируем получившийся топ навыков.

# %%
plt.figure(figsize=(8,5))
df_skills_da_top.plot.barh('skill', 'part_skill', color='#176B87', label='Доля навыков от общего количества')
plt.title(label='Топ-15 навыков DA', fontsize=15)
plt.xlabel('Доля требуемых навыков, %', fontsize=12)
plt.ylabel('Навыки', fontsize=12);

# %% [markdown]
# Для DA наиболее востребованы hard skills - SQL, Python и Pandas, из soft skills наиболее востребованы - Анализ данных и Аналитическое мышление.
# Теперь рассмотрим навыки DS.

# %%
df_skills_ds = top_skills(df_ds['key_skills'])
df_skills_ds.value_counts().head(15)
# Out:
# skills
# Python                       476
# Pandas                       407
# SQL                          314
# Документация                 239
# Machine Learning             221
# ML                            88
# Коммуникация                  88
# Математическая статистика     78
# Data Science                  66
# NLP                           53
# Git                           52
# confluence                    51
# PyTorch                       51
# Анализ данных                 49
# Big Data                      47
# Name: count, dtype: int64

# %%
df_skills_ds.nunique()
# Out:
# skills    457
# dtype: int64

# %% [markdown]
# 457 различных навыков DS. Найдём процентное соотношение для DS.

# %%
# найдё общее количество навыков
df_skills_ds.count()
# Out:
# skills    3825
# dtype: int64

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_ds_top = df_skills_ds.value_counts().head(15).reset_index()
df_skills_ds_top['part'] = round((df_skills_ds_top['count'] / 3825) * 100, 2)
df_skills_ds_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_ds_top
# Out:
#                         skill  cnt_skill  part_skill
# 0                      Python        476       12.44
# 1                      Pandas        407       10.64
# 2                         SQL        314        8.21
# 3                Документация        239        6.25
# 4            Machine Learning        221        5.78
# 5                          ML         88        2.30
# 6                Коммуникация         88        2.30
# 7   Математическая статистика         78        2.04
# 8                Data Science         66        1.73
# 9                         NLP         53        1.39
# 10                        Git         52        1.36
# 11                 confluence         51        1.33
# 12                    PyTorch         51        1.33
# 13              Анализ данных         49        1.28
# 14                   Big Data         47        1.23

# %% [markdown]
# Визуализируем наш топ навыков.

# %%
plt.figure(figsize=(8,5))
df_skills_ds_top.plot.barh('skill', 'part_skill', color='#176B87', label='Доля навыков от общего количества')
plt.title(label='Топ-15 навыков DS', fontsize=15)
plt.xlabel('Доля требуемых навыков, %', fontsize=12)
plt.ylabel('Навыки', fontsize=12);

# %% [markdown]
# **Выводы:**<br>
# В топ DA входит:<br>
# - самые востребованные: SQL, Python, Анализ данных, Аналитическое мышление, Pandas
# - средние: Документация, MS Excel, Power BI, Работа с базами данных, Работа с большим объемом информации<br>
# Для DA наиболее востребованы hard skills - SQL, Python и Pandas, из soft skills наиболее востребованы - Анализ данных и Аналитическое мышление.
#
# В топ DS входит:<br>
# - самые востребованные: Python, Pandas, SQL, Документация, Machine Learning
# - средние: ML, Коммуникация, Математическая статистика, Data Science, NLP<br>
# Для DS ещё более востребованы hard skills - Python, Pandas, SQL и Machine Learning, из soft skills наиболее востребованы - Документация.

# %% [markdown]
# #### Топ требуемых навыков для DA в зависимости от опыта

# %% [markdown]
# Посмотрим на требуемые навыки для Junior (no experince).

# %%
df_skills_da_jun1 = top_skills(df_da_jun1['key_skills'])
df_skills_da_jun1.value_counts().head(10)
# Out:
# skills
# Аналитическое мышление                 62
# SQL                                    59
# Анализ данных                          56
# Python                                 55
# MS Excel                               54
# Работа с большим объемом информации    17
# Pandas                                 15
# Коммуникация                           15
# Документация                           15
# Базы данных                            12
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_da_jun1.count()
# Out:
# skills    606
# dtype: int64

# %%
df_skills_da_jun1.nunique()
# Out:
# skills    167
# dtype: int64

# %% [markdown]
# 167 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_da_jun1_top = df_skills_da_jun1.value_counts().head(10).reset_index()
df_skills_da_jun1_top['part'] = round((df_skills_da_jun1_top['count'] / 606) * 100, 2)
df_skills_da_jun1_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_da_jun1_top
# Out:
#                                  skill  cnt_skill  part_skill
# 0               Аналитическое мышление         62       10.23
# 1                                  SQL         59        9.74
# 2                        Анализ данных         56        9.24
# 3                               Python         55        9.08
# 4                             MS Excel         54        8.91
# 5  Работа с большим объемом информации         17        2.81
# 6                               Pandas         15        2.48
# 7                         Коммуникация         15        2.48
# 8                         Документация         15        2.48
# 9                          Базы данных         12        1.98

# %% [markdown]
# Наиболее востребованные навыки для Junior это soft skills - Аналитическое мышление, Анализ данных. Из hard skills востребованы - SQL, Python и MS Excel.

# %% [markdown]
# Посмотрим на требуемые навыки для Junior+ (1-3 years).

# %%
df_skills_da_jun2 = top_skills(df_da_jun2['key_skills'])
df_skills_da_jun2.value_counts().head(10)
# Out:
# skills
# SQL                                    529
# Python                                 407
# Анализ данных                          371
# Аналитическое мышление                 356
# Pandas                                 289
# MS Excel                               114
# Power BI                               114
# Документация                           111
# Работа с базами данных                 105
# Работа с большим объемом информации     99
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_da_jun2.count()
# Out:
# skills    4705
# dtype: int64

# %%
df_skills_da_jun2.nunique()
# Out:
# skills    590
# dtype: int64

# %% [markdown]
# 590 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_da_jun2_top = df_skills_da_jun2.value_counts().head(10).reset_index()
df_skills_da_jun2_top['part'] = round((df_skills_da_jun2_top['count'] / 4705) * 100, 2)
df_skills_da_jun2_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_da_jun2_top
# Out:
#                                  skill  cnt_skill  part_skill
# 0                                  SQL        529       11.24
# 1                               Python        407        8.65
# 2                        Анализ данных        371        7.89
# 3               Аналитическое мышление        356        7.57
# 4                               Pandas        289        6.14
# 5                             MS Excel        114        2.42
# 6                             Power BI        114        2.42
# 7                         Документация        111        2.36
# 8               Работа с базами данных        105        2.23
# 9  Работа с большим объемом информации         99        2.10

# %% [markdown]
# Наиболее востребованные навыки для Junior+ (1-3 years) - SQL, Python, Анализ данных, Аналитическое мышление и Pandas.

# %% [markdown]
# Посмотрим на требуемые навыки для Middle (3-6 years).

# %%
df_skills_da_mid = top_skills(df_da_mid['key_skills'])
df_skills_da_mid.value_counts().head(10)
# Out:
# skills
# SQL                       280
# Python                    256
# Анализ данных             176
# Документация              168
# Pandas                    167
# Аналитическое мышление     67
# Power BI                   59
# Data Analysis              48
# Коммуникация               45
# Работа с базами данных     40
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_da_mid.count()
# Out:
# skills    2515
# dtype: int64

# %%
df_skills_da_mid.nunique()
# Out:
# skills    372
# dtype: int64

# %% [markdown]
# 372 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_da_mid_top = df_skills_da_mid.value_counts().head(10).reset_index()
df_skills_da_mid_top['part'] = round((df_skills_da_mid_top['count'] / 2515) * 100, 2)
df_skills_da_mid_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_da_mid_top
# Out:
#                     skill  cnt_skill  part_skill
# 0                     SQL        280       11.13
# 1                  Python        256       10.18
# 2           Анализ данных        176        7.00
# 3            Документация        168        6.68
# 4                  Pandas        167        6.64
# 5  Аналитическое мышление         67        2.66
# 6                Power BI         59        2.35
# 7           Data Analysis         48        1.91
# 8            Коммуникация         45        1.79
# 9  Работа с базами данных         40        1.59

# %% [markdown]
# Наиболее востребованные навыки для Middle (3-6 years) - SQL, Python, Анализ данных, Документация и Pandas.

# %% [markdown]
# Посмотрим на требуемые навыки для Senior (6+ years).

# %%
df_skills_da_sen = top_skills(df_da_sen['key_skills'])
df_skills_da_sen.value_counts().head(10)
# Out:
# skills
# SQL                           7
# Python                        7
# Power BI                      4
# Проактивность                 4
# Pandas                        3
# Аналитическое мышление        2
# Аналитические исследования    2
# Документация                  2
# confluence                    2
# Tableau                       2
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_da_sen.count()
# Out:
# skills    78
# dtype: int64

# %%
df_skills_da_sen.nunique()
# Out:
# skills    47
# dtype: int64

# %% [markdown]
# 590 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_da_sen_top = df_skills_da_sen.value_counts().head(10).reset_index()
df_skills_da_sen_top['part'] = round((df_skills_da_sen_top['count'] / 78) * 100, 2)
df_skills_da_sen_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_da_sen_top
# Out:
#                         skill  cnt_skill  part_skill
# 0                         SQL          7        8.97
# 1                      Python          7        8.97
# 2                    Power BI          4        5.13
# 3               Проактивность          4        5.13
# 4                      Pandas          3        3.85
# 5      Аналитическое мышление          2        2.56
# 6  Аналитические исследования          2        2.56
# 7                Документация          2        2.56
# 8                  confluence          2        2.56
# 9                     Tableau          2        2.56

# %% [markdown]
# Наиболее востребованные навыки для Senior (6+ years) - SQL, Python, Power BI, Проактивность и Pandas.

# %% [markdown]
# Чаще всего требования к специалистам DA в зависимости от требуемого опыта следующие:
# - Junior (no experince) - Аналитическое мышление, SQL, Анализ данных, Python и MS Excel. Из 167 различных требований
# - Junior+ (1-3 years) - SQL, Python, Анализ данных, Аналитическое мышление и Pandas. Из 590 различных требований
# - Middle (3-6 years) - SQL, Python, Анализ данных, Документация и Pandas. Из 347 различных требований
# - Senior (6+ years) - SQL, Python, Power BI, Проактивность и Pandas. Из 47 различных требований
#
# Больше всего требований к категории Junior+.<br>
# Новичкам не обязательно в совершенствве знать SQL и Python в отличии от остальных категорий, для Junior больше важны soft skills. Для остальных категорий в первую очередь необходимы hard skills. У Junior+ и Middle разница очень размыта, Middle должен уметь работать с документацией. Senior кроме всего должен уметь работать с визуализацией.

# %% [markdown]
# #### Топ требуемых навыков для DS в зависимости от опыта

# %% [markdown]
# Сделаем то же самое для DS.

# %% [markdown]
# Посмотрим на требуемые навыки для Junior (no experince).

# %%
df_skills_ds_jun1 = top_skills(df_ds_jun1['key_skills'])
df_skills_ds_jun1.value_counts().head(10)
# Out:
# skills
# Python                       31
# Математическая статистика    23
# Data Mining                  21
# Pandas                       20
# Git                          20
# Machine Learning              5
# Машинное обучение             5
# Документация                  4
# ML                            4
# Анализ данных                 3
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_ds_jun1.count()
# Out:
# skills    196
# dtype: int64

# %%
df_skills_ds_jun1.nunique()
# Out:
# skills    55
# dtype: int64

# %% [markdown]
# 55 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_ds_jun1_top = df_skills_ds_jun1.value_counts().head(10).reset_index()
df_skills_ds_jun1_top['part'] = round((df_skills_ds_jun1_top['count'] / 196) * 100, 2)
df_skills_ds_jun1_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_ds_jun1_top
# Out:
#                        skill  cnt_skill  part_skill
# 0                     Python         31       15.82
# 1  Математическая статистика         23       11.73
# 2                Data Mining         21       10.71
# 3                     Pandas         20       10.20
# 4                        Git         20       10.20
# 5           Machine Learning          5        2.55
# 6          Машинное обучение          5        2.55
# 7               Документация          4        2.04
# 8                         ML          4        2.04
# 9              Анализ данных          3        1.53

# %% [markdown]
# Наиболее востребованные навыки для Junior (no experince) - Python, Математическая статистика, Data Mining, Pandas и Git.

# %% [markdown]
# Посмотрим на требуемые навыки для Junior+ (1-3 years).

# %%
df_skills_ds_jun2 = top_skills(df_ds_jun2['key_skills'])
df_skills_ds_jun2.value_counts().head(10)
# Out:
# skills
# Python                       202
# Pandas                       195
# SQL                          157
# Machine Learning             101
# Документация                  94
# Коммуникация                  37
# Математическая статистика     32
# ML                            28
# Big Data                      28
# Data Science                  26
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_ds_jun2.count()
# Out:
# skills    1587
# dtype: int64

# %%
df_skills_ds_jun2.nunique()
# Out:
# skills    237
# dtype: int64

# %% [markdown]
# 590 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_ds_jun2_top = df_skills_ds_jun2.value_counts().head(10).reset_index()
df_skills_ds_jun2_top['part'] = round((df_skills_ds_jun2_top['count'] / 1587) * 100, 2)
df_skills_ds_jun2_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_ds_jun2_top
# Out:
#                        skill  cnt_skill  part_skill
# 0                     Python        202       12.73
# 1                     Pandas        195       12.29
# 2                        SQL        157        9.89
# 3           Machine Learning        101        6.36
# 4               Документация         94        5.92
# 5               Коммуникация         37        2.33
# 6  Математическая статистика         32        2.02
# 7                         ML         28        1.76
# 8                   Big Data         28        1.76
# 9               Data Science         26        1.64

# %% [markdown]
# Наиболее востребованные навыки для Junior+ (1-3 years) - Python, Pandas, SQL, Machine Learning и Документация.

# %% [markdown]
# Посмотрим на требуемые навыки для Middle (3-6 years).

# %%
df_skills_ds_mid = top_skills(df_ds_mid['key_skills'])
df_skills_ds_mid.value_counts().head(10)
# Out:
# skills
# Python              228
# Pandas              182
# SQL                 150
# Документация        131
# Machine Learning    108
# ML                   51
# Коммуникация         47
# Data Science         32
# confluence           29
# NLP                  29
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_ds_mid.count()
# Out:
# skills    1886
# dtype: int64

# %%
df_skills_ds_mid.nunique()
# Out:
# skills    316
# dtype: int64

# %% [markdown]
# 590 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_ds_mid_top = df_skills_ds_mid.value_counts().head(10).reset_index()
df_skills_ds_mid_top['part'] = round((df_skills_ds_mid_top['count'] / 1886) * 100, 2)
df_skills_ds_mid_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_ds_mid_top
# Out:
#               skill  cnt_skill  part_skill
# 0            Python        228       12.09
# 1            Pandas        182        9.65
# 2               SQL        150        7.95
# 3      Документация        131        6.95
# 4  Machine Learning        108        5.73
# 5                ML         51        2.70
# 6      Коммуникация         47        2.49
# 7      Data Science         32        1.70
# 8        confluence         29        1.54
# 9               NLP         29        1.54

# %% [markdown]
# Наиболее востребованные навыки для Middle (3-6 years) - Python, Pandas, SQL, Документация и Machine Learning.

# %% [markdown]
# Посмотрим на требуемые навыки для Senior (6+ years).

# %%
df_skills_ds_sen = top_skills(df_ds_sen['key_skills'])
df_skills_ds_sen.value_counts().head(10)
# Out:
# skills
# Python                 15
# Документация           10
# Pandas                 10
# Data Science            7
# Machine Learning        7
# ML                      5
# PyTorch                 4
# SQL                     4
# Управление командой     3
# Коммуникация            3
# Name: count, dtype: int64

# %%
# найдё общее количество навыков
df_skills_ds_sen.count()
# Out:
# skills    156
# dtype: int64

# %%
df_skills_da_sen.nunique()
# Out:
# skills    47
# dtype: int64

# %% [markdown]
# 590 различных требований.

# %%
# создадим столбец с долей требуемого навыка в процентах 
df_skills_ds_sen_top = df_skills_ds_sen.value_counts().head(10).reset_index()
df_skills_ds_sen_top['part'] = round((df_skills_ds_sen_top['count'] / 156) * 100, 2)
df_skills_ds_sen_top.columns = ['skill', 'cnt_skill', 'part_skill']
df_skills_ds_sen_top
# Out:
#                  skill  cnt_skill  part_skill
# 0               Python         15        9.62
# 1         Документация         10        6.41
# 2               Pandas         10        6.41
# 3         Data Science          7        4.49
# 4     Machine Learning          7        4.49
# 5                   ML          5        3.21
# 6              PyTorch          4        2.56
# 7                  SQL          4        2.56
# 8  Управление командой          3        1.92
# 9         Коммуникация          3        1.92

# %% [markdown]
# Наиболее востребованные навыки для Senior (6+ years) - Python, Документация, Pandas, Data Science и Machine Learning.

# %% [markdown]
# Требования к специалистам DS в зависимости от требуемого опыта следующие:<br>
# - Junior (no experince) - Python, Математическая статистика, Data Mining, Pandas и Git. ИЗ 55 различных требований
# - Junior+ (1-3 years) - Python, Pandas, SQL, Machine Learning и Документация. Из 237 различных требований
# - Middle (3-6 years) - Python, Pandas, SQL, Документация и Machine Learning. Из 316 различных требований
# - Senior (6+ years) - Python, Документация, Pandas, Data Science и Machine Learning. Из 47 различных требований
#
# Больше всего требований к Middle.<br>
# Абсолютно для всех категорий в первую очередь обязательно нужно владеть hard skills - Python и Pandas. Новичкам нужно знать Математическую статистику. У Junior+ и Middle разницы нет. Senior кроме всего должен обладать навыками Data Science.

# %% [markdown]
# ### Топ по количеству вакансий

# %% [markdown]
# Ранее мы определили, что у DA из 1381 вакансии больше всех требуется Junior+ - 60 % всезх вакансий, далее в 2 раза меньше Middle - 30 %, затем Junior - 8 % и Senior - менее 1 %.<br>
# А у DS из 756 вакансий почти на одном уровне требуются Middle - 47 % и Junior+ - 43 %, вакансий Junior и Senior значительно меньше - 5 % и 3 %<br>
# А также узнали топ организаций по общему количеству вакансий DA и DS. Теперь разобъём по категориям опыта и определим для каждой категории своих лидеров..

# %%
df_da_jun1['id'].count()
# Out:
# 119

# %%
df_da_jun1['employer'].value_counts().head(10)
# Out:
# employer
# сбер                                     12
# магнит, розничная сеть                    5
# юникон ап                                 3
# московская биржа                          2
# нао ирмаст-холдинг                        2
# согласие, страховая компания              2
# ozon                                      2
# центральный банк российской федерации     2
# сибур, группа компаний                    2
# dns технологии                            2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_da_jun1['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DA Junior', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 119 вакансий DA Junior 12 в Сбер, 5 Магнит, 3 Юникон. По 2 вакансии в Московской бирже, НАО Ирмаст-холдинг, Согласие, Ozon, ЦБ РФ, Сибур, DNS.

# %%
df_da_jun2['id'].count()
# Out:
# 830

# %%
df_da_jun2['employer'].value_counts().head(10)
# Out:
# employer
# сбер                                     82
# банк втб (пао)                           21
# мтс                                      14
# магнит, розничная сеть                   13
# центральный банк российской федерации    11
# марс                                     11
# ozon                                     10
# wildberries                               9
# деловые линии                             9
# okko                                      8
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_da_jun2['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DA Junior+', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 830 вакансий DA Junior+ 82 в Сбер, 21 в ВТБ, 14 МТС, 13 Магнит, по 11 в ЦБ РФ и Марс. В топ-10 входят: Ozon, Wildberries, Деловые линии, Okko.

# %%
df_da_mid['id'].count()
# Out:
# 422

# %%
df_da_mid['employer'].value_counts().head(10)
# Out:
# employer
# сбер                    38
# wildberries             16
# т1                      11
# ozon                    10
# maxim technology         7
# яндекс                   7
# «uzum technologies».     6
# контур                   6
# мтс                      6
# inguru.ru                6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_da_mid['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DA Middle', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 422 вакансий DA Middle 38 в Сбер, 16 в Wildberries, 11 в T1, 10 в Ozon. В топ-10 входят: Maxim Technology, Яндекс, Uzum Technologies, Контур, МТС, Inguru.ru

# %%
df_da_sen['id'].count()
# Out:
# 10

# %%
df_da_sen['employer'].value_counts()
# Out:
# employer
# леруа мерлен          2
# cloudpayments         1
# reinvent baltics      1
# секонд сайт           1
# aramco innovations    1
# paymatrix             1
# spice agency          1
# мединвестгрупп        1
# b2broker              1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_da_sen['employer'].value_counts().plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DA Senior', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 10 вакансий DA Senior 2 в Леруа Мерлен и по 1 в cloudpayments, reinvent baltics, секонд сайт, aramco innovations, paymatrix, spice agency, мединвестгрупп и b2broker.

# %% [markdown]
# Теперь посмотрим как распределены лидеры вакансий DS.

# %%
df_ds_jun1['id'].count()
# Out:
# 39

# %%
df_ds_jun1['employer'].value_counts().head(10)
# Out:
# employer
# сбер                                                        9
# молвер                                                      5
# ozon                                                        4
# lamoda tech                                                 2
# адв                                                         1
# фгбун институт психологии российской академии наук          1
# тестовая компания песочница для разработчиков по диасофт    1
# bnd llc                                                     1
# blockshop                                                   1
# мигкредит                                                   1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_ds_jun1['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DS Junior', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 39 вакансий DS Junior 9 в Сбер, 5 в Молвер, 4 в Ozon. Остальные организации разместили по одной вакансии: Lamoda Tech, АДВ, институт психологии РАН и т.д.

# %%
df_ds_jun2['id'].count()
# Out:
# 330

# %%
df_ds_jun2['employer'].value_counts().head(10)
# Out:
# employer
# сбер                             56
# банк втб (пао)                   11
# газпромбанк                       8
# ростелеком                        7
# сахалин - остров возможностей     7
# 1221системс                       7
# билайн                            7
# lamoda tech                       6
# пкб                               6
# samokat.tech                      6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_ds_jun2['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DS Junior+', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 330 вакансий DS Junior+ 56 в Сбер, 11 в ВТБ, 8 в Газпромбанк. В топ-10 входят: Ростелеком, Сахалин-остров возможностей, 1221 систем, Билайн, Lamoda Tech, ПКБ, Samokat.tech.

# %%
df_ds_mid['id'].count()
# Out:
# 359

# %%
df_ds_mid['employer'].value_counts().head(10)
# Out:
# employer
# сбер               54
# ozon               18
# газпромбанк        16
# samokat.tech       12
# wildberries         8
# т1                  7
# райффайзен банк     6
# headhunter          5
# дом.рф              5
# банк втб (пао)      5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_ds_mid['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DS Middle', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 359 вакансий DS Middle 54 в Сбер, 18 в Ozon, 16 в Газпромбанк, 12 в Samokat.tech. В топ-10 входят: Wildberries, T1, Райффайзен банк, Headhunter, Дом.рф, ВТБ.

# %%
df_ds_sen['id'].count()
# Out:
# 28

# %%
df_ds_sen['employer'].value_counts().head(10)
# Out:
# employer
# sape                  2
# гудфокаст             2
# aramco innovations    2
# биайэй-технолоджиз    2
# элемент лизинг        1
# rubbles               1
# альфа-банк            1
# selecty               1
# мокка                 1
# консалтика            1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df_ds_sen['employer'].value_counts().head(10).plot.barh(color='#176B87')
plt.title('Топ-10 организаций по количеству вакансий DS Senior', fontsize=15)
plt.xlabel('Количество вакансий', fontsize=12)
plt.ylabel('Организации', fontsize=12);

# %% [markdown]
# Из 28 вакансий DS Senior по 2 в Sape, Гудфокаст, Aramco innovations, Биайэй-Технолоджиз. В остальных организациях требуется по 1 специалисту: "э"лемент лизинг, Rubbles, Альфа-банк и т. д.

# %% [markdown]
# **Выводы:**<br>
# Из 119 вакансий DA Junior 12 в Сбер, 5 Магнит, 3 Юникон. По 2 вакансии в Московской бирже, НАО Ирмаст-холдинг, Согласие, Ozon, ЦБ РФ, Сибур, DNS.<br>
# Из 830 вакансий DA Junior+ 82 в Сбер, 21 в ВТБ, 14 МТС, 13 Магнит, по 11 в ЦБ РФ и Марс. В топ-10 входят: Ozon, Wildberries, Деловые линии, Okko.<br>
# Из 422 вакансий DA Middle 38 в Сбер, 16 в Wildberries, 11 в T1, 10 в Ozon. В топ-10 входят: Maxim Technology, Яндекс, Uzum Technologies, Контур, МТС, Inguru.ru.<br>
# Из 10 вакансий DA Senior 2 в Леруа Мерлен и по 1 в cloudpayments, reinvent baltics, секонд сайт, aramco innovations, paymatrix, spice agency, мединвестгрупп и b2broker.<br>
#
# Из 39 вакансий DS Junior 9 в Сбер, 5 в Молвер, 4 в Ozon. Остальные организации разместили по одной вакансии: Lamoda Tech, АДВ, институт психологии РАН и т.д.<br>
# Из 330 вакансий DS Junior+ 56 в Сбер, 11 в ВТБ, 8 в Газпромбанк. В топ-10 входят: Ростелеком, Сахалин-остров возможностей, 1221 систем, Билайн, Lamoda Tech, ПКБ, Samokat.tech.<br>
# Из 359 вакансий DS Middle 54 в Сбер, 18 в Ozon, 16 в Газпромбанк, 12 в Samokat.tech. В топ-10 входят: Wildberries, T1, Райффайзен банк, Headhunter, Дом.рф, ВТБ.<br>
# Из 28 вакансий DS Senior по 2 в Sape, Гудфокаст, Aramco innovations, Биайэй-Технолоджиз. В остальных организациях требуется по 1 специалисту: "э"лемент лизинг, Rubbles, Альфа-банк и т. д.<br>
#
# Самые востребованные категории Junior+ и Middle. Абсолютный лидер по всем категориям вакансий Сбер, за исключением категории Senior. В топ-10 в основном входят крупные банки: Сбер, ВТБ, Газпромбанк, ЦБ РФ, Райффайзен банк; крупные интернет-магазины: Ozon, Wildberries, Lamoda Tech, Samokat.tech; компании предоставляющие услуги связи: МТС, Билайн, Ростелеком; IT-компании: Т1, Яндекс.

# %% [markdown]
# ### Зарплаты в зависимости от категории опыта

# %% [markdown]
# Посмотрим на предлагаемы зарплаты для DA. Обновим

# %%
df_da_jun1['salary_from'].unique()
# Out:
# array([ 60000,  56000,  55000,  25000,  30000,  99500,  45000,  80000,
#         85000,  78000,  70000,  78045,  40000,  42500, 100000,  50000,
#         63000,  61000,  75000,  90000,  26000,     50,  76000, 112200,
#        140000])

# %% [markdown]
# Обнаружено аномальное значение 50, которое подлежит замене на 50000.

# %%
df_da.loc[(df_da['salary_from'] == 50) & (df_da['experience'] == 'Junior (no experince)'), 'salary_from'] = 50000
df_da_jun1 = df_da.query('experience == "Junior (no experince)"')

# %%
df_da_salaty_from = df_da.pivot_table(index='experience', values='salary_from', aggfunc=['min', 'max', 'median']).reset_index()
df_da_salaty_from.columns = ['experience', 'min', 'max', 'median']
df_da_salaty_from
# Out:
#               experience    min     max  median
# 0  Junior (no experince)  25000  140000   60000
# 1    Junior+ (1-3 years)  28940  300000   90000
# 2     Middle (3-6 years)  40000  350000  150000
# 3      Senior (6+ years)  70000  200000  200000

# %% [markdown]
# Наглядно представлены разброс зарплат и медианное значение для каждой категории DA.

# %%
df_ds_salaty_from = df_ds.pivot_table(index='experience', values='salary_from', aggfunc=['min', 'max', 'median']).reset_index()
df_ds_salaty_from.columns = ['experience', 'min', 'max', 'median']
df_ds_salaty_from
# Out:
#               experience     min     max  median
# 0  Junior (no experince)   25000  140250   60000
# 1    Junior+ (1-3 years)   50000  210000  105000
# 2     Middle (3-6 years)   93500  350000  200000
# 3      Senior (6+ years)  160000  250000  250000

# %% [markdown]
# Наглядно представлены разброс зарплат и медианное значение для каждой категории DS.

# %% [markdown]
# Мы определили нижнюю границу зарплаты для специалистов DA и DS каждого из уровней.<br>
# Создадим удобный датафрейм для наглядности.

# %%
data = {'da_min': [60000, 90000, 150000, 200000], 'ds_min': [60000, 105000, 200000, 250000]}
df_salary_from = pd.DataFrame(data, index=['Junior', 'Junior+', 'Middle', 'Senior'])

# %% [markdown]
# Визуализируем получившиеся данные.

# %%
df_salary_from.plot.bar()
plt.title('Нижний порог зароботной платы для DA И DS', fontsize=15)
plt.xlabel('Уровень опыта', fontsize=12)
plt.ylabel('Зароботная плата', fontsize=12);

# %% [markdown]
# Теперь мы видим, что специалистам без опыта предлагают одинаковый уровень зарплаты, а далее у DS зарплата выше чем у DA. Самая заметная разница у Middle - 25%, Senior - 20%, Junior+ - около 10%.

# %% [markdown]
# Повторим процедуру для верхней границы. Рассмотрим DA.

# %%
df_da_salaty_to = df_da.pivot_table(index='experience', values='salary_to', aggfunc=['min', 'max', 'median']).reset_index()
df_da_salaty_to.columns = ['experience', 'min', 'max', 'median']
df_da_salaty_to
# Out:
#               experience     min     max  median
# 0  Junior (no experince)   25000  142000   80000
# 1    Junior+ (1-3 years)   35000  300000  120000
# 2     Middle (3-6 years)   55000  495550  200000
# 3      Senior (6+ years)  200000  280000  240000

# %% [markdown]
# Наглядно представлены разброс зарплат и медианное значение для каждой категории DA.

# %%
df_ds_salaty_to = df_ds.pivot_table(index='experience', values='salary_to', aggfunc=['min', 'max', 'median']).reset_index()
df_ds_salaty_to.columns = ['experience', 'min', 'max', 'median']
df_ds_salaty_to
# Out:
#               experience     min     max  median
# 0  Junior (no experince)   25000  124752   80000
# 1    Junior+ (1-3 years)   30000  350000  200000
# 2     Middle (3-6 years)  140250  500000  300000
# 3      Senior (6+ years)  190000  550000  350000

# %% [markdown]
# Наглядно представлены разброс зарплат и медианное значение для каждой категории DS.

# %% [markdown]
# Создадим удобный датафрейм.

# %%
data = {'DA': [80000, 120000, 200000, 240000], 'DS': [80000, 200000, 300000, 350000]}
df_salary_from = pd.DataFrame(data, index=['Junior', 'Junior+', 'Middle', 'Senior'])

# %% [markdown]
# Визуализируем получившиеся данные.

# %%
df_salary_from.plot.bar()
plt.title('Верхний порог зароботной платы для DA И DS', fontsize=15)
plt.xlabel('Уровень опыта', fontsize=12)
plt.ylabel('Зароботная плата', fontsize=12);

# %% [markdown]
# Мы видим, что специалистам без опыта также предлагают одинаковый уровень зарплаты, а далее у DS зарплата выше чем у DA, причем разница существеннее, чем у нижнего порога. Самая заметная разница у Junior+ - около 40%, Middle - 34%, Senior - 31%, .

# %% [markdown]
# **Выводы:**<br>
# Видны чёткие ступени по предлагаемой зарплате в зависимости от опыта. Общая тенденция такова, что для DS зарплатная вилка больше на 10 - 40 % в зависимости от опыта, чем для DA, за исключением категории Junior - здесь паритет. Выглядит это всё следующим образом:<br>
# Зарплатная вилка DA:
# - Junior - 60-80
# - Junior+ - 90-120
# - Middle - 150-200
# - Senior - 200-240
#
# Зарплатная вилка DS:
# - Junior - 60-80
# - Junior+ - 105-200
# - Middle - 200-300
# - Senior - 250-350

# %% [markdown]
# ### Тип занятости в зависимости от категории опыта

# %% [markdown]
# Исследуем DA.

# %%
# создаё сводную таблицу
df_da_employment = df_da.pivot_table(index='experience', columns='employment', values='id', aggfunc='count')\
                    .reset_index().fillna (0)
df_da_employment.columns = ['experience', 'Полная занятость', 'Проектная работа', 'Стажировка', 'Частичная занятость']
# изменим тип данных на int
df_da_employment['Полная занятость'] = df_da_employment['Полная занятость'].astype(int)
df_da_employment['Проектная работа'] = df_da_employment['Проектная работа'].astype(int)
df_da_employment['Стажировка'] = df_da_employment['Стажировка'].astype(int)
df_da_employment['Частичная занятость'] = df_da_employment['Частичная занятость'].astype(int)
df_da_employment
# Out:
#               experience  Полная занятость  Проектная работа  Стажировка  \
# 0  Junior (no experince)               102                 1          13
# 1    Junior+ (1-3 years)               822                 2           1
# 2     Middle (3-6 years)               416                 1           0
# 3      Senior (6+ years)                10                 0           0
#
#    Частичная занятость
# 0                    3
# 1                    5
# 2                    5
# 3                    0

# %% [markdown]
# Подавляющее большинство вакансий с Полной занятостью. Редкие предложения для Проектной работы, Стажировок и Частичной занятости. У DA Senior кроме Полной занятости, других типов не бывает. Стажировки предлагают только Junior и Junior+.

# %% [markdown]
# Теперь исследуем DS.

# %%
# создаё сводную таблицу
df_ds_employment = df_ds.pivot_table(index='experience', columns='employment', values='id', aggfunc='count')\
                    .reset_index().fillna (0)
df_ds_employment.columns = ['experience', 'Полная занятость', 'Проектная работа', 'Стажировка', 'Частичная занятость']
# изменим тип данных на int
df_ds_employment['Полная занятость'] = df_ds_employment['Полная занятость'].astype(int)
df_ds_employment['Проектная работа'] = df_ds_employment['Проектная работа'].astype(int)
df_ds_employment['Стажировка'] = df_ds_employment['Стажировка'].astype(int)
df_ds_employment['Частичная занятость'] = df_ds_employment['Частичная занятость'].astype(int)
df_ds_employment
# Out:
#               experience  Полная занятость  Проектная работа  Стажировка  \
# 0  Junior (no experince)                23                 1          15
# 1    Junior+ (1-3 years)               319                 2           2
# 2     Middle (3-6 years)               356                 2           0
# 3      Senior (6+ years)                28                 0           0
#
#    Частичная занятость
# 0                    0
# 1                    7
# 2                    1
# 3                    0

# %% [markdown]
# Такая же картина наблюдается у DS, за небольшим исключением. У Junior нет частичной занятости.

# %% [markdown]
# ### График работы в зависимости от категории опыта

# %% [markdown]
# Исследуем DA.

# %%
# создаё сводную таблицу
df_da_schedule = df_da.pivot_table(index='experience', columns='schedule', values='id', aggfunc='count')\
                    .reset_index().fillna (0)
df_da_schedule.columns = ['experience', 'Гибкий график', 'Полный день', 'Сменный график', 'Удаленная работа']
# изменим тип данных на int
df_da_schedule['Гибкий график'] = df_da_schedule['Гибкий график'].astype(int)
df_da_schedule['Полный день'] = df_da_schedule['Полный день'].astype(int)
df_da_schedule['Сменный график'] = df_da_schedule['Сменный график'].astype(int)
df_da_schedule['Удаленная работа'] = df_da_schedule['Удаленная работа'].astype(int)
df_da_schedule
# Out:
#               experience  Гибкий график  Полный день  Сменный график  \
# 0  Junior (no experince)              3          101               2
# 1    Junior+ (1-3 years)             14          687               4
# 2     Middle (3-6 years)             14          302               0
# 3      Senior (6+ years)              0            7               0
#
#    Удаленная работа
# 0                13
# 1               125
# 2               106
# 3                 3

# %% [markdown]
# Больше всего вакансий предлагают Полный день, далее Удаленная работа, несколько десятков Гибкий график и единицы Сменный график. Для Senior возможны только Полный день или Удаленная работа. А Сменный график предлагают только для Junior и Junior+.

# %% [markdown]
# Исследуем DS.

# %%
# создаё сводную таблицу
df_ds_schedule = df_ds.pivot_table(index='experience', columns='schedule', values='id', aggfunc='count')\
                    .reset_index().fillna (0)
df_ds_schedule.columns = ['experience', 'Гибкий график', 'Полный день', 'Сменный график', 'Удаленная работа']
# изменим тип данных на int
df_ds_schedule['Гибкий график'] = df_ds_schedule['Гибкий график'].astype(int)
df_ds_schedule['Полный день'] = df_ds_schedule['Полный день'].astype(int)
df_ds_schedule['Сменный график'] = df_ds_schedule['Сменный график'].astype(int)
df_ds_schedule['Удаленная работа'] = df_ds_schedule['Удаленная работа'].astype(int)
df_ds_schedule
# Out:
#               experience  Гибкий график  Полный день  Сменный график  \
# 0  Junior (no experince)              7           23               0
# 1    Junior+ (1-3 years)             13          236               1
# 2     Middle (3-6 years)             16          267               1
# 3      Senior (6+ years)              2           22               1
#
#    Удаленная работа
# 0                 9
# 1                80
# 2                75
# 3                 3

# %% [markdown]
# Больше всего вакансий предлагают Полный день, далее Удаленная работа, несколько десятков Гибкий график и единицы Сменный график. А вот для DS Senior на выбор любой вариант работы. Как и у всех категорий, за небольшим исключением. Сменный график невозможен только для Junior.

# %% [markdown]
# ### Динамика размещения вакансий в зависимости от категории опыта

# %% [markdown]
# Исследуем DA.

# %%
# создадим столбец с месяцем размещения вакансии
df_da['month'] = df_da['published_at'].dt.month
df_da.head()
# Out:
#           id                                    name published_at  \
# 0  100039284  junior аналитик данных (исследователь)   2024-05-24
# 1  100039480                         аналитик данных   2024-05-24
# 2  100042705         аналитик данных (исследователь)   2024-05-24
# 3  100046788                 ведущий аналитик данных   2024-05-24
# 4  100056244                         аналитик данных   2024-05-24
#
#                      alternate_url           employer  \
# 0  https://hh.ru/vacancy/100039284  dns головной офис
# 1  https://hh.ru/vacancy/100039480              комус
# 2  https://hh.ru/vacancy/100042705  dns головной офис
# 3  https://hh.ru/vacancy/100046788           х5 group
# 4  https://hh.ru/vacancy/100056244             лукойл
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills     schedule  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  Полный день
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  Полный день
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  Полный день
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  Полный день
# 4                                   ['Документация']  Полный день
#
#          employment                                        description  \
# 0  Полная занятость  наше направление занимается повышением эффекти...
# 1  Полная занятость  сегодня комус один из крупнейших поставщиков о...
# 2  Полная занятость  наше направление занимается повышением эффекти...
# 3  Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 4  Полная занятость  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  наш направление заниматься повышение эффективн...        60000      80000
# 1  сегодня комус крупный поставщик офисный товар ...        60000      80000
# 2  наш направление заниматься повышение эффективн...        90000     120000
# 3  задача разработка бизнес модель групповой прог...        90000     120000
# 4  обязанность участие проектирование разработка ...       150000     200000
#
#       salary_bin                   key_skills_from_key_skills_field  month
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД      5
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel      5
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse      5
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...      5
# 4  ЗП не указана                                                NaN      5

# %%
# сгруппируем данные по категориям в зависимости от месяца размещения вакансий
df_da_dinam_vac = df_da.pivot_table(index='experience', columns='month', values='id', aggfunc='count') \
                    .fillna(0).astype(int)
df_da_dinam_vac.columns = ['fev', 'mar', 'apr', 'may', 'jun']
df_da_dinam_vac
# Out:
#                        fev  mar  apr  may  jun
# experience
# Junior (no experince)    0   19   30   39   31
# Junior+ (1-3 years)      0  142  213  269  206
# Middle (3-6 years)       1   83   96  138  104
# Senior (6+ years)        0    0    3    5    2

# %%
# построим линейный график
df_da_dinam_vac.T.plot()
plt.title('Динамика вакансий DA', fontsize=15)
plt.xlabel('Месяц', fontsize=12)
plt.ylabel('Количество вакансий', fontsize=12);

# %% [markdown]
# В феврале самое низкое количество вакансий, возможно из-за недостаточности данных, так как данные представлены с 13 февраля. Пиком для всех категорий DA является май. Возможно по той же причине - данные представлены по 11 июня.

# %% [markdown]
# Исследуем DS.

# %%
# создадим столбец с месяцем размещения вакансии
df_ds['month'] = df_ds['published_at'].dt.month
df_ds.head()
# Out:
#           id                               name published_at  \
# 0  100049339  стажер data science (новосибирск)   2024-05-24
# 1  100051447                     data scientist   2024-05-24
# 2  100070495       ml engineer / data scientist   2024-05-24
# 3  100076648             team lead data science   2024-05-24
# 4  100077910      data analyst / data scientist   2024-06-08
#
#                      alternate_url                             employer  \
# 0  https://hh.ru/vacancy/100049339                                 сбер
# 1  https://hh.ru/vacancy/100051447  бюро кредитных историй скоринг бюро
# 2  https://hh.ru/vacancy/100070495                               гк фск
# 3  https://hh.ru/vacancy/100076648                                 сбер
# 4  https://hh.ru/vacancy/100077910                                итсен
#
#            department         area             experience  \
# 0  Сбер для экспертов  Новосибирск  Junior (no experince)
# 1                 NaN       Москва    Junior+ (1-3 years)
# 2                 NaN       Москва    Junior+ (1-3 years)
# 3  Сбер для экспертов       Москва     Middle (3-6 years)
# 4                 NaN       Москва     Middle (3-6 years)
#
#                                           key_skills          schedule  \
# 0  ['Python', 'Математическая статистика', 'Data ...       Полный день
# 1  ['Python', 'Hadoop', 'Machine Learning', 'Рабо...  Удаленная работа
# 2  ['Python', 'PyTorch', 'Machine Learning', 'Doc...       Полный день
# 3  ['Python', 'Pandas', 'SQL', 'Machine Learning'...       Полный день
# 4  ['DataLens', 'MS SQL', 'SQL', 'Spark', 'Аналит...       Полный день
#
#          employment                                        description  \
# 0        Стажировка  sberseasons - оплачиваемая программа стажирово...
# 1  Полная занятость  бюро кредитных историй «скоринг бюро» является...
# 2  Полная занятость  о компании и команде: группа компаний фск – мн...
# 3  Полная занятость  наша команда разрабатывает модели машинного об...
# 4  Полная занятость  мы ищем талантливого middle data analyst / dat...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  sberseasons оплачивать программа стажировка ра...        60000      80000
# 1  бюро кредитный история скоринг бюро являться к...       105000     200000
# 2  компания команда группа компания фск многопроф...       105000     200000
# 3  наш команда разрабатывать модель машинный обуч...       200000     300000
# 4  искать талантливый middle data analyst data sc...       350000     300000
#
#       salary_bin                   key_skills_from_key_skills_field  month
# 0  ЗП не указана                                                NaN      5
# 1  ЗП не указана  SQL, MS SQL, Big Data, Python, Spark, Hadoop, ...      5
# 2  ЗП не указана  Python, PyTorch, ML, Docker, NLP, Pandas, SQL,...      5
# 3  ЗП не указана                                                NaN      5
# 4  ЗП не указана  Python, SQL, Обучение и развитие, Data Mining,...      6

# %%
# сгруппируем данные по категориям в зависимости от месяца размещения вакансий
df_ds_dinam_vac = df_ds.pivot_table(index='experience', columns='month', values='id', aggfunc='count') \
                    .fillna(0).astype(int)
df_ds_dinam_vac.columns = ['fev', 'mar', 'apr', 'may', 'jun']
df_ds_dinam_vac
# Out:
#                        fev  mar  apr  may  jun
# experience
# Junior (no experince)    0   12    7   13    7
# Junior+ (1-3 years)      0   81   92   70   87
# Middle (3-6 years)       0   88   91   92   88
# Senior (6+ years)        1    5   11    6    5

# %%
# построим линейный график
df_ds_dinam_vac.T.plot()
plt.title('Динамика вакансий DS', fontsize=15)
plt.xlabel('Месяц', fontsize=12)
plt.ylabel('Количество вакансий', fontsize=12);

# %% [markdown]
# В феврале 1 вакансия, так как февраль представлен одним днём. Для Middle и Junior+ с марта по июнь размещали стабильно около 80  вакансий. Чего не скажешь о Junior и Senior, количество размещаемых вакансий которых, также стабильно находились в пределах от 5 до 12.

# %% [markdown]
# **Выводы:**<br>
# Проведено основное исследование вакансий Аналитиков данных и Data Scientist.<br>
# 1. Требуемые навыки.<br>
# Из 814 всевозможных навыков в топ навыков DA входят:<br>
# - наиболее востребованные: SQL, Python, Анализ данных, Аналитическое мышление, Pandas
# - чуть менее востребованные: Документация, MS Excel, Power BI, Работа с базами данных, Работа с большим объемом информации<br>
# Мы видим, что для DA наиболее востребованы hard skills - SQL, Python и Pandas, из soft skills наиболее востребованы - Анализ данных и Аналитическое мышление.<br>
#
# Из 196 всевозможных навыков в топ навыков DS входят:<br>
# - наиболее востребованные: Python, Pandas, SQL, Документация, Machine Learning
# - чуть менее востребованные: ML, Коммуникация, Математическая статистика, Data Science, NLP<br>
# Мы видим, что для DS ещё более востребованы hard skills - Python, Pandas, SQL и Machine Learning, из soft skills наиболее востребованы - Документация.<br>
#
# Изучили требуемые навыки к специалистам DA и зависимости от требуемого опыта следующие:
# - из 167 всевозможных навыков в вакансиях Junior (no experince), самые необходимые - Аналитическое мышление, SQL, Анализ данных, Python и MS Excel;
# - из 590 всевозможных навыков в вакансиях Junior+ (1-3 years), самые необходимые - SQL, Python, Анализ данных, Аналитическое мышление и Pandas;
# - из 347 всевозможных навыков в вакансиях Middle (3-6 years), самые необходимые - SQL, Python, Анализ данных, Документация и Pandas;
# - из 47 всевозможных навыков в вакансиях Senior (6+ years), самые необходимые - SQL, Python, Power BI, Проактивность и Pandas.
#
# В вакансиях Junior+ самое большое количество требуемых навыков.<br>
# Junior не обязательно в совершенствве знать SQL и Python в отличии от остальных категорий, для Junior больше важны soft skills. Для остальных категорий в первую очередь необходимы hard skills. Между Junior+ и Middle разница в требуемых навыках почти одинаковая, Middle должен уметь работать с Документацией. Senior, кроме всего, должен уметь работать с визуализацией.
#
# Изучили требуемые навыки к специалистам DS и в зависимости от требуемого опыта следующие:<br>
# - из 55 всевозможных навыков в вакансиях Junior (no experince), самые необходимые - Python, Математическая статистика, Data Mining, Pandas и Git;
# - из 237 всевозможных навыков в вакансиях Junior+ (1-3 years), самые необходимые - Python, Pandas, SQL, Machine Learning и Документация;
# - из 316 всевозможных навыков в вакансиях Middle (3-6 years), самые необходимые - Python, Pandas, SQL, Документация и Machine Learning;
# - из 47 всевозможных навыков в вакансиях Senior (6+ years), самые необходимые - Python, Документация, Pandas, Data Science и Machine Learning. <br>
#
# В вакансиях Middle самое большое количество требуемых навыков.<br>
# Всем категориям необходимо владеть hard skills - Python и Pandas. Junior нужно знать Математическую статистику. Между Junior+ и Middle разница в требуемых навыках отсутствует. Senior кроме всего должен обладать навыками Data Science.<br>
#
# 2. Организации которые размещают вакансии DA и DS в зависимости от требуемого опыта.<br>
# Из 119 вакансий DA Junior 12 - Сбер, 5 - Магнит, 3 - Юникон. По 2 вакансии в Московской бирже, НАО Ирмаст-холдинг, Согласие, Ozon, ЦБ РФ, Сибур, DNS.<br>
# Из 830 вакансий DA Junior+ 82 - Сбер, 21 - ВТБ, 14 - МТС, 13 - Магнит, по 11 - ЦБ РФ и Марс. В топ-10 также входят: Ozon, Wildberries, Деловые линии, Okko.<br>
# Из 422 вакансий DA Middle 38 - Сбер, 16 - Wildberries, 11 - T1, 10 - Ozon. В топ-10 также входят: Maxim Technology, Яндекс, Uzum Technologies, Контур, МТС, Inguru.ru.<br>
# Из 10 вакансий DA Senior 2 - Леруа Мерлен и по 1 - cloudpayments, reinvent baltics, секонд сайт, aramco innovations, paymatrix, spice agency, мединвестгрупп и b2broker.<br>
#
# Из 39 вакансий DS Junior 9 - Сбер, 5 - Молвер, 4 - Ozon. Остальные организации разместили по одной вакансии: Lamoda Tech, АДВ, институт психологии РАН и т.д.<br>
# Из 330 вакансий DS Junior+ 56 - Сбер, 11 - ВТБ, 8 - Газпромбанк. В топ-10 также входят: Ростелеком, Сахалин-остров возможностей, 1221 систем, Билайн, Lamoda Tech, ПКБ, Samokat.tech.<br>
# Из 359 вакансий DS Middle 54 - Сбер, 18 - Ozon, 16 - Газпромбанк, 12 - Samokat.tech. В топ-10 также входят: Wildberries, T1, Райффайзен банк, Headhunter, Дом.рф, ВТБ.<br>
# Из 28 вакансий DS Senior по 2 - Sape, Гудфокаст, Aramco innovations, Биайэй-Технолоджиз. В остальных организациях требуется по 1 специалисту: "э"лемент лизинг, Rubbles, Альфа-банк и т. д.<br>
#
# Самые востребованные категории Junior+ и Middle, что не удивительно - специалиств данных категорий являются основными рабочими "руками", а в нашем случае "головами". Абсолютный лидер по всем категориям вакансий и с больши отрывом - это Сбер, за исключением категории Senior. В топ-10 в основном входят крупные банки: Сбер, ВТБ, Газпромбанк, ЦБ РФ, Райффайзен банк; крупные интернет-магазины: Ozon, Wildberries, Lamoda Tech, Samokat.tech; компании предоставляющие услуги связи: МТС, Билайн, Ростелеком; IT-компании: Т1, Яндекс.<br>
#
# 3. Зарплатная вилка.<br>
# Видны чёткие ступени по предлагаемой зарплате в зависимости от опыта. Общая тенденция такова, что для DS зарплатная вилка больше на 10 - 40 % в зависимости от опыта, чем для DA, за исключением категории Junior - здесь паритет. Предлагаемые зарплаты:<br>
# Для DA:<br>
# - Junior - 60-80
# - Junior+ - 90-120
# - Middle - 150-200
# - Senior - 200-240
#
# Для DS:<br>
# - Junior - 60-80
# - Junior+ - 105-200
# - Middle - 200-300
# - Senior - 250-350
#
# 4. Тип занятости.<br>
# Подавляющее большинство вакансий с Полной занятостью. Есть редкие предложения для Проектной работы, Стажировок и Частичной занятости. Для DA Senior кроме Полной занятости, других типов не предлагают. Стажировки предлагают только для Junior и Junior+. Такая же картина наблюдается у DS, за небольшим исключением. Для Junior не предлагают Частичную занятость.<br>
#
# 5. График работы.<br>
# Для DA больше всего вакансий предлагают Полный день - 1097, далее Удаленная работа - 247, несколько десятков Гибкий график - 31 и единицы Сменный график - 6. Для Senior возможны только Полный день или Удаленная работа. А Сменный график предлагают только для Junior и Junior+.<br>
# Для DS больше всего вакансий предлагают Полный день - 548, далее Удаленная работа - 167, несколько десятков Гибкий график - 38 и единицы Сменный график - 3. А вот для DS Senior на выбор любой вариант работы. Как и у всех категорий, за небольшим исключением. Сменный график невозможен только для Junior.<br>
#
# 6. Динамика вакансий по месяцам.<br>
# В феврале самое низкое количество вакансий DA, возможно из-за недостаточности данных, так как данные представлены с 13 февраля. Пиком для всех категорий DA является май. Возможно по той же причине в июне наблюдается просадка - данные представлены по 11 июня. По категориям также наблюдается, что больше всего вакансий размещают для Junior+, далее Middle, Junior и Senior.<br>
# В феврале 1 вакансия DS, так как февраль представлен одним днём. Для Middle и Junior+ с марта по июнь размещали стабильно около 80 вакансий. Чего не скажешь о Junior и Senior, количество размещаемых вакансий которых, также стабильно находились в пределах от 5 до 12.

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# Проведено исследование рынка предлагаемых вакансий в ходе которого выяснили какие различия существуют в предлагаемых вакансиях Аналитиков данных и Data Scientist. А также определили текущий тренд по владению необходимыми навыками для Аналитиков данных и Data Scientist.
#
# **Загрузка и чтение данных.**<br>
# В качестве исходных данных предоставлены файлы в формате Excel собранные из API сайта hh.ru.<br>
#
# Предоставленные исходные данные хорошего качества. Первичное знакомство с файлом по Аналитикам данных (далее - DA) выявило значительные пропуски в столбцах *'department', 'salary_from', 'salary_to', 'key_skills_from_key_skills_field'*. Также имелись проблемы с типами данных в столбцах *'salary_from', 'salary_to'* - необходимо изменить на int. Явные дубликаты не обнаружены.<br>
#
# Выводы после первичного анализа:<br>
# - *type* - статус вакансии на момент получения данных от api - одно значение "открытая", неинформативный столбец;
# - *employer* - работодатель - в выборке 690 организаций разместивших вакансии DA и 305 организаций - DS;
# - *area* - регион места работы - вакансии DA размещены в 70 городах, DS - в 26 городах;
# - *experience* - требуемый опыт работы - подразделяется на 4 группы;
# - *schedule* - график работы - 4 группы;
# - *employment* - тип занятости - 4 группы;
# - *salary_bin* - категория зарплаты - 5 групп.<br>
#
# Столбцы *'hard_skills_from_description', 'soft_skills_from_description', 'type'* удалены.

# %% [markdown]
# **Предобработка данных.**<br>
# В ходе предобработки улучшили качество предоставленных данных, а также провели частичное исследовалие.<br>
#
# В ходе обработки столбца *name* обнаружено большое количество вариантов названия вакансии, а также смешивание вакансии в одного специалиста, т. е. в одном названии существует отсылка и к DA, и к DS. Проблема отрасли, которая носит системный характер и говорит об необходимости введения стандартов требований к специальностям, а также об отсутствии понимания в компаниях о выполняемых задачах этими специалистами. Решить эту проблему можно на экспертном уровне, разработав стандарты и требования к специальностям. Далее введя эти стандарты в учебные заведения становиться возможным получить систему подготовки кадров заточенных под конкретные задачи для отрасли.<br>
#
# Вакансии DA были опубликованы в период с 13 февраля по 11 июня 2024 года. Вакансии DS - c 29 февраля по 11 июня 2024 года.<br>
#
# В ходе обработки неявных дубликатов по 4 столбцам *name', 'employer', 'area', 'experience'*. Выявлено 420 и 218 дублей DA и DS. Отсюда вывод, что количество вакансий DA и DS завышено на 23 %. Возможная причина таких дубликатов - при обновлении даты размещения вакансий создают новую вакансию с более свежей датой, вместо того чтобы обновить дату уже размещенной вакансии.<br>
#
# Абсолютные лидеры по размещенным вакансиям г. Москва и г. Санкт-Петербург, что не удивительно. Также в топ-10 входят города миллионники и областные центры, что тоже не удивительно.<br>
#
# В столбце *'experience'* всего 4 категории: Junior (no experince), Junior+ (1-3 years), Middle (3-6 years), Senior (6+ years). По количеству требуемых специалистов наблюдается принципиальная разница. У DA больше всего требуются Junior+ (1-3 years) - 60 % всех вакансий, далее в 2 раза меньше Middle (3-6 years) - 30 %, затем Junior (no experince) - 8 % и Senior (6+ years) - менее 1 %.
# У DS в равной степени требуются Middle (3-6 years) - 47 % и Junior+ (1-3 years) - 43 %,  значительно меньше вакансий Junior (no experince) и Senior (6+ years) - 5 % и 3 %.<br>
#
# Большое количество пропусков было обнаружено в столбце *key_skills* - 273 и 128, которые заменили на 5 самых востребованных навыков в зависимости от опыта. А также проблема со значениями столбца, которые представляют собой списки "обернутые в строку".<br>
#
# В столбце *'schedule'* 4 типа графика работы. Абсолютное большинство работодателей хотели бы задействовать специалистов на полный рабочий день, в несколько раз меньше на удалённой работе и незначительное количество на гибком и сменном графике.<br>
#
# В столбце *'employment'* абсолютное большинство работодателей предлагают полную занятость - около 97 % и на 3 % приходится - стажировка, частичная занятость, проектная работа.<br>
#
# В столбце *'salary_from'* было выявленно 1086 и 678 пропусков, что очень много. В ходе обработки пропусков выделили медианные значения для каждой группы в соответствии с опытом и заменили пропуски этими значениями. Наблюдаются чёткие границы по уровню заработной платы в зависимости от опыта.<br>
# Нижняя граница DA:<br>
# - Junior (no experince) - 60 тыс.
# - Junior+ (1-3 years) - 90 тыс.
# - Middle (3-6 years) - 150 тыс.
# - Senior (6+ years) - 200 тыс.<br>
# Нижняя граница DS:<br>
# - Junior (no experince) - 60 тыс.
# - Junior+ (1-3 years) - 105 тыс.
# - Middle (3-6 years) - 200 тыс.
# - Senior (6+ years) - 160 тыс., связано с тем, что имеется одно единственное значение, которое не соответствует рыночным. Заполнили пропуски - 250 тыс.<br>
#
# В столбце *'salary_to'* наблюдалась такая же картина - большое количество пропусков, которые заменили на медианные значения.<br>
# Наблюдаются также чёткие границы по зарплатам в зависимости от уроня опыта.<br>
# Верхняя граница DA:<br>
# - Junior (no experince) - 80 тыс.
# - Junior+ (1-3 years) - 120 тыс.
# - Middle (3-6 years) - 200 тыс.
# - Senior (6+ years) - 240 тыс.<br>
# Верхняя граница DS:<br>
# - Junior (no experince) - 80 тыс.
# - Junior+ (1-3 years) - 200 тыс., что на 80 больше, чем у DA
# - Middle (3-6 years) - 300 тыс., что на 100 больше
# - Senior (6+ years) - 300 тыс., связано с тем, что имеется всего 3 значения. Заменим на 350 тыс.<br>
#
# Изменили тип данных в столбцах *'salary_from'* и *'salary_to'* на int.

# %% [markdown]
# **Основное исследование.**<br>
# 1. Требуемые навыки.<br>
# 814 уникальных навыка которые упоминались в вакансиях DA. В топ-10 входят:<br>
# - наиболее востребованные: SQL, Python, Анализ данных, Аналитическое мышление, Pandas
# - чуть менее востребованные: Документация, MS Excel, Power BI, Работа с базами данных, Работа с большим объемом информации.<br>
# Мы видим, что для DA наиболее востребованы hard skills - SQL, Python и Pandas, из soft skills наиболее востребованы - Анализ данных и Аналитическое мышление.<br>
#
# 196 уникальных навыка которые упоминались в вакансиях DS. В топ-10 входят:<br>
# - наиболее востребованные: Python, Pandas, SQL, Документация, Machine Learning
# - чуть менее востребованные: ML, Коммуникация, Математическая статистика, Data Science, NLP.<br>
# Мы видим, что для DS ещё более востребованы hard skills - Python, Pandas, SQL и Machine Learning, из soft skills наиболее востребованы - Документация.<br>
#
# Более подробно изучили требуемые навыки к специалистам DA в зависимости от требуемого опыта:
# - из 167 всевозможных навыков в вакансиях Junior (no experince), самые необходимые - Аналитическое мышление, SQL, Анализ данных, Python и MS Excel;
# - из 590 всевозможных навыков в вакансиях Junior+ (1-3 years), самые необходимые - SQL, Python, Анализ данных, Аналитическое мышление и Pandas;
# - из 347 всевозможных навыков в вакансиях Middle (3-6 years), самые необходимые - SQL, Python, Анализ данных, Документация и Pandas;
# - из 47 всевозможных навыков в вакансиях Senior (6+ years), самые необходимые - SQL, Python, Power BI, Проактивность и Pandas.
#
# В вакансиях Junior+ самое большое количество требуемых навыков.<br>
# Junior не обязательно в совершенствве знать SQL и Python в отличии от остальных категорий, для Junior наимболее важными являются soft skills. Для остальных категорий в первую очередь необходимы hard skills. Между Junior+ и Middle разница в требуемых навыках почти одинаковая, с разницей лишь в том, что Middle должен уметь работать с Документацией. Senior, кроме всего, должен уметь работать с визуализацией.
#
# Более подробно изучили требуемые навыки к специалистам DS в зависимости от требуемого опыта:<br>
# - из 55 всевозможных навыков в вакансиях Junior (no experince), самые необходимые - Python, Математическая статистика, Data Mining, Pandas и Git;
# - из 237 всевозможных навыков в вакансиях Junior+ (1-3 years), самые необходимые - Python, Pandas, SQL, Machine Learning и Документация;
# - из 316 всевозможных навыков в вакансиях Middle (3-6 years), самые необходимые - Python, Pandas, SQL, Документация и Machine Learning;
# - из 47 всевозможных навыков в вакансиях Senior (6+ years), самые необходимые - Python, Документация, Pandas, Data Science и Machine Learning. <br>
#
# В вакансиях Middle самое большое количество требуемых навыков.<br>
# Всем категориям в первую очередь необходимо владеть hard skills - Python и Pandas. Junior нужно знать Математическую статистику. Между Junior+ и Middle разница в требуемых навыках отсутствует. Senior кроме всего должен обладать навыками Data Science.<br>
#
# 2. Организации которые размещают вакансии DA и DS в зависимости от требуемого опыта.<br>
# Из 119 размещённых вакансий DA Junior 12 - Сбер, 5 - Магнит, 3 - Юникон. По 2 вакансии в Московской бирже, НАО Ирмаст-холдинг, Согласие, Ozon, ЦБ РФ, Сибур, DNS.<br>
# Из 830 размещённых вакансий DA Junior+ 82 - Сбер, 21 - ВТБ, 14 - МТС, 13 - Магнит, по 11 - ЦБ РФ и Марс. В топ-10 также входят: Ozon, Wildberries, Деловые линии, Okko.<br>
# Из 422 размещённых вакансий DA Middle 38 - Сбер, 16 - Wildberries, 11 - T1, 10 - Ozon. В топ-10 также входят: Maxim Technology, Яндекс, Uzum Technologies, Контур, МТС, Inguru.ru.<br>
# Из 10 размещённых вакансий DA Senior 2 - Леруа Мерлен и по 1 - cloudpayments, reinvent baltics, секонд сайт, aramco innovations, paymatrix, spice agency, мединвестгрупп и b2broker.<br>
#
# Из 39 размещённых вакансий DS Junior 9 - Сбер, 5 - Молвер, 4 - Ozon. Остальные организации разместили по одной вакансии: Lamoda Tech, АДВ, институт психологии РАН и т.д.<br>
# Из 330 размещённых вакансий DS Junior+ 56 - Сбер, 11 - ВТБ, 8 - Газпромбанк. В топ-10 также входят: Ростелеком, Сахалин-остров возможностей, 1221 систем, Билайн, Lamoda Tech, ПКБ, Samokat.tech.<br>
# Из 359 размещённых вакансий DS Middle 54 - Сбер, 18 - Ozon, 16 - Газпромбанк, 12 - Samokat.tech. В топ-10 также входят: Wildberries, T1, Райффайзен банк, Headhunter, Дом.рф, ВТБ.<br>
# Из 28 размещённых вакансий DS Senior по 2 - Sape, Гудфокаст, Aramco innovations, Биайэй-Технолоджиз. В остальных организациях требуется по 1 специалисту: "э"лемент лизинг, Rubbles, Альфа-банк и т. д.<br>
#
# Самые востребованные категории, что у DA, что у DS - Junior+ и Middle, и это не удивительно - специалисты данных категорий являются основными рабочими "руками", а в нашем случае "головами". Абсолютный лидер по всем категориям вакансий и с больши отрывом - это Сбер, за исключением категории Senior. В топ-10 в основном входят крупные банки: Сбер, ВТБ, Газпромбанк, ЦБ РФ, Райффайзен банк; крупные интернет-магазины: Ozon, Wildberries, Lamoda Tech, Samokat.tech; компании предоставляющие услуги связи: МТС, Билайн, Ростелеком; IT-компании: Т1, Яндекс.<br>
#
# 3. Зарплатная вилка.<br>
# Видны чёткие ступени по предлагаемой зарплате в зависимости от опыта. Общая тенденция такова, что для DS зарплатная вилка выше на 10 - 40 % в зависимости от опыта, чем для DA, за исключением категории Junior - здесь паритет. Предлагаемые зарплаты:<br>
# Для DA:<br>
# - Junior - 60-80
# - Junior+ - 90-120
# - Middle - 150-200
# - Senior - 200-240
#
# Для DS:<br>
# - Junior - 60-80
# - Junior+ - 105-200
# - Middle - 200-300
# - Senior - 250-350
#
# 4. Тип занятости.<br>
# Подавляющее большинство вакансий с Полной занятостью. Есть редкие предложения для Проектной работы, Стажировок и Частичной занятости. Для DA Senior кроме Полной занятости, других типов не предлагают. Стажировки предлагают только для Junior и Junior+. Такая же картина наблюдается у DS, за небольшим исключением. Для Junior не предлагают Частичную занятость.<br>
#
# 5. График работы.<br>
# Для DA больше всего вакансий предлагают Полный день - 1097, далее Удаленная работа - 247, несколько десятков Гибкий график - 31 и единицы Сменный график - 6. Для Senior возможны только Полный день или Удаленная работа. А Сменный график предлагают только для Junior и Junior+.<br>
# Для DS больше всего вакансий предлагают Полный день - 548, далее Удаленная работа - 167, несколько десятков Гибкий график - 38 и единицы Сменный график - 3. А вот для DS Senior на выбор любой вариант работы. Как и у всех категорий, за небольшим исключением. Сменный график невозможен только для Junior.<br>
#
# 6. Динамика вакансий по месяцам.<br>
# В феврале самое низкое количество вакансий DA, возможно из-за недостаточности данных, так как данные представлены с 13 февраля. Пиком для всех категорий DA является май. Возможно по той же причине в июне наблюдается просадка - данные представлены по 11 июня. По категориям также наблюдается, что больше всего вакансий размещают для Junior+, далее Middle, Junior и Senior.<br>
# В феврале 1 вакансия DS, так как февраль представлен одним днём. Для Middle и Junior+ с марта по июнь размещали стабильно около 80 вакансий. Чего не скажешь о Junior и Senior, количество размещаемых вакансий которых, также стабильно находились в пределах от 5 до 12.<br>
#
# Таким образом типичные вакансии выглядят следующим образом:<br>
# Вакансия DA: требуется Junior+ или Middle с опытом от 1 года в банковский сектор, интернет магазин с зарплатой 90 - 200 тыс. на полную занятость, на полный рабочий день, который умеет работать с: SQL, Python, Pandas, MS Excel, Power BI. Имеет такие навыки как: Анализ данных, Аналитическое мышление, Документация, Работа с базами данных, Работа с большим объемом информации.<br>
#
# Вакансия DS: требуется Junior+ или Middle с опытом от 1 года в банковский сектор, интернет магазин с зарплатой 105 - 300 тыс. на полную занятость, на полный рабочий день, который умеет работать с: Python, Pandas, SQL, Machine Learning, Data Science, NLP. Имеет такие навыки как: Документация, Коммуникация, Математическая статистика.
